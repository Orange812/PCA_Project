# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, train_test_split
import sklearn

print(f"scikit-learn 版本: {sklearn.__version__}")

# ====================== 计算防守统计数据 ======================
def compute_defensive_stats(match_df, team_positions_df):
    """计算球队的防守统计数据，包括6种比率、总失球数和平均失球数"""
    epsilon = 1e-8  # 提高数值稳定性
    team_stats = {}
    for team in team_positions_df['team_name'].unique():
        team_stats[team] = {
            'total_goals_conceded': 0, 'ratio1_list': [], 'ratio2_list': [], 'ratio3_list': [],
            'ratio4_list': [], 'ratio5_list': [], 'ratio6_list': [], 'num_matches': 0
        }

    # 主场比赛统计
    for idx, row in match_df.iterrows():
        home_team, away_team = row['home_team_name'], row['away_team_name']
        if home_team not in team_stats or away_team not in team_stats:
            print(f"警告: 主队 {home_team} 或客队 {away_team} 未找到，跳过比赛 {idx}")
            continue
        if row['Pre-Match PPG (Away)'] > 0:
            team_stats[home_team]['ratio1_list'].append(
                row['away_team_goal_count'] / (row['Pre-Match PPG (Away)'] + epsilon))
        if row['away_team_corner_count'] > 0:
            team_stats[home_team]['ratio2_list'].append(
                row['away_team_goal_count'] / (row['away_team_corner_count'] + epsilon))
        denominator = row['home_team_yellow_cards'] + row['home_team_red_cards'] + row['home_team_fouls'] + epsilon
        team_stats[home_team]['ratio3_list'].append(row['away_team_goal_count'] / denominator)
        if row['team_b_xg'] > 0:
            team_stats[home_team]['ratio4_list'].append(row['away_team_goal_count'] / (row['team_b_xg'] + epsilon))
        shots_total = row['away_team_shots_on_target'] + row['away_team_shots_off_target'] + epsilon
        team_stats[home_team]['ratio5_list'].append(row['away_team_goal_count'] / shots_total)
        if row['away_team_possession'] > 0:
            team_stats[home_team]['ratio6_list'].append(
                row['away_team_goal_count'] / (row['away_team_possession'] + epsilon))
        team_stats[home_team]['total_goals_conceded'] += row['away_team_goal_count']
        team_stats[home_team]['num_matches'] += 1  # 记录主场比赛场次

    # 客场比赛统计w
    for idx, row in match_df.iterrows():
        away_team = row['away_team_name']
        if away_team not in team_stats:
            print(f"警告: 客队 {away_team} 未找到，跳过比赛 {idx}")
            continue
        team_stats[away_team]['total_goals_conceded'] += row['home_team_goal_count']
        team_stats[away_team]['num_matches'] += 1  # 记录客场比赛场次

    # 汇总数据
    data = []
    for team, stats in team_stats.items():
        num_matches = stats['num_matches']
        average_goals_conceded = stats['total_goals_conceded'] / num_matches if num_matches > 0 else 0
        data.append({
            'team_name': team,
            'ratio1': np.mean(stats['ratio1_list']) if stats['ratio1_list'] else 0,
            'ratio2': np.mean(stats['ratio2_list']) if stats['ratio2_list'] else 0,
            'ratio3': np.mean(stats['ratio3_list']) if stats['ratio3_list'] else 0,
            'ratio4': np.mean(stats['ratio4_list']) if stats['ratio4_list'] else 0,
            'ratio5': np.mean(stats['ratio5_list']) if stats['ratio5_list'] else 0,
            'ratio6': np.mean(stats['ratio6_list']) if stats['ratio6_list'] else 0,
            'total_goals_conceded': stats['total_goals_conceded'],
            'average_goals_conceded': average_goals_conceded
        })

    return pd.DataFrame(data)

# ====================== 计算进攻统计数据 ======================
def compute_offensive_stats(match_df, team_positions_df):
    """计算球队的进攻统计数据，包括6种比率、总进球数和平均进球数"""
    epsilon = 1e-8  # 提高数值稳定性
    team_stats = {}
    for team in team_positions_df['team_name'].unique():
        team_stats[team] = {
            'total_goals_scored': 0, 'off_ratio1_list': [], 'off_ratio2_list': [], 'off_ratio3_list': [],
            'off_ratio4_list': [], 'off_ratio5_list': [], 'off_ratio6_list': [], 'num_matches': 0
        }

    # 主场比赛统计
    for idx, row in match_df.iterrows():
        home_team, away_team = row['home_team_name'], row['away_team_name']
        if home_team not in team_stats or away_team not in team_stats:
            continue
        if row['Pre-Match PPG (Home)'] > 0:
            team_stats[home_team]['off_ratio1_list'].append(
                row['home_team_goal_count'] / (row['Pre-Match PPG (Home)'] + epsilon))
        if row['home_team_corner_count'] > 0:
            team_stats[home_team]['off_ratio2_list'].append(
                row['home_team_goal_count'] / (row['home_team_corner_count'] + epsilon))
        denominator = row['away_team_yellow_cards'] + row['away_team_red_cards'] + row['away_team_fouls'] + epsilon
        team_stats[home_team]['off_ratio3_list'].append(row['home_team_goal_count'] / denominator)
        if row['team_a_xg'] > 0:
            team_stats[home_team]['off_ratio4_list'].append(row['home_team_goal_count'] / (row['team_a_xg'] + epsilon))
        shots_total = row['home_team_shots_on_target'] + row['home_team_shots_off_target'] + epsilon
        team_stats[home_team]['off_ratio5_list'].append(row['home_team_goal_count'] / shots_total)
        if row['home_team_possession'] > 0:
            team_stats[home_team]['off_ratio6_list'].append(
                row['home_team_goal_count'] / (row['home_team_possession'] + epsilon))
        team_stats[home_team]['total_goals_scored'] += row['home_team_goal_count']
        team_stats[home_team]['num_matches'] += 1

    # 客场比赛统计
    for idx, row in match_df.iterrows():
        away_team = row['away_team_name']
        if away_team not in team_stats:
            continue
        team_stats[away_team]['total_goals_scored'] += row['away_team_goal_count']
        team_stats[away_team]['num_matches'] += 1

    # 汇总数据
    data = []
    for team, stats in team_stats.items():
        num_matches = stats['num_matches']
        average_goals_scored = stats['total_goals_scored'] / num_matches if num_matches > 0 else 0
        data.append({
            'team_name': team,
            'off_ratio1': np.mean(stats['off_ratio1_list']) if stats['off_ratio1_list'] else 0,
            'off_ratio2': np.mean(stats['off_ratio2_list']) if stats['off_ratio2_list'] else 0,
            'off_ratio3': np.mean(stats['off_ratio3_list']) if stats['off_ratio3_list'] else 0,
            'off_ratio4': np.mean(stats['off_ratio4_list']) if stats['off_ratio4_list'] else 0,
            'off_ratio5': np.mean(stats['off_ratio5_list']) if stats['off_ratio5_list'] else 0,
            'off_ratio6': np.mean(stats['off_ratio6_list']) if stats['off_ratio6_list'] else 0,
            'total_goals_scored': stats['total_goals_scored'],
            'average_goals_scored': average_goals_scored
        })

    return pd.DataFrame(data)

# ====================== ELO评分算法实现 ======================
def initialize_elo_scores(team_positions_df):
    """初始化球队ELO分数"""
    teams = team_positions_df['team_name'].unique().tolist()
    team_elo = {team: 1500 for team in teams}
    for team in teams:
        team_data = team_positions_df[team_positions_df['team_name'] == team]
        rank = team_data['points_per_game'].rank().iloc[0]
        team_elo[team] += (20 * (len(teams) - rank))
    return team_elo

def update_elo_scores(elo_scores, home_team, away_team, home_score, away_score, K=30):
    """更新ELO分数"""
    home_elo, away_elo = elo_scores[home_team], elo_scores[away_team]
    expected_home = 1 / (1 + 10 ** ((away_elo - home_elo) / 400))
    expected_away = 1 / (1 + 10 ** ((home_elo - away_elo) / 400))

    if home_score > away_score:
        elo_scores[home_team] += K * (1 - expected_home)
        elo_scores[away_team] += K * (0 - expected_away)
    elif home_score < away_score:
        elo_scores[home_team] += K * (0 - expected_home)
        elo_scores[away_team] += K * (1 - expected_away)
    else:
        elo_scores[home_team] += K * (0.5 - expected_home)
        elo_scores[away_team] += K * (0.5 - expected_away)
    return elo_scores

# ====================== 数据加载函数（含交叉验证） ======================
def load_all_league_data(base_path, leagues, seasons):
    """加载所有联赛数据并进行预处理"""
    all_team_positions, all_match_positions = [], []
    for country_name, league_name in leagues:
        for season in seasons:
            print(f"加载数据: {country_name} - {league_name} - {season}")
            team_file = os.path.join(base_path, f"{country_name}-{league_name}-teams-{season}-stats.csv")
            match_file = os.path.join(base_path, f"{country_name}-{league_name}-matches-{season}-stats.csv")
            if not os.path.exists(team_file) or not os.path.exists(match_file):
                print(f"警告: {country_name} - {league_name} - {season} 文件缺失")
                continue

            team_df = pd.read_csv(team_file)
            match_df = pd.read_csv(match_file)

            # 统一球队名称格式
            team_df['team_name'] = team_df.get('common_name', team_df.get('team_name', None)).str.strip().str.lower()
            match_df['home_team_name'] = match_df['home_team_name'].str.strip().str.lower()
            match_df['away_team_name'] = match_df['away_team_name'].str.strip().str.lower()

            team_names = team_df['team_name'].unique()
            original_match_count = len(match_df)
            match_df = match_df[
                match_df['home_team_name'].isin(team_names) & match_df['away_team_name'].isin(team_names)]
            if len(match_df) < original_match_count:
                print(f"警告: 过滤了 {original_match_count - len(match_df)} 场比赛")

            if match_df.empty:
                print("警告: 无有效比赛数据")
                continue

            # 计算防守和进攻统计
            defensive_stats_df = compute_defensive_stats(match_df, team_df)
            offensive_stats_df = compute_offensive_stats(match_df, team_df)
            if defensive_stats_df.empty or offensive_stats_df.empty:
                print("警告: 未计算出防守或进攻统计")
                continue

            team_df = team_df.merge(defensive_stats_df, on='team_name', how='left')
            team_df = team_df.merge(offensive_stats_df, on='team_name', how='left')

            for col in ['ratio1', 'ratio2', 'ratio3', 'ratio4', 'ratio5', 'ratio6', 'total_goals_conceded', 'average_goals_conceded',
                        'off_ratio1', 'off_ratio2', 'off_ratio3', 'off_ratio4', 'off_ratio5', 'off_ratio6', 'total_goals_scored', 'average_goals_scored']:
                if col not in team_df.columns:
                    print(f"警告: {col} 列缺失，设为0")
                    team_df[col] = 0

            # 归一化防守得分
            if 'total_goals_conceded' in team_df.columns and team_df['total_goals_conceded'].max() != team_df['total_goals_conceded'].min():
                team_df['normalized_defense_score'] = (team_df['total_goals_conceded'].max() - team_df['total_goals_conceded']) / (
                    team_df['total_goals_conceded'].max() - team_df['total_goals_conceded'].min() + 1e-8)
            else:
                team_df['normalized_defense_score'] = 0

            # PCA降维（防守和进攻数据）
            defensive_columns = ['total_goals_conceded', 'ratio1', 'ratio2', 'ratio3', 'ratio4', 'ratio5', 'ratio6', 'average_goals_conceded']
            offensive_columns = ['total_goals_scored', 'off_ratio1', 'off_ratio2', 'off_ratio3', 'off_ratio4', 'off_ratio5', 'off_ratio6', 'average_goals_scored']
            team_df_defensive = team_df[defensive_columns].fillna(0)
            kf = KFold(n_splits=5, shuffle=True, random_state=42)
            pca_results = []
            for train_idx, _ in kf.split(team_df_defensive):
                train_data = team_df_defensive.iloc[train_idx]
                scaler = StandardScaler()
                X_scaled = scaler.fit_transform(train_data)
                pca = PCA(n_components=2)
                X_pca = pca.fit_transform(X_scaled)
                pca_results.append(X_pca)
            X_pca_avg = np.mean([np.pad(r, ((0, len(team_df_defensive) - len(r)), (0, 0)), 'constant') for r in pca_results], axis=0)

            team_positions = pd.DataFrame({
                'team_name': team_df['team_name'], 'PC1': X_pca_avg[:, 0], 'PC2': X_pca_avg[:, 1],
                'points_per_game': team_df['points_per_game'], 'league': league_name, 'season': season,
                'ratio1': team_df['ratio1'], 'ratio2': team_df['ratio2'], 'ratio3': team_df['ratio3'],
                'ratio4': team_df['ratio4'], 'ratio5': team_df['ratio5'], 'ratio6': team_df['ratio6'],
                'off_ratio1': team_df['off_ratio1'], 'off_ratio2': team_df['off_ratio2'], 'off_ratio3': team_df['off_ratio3'],
                'off_ratio4': team_df['off_ratio4'], 'off_ratio5': team_df['off_ratio5'], 'off_ratio6': team_df['off_ratio6'],
                'normalized_defense_score': team_df['normalized_defense_score'],
                'total_goals_conceded': team_df['total_goals_conceded'],
                'average_goals_conceded': team_df['average_goals_conceded'],
                'total_goals_scored': team_df['total_goals_scored'],
                'average_goals_scored': team_df['average_goals_scored']
            })
            team_positions['team_season'] = league_name + '_' + team_positions['team_name'] + '_' + team_positions['season']
            all_team_positions.append(team_positions)

            # 比赛数据PCA
            match_df = match_df.drop(columns=['timestamp', 'date_GMT', 'status', 'attendance', 'referee', 'stadium_name', 'Game Week'], errors='ignore')
            numeric_cols = match_df.select_dtypes(include=[np.number]).columns
            match_df[numeric_cols] = match_df[numeric_cols].fillna(match_df[numeric_cols].mean())
            pca_match_results = []
            for train_idx, _ in kf.split(match_df[numeric_cols]):
                train_data = match_df[numeric_cols].iloc[train_idx]
                scaler = StandardScaler()
                X_scaled = scaler.fit_transform(train_data)
                pca = PCA(n_components=2)
                X_pca = pca.fit_transform(X_scaled)
                pca_match_results.append(X_pca)
            X_pca_match_avg = np.mean([np.pad(r, ((0, len(match_df) - len(r)), (0, 0)), 'constant') for r in pca_match_results], axis=0)

            match_positions = pd.DataFrame({
                'home_team_name': match_df['home_team_name'], 'away_team_name': match_df['away_team_name'],
                'PC1': X_pca_match_avg[:, 0], 'PC2': X_pca_match_avg[:, 1], 'league': league_name, 'season': season
            })
            all_match_positions.append(match_positions)

    return pd.concat(all_team_positions, ignore_index=True), pd.concat(all_match_positions, ignore_index=True)

# ====================== 损失函数 ======================
def compute_total_loss(positions, match_home_idx, match_away_idx, match_PC1, match_PC2, points_per_game, rank_scale,
                       def_ratios, w_def, off_ratios, w_off, normalized_defense_score, lambda_defense, lambda_offense,
                       lambda_supervision, lambda_reg, elo_scores):
    """计算总损失，包括匹配损失、防守损失、进攻损失和监督损失"""
    epsilon = 1e-8
    if tf.shape(match_home_idx)[0] == 0:
        return tf.constant(0.0, dtype=tf.float32)

    # 匹配损失
    home_pos = tf.gather(positions, match_home_idx)
    away_pos = tf.gather(positions, match_away_idx)
    match_points = tf.stack([match_PC1, match_PC2], axis=1)
    dist_home = tf.norm(home_pos - match_points + epsilon, axis=1)
    dist_away = tf.norm(away_pos - match_points + epsilon, axis=1)
    all_distances = tf.concat([dist_home, dist_away], axis=0)
    dist_range = tf.reduce_max(all_distances) - tf.reduce_min(all_distances) + epsilon
    dist_home_norm = (dist_home - tf.reduce_min(all_distances)) / dist_range
    dist_away_norm = (dist_away - tf.reduce_min(all_distances)) / dist_range

    home_elo = tf.gather(elo_scores, match_home_idx)
    away_elo = tf.gather(elo_scores, match_away_idx)
    elo_diff = tf.abs(home_elo - away_elo)
    weight = 1.0 / (1.0 + elo_diff * rank_scale + epsilon)
    match_loss = tf.reduce_mean(weight * (dist_home_norm + dist_away_norm))

    # 防守损失
    w_def = tf.abs(w_def)
    defense_target = -tf.reduce_sum(w_def * def_ratios, axis=1)
    defense_loss = tf.reduce_mean(tf.square(positions[:, 1] - defense_target))

    # 进攻损失
    w_off = tf.abs(w_off)
    offense_target = tf.reduce_sum(w_off * off_ratios, axis=1)
    offense_loss = tf.reduce_mean(tf.square(positions[:, 0] - offense_target))

    # 监督损失
    supervision_loss = tf.reduce_mean(tf.square(defense_target - normalized_defense_score))

    # 正则化
    regularization_loss = lambda_reg * (tf.reduce_sum(tf.square(w_def)) + tf.reduce_sum(tf.square(w_off)))

    total_loss = (match_loss + lambda_defense * defense_loss + lambda_offense * offense_loss +
                  lambda_supervision * supervision_loss + regularization_loss)
    return tf.where(tf.math.is_nan(total_loss) | tf.math.is_inf(total_loss), 0.0, total_loss)

# ====================== Adam优化函数 ======================
def adam_optimize_positions(team_positions_df, match_positions_df, initial_lr=0.005, decay_steps=20000, decay_rate=0.9,
                            clipnorm=0.5, iterations=30000, verbose_interval=1000, random_seed=42, lambda_defense=0.1,
                            lambda_offense=0.1, lambda_supervision=0.1, lambda_reg=0.01, w_def=None, w_off=None):
    """使用Adam优化球队位置，移除早停机制以完整训练"""
    team_seasons = team_positions_df['team_season'].unique()
    team_season_to_idx = {t: i for i, t in enumerate(team_seasons)}

    elo_scores_dict = initialize_elo_scores(team_positions_df)
    team_names = [t.split('_')[1] for t in team_seasons]
    elo_scores = tf.convert_to_tensor([elo_scores_dict[name] for name in team_names], dtype=tf.float32)

    team_positions_df = team_positions_df.set_index('team_season')
    init_positions = team_positions_df[['PC1', 'PC2']].values
    def_ratios = team_positions_df[['ratio1', 'ratio2', 'ratio3', 'ratio4', 'ratio5', 'ratio6', 'total_goals_conceded', 'average_goals_conceded']].values
    off_ratios = team_positions_df[['off_ratio1', 'off_ratio2', 'off_ratio3', 'off_ratio4', 'off_ratio5', 'off_ratio6', 'total_goals_scored', 'average_goals_scored']].values

    scaler_pos = StandardScaler()
    scaler_def = StandardScaler()
    scaler_off = StandardScaler()
    positions_scaled = scaler_pos.fit_transform(init_positions)
    def_ratios_scaled = scaler_def.fit_transform(def_ratios)
    off_ratios_scaled = scaler_off.fit_transform(off_ratios)

    positions = tf.Variable(positions_scaled, dtype=tf.float32)
    def_ratios = tf.constant(def_ratios_scaled, dtype=tf.float32)
    off_ratios = tf.constant(off_ratios_scaled, dtype=tf.float32)
    normalized_defense_score = tf.constant(team_positions_df['normalized_defense_score'].values, dtype=tf.float32)
    points_per_game = tf.constant(team_positions_df['points_per_game'].values, dtype=tf.float32)

    match_array = [
        [team_season_to_idx[f"{row['league']}_{row['home_team_name']}_{row['season']}"],
         team_season_to_idx[f"{row['league']}_{row['away_team_name']}_{row['season']}"], row['PC1'], row['PC2']]
        for _, row in match_positions_df.iterrows()
        if f"{row['league']}_{row['home_team_name']}_{row['season']}" in team_season_to_idx and
           f"{row['league']}_{row['away_team_name']}_{row['season']}" in team_season_to_idx
    ]
    match_array = np.array(match_array, dtype=np.float32)
    if len(match_array) == 0:
        print("警告: 无有效比赛数据")
        return [], team_positions_df.reset_index(), None, None, None

    match_home_idx = tf.constant(match_array[:, 0], dtype=tf.int32)
    match_away_idx = tf.constant(match_array[:, 1], dtype=tf.int32)
    match_PC1 = tf.constant(match_array[:, 2], dtype=tf.float32)
    match_PC2 = tf.constant(match_array[:, 3], dtype=tf.float32)

    tf.random.set_seed(random_seed)
    rank_scale = tf.Variable(1.0, dtype=tf.float32)
    w_def = tf.Variable(np.abs(w_def) if w_def is not None else np.ones(8, dtype=np.float32) / 8, dtype=tf.float32)
    w_off = tf.Variable(np.abs(w_off) if w_off is not None else np.ones(8, dtype=np.float32) / 8, dtype=tf.float32)
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(initial_lr, decay_steps, decay_rate)
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule, clipnorm=clipnorm)

    losses, best_loss = [], float('inf')
    best_positions, best_rank_scale, best_w_def, best_w_off = positions.numpy().copy(), 1.0, w_def.numpy().copy(), w_off.numpy().copy()

    for i in range(iterations):
        with tf.GradientTape() as tape:
            loss = compute_total_loss(positions, match_home_idx, match_away_idx, match_PC1, match_PC2, points_per_game,
                                      rank_scale, def_ratios, w_def, off_ratios, w_off, normalized_defense_score,
                                      lambda_defense, lambda_offense, lambda_supervision, lambda_reg, elo_scores)
        grads = tape.gradient(loss, [positions, rank_scale, w_def, w_off])
        if any(g is None for g in grads):
            print(f"警告: 迭代 {i + 1} 梯度为None")
            continue
        optimizer.apply_gradients(zip(grads, [positions, rank_scale, w_def, w_off]))
        loss_val = float(loss.numpy())
        losses.append(loss_val)

        # 记录最佳模型但不中断训练
        if loss_val < best_loss:
            best_loss = loss_val
            best_positions, best_rank_scale, best_w_def, best_w_off = (positions.numpy().copy(), float(rank_scale.numpy()),
                                                                       w_def.numpy().copy(), w_off.numpy().copy())

        if (i + 1) % verbose_interval == 0:
            print(f"迭代 {i + 1}/{iterations}, 损失 = {loss_val:.4f}, rank_scale = {rank_scale.numpy():.4f}, 最佳损失 = {best_loss:.4f}")

    # 使用最佳模型更新最终结果
    positions.assign(best_positions)
    rank_scale.assign(best_rank_scale)
    w_def.assign(best_w_def)
    w_off.assign(best_w_off)
    final_pos = scaler_pos.inverse_transform(positions.numpy())
    for idx, team_season in enumerate(team_seasons):
        team_positions_df.loc[team_season, 'PC1'] = final_pos[idx, 0]
        team_positions_df.loc[team_season, 'PC2'] = final_pos[idx, 1]
    team_positions_df = team_positions_df.reset_index()
    return losses, team_positions_df, best_rank_scale, best_w_def, best_w_off

# ====================== 随机搜索超参数调整 ======================
def random_search_hyperparameters(team_positions, match_positions, w_def, w_off, n_iter=10, random_state=42):
    """随机搜索最佳超参数"""
    np.random.seed(random_state)
    best_loss, best_params = float('inf'), None

    for _ in range(n_iter):
        params = {
            'lambda_defense': np.random.uniform(0.01, 0.2),
            'lambda_offense': np.random.uniform(0.01, 0.2),
            'lambda_supervision': np.random.uniform(0.01, 0.2),
            'lambda_reg': np.random.uniform(0.001, 0.02)
        }
        print(f"\n随机搜索: {params}")

        losses, _, _, _, _ = adam_optimize_positions(
            team_positions.copy(), match_positions.copy(), w_def=w_def, w_off=w_off, **params
        )
        if losses and losses[-1] < best_loss:
            best_loss = losses[-1]
            best_params = params

    print(f"\n最佳超参数: {best_params}, 最佳损失: {best_loss:.4f}")
    return best_params

# ====================== 可视化函数 ======================
def visualize_team_evolution_by_league_static(team_positions_df, seasons_order):
    """按联赛可视化球队演变"""
    output_dir = "/Users/peixuanma/Downloads/Output_Graphs"
    os.makedirs(output_dir, exist_ok=True)

    for league in team_positions_df['league'].unique():
        league_df = team_positions_df[team_positions_df['league'] == league].copy()
        valid_teams = league_df.groupby("team_name").filter(lambda x: x['season'].nunique() == len(seasons_order))['team_name'].unique()
        if not valid_teams.size:
            valid_teams = league_df['team_name'].unique()
        valid_df = league_df[league_df['team_name'].isin(valid_teams)].sort_values(['team_name', 'season'])

        plt.figure(figsize=(10, 8))
        plt.title(f"{league} - 球队演变 (进攻-防守)")
        plt.xlabel("PC1 (进攻)")
        plt.ylabel("PC2 (防守)")
        plt.grid(True)

        for team in valid_df['team_name'].unique():
            sub = valid_df[valid_df['team_name'] == team]
            plt.plot(sub['PC1'], sub['PC2'], marker='o', label=team)
            for _, row in sub.iterrows():
                plt.text(row['PC1'], row['PC2'], row['season'], fontsize=8, ha='right')

        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        plt.tight_layout()
        filename = os.path.join(output_dir, f"{league}_evolution.png")
        plt.savefig(filename, dpi=150)
        plt.close()
        print(f"保存 {league} 图 -> {filename}")

# ====================== 主函数 ======================
if __name__ == "__main__":
    base_path = '/Users/peixuanma/Downloads/data1'
    leagues = [
        ("england", "premier-league"), ("germany", "bundesliga"), ("spain", "la-liga"),
        ("france", "ligue-1"), ("france", "ligue-2"), ("italy", "serie-a"), ("netherlands", "eredivisie"),
        ("portugal", "ligapro"), ("denmark", "superliga"), ("england", "championship"), ("spain", "segunda-division"),
        ("switzerland", "super-league"), ("portugal", "liga-nos"), ("italy", "serie-b"), ("germany", "2-bundesliga"),
        ("scotland", "premiership"), ("belgium", "pro-league"), ("austria", "bundesliga"),
    ]
    seasons = [
        "2013-to-2014", "2014-to-2015", "2015-to-2016", "2016-to-2017", "2017-to-2018",
        "2018-to-2019", "2019-to-2020", "2020-to-2021", "2021-to-2022", "2022-to-2023", "2023-to-2024"
    ]

    # 手动输入防守和进攻权重（示例值）
    w_def = np.array([
        0.12714323,  # ratio1
        0.11415731,  # ratio2
        0.04532705,  # ratio3
        0.23075414,  # ratio4
        0.03240472,  # ratio5
        0.14205644,  # ratio6
        0.13323908,  # total_goals_conceded
        0.17491804   # average_goals_conceded
    ], dtype=np.float32)

    w_off = np.array([
        0.07438711,
        0.07787083,
        0.08495551,
        0.22353454,
        0.08152269,
        0.08466186,
        0.16022788,
        0.21283953 # average_goals_scored
    ], dtype=np.float32)

    # 加载数据
    print("===== 加载数据 =====")
    all_team_positions, all_match_positions = load_all_league_data(base_path, leagues, seasons)

    # 随机搜索超参数
    print("\n===== 随机搜索超参数 =====")
    best_params = random_search_hyperparameters(all_team_positions, all_match_positions, w_def, w_off)

    # 最终训练
    print("\n===== 最终训练 =====")
    final_losses, final_team_positions, final_rank_scale, final_w_def, final_w_off = adam_optimize_positions(
        all_team_positions.copy(), all_match_positions.copy(), w_def=w_def, w_off=w_off, **best_params
    )
    if final_losses:
        final_team_positions.to_csv("trained_team_positions.csv", index=False)
        print(f"最终损失: {final_losses[-1]:.4f}")
        print(f"最终防守权重: {final_w_def}")
        print(f"最终进攻权重: {final_w_off}")

    # 可视化
    print("\n===== 可视化 =====")
    visualize_team_evolution_by_league_static(final_team_positions, seasons)

    print("\n完成！")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# scikit-learn 版本: 1.4.2
# ===== 加载数据 =====
# 加载数据: england - premier-league - 2013-to-2014
# 加载数据: england - premier-league - 2014-to-2015
# 加载数据: england - premier-league - 2015-to-2016
# 加载数据: england - premier-league - 2016-to-2017
# 加载数据: england - premier-league - 2017-to-2018
# 加载数据: england - premier-league - 2018-to-2019
# 加载数据: england - premier-league - 2019-to-2020
# 加载数据: england - premier-league - 2020-to-2021
# 加载数据: england - premier-league - 2021-to-2022
# 加载数据: england - premier-league - 2022-to-2023
# 加载数据: england - premier-league - 2023-to-2024
# 加载数据: germany - bundesliga - 2013-to-2014
# 加载数据: germany - bundesliga - 2014-to-2015
# 加载数据: germany - bundesliga - 2015-to-2016
# 加载数据: germany - bundesliga - 2016-to-2017
# 加载数据: germany - bundesliga - 2017-to-2018
# 加载数据: germany - bundesliga - 2018-to-2019
# 加载数据: germany - bundesliga - 2019-to-2020
# 加载数据: germany - bundesliga - 2020-to-2021
# 加载数据: germany - bundesliga - 2021-to-2022
# 加载数据: germany - bundesliga - 2022-to-2023
# 加载数据: germany - bundesliga - 2023-to-2024
# 加载数据: spain - la-liga - 2013-to-2014
# 加载数据: spain - la-liga - 2014-to-2015
# 加载数据: spain - la-liga - 2015-to-2016
# 加载数据: spain - la-liga - 2016-to-2017
# 加载数据: spain - la-liga - 2017-to-2018
# 加载数据: spain - la-liga - 2018-to-2019
# 加载数据: spain - la-liga - 2019-to-2020
# 加载数据: spain - la-liga - 2020-to-2021
# 加载数据: spain - la-liga - 2021-to-2022
# 加载数据: spain - la-liga - 2022-to-2023
# 加载数据: spain - la-liga - 2023-to-2024
# 加载数据: france - ligue-1 - 2013-to-2014
# 加载数据: france - ligue-1 - 2014-to-2015
# 加载数据: france - ligue-1 - 2015-to-2016
# 加载数据: france - ligue-1 - 2016-to-2017
# 加载数据: france - ligue-1 - 2017-to-2018
# 加载数据: france - ligue-1 - 2018-to-2019
# 加载数据: france - ligue-1 - 2019-to-2020
# 警告: france - ligue-1 - 2019-to-2020 文件缺失
# 加载数据: france - ligue-1 - 2020-to-2021
# 加载数据: france - ligue-1 - 2021-to-2022
# 加载数据: france - ligue-1 - 2022-to-2023
# 加载数据: france - ligue-1 - 2023-to-2024
# 加载数据: france - ligue-2 - 2013-to-2014
# 加载数据: france - ligue-2 - 2014-to-2015
# 加载数据: france - ligue-2 - 2015-to-2016
# 加载数据: france - ligue-2 - 2016-to-2017
# 加载数据: france - ligue-2 - 2017-to-2018
# 加载数据: france - ligue-2 - 2018-to-2019
# 加载数据: france - ligue-2 - 2019-to-2020
# 警告: france - ligue-2 - 2019-to-2020 文件缺失
# 加载数据: france - ligue-2 - 2020-to-2021
# 加载数据: france - ligue-2 - 2021-to-2022
# 加载数据: france - ligue-2 - 2022-to-2023
# 加载数据: france - ligue-2 - 2023-to-2024
# 加载数据: italy - serie-a - 2013-to-2014
# 加载数据: italy - serie-a - 2014-to-2015
# 加载数据: italy - serie-a - 2015-to-2016
# 加载数据: italy - serie-a - 2016-to-2017
# 加载数据: italy - serie-a - 2017-to-2018
# 加载数据: italy - serie-a - 2018-to-2019
# 加载数据: italy - serie-a - 2019-to-2020
# 加载数据: italy - serie-a - 2020-to-2021
# 加载数据: italy - serie-a - 2021-to-2022
# 加载数据: italy - serie-a - 2022-to-2023
# 加载数据: italy - serie-a - 2023-to-2024
# 加载数据: netherlands - eredivisie - 2013-to-2014
# 加载数据: netherlands - eredivisie - 2014-to-2015
# 加载数据: netherlands - eredivisie - 2015-to-2016
# 加载数据: netherlands - eredivisie - 2016-to-2017
# 加载数据: netherlands - eredivisie - 2017-to-2018
# 加载数据: netherlands - eredivisie - 2018-to-2019
# 加载数据: netherlands - eredivisie - 2019-to-2020
# 加载数据: netherlands - eredivisie - 2020-to-2021
# 加载数据: netherlands - eredivisie - 2021-to-2022
# 加载数据: netherlands - eredivisie - 2022-to-2023
# 加载数据: netherlands - eredivisie - 2023-to-2024
# 加载数据: portugal - ligapro - 2013-to-2014
# 警告: portugal - ligapro - 2013-to-2014 文件缺失
# 加载数据: portugal - ligapro - 2014-to-2015
# 加载数据: portugal - ligapro - 2015-to-2016
# 加载数据: portugal - ligapro - 2016-to-2017
# 加载数据: portugal - ligapro - 2017-to-2018
# 加载数据: portugal - ligapro - 2018-to-2019
# 加载数据: portugal - ligapro - 2019-to-2020
# 加载数据: portugal - ligapro - 2020-to-2021
# 加载数据: portugal - ligapro - 2021-to-2022
# 加载数据: portugal - ligapro - 2022-to-2023
# 加载数据: portugal - ligapro - 2023-to-2024
# 加载数据: denmark - superliga - 2013-to-2014
# 加载数据: denmark - superliga - 2014-to-2015
# 加载数据: denmark - superliga - 2015-to-2016
# 加载数据: denmark - superliga - 2016-to-2017
# 加载数据: denmark - superliga - 2017-to-2018
# 加载数据: denmark - superliga - 2018-to-2019
# 加载数据: denmark - superliga - 2019-to-2020
# 加载数据: denmark - superliga - 2020-to-2021
# 加载数据: denmark - superliga - 2021-to-2022
# 加载数据: denmark - superliga - 2022-to-2023
# 加载数据: denmark - superliga - 2023-to-2024
# 加载数据: england - championship - 2013-to-2014
# 加载数据: england - championship - 2014-to-2015
# 加载数据: england - championship - 2015-to-2016
# 加载数据: england - championship - 2016-to-2017
# 加载数据: england - championship - 2017-to-2018
# 加载数据: england - championship - 2018-to-2019
# 加载数据: england - championship - 2019-to-2020
# 加载数据: england - championship - 2020-to-2021
# 加载数据: england - championship - 2021-to-2022
# 加载数据: england - championship - 2022-to-2023
# 加载数据: england - championship - 2023-to-2024
# 加载数据: spain - segunda-division - 2013-to-2014
# 加载数据: spain - segunda-division - 2014-to-2015
# 加载数据: spain - segunda-division - 2015-to-2016
# 加载数据: spain - segunda-division - 2016-to-2017
# 加载数据: spain - segunda-division - 2017-to-2018
# 加载数据: spain - segunda-division - 2018-to-2019
# 加载数据: spain - segunda-division - 2019-to-2020
# 加载数据: spain - segunda-division - 2020-to-2021
# 加载数据: spain - segunda-division - 2021-to-2022
# 加载数据: spain - segunda-division - 2022-to-2023
# 加载数据: spain - segunda-division - 2023-to-2024
# 加载数据: switzerland - super-league - 2013-to-2014
# 加载数据: switzerland - super-league - 2014-to-2015
# 加载数据: switzerland - super-league - 2015-to-2016
# 加载数据: switzerland - super-league - 2016-to-2017
# 加载数据: switzerland - super-league - 2017-to-2018
# 加载数据: switzerland - super-league - 2018-to-2019
# 加载数据: switzerland - super-league - 2019-to-2020
# 加载数据: switzerland - super-league - 2020-to-2021
# 加载数据: switzerland - super-league - 2021-to-2022
# 加载数据: switzerland - super-league - 2022-to-2023
# 加载数据: switzerland - super-league - 2023-to-2024
# 加载数据: portugal - liga-nos - 2013-to-2014
# 加载数据: portugal - liga-nos - 2014-to-2015
# 加载数据: portugal - liga-nos - 2015-to-2016
# 加载数据: portugal - liga-nos - 2016-to-2017
# 加载数据: portugal - liga-nos - 2017-to-2018
# 加载数据: portugal - liga-nos - 2018-to-2019
# 加载数据: portugal - liga-nos - 2019-to-2020
# 加载数据: portugal - liga-nos - 2020-to-2021
# 加载数据: portugal - liga-nos - 2021-to-2022
# 加载数据: portugal - liga-nos - 2022-to-2023
# 加载数据: portugal - liga-nos - 2023-to-2024
# 加载数据: italy - serie-b - 2013-to-2014
# 加载数据: italy - serie-b - 2014-to-2015
# 加载数据: italy - serie-b - 2015-to-2016
# 加载数据: italy - serie-b - 2016-to-2017
# 加载数据: italy - serie-b - 2017-to-2018
# 加载数据: italy - serie-b - 2018-to-2019
# 加载数据: italy - serie-b - 2019-to-2020
# 加载数据: italy - serie-b - 2020-to-2021
# 加载数据: italy - serie-b - 2021-to-2022
# 加载数据: italy - serie-b - 2022-to-2023
# 加载数据: italy - serie-b - 2023-to-2024
# 加载数据: germany - 2-bundesliga - 2013-to-2014
# 加载数据: germany - 2-bundesliga - 2014-to-2015
# 加载数据: germany - 2-bundesliga - 2015-to-2016
# 加载数据: germany - 2-bundesliga - 2016-to-2017
# 加载数据: germany - 2-bundesliga - 2017-to-2018
# 加载数据: germany - 2-bundesliga - 2018-to-2019
# 加载数据: germany - 2-bundesliga - 2019-to-2020
# 加载数据: germany - 2-bundesliga - 2020-to-2021
# 加载数据: germany - 2-bundesliga - 2021-to-2022
# 加载数据: germany - 2-bundesliga - 2022-to-2023
# 加载数据: germany - 2-bundesliga - 2023-to-2024
# 加载数据: scotland - premiership - 2013-to-2014
# 加载数据: scotland - premiership - 2014-to-2015
# 加载数据: scotland - premiership - 2015-to-2016
# 加载数据: scotland - premiership - 2016-to-2017
# 加载数据: scotland - premiership - 2017-to-2018
# 加载数据: scotland - premiership - 2018-to-2019
# 加载数据: scotland - premiership - 2019-to-2020
# 加载数据: scotland - premiership - 2020-to-2021
# 加载数据: scotland - premiership - 2021-to-2022
# 加载数据: scotland - premiership - 2022-to-2023
# 加载数据: scotland - premiership - 2023-to-2024
# 加载数据: belgium - pro-league - 2013-to-2014
# 警告: belgium - pro-league - 2013-to-2014 文件缺失
# 加载数据: belgium - pro-league - 2014-to-2015
# 警告: belgium - pro-league - 2014-to-2015 文件缺失
# 加载数据: belgium - pro-league - 2015-to-2016
# 加载数据: belgium - pro-league - 2016-to-2017
# 加载数据: belgium - pro-league - 2017-to-2018
# 加载数据: belgium - pro-league - 2018-to-2019
# 加载数据: belgium - pro-league - 2019-to-2020
# 加载数据: belgium - pro-league - 2020-to-2021
# 加载数据: belgium - pro-league - 2021-to-2022
# 加载数据: belgium - pro-league - 2022-to-2023
# 加载数据: belgium - pro-league - 2023-to-2024
# 加载数据: austria - bundesliga - 2013-to-2014
# 加载数据: austria - bundesliga - 2014-to-2015
# 加载数据: austria - bundesliga - 2015-to-2016
# 加载数据: austria - bundesliga - 2016-to-2017
# 加载数据: austria - bundesliga - 2017-to-2018
# 加载数据: austria - bundesliga - 2018-to-2019
# 加载数据: austria - bundesliga - 2019-to-2020
# 加载数据: austria - bundesliga - 2020-to-2021
# 加载数据: austria - bundesliga - 2021-to-2022
# 加载数据: austria - bundesliga - 2022-to-2023
# 加载数据: austria - bundesliga - 2023-to-2024
#
# ===== 随机搜索超参数 =====
#
# 随机搜索: {'lambda_defense': 0.08116262258099888, 'lambda_offense': 0.19063571821788408, 'lambda_supervision': 0.14907884894416698, 'lambda_reg': 0.012374511199743695}
# 迭代 1000/30000, 损失 = 0.0617, rank_scale = 3.1793, 最佳损失 = 0.0617
# 迭代 2000/30000, 损失 = 0.0595, rank_scale = 4.4856, 最佳损失 = 0.0595
# 迭代 3000/30000, 损失 = 0.0591, rank_scale = 5.7309, 最佳损失 = 0.0591
# 迭代 4000/30000, 损失 = 0.0589, rank_scale = 7.0322, 最佳损失 = 0.0589
# 迭代 5000/30000, 损失 = 0.0588, rank_scale = 8.4447, 最佳损失 = 0.0588
# 迭代 6000/30000, 损失 = 0.0587, rank_scale = 10.0079, 最佳损失 = 0.0587
# 迭代 7000/30000, 损失 = 0.0586, rank_scale = 11.7520, 最佳损失 = 0.0586
# 迭代 8000/30000, 损失 = 0.0586, rank_scale = 13.6980, 最佳损失 = 0.0586
# 迭代 9000/30000, 损失 = 0.0585, rank_scale = 15.8573, 最佳损失 = 0.0585
# 迭代 10000/30000, 损失 = 0.0585, rank_scale = 18.2326, 最佳损失 = 0.0585
# 迭代 11000/30000, 损失 = 0.0584, rank_scale = 20.8161, 最佳损失 = 0.0584
# 迭代 12000/30000, 损失 = 0.0584, rank_scale = 23.5935, 最佳损失 = 0.0584
# 迭代 13000/30000, 损失 = 0.0584, rank_scale = 26.5430, 最佳损失 = 0.0584
# 迭代 14000/30000, 损失 = 0.0584, rank_scale = 29.6413, 最佳损失 = 0.0584
# 迭代 15000/30000, 损失 = 0.0584, rank_scale = 32.8611, 最佳损失 = 0.0584
# 迭代 16000/30000, 损失 = 0.0583, rank_scale = 36.1800, 最佳损失 = 0.0583
# 迭代 17000/30000, 损失 = 0.0583, rank_scale = 39.5751, 最佳损失 = 0.0583
# 迭代 18000/30000, 损失 = 0.0583, rank_scale = 43.0268, 最佳损失 = 0.0583
# 迭代 19000/30000, 损失 = 0.0583, rank_scale = 46.5188, 最佳损失 = 0.0583
# 迭代 20000/30000, 损失 = 0.0583, rank_scale = 50.0364, 最佳损失 = 0.0583
# 迭代 21000/30000, 损失 = 0.0583, rank_scale = 53.5669, 最佳损失 = 0.0583
# 迭代 22000/30000, 损失 = 0.0583, rank_scale = 57.0997, 最佳损失 = 0.0583
# 迭代 23000/30000, 损失 = 0.0583, rank_scale = 60.6273, 最佳损失 = 0.0583
# 迭代 24000/30000, 损失 = 0.0583, rank_scale = 64.1405, 最佳损失 = 0.0583
# 迭代 25000/30000, 损失 = 0.0583, rank_scale = 67.6341, 最佳损失 = 0.0583
# 迭代 26000/30000, 损失 = 0.0583, rank_scale = 71.1028, 最佳损失 = 0.0583
# 迭代 27000/30000, 损失 = 0.0583, rank_scale = 74.5412, 最佳损失 = 0.0583
# 迭代 28000/30000, 损失 = 0.0583, rank_scale = 77.9452, 最佳损失 = 0.0583
# 迭代 29000/30000, 损失 = 0.0583, rank_scale = 81.3130, 最佳损失 = 0.0582
# 迭代 30000/30000, 损失 = 0.0583, rank_scale = 84.6413, 最佳损失 = 0.0582
#
# 随机搜索: {'lambda_defense': 0.039643541684062936, 'lambda_offense': 0.039638958863878505, 'lambda_supervision': 0.021035886311957897, 'lambda_reg': 0.01745734676972377}
# 迭代 1000/30000, 损失 = 0.0235, rank_scale = 3.1538, 最佳损失 = 0.0235
# 迭代 2000/30000, 损失 = 0.0211, rank_scale = 4.3677, 最佳损失 = 0.0211
# 迭代 3000/30000, 损失 = 0.0204, rank_scale = 5.4626, 最佳损失 = 0.0204
# 迭代 4000/30000, 损失 = 0.0201, rank_scale = 6.5908, 最佳损失 = 0.0201
# 迭代 5000/30000, 损失 = 0.0198, rank_scale = 7.8253, 最佳损失 = 0.0198
# 迭代 6000/30000, 损失 = 0.0197, rank_scale = 9.2072, 最佳损失 = 0.0197
# 迭代 7000/30000, 损失 = 0.0197, rank_scale = 10.7699, 最佳损失 = 0.0197
# 迭代 8000/30000, 损失 = 0.0196, rank_scale = 12.5408, 最佳损失 = 0.0196
# 迭代 9000/30000, 损失 = 0.0196, rank_scale = 14.5339, 最佳损失 = 0.0196
# 迭代 10000/30000, 损失 = 0.0195, rank_scale = 16.7528, 最佳损失 = 0.0195
# 迭代 11000/30000, 损失 = 0.0195, rank_scale = 19.1909, 最佳损失 = 0.0195
# 迭代 12000/30000, 损失 = 0.0195, rank_scale = 21.8343, 最佳损失 = 0.0195
# 迭代 13000/30000, 损失 = 0.0195, rank_scale = 24.6640, 最佳损失 = 0.0195
# 迭代 14000/30000, 损失 = 0.0195, rank_scale = 27.6537, 最佳损失 = 0.0195
# 迭代 15000/30000, 损失 = 0.0194, rank_scale = 30.7772, 最佳损失 = 0.0194
# 迭代 16000/30000, 损失 = 0.0194, rank_scale = 34.0085, 最佳损失 = 0.0194
# 迭代 17000/30000, 损失 = 0.0194, rank_scale = 37.3222, 最佳损失 = 0.0194
# 迭代 18000/30000, 损失 = 0.0194, rank_scale = 40.6962, 最佳损失 = 0.0194
# 迭代 19000/30000, 损失 = 0.0194, rank_scale = 44.1129, 最佳损失 = 0.0194
# 迭代 20000/30000, 损失 = 0.0194, rank_scale = 47.5542, 最佳损失 = 0.0194
# 迭代 21000/30000, 损失 = 0.0194, rank_scale = 51.0059, 最佳损失 = 0.0194
# 迭代 22000/30000, 损失 = 0.0194, rank_scale = 54.4571, 最佳损失 = 0.0194
# 迭代 23000/30000, 损失 = 0.0194, rank_scale = 57.8971, 最佳损失 = 0.0194
# 迭代 24000/30000, 损失 = 0.0194, rank_scale = 61.3186, 最佳损失 = 0.0194
# 迭代 25000/30000, 损失 = 0.0194, rank_scale = 64.7126, 最佳损失 = 0.0194
# 迭代 26000/30000, 损失 = 0.0194, rank_scale = 68.0745, 最佳损失 = 0.0194
# 迭代 27000/30000, 损失 = 0.0194, rank_scale = 71.3989, 最佳损失 = 0.0194
# 迭代 28000/30000, 损失 = 0.0194, rank_scale = 74.6840, 最佳损失 = 0.0194
# 迭代 29000/30000, 损失 = 0.0194, rank_scale = 77.9240, 最佳损失 = 0.0194
# 迭代 30000/30000, 损失 = 0.0194, rank_scale = 81.1179, 最佳损失 = 0.0194
#
# 随机搜索: {'lambda_defense': 0.12421185223120967, 'lambda_offense': 0.14453378978124864, 'lambda_supervision': 0.013911053916202466, 'lambda_reg': 0.019428287191077892}
# 迭代 1000/30000, 损失 = 0.0255, rank_scale = 3.1811, 最佳损失 = 0.0255
# 迭代 2000/30000, 损失 = 0.0229, rank_scale = 4.5006, 最佳损失 = 0.0229
# 迭代 3000/30000, 损失 = 0.0225, rank_scale = 5.7422, 最佳损失 = 0.0225
# 迭代 4000/30000, 损失 = 0.0224, rank_scale = 7.0343, 最佳损失 = 0.0224
# 迭代 5000/30000, 损失 = 0.0222, rank_scale = 8.4405, 最佳损失 = 0.0222
# 迭代 6000/30000, 损失 = 0.0222, rank_scale = 9.9995, 最佳损失 = 0.0222
# 迭代 7000/30000, 损失 = 0.0221, rank_scale = 11.7399, 最佳损失 = 0.0221
# 迭代 8000/30000, 损失 = 0.0220, rank_scale = 13.6825, 最佳损失 = 0.0220
# 迭代 9000/30000, 损失 = 0.0220, rank_scale = 15.8387, 最佳损失 = 0.0220
# 迭代 10000/30000, 损失 = 0.0220, rank_scale = 18.2111, 最佳损失 = 0.0220
# 迭代 11000/30000, 损失 = 0.0219, rank_scale = 20.7922, 最佳损失 = 0.0219
# 迭代 12000/30000, 损失 = 0.0219, rank_scale = 23.5674, 最佳损失 = 0.0219
# 迭代 13000/30000, 损失 = 0.0219, rank_scale = 26.5154, 最佳损失 = 0.0219
# 迭代 14000/30000, 损失 = 0.0219, rank_scale = 29.6113, 最佳损失 = 0.0219
# 迭代 15000/30000, 损失 = 0.0218, rank_scale = 32.8302, 最佳损失 = 0.0218
# 迭代 16000/30000, 损失 = 0.0218, rank_scale = 36.1471, 最佳损失 = 0.0218
# 迭代 17000/30000, 损失 = 0.0218, rank_scale = 39.5411, 最佳损失 = 0.0218
# 迭代 18000/30000, 损失 = 0.0218, rank_scale = 42.9919, 最佳损失 = 0.0218
# 迭代 19000/30000, 损失 = 0.0218, rank_scale = 46.4823, 最佳损失 = 0.0218
# 迭代 20000/30000, 损失 = 0.0218, rank_scale = 49.9982, 最佳损失 = 0.0218
# 迭代 21000/30000, 损失 = 0.0218, rank_scale = 53.5280, 最佳损失 = 0.0218
# 迭代 22000/30000, 损失 = 0.0218, rank_scale = 57.0604, 最佳损失 = 0.0218
# 迭代 23000/30000, 损失 = 0.0218, rank_scale = 60.5859, 最佳损失 = 0.0218
# 迭代 24000/30000, 损失 = 0.0218, rank_scale = 64.0974, 最佳损失 = 0.0217
# 迭代 25000/30000, 损失 = 0.0218, rank_scale = 67.5893, 最佳损失 = 0.0217
# 迭代 26000/30000, 损失 = 0.0217, rank_scale = 71.0561, 最佳损失 = 0.0217
# 迭代 27000/30000, 损失 = 0.0217, rank_scale = 74.4925, 最佳损失 = 0.0217
# 迭代 28000/30000, 损失 = 0.0217, rank_scale = 77.8954, 最佳损失 = 0.0217
# 迭代 29000/30000, 损失 = 0.0218, rank_scale = 81.2616, 最佳损失 = 0.0217
# 迭代 30000/30000, 损失 = 0.0217, rank_scale = 84.5879, 最佳损失 = 0.0217
#
# 随机搜索: {'lambda_defense': 0.16816410175208013, 'lambda_offense': 0.05034443102887247, 'lambda_supervision': 0.04454674376934912, 'lambda_reg': 0.004484685687215243}
# 迭代 1000/30000, 损失 = 0.0327, rank_scale = 3.1893, 最佳损失 = 0.0327
# 迭代 2000/30000, 损失 = 0.0283, rank_scale = 4.4737, 最佳损失 = 0.0283
# 迭代 3000/30000, 损失 = 0.0272, rank_scale = 5.6094, 最佳损失 = 0.0272
# 迭代 4000/30000, 损失 = 0.0269, rank_scale = 6.7498, 最佳损失 = 0.0269
# 迭代 5000/30000, 损失 = 0.0268, rank_scale = 7.9855, 最佳损失 = 0.0268
# 迭代 6000/30000, 损失 = 0.0267, rank_scale = 9.3785, 最佳损失 = 0.0267
# 迭代 7000/30000, 损失 = 0.0267, rank_scale = 10.9668, 最佳损失 = 0.0267
# 迭代 8000/30000, 损失 = 0.0266, rank_scale = 12.7682, 最佳损失 = 0.0266
# 迭代 9000/30000, 损失 = 0.0266, rank_scale = 14.7923, 最佳损失 = 0.0266
# 迭代 10000/30000, 损失 = 0.0266, rank_scale = 17.0411, 最佳损失 = 0.0266
# 迭代 11000/30000, 损失 = 0.0266, rank_scale = 19.5088, 最佳损失 = 0.0265
# 迭代 12000/30000, 损失 = 0.0265, rank_scale = 22.1804, 最佳损失 = 0.0265
# 迭代 13000/30000, 损失 = 0.0265, rank_scale = 25.0347, 最佳损失 = 0.0265
# 迭代 14000/30000, 损失 = 0.0265, rank_scale = 28.0465, 最佳损失 = 0.0265
# 迭代 15000/30000, 损失 = 0.0265, rank_scale = 31.1900, 最佳损失 = 0.0265
# 迭代 16000/30000, 损失 = 0.0265, rank_scale = 34.4397, 最佳损失 = 0.0265
# 迭代 17000/30000, 损失 = 0.0265, rank_scale = 37.7705, 最佳损失 = 0.0265
# 迭代 18000/30000, 损失 = 0.0265, rank_scale = 41.1616, 最佳损失 = 0.0265
# 迭代 19000/30000, 损失 = 0.0265, rank_scale = 44.5942, 最佳损失 = 0.0264
# 迭代 20000/30000, 损失 = 0.0264, rank_scale = 48.0514, 最佳损失 = 0.0264
# 迭代 21000/30000, 损失 = 0.0264, rank_scale = 51.5215, 最佳损失 = 0.0264
# 迭代 22000/30000, 损失 = 0.0264, rank_scale = 54.9907, 最佳损失 = 0.0264
# 迭代 23000/30000, 损失 = 0.0264, rank_scale = 58.4500, 最佳损失 = 0.0264
# 迭代 24000/30000, 损失 = 0.0264, rank_scale = 61.8911, 最佳损失 = 0.0264
# 迭代 25000/30000, 损失 = 0.0264, rank_scale = 65.3073, 最佳损失 = 0.0264
# 迭代 26000/30000, 损失 = 0.0264, rank_scale = 68.6925, 最佳损失 = 0.0264
# 迭代 27000/30000, 损失 = 0.0264, rank_scale = 72.0423, 最佳损失 = 0.0264
# 迭代 28000/30000, 损失 = 0.0264, rank_scale = 75.3535, 最佳损失 = 0.0264
# 迭代 29000/30000, 损失 = 0.0264, rank_scale = 78.6221, 最佳损失 = 0.0264
# 迭代 30000/30000, 损失 = 0.0264, rank_scale = 81.8456, 最佳损失 = 0.0264
#
# 随机搜索: {'lambda_defense': 0.06780602616231217, 'lambda_offense': 0.1097037220101252, 'lambda_supervision': 0.092069553542002, 'lambda_reg': 0.006533353663762796}
# 迭代 1000/30000, 损失 = 0.0448, rank_scale = 3.1676, 最佳损失 = 0.0448
# 迭代 2000/30000, 损失 = 0.0426, rank_scale = 4.4300, 最佳损失 = 0.0426
# 迭代 3000/30000, 损失 = 0.0422, rank_scale = 5.6175, 最佳损失 = 0.0422
# 迭代 4000/30000, 损失 = 0.0420, rank_scale = 6.8692, 最佳损失 = 0.0420
# 迭代 5000/30000, 损失 = 0.0419, rank_scale = 8.2394, 最佳损失 = 0.0419
# 迭代 6000/30000, 损失 = 0.0418, rank_scale = 9.7624, 最佳损失 = 0.0418
# 迭代 7000/30000, 损失 = 0.0418, rank_scale = 11.4660, 最佳损失 = 0.0417
# 迭代 8000/30000, 损失 = 0.0417, rank_scale = 13.3715, 最佳损失 = 0.0417
# 迭代 9000/30000, 损失 = 0.0416, rank_scale = 15.4908, 最佳损失 = 0.0416
# 迭代 10000/30000, 损失 = 0.0416, rank_scale = 17.8280, 最佳损失 = 0.0416
# 迭代 11000/30000, 损失 = 0.0416, rank_scale = 20.3752, 最佳损失 = 0.0416
# 迭代 12000/30000, 损失 = 0.0415, rank_scale = 23.1180, 最佳损失 = 0.0415
# 迭代 13000/30000, 损失 = 0.0415, rank_scale = 26.0368, 最佳损失 = 0.0415
# 迭代 14000/30000, 损失 = 0.0415, rank_scale = 29.1063, 最佳损失 = 0.0415
# 迭代 15000/30000, 损失 = 0.0415, rank_scale = 32.3017, 最佳损失 = 0.0415
# 迭代 16000/30000, 损失 = 0.0415, rank_scale = 35.5979, 最佳损失 = 0.0415
# 迭代 17000/30000, 损失 = 0.0415, rank_scale = 38.9722, 最佳损失 = 0.0414
# 迭代 18000/30000, 损失 = 0.0414, rank_scale = 42.4037, 最佳损失 = 0.0414
# 迭代 19000/30000, 损失 = 0.0414, rank_scale = 45.8762, 最佳损失 = 0.0414
# 迭代 20000/30000, 损失 = 0.0414, rank_scale = 49.3738, 最佳损失 = 0.0414
# 迭代 21000/30000, 损失 = 0.0414, rank_scale = 52.8846, 最佳损失 = 0.0414
# 迭代 22000/30000, 损失 = 0.0414, rank_scale = 56.3974, 最佳损失 = 0.0414
# 迭代 23000/30000, 损失 = 0.0414, rank_scale = 59.9027, 最佳损失 = 0.0414
# 迭代 24000/30000, 损失 = 0.0414, rank_scale = 63.3931, 最佳损失 = 0.0414
# 迭代 25000/30000, 损失 = 0.0414, rank_scale = 66.8617, 最佳损失 = 0.0414
# 迭代 26000/30000, 损失 = 0.0414, rank_scale = 70.3033, 最佳损失 = 0.0414
# 迭代 27000/30000, 损失 = 0.0414, rank_scale = 73.7122, 最佳损失 = 0.0414
# 迭代 28000/30000, 损失 = 0.0414, rank_scale = 77.0859, 最佳损失 = 0.0414
# 迭代 29000/30000, 损失 = 0.0414, rank_scale = 80.4219, 最佳损失 = 0.0414
# 迭代 30000/30000, 损失 = 0.0414, rank_scale = 83.7157, 最佳损失 = 0.0414
#
# 随机搜索: {'lambda_defense': 0.1262520499972521, 'lambda_offense': 0.036503833523887946, 'lambda_supervision': 0.06550748322169145, 'lambda_reg': 0.007960875022580142}
# 迭代 1000/30000, 损失 = 0.0377, rank_scale = 3.1739, 最佳损失 = 0.0377
# 迭代 2000/30000, 损失 = 0.0335, rank_scale = 4.4450, 最佳损失 = 0.0335
# 迭代 3000/30000, 损失 = 0.0321, rank_scale = 5.5760, 最佳损失 = 0.0321
# 迭代 4000/30000, 损失 = 0.0316, rank_scale = 6.6966, 最佳损失 = 0.0316
# 迭代 5000/30000, 损失 = 0.0314, rank_scale = 7.8919, 最佳损失 = 0.0314
# 迭代 6000/30000, 损失 = 0.0313, rank_scale = 9.2283, 最佳损失 = 0.0313
# 迭代 7000/30000, 损失 = 0.0313, rank_scale = 10.7548, 最佳损失 = 0.0313
# 迭代 8000/30000, 损失 = 0.0313, rank_scale = 12.5001, 最佳损失 = 0.0312
# 迭代 9000/30000, 损失 = 0.0312, rank_scale = 14.4743, 最佳损失 = 0.0312
# 迭代 10000/30000, 损失 = 0.0312, rank_scale = 16.6779, 最佳损失 = 0.0312
# 迭代 11000/30000, 损失 = 0.0312, rank_scale = 19.1047, 最佳损失 = 0.0312
# 迭代 12000/30000, 损失 = 0.0311, rank_scale = 21.7387, 最佳损失 = 0.0311
# 迭代 13000/30000, 损失 = 0.0311, rank_scale = 24.5602, 最佳损失 = 0.0311
# 迭代 14000/30000, 损失 = 0.0311, rank_scale = 27.5431, 最佳损失 = 0.0311
# 迭代 15000/30000, 损失 = 0.0311, rank_scale = 30.6615, 最佳损失 = 0.0311
# 迭代 16000/30000, 损失 = 0.0311, rank_scale = 33.8873, 最佳损失 = 0.0311
# 迭代 17000/30000, 损失 = 0.0311, rank_scale = 37.1965, 最佳损失 = 0.0311
# 迭代 18000/30000, 损失 = 0.0311, rank_scale = 40.5666, 最佳损失 = 0.0311
# 迭代 19000/30000, 损失 = 0.0311, rank_scale = 43.9784, 最佳损失 = 0.0311
# 迭代 20000/30000, 损失 = 0.0311, rank_scale = 47.4147, 最佳损失 = 0.0311
# 迭代 21000/30000, 损失 = 0.0311, rank_scale = 50.8623, 最佳损失 = 0.0310
# 迭代 22000/30000, 损失 = 0.0311, rank_scale = 54.3094, 最佳损失 = 0.0310
# 迭代 23000/30000, 损失 = 0.0310, rank_scale = 57.7449, 最佳损失 = 0.0310
# 迭代 24000/30000, 损失 = 0.0310, rank_scale = 61.1598, 最佳损失 = 0.0310
# 迭代 25000/30000, 损失 = 0.0310, rank_scale = 64.5483, 最佳损失 = 0.0310
# 迭代 26000/30000, 损失 = 0.0310, rank_scale = 67.9044, 最佳损失 = 0.0310
# 迭代 27000/30000, 损失 = 0.0310, rank_scale = 71.2232, 最佳损失 = 0.0310
# 迭代 28000/30000, 损失 = 0.0310, rank_scale = 74.5006, 最佳损失 = 0.0310
# 迭代 29000/30000, 损失 = 0.0310, rank_scale = 77.7339, 最佳损失 = 0.0310
# 迭代 30000/30000, 损失 = 0.0310, rank_scale = 80.9199, 最佳损失 = 0.0310
#
# 随机搜索: {'lambda_defense': 0.09665329700123683, 'lambda_offense': 0.15918343266467258, 'lambda_supervision': 0.047938018610088354, 'lambda_reg': 0.01077045432985862}
# 迭代 1000/30000, 损失 = 0.0344, rank_scale = 3.1773, 最佳损失 = 0.0344
# 迭代 2000/30000, 损失 = 0.0322, rank_scale = 4.4855, 最佳损失 = 0.0322
# 迭代 3000/30000, 损失 = 0.0318, rank_scale = 5.7333, 最佳损失 = 0.0318
# 迭代 4000/30000, 损失 = 0.0316, rank_scale = 7.0376, 最佳损失 = 0.0316
# 迭代 5000/30000, 损失 = 0.0315, rank_scale = 8.4532, 最佳损失 = 0.0315
# 迭代 6000/30000, 损失 = 0.0314, rank_scale = 10.0188, 最佳损失 = 0.0314
# 迭代 7000/30000, 损失 = 0.0313, rank_scale = 11.7646, 最佳损失 = 0.0313
# 迭代 8000/30000, 损失 = 0.0313, rank_scale = 13.7119, 最佳损失 = 0.0313
# 迭代 9000/30000, 损失 = 0.0312, rank_scale = 15.8728, 最佳损失 = 0.0312
# 迭代 10000/30000, 损失 = 0.0312, rank_scale = 18.2491, 最佳损失 = 0.0312
# 迭代 11000/30000, 损失 = 0.0312, rank_scale = 20.8342, 最佳损失 = 0.0312
# 迭代 12000/30000, 损失 = 0.0311, rank_scale = 23.6125, 最佳损失 = 0.0311
# 迭代 13000/30000, 损失 = 0.0311, rank_scale = 26.5635, 最佳损失 = 0.0311
# 迭代 14000/30000, 损失 = 0.0311, rank_scale = 29.6620, 最佳损失 = 0.0311
# 迭代 15000/30000, 损失 = 0.0311, rank_scale = 32.8836, 最佳损失 = 0.0311
# 迭代 16000/30000, 损失 = 0.0311, rank_scale = 36.2030, 最佳损失 = 0.0311
# 迭代 17000/30000, 损失 = 0.0311, rank_scale = 39.5982, 最佳损失 = 0.0310
# 迭代 18000/30000, 损失 = 0.0310, rank_scale = 43.0511, 最佳损失 = 0.0310
# 迭代 19000/30000, 损失 = 0.0310, rank_scale = 46.5437, 最佳损失 = 0.0310
# 迭代 20000/30000, 损失 = 0.0310, rank_scale = 50.0611, 最佳损失 = 0.0310
# 迭代 21000/30000, 损失 = 0.0310, rank_scale = 53.5926, 最佳损失 = 0.0310
# 迭代 22000/30000, 损失 = 0.0310, rank_scale = 57.1270, 最佳损失 = 0.0310
# 迭代 23000/30000, 损失 = 0.0310, rank_scale = 60.6543, 最佳损失 = 0.0310
# 迭代 24000/30000, 损失 = 0.0310, rank_scale = 64.1686, 最佳损失 = 0.0310
# 迭代 25000/30000, 损失 = 0.0310, rank_scale = 67.6637, 最佳损失 = 0.0310
# 迭代 26000/30000, 损失 = 0.0310, rank_scale = 71.1324, 最佳损失 = 0.0310
# 迭代 27000/30000, 损失 = 0.0310, rank_scale = 74.5714, 最佳损失 = 0.0310
# 迭代 28000/30000, 损失 = 0.0310, rank_scale = 77.9771, 最佳损失 = 0.0310
# 迭代 29000/30000, 损失 = 0.0310, rank_scale = 81.3454, 最佳损失 = 0.0310
# 迭代 30000/30000, 损失 = 0.0310, rank_scale = 84.6753, 最佳损失 = 0.0310
#
# 随机搜索: {'lambda_defense': 0.12255876808378807, 'lambda_offense': 0.01882557841679957, 'lambda_supervision': 0.1254335218612733, 'lambda_reg': 0.004239958350058539}
# 迭代 1000/30000, 损失 = 0.0531, rank_scale = 3.1725, 最佳损失 = 0.0531
# 迭代 2000/30000, 损失 = 0.0487, rank_scale = 4.4342, 最佳损失 = 0.0487
# 迭代 3000/30000, 损失 = 0.0469, rank_scale = 5.5480, 最佳损失 = 0.0469
# 迭代 4000/30000, 损失 = 0.0459, rank_scale = 6.6373, 最佳损失 = 0.0459
# 迭代 5000/30000, 损失 = 0.0455, rank_scale = 7.7793, 最佳损失 = 0.0455
# 迭代 6000/30000, 损失 = 0.0452, rank_scale = 9.0285, 最佳损失 = 0.0452
# 迭代 7000/30000, 损失 = 0.0451, rank_scale = 10.4323, 最佳损失 = 0.0451
# 迭代 8000/30000, 损失 = 0.0451, rank_scale = 12.0358, 最佳损失 = 0.0451
# 迭代 9000/30000, 损失 = 0.0451, rank_scale = 13.8729, 最佳损失 = 0.0451
# 迭代 10000/30000, 损失 = 0.0451, rank_scale = 15.9575, 最佳损失 = 0.0451
# 迭代 11000/30000, 损失 = 0.0450, rank_scale = 18.2808, 最佳损失 = 0.0450
# 迭代 12000/30000, 损失 = 0.0450, rank_scale = 20.8266, 最佳损失 = 0.0450
# 迭代 13000/30000, 损失 = 0.0450, rank_scale = 23.5716, 最佳损失 = 0.0450
# 迭代 14000/30000, 损失 = 0.0450, rank_scale = 26.4883, 最佳损失 = 0.0450
# 迭代 15000/30000, 损失 = 0.0450, rank_scale = 29.5476, 最佳损失 = 0.0450
# 迭代 16000/30000, 损失 = 0.0450, rank_scale = 32.7207, 最佳损失 = 0.0450
# 迭代 17000/30000, 损失 = 0.0450, rank_scale = 35.9817, 最佳损失 = 0.0450
# 迭代 18000/30000, 损失 = 0.0450, rank_scale = 39.3052, 最佳损失 = 0.0450
# 迭代 19000/30000, 损失 = 0.0450, rank_scale = 42.6715, 最佳损失 = 0.0450
# 迭代 20000/30000, 损失 = 0.0449, rank_scale = 46.0618, 最佳损失 = 0.0449
# 迭代 21000/30000, 损失 = 0.0449, rank_scale = 49.4608, 最佳损失 = 0.0449
# 迭代 22000/30000, 损失 = 0.0450, rank_scale = 52.8570, 最佳损失 = 0.0449
# 迭代 23000/30000, 损失 = 0.0449, rank_scale = 56.2385, 最佳损失 = 0.0449
# 迭代 24000/30000, 损失 = 0.0449, rank_scale = 59.5961, 最佳损失 = 0.0449
# 迭代 25000/30000, 损失 = 0.0449, rank_scale = 62.9232, 最佳损失 = 0.0449
# 迭代 26000/30000, 损失 = 0.0449, rank_scale = 66.2133, 最佳损失 = 0.0449
# 迭代 27000/30000, 损失 = 0.0449, rank_scale = 69.4607, 最佳损失 = 0.0449
# 迭代 28000/30000, 损失 = 0.0449, rank_scale = 72.6636, 最佳损失 = 0.0449
# 迭代 29000/30000, 损失 = 0.0449, rank_scale = 75.8174, 最佳损失 = 0.0449
# 迭代 30000/30000, 损失 = 0.0449, rank_scale = 78.9213, 最佳损失 = 0.0449
#
# 随机搜索: {'lambda_defense': 0.022359802667203107, 'lambda_offense': 0.19028825207813332, 'lambda_supervision': 0.1934700862841663, 'lambda_reg': 0.01635954961421276}
# 迭代 1000/30000, 损失 = 0.0713, rank_scale = 3.1705, 最佳损失 = 0.0713
# 迭代 2000/30000, 损失 = 0.0688, rank_scale = 4.4350, 最佳损失 = 0.0688
# 迭代 3000/30000, 损失 = 0.0674, rank_scale = 5.5868, 最佳损失 = 0.0674
# 迭代 4000/30000, 损失 = 0.0666, rank_scale = 6.7350, 最佳损失 = 0.0666
# 迭代 5000/30000, 损失 = 0.0663, rank_scale = 7.9398, 最佳损失 = 0.0663
# 迭代 6000/30000, 损失 = 0.0662, rank_scale = 9.2616, 最佳损失 = 0.0662
# 迭代 7000/30000, 损失 = 0.0661, rank_scale = 10.7589, 最佳损失 = 0.0661
# 迭代 8000/30000, 损失 = 0.0661, rank_scale = 12.4741, 最佳损失 = 0.0661
# 迭代 9000/30000, 损失 = 0.0661, rank_scale = 14.4248, 最佳损失 = 0.0661
# 迭代 10000/30000, 损失 = 0.0660, rank_scale = 16.6108, 最佳损失 = 0.0660
# 迭代 11000/30000, 损失 = 0.0660, rank_scale = 19.0240, 最佳损失 = 0.0660
# 迭代 12000/30000, 损失 = 0.0660, rank_scale = 21.6479, 最佳损失 = 0.0660
# 迭代 13000/30000, 损失 = 0.0660, rank_scale = 24.4609, 最佳损失 = 0.0660
# 迭代 14000/30000, 损失 = 0.0660, rank_scale = 27.4374, 最佳损失 = 0.0660
# 迭代 15000/30000, 损失 = 0.0660, rank_scale = 30.5495, 最佳损失 = 0.0660
# 迭代 16000/30000, 损失 = 0.0660, rank_scale = 33.7704, 最佳损失 = 0.0660
# 迭代 17000/30000, 损失 = 0.0659, rank_scale = 37.0755, 最佳损失 = 0.0659
# 迭代 18000/30000, 损失 = 0.0660, rank_scale = 40.4413, 最佳损失 = 0.0659
# 迭代 19000/30000, 损失 = 0.0659, rank_scale = 43.8491, 最佳损失 = 0.0659
# 迭代 20000/30000, 损失 = 0.0659, rank_scale = 47.2821, 最佳损失 = 0.0659
# 迭代 21000/30000, 损失 = 0.0659, rank_scale = 50.7258, 最佳损失 = 0.0659
# 迭代 22000/30000, 损失 = 0.0659, rank_scale = 54.1675, 最佳损失 = 0.0659
# 迭代 23000/30000, 损失 = 0.0659, rank_scale = 57.5974, 最佳损失 = 0.0659
# 迭代 24000/30000, 损失 = 0.0659, rank_scale = 61.0073, 最佳损失 = 0.0659
# 迭代 25000/30000, 损失 = 0.0659, rank_scale = 64.3901, 最佳损失 = 0.0659
# 迭代 26000/30000, 损失 = 0.0659, rank_scale = 67.7400, 最佳损失 = 0.0659
# 迭代 27000/30000, 损失 = 0.0659, rank_scale = 71.0517, 最佳损失 = 0.0659
# 迭代 28000/30000, 损失 = 0.0659, rank_scale = 74.3223, 最佳损失 = 0.0659
# 迭代 29000/30000, 损失 = 0.0659, rank_scale = 77.5480, 最佳损失 = 0.0659
# 迭代 30000/30000, 损失 = 0.0659, rank_scale = 80.7264, 最佳损失 = 0.0659
#
# 随机搜索: {'lambda_defense': 0.06787661614294044, 'lambda_offense': 0.028557701661212936, 'lambda_supervision': 0.1400042750373098, 'lambda_reg': 0.009362897381052424}
# 迭代 1000/30000, 损失 = 0.0561, rank_scale = 3.1599, 最佳损失 = 0.0561
# 迭代 2000/30000, 损失 = 0.0532, rank_scale = 4.3909, 最佳损失 = 0.0532
# 迭代 3000/30000, 损失 = 0.0518, rank_scale = 5.5085, 最佳损失 = 0.0518
# 迭代 4000/30000, 损失 = 0.0509, rank_scale = 6.6326, 最佳损失 = 0.0509
# 迭代 5000/30000, 损失 = 0.0506, rank_scale = 7.8190, 最佳损失 = 0.0506
# 迭代 6000/30000, 损失 = 0.0505, rank_scale = 9.1242, 最佳损失 = 0.0505
# 迭代 7000/30000, 损失 = 0.0504, rank_scale = 10.6051, 最佳损失 = 0.0504
# 迭代 8000/30000, 损失 = 0.0504, rank_scale = 12.3028, 最佳损失 = 0.0504
# 迭代 9000/30000, 损失 = 0.0503, rank_scale = 14.2346, 最佳损失 = 0.0503
# 迭代 10000/30000, 损失 = 0.0503, rank_scale = 16.4002, 最佳损失 = 0.0503
# 迭代 11000/30000, 损失 = 0.0503, rank_scale = 18.7928, 最佳损失 = 0.0503
# 迭代 12000/30000, 损失 = 0.0503, rank_scale = 21.3967, 最佳损失 = 0.0503
# 迭代 13000/30000, 损失 = 0.0503, rank_scale = 24.1916, 最佳损失 = 0.0502
# 迭代 14000/30000, 损失 = 0.0503, rank_scale = 27.1509, 最佳损失 = 0.0502
# 迭代 15000/30000, 损失 = 0.0502, rank_scale = 30.2471, 最佳损失 = 0.0502
# 迭代 16000/30000, 损失 = 0.0502, rank_scale = 33.4537, 最佳损失 = 0.0502
# 迭代 17000/30000, 损失 = 0.0502, rank_scale = 36.7447, 最佳损失 = 0.0502
# 迭代 18000/30000, 损失 = 0.0502, rank_scale = 40.0983, 最佳损失 = 0.0502
# 迭代 19000/30000, 损失 = 0.0502, rank_scale = 43.4935, 最佳损失 = 0.0502
# 迭代 20000/30000, 损失 = 0.0502, rank_scale = 46.9137, 最佳损失 = 0.0502
# 迭代 21000/30000, 损失 = 0.0502, rank_scale = 50.3437, 最佳损失 = 0.0502
# 迭代 22000/30000, 损失 = 0.0502, rank_scale = 53.7712, 最佳损失 = 0.0502
# 迭代 23000/30000, 损失 = 0.0502, rank_scale = 57.1863, 最佳损失 = 0.0502
# 迭代 24000/30000, 损失 = 0.0502, rank_scale = 60.5809, 最佳损失 = 0.0502
# 迭代 25000/30000, 损失 = 0.0502, rank_scale = 63.9466, 最佳损失 = 0.0502
# 迭代 26000/30000, 损失 = 0.0502, rank_scale = 67.2786, 最佳损失 = 0.0502
# 迭代 27000/30000, 损失 = 0.0502, rank_scale = 70.5710, 最佳损失 = 0.0502
# 迭代 28000/30000, 损失 = 0.0502, rank_scale = 73.8202, 最佳损失 = 0.0502
# 迭代 29000/30000, 损失 = 0.0502, rank_scale = 77.0246, 最佳损失 = 0.0502
# 迭代 30000/30000, 损失 = 0.0502, rank_scale = 80.1806, 最佳损失 = 0.0501
#
# 最佳超参数: {'lambda_defense': 0.039643541684062936, 'lambda_offense': 0.039638958863878505, 'lambda_supervision': 0.021035886311957897, 'lambda_reg': 0.01745734676972377}, 最佳损失: 0.0194
#
# ===== 最终训练 =====
# 迭代 1000/30000, 损失 = 0.0235, rank_scale = 3.1538, 最佳损失 = 0.0235
# 迭代 2000/30000, 损失 = 0.0211, rank_scale = 4.3677, 最佳损失 = 0.0211
# 迭代 3000/30000, 损失 = 0.0204, rank_scale = 5.4626, 最佳损失 = 0.0204
# 迭代 4000/30000, 损失 = 0.0201, rank_scale = 6.5908, 最佳损失 = 0.0201
# 迭代 5000/30000, 损失 = 0.0198, rank_scale = 7.8253, 最佳损失 = 0.0198
# 迭代 6000/30000, 损失 = 0.0197, rank_scale = 9.2072, 最佳损失 = 0.0197
# 迭代 7000/30000, 损失 = 0.0197, rank_scale = 10.7699, 最佳损失 = 0.0197
# 迭代 8000/30000, 损失 = 0.0196, rank_scale = 12.5408, 最佳损失 = 0.0196
# 迭代 9000/30000, 损失 = 0.0196, rank_scale = 14.5339, 最佳损失 = 0.0196
# 迭代 10000/30000, 损失 = 0.0195, rank_scale = 16.7528, 最佳损失 = 0.0195
# 迭代 11000/30000, 损失 = 0.0195, rank_scale = 19.1909, 最佳损失 = 0.0195
# 迭代 12000/30000, 损失 = 0.0195, rank_scale = 21.8343, 最佳损失 = 0.0195
# 迭代 13000/30000, 损失 = 0.0195, rank_scale = 24.6640, 最佳损失 = 0.0195
# 迭代 14000/30000, 损失 = 0.0195, rank_scale = 27.6537, 最佳损失 = 0.0195
# 迭代 15000/30000, 损失 = 0.0194, rank_scale = 30.7772, 最佳损失 = 0.0194
# 迭代 16000/30000, 损失 = 0.0194, rank_scale = 34.0085, 最佳损失 = 0.0194
# 迭代 17000/30000, 损失 = 0.0194, rank_scale = 37.3222, 最佳损失 = 0.0194
# 迭代 18000/30000, 损失 = 0.0194, rank_scale = 40.6962, 最佳损失 = 0.0194
# 迭代 19000/30000, 损失 = 0.0194, rank_scale = 44.1129, 最佳损失 = 0.0194
# 迭代 20000/30000, 损失 = 0.0194, rank_scale = 47.5542, 最佳损失 = 0.0194
# 迭代 21000/30000, 损失 = 0.0194, rank_scale = 51.0059, 最佳损失 = 0.0194
# 迭代 22000/30000, 损失 = 0.0194, rank_scale = 54.4571, 最佳损失 = 0.0194
# 迭代 23000/30000, 损失 = 0.0194, rank_scale = 57.8971, 最佳损失 = 0.0194
# 迭代 24000/30000, 损失 = 0.0194, rank_scale = 61.3186, 最佳损失 = 0.0194
# 迭代 25000/30000, 损失 = 0.0194, rank_scale = 64.7126, 最佳损失 = 0.0194
# 迭代 26000/30000, 损失 = 0.0194, rank_scale = 68.0745, 最佳损失 = 0.0194
# 迭代 27000/30000, 损失 = 0.0194, rank_scale = 71.3989, 最佳损失 = 0.0194
# 迭代 28000/30000, 损失 = 0.0194, rank_scale = 74.6840, 最佳损失 = 0.0194
# 迭代 29000/30000, 损失 = 0.0194, rank_scale = 77.9240, 最佳损失 = 0.0194
# 迭代 30000/30000, 损失 = 0.0194, rank_scale = 81.1179, 最佳损失 = 0.0194
# 最终损失: 0.0194
# 最终防守权重: [-0.02514944 -0.00693218  0.00252416  0.00011669 -0.0029795  -0.02120511
#   0.06241486  0.06597842]
# 最终进攻权重: [ 7.2274809e-03  8.7510711e-03 -4.5784204e-03  2.7211592e-02
#  -9.0121066e-06  6.7889029e-03  4.3415642e-04  6.7820004e-03]
#
# ===== 可视化 =====
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 premier-league 图 -> /Users/peixuanma/Downloads/Output_Graphs/premier-league_evolution.png
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 bundesliga 图 -> /Users/peixuanma/Downloads/Output_Graphs/bundesliga_evolution.png
# 保存 la-liga 图 -> /Users/peixuanma/Downloads/Output_Graphs/la-liga_evolution.png
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 ligue-1 图 -> /Users/peixuanma/Downloads/Output_Graphs/ligue-1_evolution.png
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 serie-b 图 -> /Users/peixuanma/Downloads/Output_Graphs/serie-b_evolution.png
# 保存 2-bundesliga 图 -> /Users/peixuanma/Downloads/Output_Graphs/2-bundesliga_evolution.png
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 premiership 图 -> /Users/peixuanma/Downloads/Output_Graphs/premiership_evolution.png
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:461: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_67204/3904674940.py:463: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 pro-league 图 -> /Users/peixuanma/Downloads/Output_Graphs/pro-league_evolution.png
#
# 完成！

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, train_test_split
import sklearn

print(f"scikit-learn 版本: {sklearn.__version__}")

# ====================== 计算防守统计数据 ======================
def compute_defensive_stats(match_df, team_positions_df):
    """计算球队的防守统计数据，包括6种比率、总失球数和平均失球数"""
    epsilon = 1e-8  # 提高数值稳定性
    team_stats = {}
    for team in team_positions_df['team_name'].unique():
        team_stats[team] = {
            'total_goals_conceded': 0, 'ratio1_list': [], 'ratio2_list': [], 'ratio3_list': [],
            'ratio4_list': [], 'ratio5_list': [], 'ratio6_list': [], 'num_matches': 0
        }

    # 主场比赛统计
    for idx, row in match_df.iterrows():
        home_team, away_team = row['home_team_name'], row['away_team_name']
        if home_team not in team_stats or away_team not in team_stats:
            print(f"警告: 主队 {home_team} 或客队 {away_team} 未找到，跳过比赛 {idx}")
            continue
        if row['Pre-Match PPG (Away)'] > 0:
            team_stats[home_team]['ratio1_list'].append(
                row['away_team_goal_count'] / (row['Pre-Match PPG (Away)'] + epsilon))
        if row['away_team_corner_count'] > 0:
            team_stats[home_team]['ratio2_list'].append(
                row['away_team_goal_count'] / (row['away_team_corner_count'] + epsilon))
        denominator = row['home_team_yellow_cards'] + row['home_team_red_cards'] + row['home_team_fouls'] + epsilon
        team_stats[home_team]['ratio3_list'].append(row['away_team_goal_count'] / denominator)
        if row['team_b_xg'] > 0:
            team_stats[home_team]['ratio4_list'].append(row['away_team_goal_count'] / (row['team_b_xg'] + epsilon))
        shots_total = row['away_team_shots_on_target'] + row['away_team_shots_off_target'] + epsilon
        team_stats[home_team]['ratio5_list'].append(row['away_team_goal_count'] / shots_total)
        if row['away_team_possession'] > 0:
            team_stats[home_team]['ratio6_list'].append(
                row['away_team_goal_count'] / (row['away_team_possession'] + epsilon))
        team_stats[home_team]['total_goals_conceded'] += row['away_team_goal_count']
        team_stats[home_team]['num_matches'] += 1  # 记录主场比赛场次

    # 客场比赛统计
    for idx, row in match_df.iterrows():
        away_team = row['away_team_name']
        if away_team not in team_stats:
            print(f"警告: 客队 {away_team} 未找到，跳过比赛 {idx}")
            continue
        team_stats[away_team]['total_goals_conceded'] += row['home_team_goal_count']
        team_stats[away_team]['num_matches'] += 1  # 记录客场比赛场次

    # 汇总数据
    data = []
    for team, stats in team_stats.items():
        num_matches = stats['num_matches']
        average_goals_conceded = stats['total_goals_conceded'] / num_matches if num_matches > 0 else 0
        data.append({
            'team_name': team,
            'ratio1': np.mean(stats['ratio1_list']) if stats['ratio1_list'] else 0,
            'ratio2': np.mean(stats['ratio2_list']) if stats['ratio2_list'] else 0,
            'ratio3': np.mean(stats['ratio3_list']) if stats['ratio3_list'] else 0,
            'ratio4': np.mean(stats['ratio4_list']) if stats['ratio4_list'] else 0,
            'ratio5': np.mean(stats['ratio5_list']) if stats['ratio5_list'] else 0,
            'ratio6': np.mean(stats['ratio6_list']) if stats['ratio6_list'] else 0,
            'total_goals_conceded': stats['total_goals_conceded'],
            'average_goals_conceded': average_goals_conceded
        })

    return pd.DataFrame(data)

# ====================== 计算进攻统计数据 ======================
def compute_offensive_stats(match_df, team_positions_df):
    """计算球队的进攻统计数据，包括6种比率、总进球数和平均进球数"""
    epsilon = 1e-8  # 提高数值稳定性
    team_stats = {}
    for team in team_positions_df['team_name'].unique():
        team_stats[team] = {
            'total_goals_scored': 0, 'off_ratio1_list': [], 'off_ratio2_list': [], 'off_ratio3_list': [],
            'off_ratio4_list': [], 'off_ratio5_list': [], 'off_ratio6_list': [], 'num_matches': 0
        }

    # 主场比赛统计
    for idx, row in match_df.iterrows():
        home_team, away_team = row['home_team_name'], row['away_team_name']
        if home_team not in team_stats or away_team not in team_stats:
            continue
        if row['Pre-Match PPG (Home)'] > 0:
            team_stats[home_team]['off_ratio1_list'].append(
                row['home_team_goal_count'] / (row['Pre-Match PPG (Home)'] + epsilon))
        if row['home_team_corner_count'] > 0:
            team_stats[home_team]['off_ratio2_list'].append(
                row['home_team_goal_count'] / (row['home_team_corner_count'] + epsilon))
        denominator = row['away_team_yellow_cards'] + row['away_team_red_cards'] + row['away_team_fouls'] + epsilon
        team_stats[home_team]['off_ratio3_list'].append(row['home_team_goal_count'] / denominator)
        if row['team_a_xg'] > 0:
            team_stats[home_team]['off_ratio4_list'].append(row['home_team_goal_count'] / (row['team_a_xg'] + epsilon))
        shots_total = row['home_team_shots_on_target'] + row['home_team_shots_off_target'] + epsilon
        team_stats[home_team]['off_ratio5_list'].append(row['home_team_goal_count'] / shots_total)
        if row['home_team_possession'] > 0:
            team_stats[home_team]['off_ratio6_list'].append(
                row['home_team_goal_count'] / (row['home_team_possession'] + epsilon))
        team_stats[home_team]['total_goals_scored'] += row['home_team_goal_count']
        team_stats[home_team]['num_matches'] += 1

    # 客场比赛统计
    for idx, row in match_df.iterrows():
        away_team = row['away_team_name']
        if away_team not in team_stats:
            continue
        team_stats[away_team]['total_goals_scored'] += row['away_team_goal_count']
        team_stats[away_team]['num_matches'] += 1

    # 汇总数据
    data = []
    for team, stats in team_stats.items():
        num_matches = stats['num_matches']
        average_goals_scored = stats['total_goals_scored'] / num_matches if num_matches > 0 else 0
        data.append({
            'team_name': team,
            'off_ratio1': np.mean(stats['off_ratio1_list']) if stats['off_ratio1_list'] else 0,
            'off_ratio2': np.mean(stats['off_ratio2_list']) if stats['off_ratio2_list'] else 0,
            'off_ratio3': np.mean(stats['off_ratio3_list']) if stats['off_ratio3_list'] else 0,
            'off_ratio4': np.mean(stats['off_ratio4_list']) if stats['off_ratio4_list'] else 0,
            'off_ratio5': np.mean(stats['off_ratio5_list']) if stats['off_ratio5_list'] else 0,
            'off_ratio6': np.mean(stats['off_ratio6_list']) if stats['off_ratio6_list'] else 0,
            'total_goals_scored': stats['total_goals_scored'],
            'average_goals_scored': average_goals_scored
        })

    return pd.DataFrame(data)

# ====================== ELO评分算法实现 ======================
def initialize_elo_scores(team_positions_df):
    """初始化球队ELO分数"""
    teams = team_positions_df['team_name'].unique().tolist()
    team_elo = {team: 1500 for team in teams}
    for team in teams:
        team_data = team_positions_df[team_positions_df['team_name'] == team]
        rank = team_data['points_per_game'].rank().iloc[0]
        team_elo[team] += (20 * (len(teams) - rank))
    return team_elo

def update_elo_scores(elo_scores, home_team, away_team, home_score, away_score, K=30):
    """更新ELO分数"""
    home_elo, away_elo = elo_scores[home_team], elo_scores[away_team]
    expected_home = 1 / (1 + 10 ** ((away_elo - home_elo) / 400))
    expected_away = 1 / (1 + 10 ** ((home_elo - away_elo) / 400))

    if home_score > away_score:
        elo_scores[home_team] += K * (1 - expected_home)
        elo_scores[away_team] += K * (0 - expected_away)
    elif home_score < away_score:
        elo_scores[home_team] += K * (0 - expected_home)
        elo_scores[away_team] += K * (1 - expected_away)
    else:
        elo_scores[home_team] += K * (0.5 - expected_home)
        elo_scores[away_team] += K * (0.5 - expected_away)
    return elo_scores

# ====================== 数据加载函数（含交叉验证） ======================
def load_all_league_data(base_path, leagues, seasons):
    """加载所有联赛数据并进行预处理"""
    all_team_positions, all_match_positions = [], []
    for country_name, league_name in leagues:
        for season in seasons:
            print(f"加载数据: {country_name} - {league_name} - {season}")
            team_file = os.path.join(base_path, f"{country_name}-{league_name}-teams-{season}-stats.csv")
            match_file = os.path.join(base_path, f"{country_name}-{league_name}-matches-{season}-stats.csv")
            if not os.path.exists(team_file) or not os.path.exists(match_file):
                print(f"警告: {country_name} - {league_name} - {season} 文件缺失")
                continue

            team_df = pd.read_csv(team_file)
            match_df = pd.read_csv(match_file)

            # 统一球队名称格式
            team_df['team_name'] = team_df.get('common_name', team_df.get('team_name', None)).str.strip().str.lower()
            match_df['home_team_name'] = match_df['home_team_name'].str.strip().str.lower()
            match_df['away_team_name'] = match_df['away_team_name'].str.strip().str.lower()

            team_names = team_df['team_name'].unique()
            original_match_count = len(match_df)
            match_df = match_df[
                match_df['home_team_name'].isin(team_names) & match_df['away_team_name'].isin(team_names)]
            if len(match_df) < original_match_count:
                print(f"警告: 过滤了 {original_match_count - len(match_df)} 场比赛")

            if match_df.empty:
                print("警告: 无有效比赛数据")
                continue

            # 计算防守和进攻统计
            defensive_stats_df = compute_defensive_stats(match_df, team_df)
            offensive_stats_df = compute_offensive_stats(match_df, team_df)
            if defensive_stats_df.empty or offensive_stats_df.empty:
                print("警告: 未计算出防守或进攻统计")
                continue

            team_df = team_df.merge(defensive_stats_df, on='team_name', how='left')
            team_df = team_df.merge(offensive_stats_df, on='team_name', how='left')

            for col in ['ratio1', 'ratio2', 'ratio3', 'ratio4', 'ratio5', 'ratio6', 'total_goals_conceded', 'average_goals_conceded',
                        'off_ratio1', 'off_ratio2', 'off_ratio3', 'off_ratio4', 'off_ratio5', 'off_ratio6', 'total_goals_scored', 'average_goals_scored']:
                if col not in team_df.columns:
                    print(f"警告: {col} 列缺失，设为0")
                    team_df[col] = 0

            # 归一化防守得分
            if 'total_goals_conceded' in team_df.columns and team_df['total_goals_conceded'].max() != team_df['total_goals_conceded'].min():
                team_df['normalized_defense_score'] = (team_df['total_goals_conceded'].max() - team_df['total_goals_conceded']) / (
                    team_df['total_goals_conceded'].max() - team_df['total_goals_conceded'].min() + 1e-8)
            else:
                team_df['normalized_defense_score'] = 0

            # PCA降维（防守和进攻数据）
            defensive_columns = ['total_goals_conceded', 'ratio1', 'ratio2', 'ratio3', 'ratio4', 'ratio5', 'ratio6', 'average_goals_conceded']
            offensive_columns = ['total_goals_scored', 'off_ratio1', 'off_ratio2', 'off_ratio3', 'off_ratio4', 'off_ratio5', 'off_ratio6', 'average_goals_scored']
            team_df_defensive = team_df[defensive_columns].fillna(0)
            kf = KFold(n_splits=5, shuffle=True, random_state=42)
            pca_results = []
            for train_idx, _ in kf.split(team_df_defensive):
                train_data = team_df_defensive.iloc[train_idx]
                scaler = StandardScaler()
                X_scaled = scaler.fit_transform(train_data)
                pca = PCA(n_components=2)
                X_pca = pca.fit_transform(X_scaled)
                pca_results.append(X_pca)
            X_pca_avg = np.mean([np.pad(r, ((0, len(team_df_defensive) - len(r)), (0, 0)), 'constant') for r in pca_results], axis=0)

            team_positions = pd.DataFrame({
                'team_name': team_df['team_name'], 'PC1': X_pca_avg[:, 0], 'PC2': X_pca_avg[:, 1],
                'points_per_game': team_df['points_per_game'], 'league': league_name, 'season': season,
                'ratio1': team_df['ratio1'], 'ratio2': team_df['ratio2'], 'ratio3': team_df['ratio3'],
                'ratio4': team_df['ratio4'], 'ratio5': team_df['ratio5'], 'ratio6': team_df['ratio6'],
                'off_ratio1': team_df['off_ratio1'], 'off_ratio2': team_df['off_ratio2'], 'off_ratio3': team_df['off_ratio3'],
                'off_ratio4': team_df['off_ratio4'], 'off_ratio5': team_df['off_ratio5'], 'off_ratio6': team_df['off_ratio6'],
                'normalized_defense_score': team_df['normalized_defense_score'],
                'total_goals_conceded': team_df['total_goals_conceded'],
                'average_goals_conceded': team_df['average_goals_conceded'],
                'total_goals_scored': team_df['total_goals_scored'],
                'average_goals_scored': team_df['average_goals_scored']
            })
            team_positions['team_season'] = league_name + '_' + team_positions['team_name'] + '_' + team_positions['season']
            all_team_positions.append(team_positions)

            # 比赛数据PCA
            match_df = match_df.drop(columns=['timestamp', 'date_GMT', 'status', 'attendance', 'referee', 'stadium_name', 'Game Week'], errors='ignore')
            numeric_cols = match_df.select_dtypes(include=[np.number]).columns
            match_df[numeric_cols] = match_df[numeric_cols].fillna(match_df[numeric_cols].mean())
            pca_match_results = []
            for train_idx, _ in kf.split(match_df[numeric_cols]):
                train_data = match_df[numeric_cols].iloc[train_idx]
                scaler = StandardScaler()
                X_scaled = scaler.fit_transform(train_data)
                pca = PCA(n_components=2)
                X_pca = pca.fit_transform(X_scaled)
                pca_match_results.append(X_pca)
            X_pca_match_avg = np.mean([np.pad(r, ((0, len(match_df) - len(r)), (0, 0)), 'constant') for r in pca_match_results], axis=0)

            match_positions = pd.DataFrame({
                'home_team_name': match_df['home_team_name'], 'away_team_name': match_df['away_team_name'],
                'PC1': X_pca_match_avg[:, 0], 'PC2': X_pca_match_avg[:, 1], 'league': league_name, 'season': season
            })
            all_match_positions.append(match_positions)

    return pd.concat(all_team_positions, ignore_index=True), pd.concat(all_match_positions, ignore_index=True)

# ====================== 计算主客场差异比值 ======================
def compute_home_away_ratios(team_positions_df, match_positions_df, w_def, w_off):
    """计算每支球队在每个赛季面对每个对手的主客场差异比值"""
    epsilon = 1e-8
    ratios_dict = {}

    # 按赛季和联赛分组
    for (league, season), team_group in team_positions_df.groupby(['league', 'season']):
        match_group = match_positions_df[(match_positions_df['league'] == league) & (match_positions_df['season'] == season)]
        
        for team in team_group['team_name'].unique():
            team_data = team_group[team_group['team_name'] == team].iloc[0]
            
            # 计算主场进攻和防守参数
            home_offense = (team_data['off_ratio1'] * w_off[0] + team_data['off_ratio2'] * w_off[1] +
                            team_data['off_ratio3'] * w_off[2] + team_data['off_ratio4'] * w_off[3] +
                            team_data['off_ratio5'] * w_off[4] + team_data['off_ratio6'] * w_off[5] +
                            team_data['total_goals_scored'] * w_off[6] + team_data['average_goals_scored'] * w_off[7])
            home_defense = (team_data['ratio1'] * w_def[0] + team_data['ratio2'] * w_def[1] +
                            team_data['ratio3'] * w_def[2] + team_data['ratio4'] * w_def[3] +
                            team_data['ratio5'] * w_def[4] + team_data['ratio6'] * w_def[5] +
                            team_data['total_goals_conceded'] * w_def[6] + team_data['average_goals_conceded'] * w_def[7])
            
            # 计算主场综合能力参数
            home_comprehensive = 0.5 * home_offense + 0.5 * home_defense

            # 对每个对手计算客场表现
            for _, match in match_group.iterrows():
                if match['home_team_name'] == team:
                    opponent = match['away_team_name']
                elif match['away_team_name'] == team:
                    opponent = match['home_team_name']
                else:
                    continue
                
                # 假设客场表现基于主场表现的调整（此处可根据实际数据优化）
                # 示例：客场进攻减少20%，防守增加20%
                away_offense = home_offense * 0.8
                away_defense = home_defense * 1.2
                away_comprehensive = 0.5 * away_offense + 0.5 * away_defense
                
                # 计算主客场差异比值
                ratio = away_comprehensive / (home_comprehensive + epsilon)
                key = f"{league}_{team}_{season}_{opponent}"
                ratios_dict[key] = ratio

    return ratios_dict

# ====================== 损失函数 ======================
def compute_total_loss(positions, match_home_idx, match_away_idx, match_PC1, match_PC2, points_per_game, rank_scale,
                       def_ratios, w_def, off_ratios, w_off, normalized_defense_score, lambda_defense, lambda_offense,
                       lambda_supervision, lambda_reg, elo_scores, home_away_ratios, match_positions_df):
    """计算总损失，考虑主客场差异调整约束距离"""
    epsilon = 1e-8
    if tf.shape(match_home_idx)[0] == 0:
        return tf.constant(0.0, dtype=tf.float32)

    # 匹配损失
    home_pos = tf.gather(positions, match_home_idx)
    away_pos = tf.gather(positions, match_away_idx)
    match_points = tf.stack([match_PC1, match_PC2], axis=1)
    dist_home = tf.norm(home_pos - match_points + epsilon, axis=1)
    dist_away = tf.norm(away_pos - match_points + epsilon, axis=1)
    all_distances = tf.concat([dist_home, dist_away], axis=0)
    dist_range = tf.reduce_max(all_distances) - tf.reduce_min(all_distances) + epsilon
    dist_home_norm = (dist_home - tf.reduce_min(all_distances)) / dist_range
    dist_away_norm = (dist_away - tf.reduce_min(all_distances)) / dist_range

    home_elo = tf.gather(elo_scores, match_home_idx)
    away_elo = tf.gather(elo_scores, match_away_idx)
    elo_diff = tf.abs(home_elo - away_elo)
    weight = 1.0 / (1.0 + elo_diff * rank_scale + epsilon)

    # 计算主客场差异比值并调整约束距离
    adjusted_dist_home = []
    adjusted_dist_away = []

    for i in range(len(match_home_idx)):
        home_team = match_positions_df.iloc[i]['home_team_name']
        away_team = match_positions_df.iloc[i]['away_team_name']
        league = match_positions_df.iloc[i]['league']
        season = match_positions_df.iloc[i]['season']
        
        # 主场约束（正常）
        home_key = f"{league}_{home_team}_{season}_{away_team}"
        home_ratio = home_away_ratios.get(home_key, 1.0)  # 默认值1.0
        adjusted_dist_home.append(dist_home_norm[i])

        # 客场约束（根据ELO调整）
        away_key = f"{league}_{away_team}_{season}_{home_team}"
        away_ratio = home_away_ratios.get(away_key, 1.0)
        if home_elo[i] > away_elo[i]:
            adjusted_dist_away.append(dist_away_norm[i] * away_ratio * elo_diff[i])
        else:
            adjusted_dist_away.append(dist_away_norm[i] * away_ratio / (elo_diff[i] + epsilon))

    adjusted_dist_home = tf.stack(adjusted_dist_home)
    adjusted_dist_away = tf.stack(adjusted_dist_away)
    match_loss = tf.reduce_mean(weight * (adjusted_dist_home + adjusted_dist_away))

    # 防守损失
    w_def = tf.abs(w_def)
    defense_target = -tf.reduce_sum(w_def * def_ratios, axis=1)
    defense_loss = tf.reduce_mean(tf.square(positions[:, 1] - defense_target))

    # 进攻损失
    w_off = tf.abs(w_off)
    offense_target = tf.reduce_sum(w_off * off_ratios, axis=1)
    offense_loss = tf.reduce_mean(tf.square(positions[:, 0] - offense_target))

    # 监督损失
    supervision_loss = tf.reduce_mean(tf.square(defense_target - normalized_defense_score))

    # 正则化
    regularization_loss = lambda_reg * (tf.reduce_sum(tf.square(w_def)) + tf.reduce_sum(tf.square(w_off)))

    total_loss = (match_loss + lambda_defense * defense_loss + lambda_offense * offense_loss +
                  lambda_supervision * supervision_loss + regularization_loss)
    return tf.where(tf.math.is_nan(total_loss) | tf.math.is_inf(total_loss), 0.0, total_loss)

# ====================== Adam优化函数 ======================
def adam_optimize_positions(team_positions_df, match_positions_df, initial_lr=0.005, decay_steps=20000, decay_rate=0.9,
                            clipnorm=0.5, iterations=30000, verbose_interval=1000, random_seed=42, lambda_defense=0.1,
                            lambda_offense=0.1, lambda_supervision=0.1, lambda_reg=0.01, w_def=None, w_off=None):
    """使用Adam优化球队位置，考虑主客场差异"""
    team_seasons = team_positions_df['team_season'].unique()
    team_season_to_idx = {t: i for i, t in enumerate(team_seasons)}

    elo_scores_dict = initialize_elo_scores(team_positions_df)
    team_names = [t.split('_')[1] for t in team_seasons]
    elo_scores = tf.convert_to_tensor([elo_scores_dict[name] for name in team_names], dtype=tf.float32)

    team_positions_df = team_positions_df.set_index('team_season')
    init_positions = team_positions_df[['PC1', 'PC2']].values
    def_ratios = team_positions_df[['ratio1', 'ratio2', 'ratio3', 'ratio4', 'ratio5', 'ratio6', 'total_goals_conceded', 'average_goals_conceded']].values
    off_ratios = team_positions_df[['off_ratio1', 'off_ratio2', 'off_ratio3', 'off_ratio4', 'off_ratio5', 'off_ratio6', 'total_goals_scored', 'average_goals_scored']].values

    scaler_pos = StandardScaler()
    scaler_def = StandardScaler()
    scaler_off = StandardScaler()
    positions_scaled = scaler_pos.fit_transform(init_positions)
    def_ratios_scaled = scaler_def.fit_transform(def_ratios)
    off_ratios_scaled = scaler_off.fit_transform(off_ratios)

    positions = tf.Variable(positions_scaled, dtype=tf.float32)
    def_ratios = tf.constant(def_ratios_scaled, dtype=tf.float32)
    off_ratios = tf.constant(off_ratios_scaled, dtype=tf.float32)
    normalized_defense_score = tf.constant(team_positions_df['normalized_defense_score'].values, dtype=tf.float32)
    points_per_game = tf.constant(team_positions_df['points_per_game'].values, dtype=tf.float32)

    match_array = [
        [team_season_to_idx[f"{row['league']}_{row['home_team_name']}_{row['season']}"],
         team_season_to_idx[f"{row['league']}_{row['away_team_name']}_{row['season']}"], row['PC1'], row['PC2']]
        for _, row in match_positions_df.iterrows()
        if f"{row['league']}_{row['home_team_name']}_{row['season']}" in team_season_to_idx and
           f"{row['league']}_{row['away_team_name']}_{row['season']}" in team_season_to_idx
    ]
    match_array = np.array(match_array, dtype=np.float32)
    if len(match_array) == 0:
        print("警告: 无有效比赛数据")
        return [], team_positions_df.reset_index(), None, None, None

    match_home_idx = tf.constant(match_array[:, 0], dtype=tf.int32)
    match_away_idx = tf.constant(match_array[:, 1], dtype=tf.int32)
    match_PC1 = tf.constant(match_array[:, 2], dtype=tf.float32)
    match_PC2 = tf.constant(match_array[:, 3], dtype=tf.float32)

    # 计算主客场差异比值
    home_away_ratios = compute_home_away_ratios(team_positions_df.reset_index(), match_positions_df, w_def, w_off)

    tf.random.set_seed(random_seed)
    rank_scale = tf.Variable(1.0, dtype=tf.float32)
    w_def = tf.Variable(np.abs(w_def) if w_def is not None else np.ones(8, dtype=np.float32) / 8, dtype=tf.float32)
    w_off = tf.Variable(np.abs(w_off) if w_off is not None else np.ones(8, dtype=np.float32) / 8, dtype=tf.float32)
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(initial_lr, decay_steps, decay_rate)
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule, clipnorm=clipnorm)

    losses, best_loss = [], float('inf')
    best_positions, best_rank_scale, best_w_def, best_w_off = positions.numpy().copy(), 1.0, w_def.numpy().copy(), w_off.numpy().copy()

    for i in range(iterations):
        with tf.GradientTape() as tape:
            loss = compute_total_loss(positions, match_home_idx, match_away_idx, match_PC1, match_PC2, points_per_game,
                                      rank_scale, def_ratios, w_def, off_ratios, w_off, normalized_defense_score,
                                      lambda_defense, lambda_offense, lambda_supervision, lambda_reg, elo_scores,
                                      home_away_ratios, match_positions_df)
        grads = tape.gradient(loss, [positions, rank_scale, w_def, w_off])
        if any(g is None for g in grads):
            print(f"警告: 迭代 {i + 1} 梯度为None")
            continue
        optimizer.apply_gradients(zip(grads, [positions, rank_scale, w_def, w_off]))
        loss_val = float(loss.numpy())
        losses.append(loss_val)

        if loss_val < best_loss:
            best_loss = loss_val
            best_positions, best_rank_scale, best_w_def, best_w_off = (positions.numpy().copy(), float(rank_scale.numpy()),
                                                                       w_def.numpy().copy(), w_off.numpy().copy())

        if (i + 1) % verbose_interval == 0:
            print(f"迭代 {i + 1}/{iterations}, 损失 = {loss_val:.4f}, rank_scale = {rank_scale.numpy():.4f}, 最佳损失 = {best_loss:.4f}")

    positions.assign(best_positions)
    rank_scale.assign(best_rank_scale)
    w_def.assign(best_w_def)
    w_off.assign(best_w_off)
    final_pos = scaler_pos.inverse_transform(positions.numpy())
    for idx, team_season in enumerate(team_seasons):
        team_positions_df.loc[team_season, 'PC1'] = final_pos[idx, 0]
        team_positions_df.loc[team_season, 'PC2'] = final_pos[idx, 1]
    team_positions_df = team_positions_df.reset_index()
    return losses, team_positions_df, best_rank_scale, best_w_def, best_w_off

# ====================== 随机搜索超参数调整 ======================
def random_search_hyperparameters(team_positions, match_positions, w_def, w_off, n_iter=10, random_state=42):
    """随机搜索最佳超参数"""
    np.random.seed(random_state)
    best_loss, best_params = float('inf'), None

    for _ in range(n_iter):
        params = {
            'lambda_defense': np.random.uniform(0.01, 0.2),
            'lambda_offense': np.random.uniform(0.01, 0.2),
            'lambda_supervision': np.random.uniform(0.01, 0.2),
            'lambda_reg': np.random.uniform(0.001, 0.02)
        }
        print(f"\n随机搜索: {params}")

        losses, _, _, _, _ = adam_optimize_positions(
            team_positions.copy(), match_positions.copy(), w_def=w_def, w_off=w_off, **params
        )
        if losses and losses[-1] < best_loss:
            best_loss = losses[-1]
            best_params = params

    print(f"\n最佳超参数: {best_params}, 最佳损失: {best_loss:.4f}")
    return best_params

# ====================== 可视化函数 ======================
def visualize_team_evolution_by_league_static(team_positions_df, seasons_order):
    """按联赛可视化球队演变"""
    output_dir = "/Users/peixuanma/Downloads/Output_Graphs"
    os.makedirs(output_dir, exist_ok=True)

    for league in team_positions_df['league'].unique():
        league_df = team_positions_df[team_positions_df['league'] == league].copy()
        valid_teams = league_df.groupby("team_name").filter(lambda x: x['season'].nunique() == len(seasons_order))['team_name'].unique()
        if not valid_teams.size:
            valid_teams = league_df['team_name'].unique()
        valid_df = league_df[league_df['team_name'].isin(valid_teams)].sort_values(['team_name', 'season'])

        plt.figure(figsize=(10, 8))
        plt.title(f"{league} - 球队演变 (进攻-防守)")
        plt.xlabel("PC1 (进攻)")
        plt.ylabel("PC2 (防守)")
        plt.grid(True)

        for team in valid_df['team_name'].unique():
            sub = valid_df[valid_df['team_name'] == team]
            plt.plot(sub['PC1'], sub['PC2'], marker='o', label=team)
            for _, row in sub.iterrows():
                plt.text(row['PC1'], row['PC2'], row['season'], fontsize=8, ha='right')

        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        plt.tight_layout()
        filename = os.path.join(output_dir, f"{league}_evolution.png")
        plt.savefig(filename, dpi=150)
        plt.close()
        print(f"保存 {league} 图 -> {filename}")

# ====================== 主函数 ======================
if __name__ == "__main__":
    base_path = '/Users/peixuanma/Downloads/data1'
    leagues = [
        ("england", "premier-league"), ("germany", "bundesliga"), ("spain", "la-liga"),
        ("france", "ligue-1"), ("france", "ligue-2"), ("italy", "serie-a"), ("netherlands", "eredivisie"),
        ("portugal", "ligapro"), ("denmark", "superliga"), ("england", "championship"), ("spain", "segunda-division"),
        ("switzerland", "super-league"), ("portugal", "liga-nos"), ("italy", "serie-b"), ("germany", "2-bundesliga"),
        ("scotland", "premiership"), ("belgium", "pro-league"), ("austria", "bundesliga"),
    ]
    seasons = [
        "2013-to-2014", "2014-to-2015", "2015-to-2016", "2016-to-2017", "2017-to-2018",
        "2018-to-2019", "2019-to-2020", "2020-to-2021", "2021-to-2022", "2022-to-2023", "2023-to-2024"
    ]

    # 手动输入防守和进攻权重（示例值）
    w_def = np.array([
        0.12714323,  # ratio1
        0.11415731,  # ratio2
        0.04532705,  # ratio3
        0.23075414,  # ratio4
        0.03240472,  # ratio5
        0.14205644,  # ratio6
        0.13323908,  # total_goals_conceded
        0.17491804   # average_goals_conceded
    ], dtype=np.float32)

    w_off = np.array([
        0.07438711,  # off_ratio1
        0.07787083,  # off_ratio2
        0.08495551,  # off_ratio3
        0.22353454,  # off_ratio4
        0.08152269,  # off_ratio5
        0.08466186,  # off_ratio6
        0.16022788,  # total_goals_scored
        0.21283953   # average_goals_scored
    ], dtype=np.float32)

    # 加载数据
    print("===== 加载数据 =====")
    all_team_positions, all_match_positions = load_all_league_data(base_path, leagues, seasons)

    # 随机搜索超参数
    print("\n===== 随机搜索超参数 =====")
    best_params = random_search_hyperparameters(all_team_positions, all_match_positions, w_def, w_off)

    # 最终训练
    print("\n===== 最终训练 =====")
    final_losses, final_team_positions, final_rank_scale, final_w_def, final_w_off = adam_optimize_positions(
        all_team_positions.copy(), all_match_positions.copy(), w_def=w_def, w_off=w_off, **best_params
    )
    if final_losses:
        final_team_positions.to_csv("trained_team_positions.csv", index=False)
        print(f"最终损失: {final_losses[-1]:.4f}")
        print(f"最终防守权重: {final_w_def}")
        print(f"最终进攻权重: {final_w_off}")

    # 可视化
    print("\n===== 可视化 =====")
    visualize_team_evolution_by_league_static(final_team_positions, seasons)

    print("\n完成！")
# Out:
# scikit-learn 版本: 1.4.2
# ===== 加载数据 =====
# 加载数据: england - premier-league - 2013-to-2014
# 加载数据: england - premier-league - 2014-to-2015
# 加载数据: england - premier-league - 2015-to-2016
# 加载数据: england - premier-league - 2016-to-2017
# 加载数据: england - premier-league - 2017-to-2018
# 加载数据: england - premier-league - 2018-to-2019
# 加载数据: england - premier-league - 2019-to-2020
# 加载数据: england - premier-league - 2020-to-2021
# 加载数据: england - premier-league - 2021-to-2022
# 加载数据: england - premier-league - 2022-to-2023
# 加载数据: england - premier-league - 2023-to-2024
# 加载数据: germany - bundesliga - 2013-to-2014
# 加载数据: germany - bundesliga - 2014-to-2015
# 加载数据: germany - bundesliga - 2015-to-2016
# 加载数据: germany - bundesliga - 2016-to-2017
# 加载数据: germany - bundesliga - 2017-to-2018
# 加载数据: germany - bundesliga - 2018-to-2019
# 加载数据: germany - bundesliga - 2019-to-2020
# 加载数据: germany - bundesliga - 2020-to-2021
# 加载数据: germany - bundesliga - 2021-to-2022
# 加载数据: germany - bundesliga - 2022-to-2023
# 加载数据: germany - bundesliga - 2023-to-2024
# 加载数据: spain - la-liga - 2013-to-2014
# 加载数据: spain - la-liga - 2014-to-2015
# 加载数据: spain - la-liga - 2015-to-2016
# 加载数据: spain - la-liga - 2016-to-2017
# 加载数据: spain - la-liga - 2017-to-2018
# 加载数据: spain - la-liga - 2018-to-2019
# 加载数据: spain - la-liga - 2019-to-2020
# 加载数据: spain - la-liga - 2020-to-2021
# 加载数据: spain - la-liga - 2021-to-2022
# 加载数据: spain - la-liga - 2022-to-2023
# 加载数据: spain - la-liga - 2023-to-2024
# 加载数据: france - ligue-1 - 2013-to-2014
# 加载数据: france - ligue-1 - 2014-to-2015
# 加载数据: france - ligue-1 - 2015-to-2016
# 加载数据: france - ligue-1 - 2016-to-2017
# 加载数据: france - ligue-1 - 2017-to-2018
# 加载数据: france - ligue-1 - 2018-to-2019
# 加载数据: france - ligue-1 - 2019-to-2020
# 警告: france - ligue-1 - 2019-to-2020 文件缺失
# 加载数据: france - ligue-1 - 2020-to-2021
# 加载数据: france - ligue-1 - 2021-to-2022
# 加载数据: france - ligue-1 - 2022-to-2023
# 加载数据: france - ligue-1 - 2023-to-2024
# 加载数据: france - ligue-2 - 2013-to-2014
# 加载数据: france - ligue-2 - 2014-to-2015
# 加载数据: france - ligue-2 - 2015-to-2016
# 加载数据: france - ligue-2 - 2016-to-2017
# 加载数据: france - ligue-2 - 2017-to-2018
# 加载数据: france - ligue-2 - 2018-to-2019
# 加载数据: france - ligue-2 - 2019-to-2020
# 警告: france - ligue-2 - 2019-to-2020 文件缺失
# 加载数据: france - ligue-2 - 2020-to-2021
# 加载数据: france - ligue-2 - 2021-to-2022
# 加载数据: france - ligue-2 - 2022-to-2023
# 加载数据: france - ligue-2 - 2023-to-2024
# 加载数据: italy - serie-a - 2013-to-2014
# 加载数据: italy - serie-a - 2014-to-2015
# 加载数据: italy - serie-a - 2015-to-2016
# 加载数据: italy - serie-a - 2016-to-2017
# 加载数据: italy - serie-a - 2017-to-2018
# 加载数据: italy - serie-a - 2018-to-2019
# 加载数据: italy - serie-a - 2019-to-2020
# 加载数据: italy - serie-a - 2020-to-2021
# 加载数据: italy - serie-a - 2021-to-2022
# 加载数据: italy - serie-a - 2022-to-2023
# 加载数据: italy - serie-a - 2023-to-2024
# 加载数据: netherlands - eredivisie - 2013-to-2014
# 加载数据: netherlands - eredivisie - 2014-to-2015
# 加载数据: netherlands - eredivisie - 2015-to-2016
# 加载数据: netherlands - eredivisie - 2016-to-2017
# 加载数据: netherlands - eredivisie - 2017-to-2018
# 加载数据: netherlands - eredivisie - 2018-to-2019
# 加载数据: netherlands - eredivisie - 2019-to-2020
# 加载数据: netherlands - eredivisie - 2020-to-2021
# 加载数据: netherlands - eredivisie - 2021-to-2022
# 加载数据: netherlands - eredivisie - 2022-to-2023
# 加载数据: netherlands - eredivisie - 2023-to-2024
# 加载数据: portugal - ligapro - 2013-to-2014
# 警告: portugal - ligapro - 2013-to-2014 文件缺失
# 加载数据: portugal - ligapro - 2014-to-2015
# 加载数据: portugal - ligapro - 2015-to-2016
# 加载数据: portugal - ligapro - 2016-to-2017
# 加载数据: portugal - ligapro - 2017-to-2018
# 加载数据: portugal - ligapro - 2018-to-2019
# 加载数据: portugal - ligapro - 2019-to-2020
# 加载数据: portugal - ligapro - 2020-to-2021
# 加载数据: portugal - ligapro - 2021-to-2022
# 加载数据: portugal - ligapro - 2022-to-2023
# 加载数据: portugal - ligapro - 2023-to-2024
# 加载数据: denmark - superliga - 2013-to-2014
# 加载数据: denmark - superliga - 2014-to-2015
# 加载数据: denmark - superliga - 2015-to-2016
# 加载数据: denmark - superliga - 2016-to-2017
# 加载数据: denmark - superliga - 2017-to-2018
# 加载数据: denmark - superliga - 2018-to-2019
# 加载数据: denmark - superliga - 2019-to-2020
# 加载数据: denmark - superliga - 2020-to-2021
# 加载数据: denmark - superliga - 2021-to-2022
# 加载数据: denmark - superliga - 2022-to-2023
# 加载数据: denmark - superliga - 2023-to-2024
# 加载数据: england - championship - 2013-to-2014
# 加载数据: england - championship - 2014-to-2015
# 加载数据: england - championship - 2015-to-2016
# 加载数据: england - championship - 2016-to-2017
# 加载数据: england - championship - 2017-to-2018
# 加载数据: england - championship - 2018-to-2019
# 加载数据: england - championship - 2019-to-2020
# 加载数据: england - championship - 2020-to-2021
# 加载数据: england - championship - 2021-to-2022
# 加载数据: england - championship - 2022-to-2023
# 加载数据: england - championship - 2023-to-2024
# 加载数据: spain - segunda-division - 2013-to-2014
# 加载数据: spain - segunda-division - 2014-to-2015
# 加载数据: spain - segunda-division - 2015-to-2016
# 加载数据: spain - segunda-division - 2016-to-2017
# 加载数据: spain - segunda-division - 2017-to-2018
# 加载数据: spain - segunda-division - 2018-to-2019
# 加载数据: spain - segunda-division - 2019-to-2020
# 加载数据: spain - segunda-division - 2020-to-2021
# 加载数据: spain - segunda-division - 2021-to-2022
# 加载数据: spain - segunda-division - 2022-to-2023
# 加载数据: spain - segunda-division - 2023-to-2024
# 加载数据: switzerland - super-league - 2013-to-2014
# 加载数据: switzerland - super-league - 2014-to-2015
# 加载数据: switzerland - super-league - 2015-to-2016
# 加载数据: switzerland - super-league - 2016-to-2017
# 加载数据: switzerland - super-league - 2017-to-2018
# 加载数据: switzerland - super-league - 2018-to-2019
# 加载数据: switzerland - super-league - 2019-to-2020
# 加载数据: switzerland - super-league - 2020-to-2021
# 加载数据: switzerland - super-league - 2021-to-2022
# 加载数据: switzerland - super-league - 2022-to-2023
# 加载数据: switzerland - super-league - 2023-to-2024
# 加载数据: portugal - liga-nos - 2013-to-2014
# 加载数据: portugal - liga-nos - 2014-to-2015
# 加载数据: portugal - liga-nos - 2015-to-2016
# 加载数据: portugal - liga-nos - 2016-to-2017
# 加载数据: portugal - liga-nos - 2017-to-2018
# 加载数据: portugal - liga-nos - 2018-to-2019
# 加载数据: portugal - liga-nos - 2019-to-2020
# 加载数据: portugal - liga-nos - 2020-to-2021
# 加载数据: portugal - liga-nos - 2021-to-2022
# 加载数据: portugal - liga-nos - 2022-to-2023
# 加载数据: portugal - liga-nos - 2023-to-2024
# 加载数据: italy - serie-b - 2013-to-2014
# 加载数据: italy - serie-b - 2014-to-2015
# 加载数据: italy - serie-b - 2015-to-2016
# 加载数据: italy - serie-b - 2016-to-2017
# 加载数据: italy - serie-b - 2017-to-2018
# 加载数据: italy - serie-b - 2018-to-2019
# 加载数据: italy - serie-b - 2019-to-2020
# 加载数据: italy - serie-b - 2020-to-2021
# 加载数据: italy - serie-b - 2021-to-2022
# 加载数据: italy - serie-b - 2022-to-2023
# 加载数据: italy - serie-b - 2023-to-2024
# 加载数据: germany - 2-bundesliga - 2013-to-2014
# 加载数据: germany - 2-bundesliga - 2014-to-2015
# 加载数据: germany - 2-bundesliga - 2015-to-2016
# 加载数据: germany - 2-bundesliga - 2016-to-2017
# 加载数据: germany - 2-bundesliga - 2017-to-2018
# 加载数据: germany - 2-bundesliga - 2018-to-2019
# 加载数据: germany - 2-bundesliga - 2019-to-2020
# 加载数据: germany - 2-bundesliga - 2020-to-2021
# 加载数据: germany - 2-bundesliga - 2021-to-2022
# 加载数据: germany - 2-bundesliga - 2022-to-2023
# 加载数据: germany - 2-bundesliga - 2023-to-2024
# 加载数据: scotland - premiership - 2013-to-2014
# 加载数据: scotland - premiership - 2014-to-2015
# 加载数据: scotland - premiership - 2015-to-2016
# 加载数据: scotland - premiership - 2016-to-2017
# 加载数据: scotland - premiership - 2017-to-2018
# 加载数据: scotland - premiership - 2018-to-2019
# 加载数据: scotland - premiership - 2019-to-2020
# 加载数据: scotland - premiership - 2020-to-2021
# 加载数据: scotland - premiership - 2021-to-2022
# 加载数据: scotland - premiership - 2022-to-2023
# 加载数据: scotland - premiership - 2023-to-2024
# 加载数据: belgium - pro-league - 2013-to-2014
# 警告: belgium - pro-league - 2013-to-2014 文件缺失
# 加载数据: belgium - pro-league - 2014-to-2015
# 警告: belgium - pro-league - 2014-to-2015 文件缺失
# 加载数据: belgium - pro-league - 2015-to-2016
# 加载数据: belgium - pro-league - 2016-to-2017
# 加载数据: belgium - pro-league - 2017-to-2018
# 加载数据: belgium - pro-league - 2018-to-2019
# 加载数据: belgium - pro-league - 2019-to-2020
# 加载数据: belgium - pro-league - 2020-to-2021
# 加载数据: belgium - pro-league - 2021-to-2022
# 加载数据: belgium - pro-league - 2022-to-2023
# 加载数据: belgium - pro-league - 2023-to-2024
# 加载数据: austria - bundesliga - 2013-to-2014
# 加载数据: austria - bundesliga - 2014-to-2015
# 加载数据: austria - bundesliga - 2015-to-2016
# 加载数据: austria - bundesliga - 2016-to-2017
# 加载数据: austria - bundesliga - 2017-to-2018
# 加载数据: austria - bundesliga - 2018-to-2019
# 加载数据: austria - bundesliga - 2019-to-2020
# 加载数据: austria - bundesliga - 2020-to-2021
# 加载数据: austria - bundesliga - 2021-to-2022
# 加载数据: austria - bundesliga - 2022-to-2023
# 加载数据: austria - bundesliga - 2023-to-2024
#
# ===== 随机搜索超参数 =====
#
# 随机搜索: {'lambda_defense': 0.08116262258099888, 'lambda_offense': 0.19063571821788408, 'lambda_supervision': 0.14907884894416698, 'lambda_reg': 0.012374511199743695}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_25839/2937681765.py in ?()
#     583     all_team_positions, all_match_positions = load_all_league_data(base_path, leagues, seasons)
#     584
#     585     # 随机搜索超参数
#     586     print("\n===== 随机搜索超参数 =====")
# --> 587     best_params = random_search_hyperparameters(all_team_positions, all_match_positions, w_def, w_off)
#     588
#     589     # 最终训练
#     590     print("\n===== 最终训练 =====")
#
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_25839/2937681765.py in ?(team_positions, match_positions, w_def, w_off, n_iter, random_state)
#     497             'lambda_reg': np.random.uniform(0.001, 0.02)
#     498         }
#     499         print(f"\n随机搜索: {params}")
#     500
# --> 501         losses, _, _, _, _ = adam_optimize_positions(
#     502             team_positions.copy(), match_positions.copy(), w_def=w_def, w_off=w_off, **params
#     503         )
#     504         if losses and losses[-1] < best_loss:
#
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_25839/2937681765.py in ?(team_positions_df, match_positions_df, initial_lr, decay_steps, decay_rate, clipnorm, iterations, verbose_interval, random_seed, lambda_defense, lambda_offense, lambda_supervision, lambda_reg, w_def, w_off)
#     451     best_positions, best_rank_scale, best_w_def, best_w_off = positions.numpy().copy(), 1.0, w_def.numpy().copy(), w_off.numpy().copy()
#     452
#     453     for i in range(iterations):
#     454         with tf.GradientTape() as tape:
# --> 455             loss = compute_total_loss(positions, match_home_idx, match_away_idx, match_PC1, match_PC2, points_per_game,
#     456                                       rank_scale, def_ratios, w_def, off_ratios, w_off, normalized_defense_score,
#     457                                       lambda_defense, lambda_offense, lambda_supervision, lambda_reg, elo_scores,
#     458                                       home_away_ratios, match_positions_df)
#
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_25839/2937681765.py in ?(positions, match_home_idx, match_away_idx, match_PC1, match_PC2, points_per_game, rank_scale, def_ratios, w_def, off_ratios, w_off, normalized_defense_score, lambda_defense, lambda_offense, lambda_supervision, lambda_reg, elo_scores, home_away_ratios, match_positions_df)
#     363         away_ratio = home_away_ratios.get(away_key, 1.0)
#     364         if home_elo[i] > away_elo[i]:
#     365             adjusted_dist_away.append(dist_away_norm[i] * away_ratio * elo_diff[i])
#     366         else:
# --> 367             adjusted_dist_away.append(dist_away_norm[i] * away_ratio / (elo_diff[i] + epsilon))
#     368
#     369     adjusted_dist_home = tf.stack(adjusted_dist_home)
#     370     adjusted_dist_away = tf.stack(adjusted_dist_away)
#
# /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/ops/tensor_getitem_override.py in ?(tensor, slice_spec, var)
#     252           packed_strides = gen_math_ops.cast(packed_strides, dtypes.int16)
#     253     else:
#     254       var_empty = constant_op.constant([], dtype=dtypes.int32)
#     255       packed_begin = packed_end = packed_strides = var_empty
# --> 256     return array_ops.strided_slice(
#     257         tensor,
#     258         packed_begin,
#     259         packed_end,
#
# /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/ops/array_ops.py in ?(input_, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, var, name)
#    1093
#    1094   if strides is None:
#    1095     strides = ones_like(begin)
#    1096
# -> 1097   op = gen_array_ops.strided_slice(
#    1098       input=input_,
#    1099       begin=begin,
#    1100       end=end,
#
# /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/ops/gen_array_ops.py in ?(input, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, name)
#   11010         "new_axis_mask", new_axis_mask, "shrink_axis_mask", shrink_axis_mask)
#   11011       return _result
#   11012     except _core._NotOkStatusException as e:
#   11013       _ops.raise_from_not_ok_status(e, name)
# > 11014     except _core._FallbackException:
#   11015       pass
#   11016     try:
#   11017       return strided_slice_eager_fallback(
#
# KeyboardInterrupt:

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.model_selection import KFold
import sklearn

print(f"scikit-learn 版本: {sklearn.__version__}")

# ====================== 计算防守统计数据 ======================
def compute_defensive_stats(match_df, team_positions_df):
    """计算球队的防守统计数据，包括6种比率、总失球数和平均失球数"""
    epsilon = 1e-8  # 提高数值稳定性
    team_stats = {}
    for team in team_positions_df['team_name'].unique():
        team_stats[team] = {
            'total_goals_conceded': 0, 'ratio1_list': [], 'ratio2_list': [], 'ratio3_list': [],
            'ratio4_list': [], 'ratio5_list': [], 'ratio6_list': [], 'num_matches': 0
        }

    # 主场比赛统计
    for idx, row in match_df.iterrows():
        home_team, away_team = row['home_team_name'], row['away_team_name']
        if home_team not in team_stats or away_team not in team_stats:
            print(f"警告: 主队 {home_team} 或客队 {away_team} 未找到，跳过比赛 {idx}")
            continue
        if row['Pre-Match PPG (Away)'] > 0:
            team_stats[home_team]['ratio1_list'].append(
                row['away_team_goal_count'] / (row['Pre-Match PPG (Away)'] + epsilon))
        if row['away_team_corner_count'] > 0:
            team_stats[home_team]['ratio2_list'].append(
                row['away_team_goal_count'] / (row['away_team_corner_count'] + epsilon))
        denominator = row['home_team_yellow_cards'] + row['home_team_red_cards'] + row['home_team_fouls'] + epsilon
        team_stats[home_team]['ratio3_list'].append(row['away_team_goal_count'] / denominator)
        if row['team_b_xg'] > 0:
            team_stats[home_team]['ratio4_list'].append(row['away_team_goal_count'] / (row['team_b_xg'] + epsilon))
        shots_total = row['away_team_shots_on_target'] + row['away_team_shots_off_target'] + epsilon
        team_stats[home_team]['ratio5_list'].append(row['away_team_goal_count'] / shots_total)
        if row['away_team_possession'] > 0:
            team_stats[home_team]['ratio6_list'].append(
                row['away_team_goal_count'] / (row['away_team_possession'] + epsilon))
        team_stats[home_team]['total_goals_conceded'] += row['away_team_goal_count']
        team_stats[home_team]['num_matches'] += 1

    # 客场比赛统计
    for idx, row in match_df.iterrows():
        away_team = row['away_team_name']
        if away_team not in team_stats:
            print(f"警告: 客队 {away_team} 未找到，跳过比赛 {idx}")
            continue
        team_stats[away_team]['total_goals_conceded'] += row['home_team_goal_count']
        team_stats[away_team]['num_matches'] += 1

    # 汇总数据
    data = []
    for team, stats in team_stats.items():
        num_matches = stats['num_matches']
        average_goals_conceded = stats['total_goals_conceded'] / num_matches if num_matches > 0 else 0
        data.append({
            'team_name': team,
            'ratio1': np.mean(stats['ratio1_list']) if stats['ratio1_list'] else 0,
            'ratio2': np.mean(stats['ratio2_list']) if stats['ratio2_list'] else 0,
            'ratio3': np.mean(stats['ratio3_list']) if stats['ratio3_list'] else 0,
            'ratio4': np.mean(stats['ratio4_list']) if stats['ratio4_list'] else 0,
            'ratio5': np.mean(stats['ratio5_list']) if stats['ratio5_list'] else 0,
            'ratio6': np.mean(stats['ratio6_list']) if stats['ratio6_list'] else 0,
            'total_goals_conceded': stats['total_goals_conceded'],
            'average_goals_conceded': average_goals_conceded
        })

    return pd.DataFrame(data)

# ====================== 计算进攻统计数据 ======================
def compute_offensive_stats(match_df, team_positions_df):
    """计算球队的进攻统计数据，包括6种比率、总进球数和平均进球数"""
    epsilon = 1e-8  # 提高数值稳定性
    team_stats = {}
    for team in team_positions_df['team_name'].unique():
        team_stats[team] = {
            'total_goals_scored': 0, 'off_ratio1_list': [], 'off_ratio2_list': [], 'off_ratio3_list': [],
            'off_ratio4_list': [], 'off_ratio5_list': [], 'off_ratio6_list': [], 'num_matches': 0
        }

    # 主场比赛统计
    for idx, row in match_df.iterrows():
        home_team, away_team = row['home_team_name'], row['away_team_name']
        if home_team not in team_stats or away_team not in team_stats:
            continue
        if row['Pre-Match PPG (Home)'] > 0:
            team_stats[home_team]['off_ratio1_list'].append(
                row['home_team_goal_count'] / (row['Pre-Match PPG (Home)'] + epsilon))
        if row['home_team_corner_count'] > 0:
            team_stats[home_team]['off_ratio2_list'].append(
                row['home_team_goal_count'] / (row['home_team_corner_count'] + epsilon))
        denominator = row['away_team_yellow_cards'] + row['away_team_red_cards'] + row['away_team_fouls'] + epsilon
        team_stats[home_team]['off_ratio3_list'].append(row['home_team_goal_count'] / denominator)
        if row['team_a_xg'] > 0:
            team_stats[home_team]['off_ratio4_list'].append(row['home_team_goal_count'] / (row['team_a_xg'] + epsilon))
        shots_total = row['home_team_shots_on_target'] + row['home_team_shots_off_target'] + epsilon
        team_stats[home_team]['off_ratio5_list'].append(row['home_team_goal_count'] / shots_total)
        if row['home_team_possession'] > 0:
            team_stats[home_team]['off_ratio6_list'].append(
                row['home_team_goal_count'] / (row['home_team_possession'] + epsilon))
        team_stats[home_team]['total_goals_scored'] += row['home_team_goal_count']
        team_stats[home_team]['num_matches'] += 1

    # 客场比赛统计
    for idx, row in match_df.iterrows():
        away_team = row['away_team_name']
        if away_team not in team_stats:
            continue
        team_stats[away_team]['total_goals_scored'] += row['away_team_goal_count']
        team_stats[away_team]['num_matches'] += 1

    # 汇总数据
    data = []
    for team, stats in team_stats.items():
        num_matches = stats['num_matches']
        average_goals_scored = stats['total_goals_scored'] / num_matches if num_matches > 0 else 0
        data.append({
            'team_name': team,
            'off_ratio1': np.mean(stats['off_ratio1_list']) if stats['off_ratio1_list'] else 0,
            'off_ratio2': np.mean(stats['off_ratio2_list']) if stats['off_ratio2_list'] else 0,
            'off_ratio3': np.mean(stats['off_ratio3_list']) if stats['off_ratio3_list'] else 0,
            'off_ratio4': np.mean(stats['off_ratio4_list']) if stats['off_ratio4_list'] else 0,
            'off_ratio5': np.mean(stats['off_ratio5_list']) if stats['off_ratio5_list'] else 0,
            'off_ratio6': np.mean(stats['off_ratio6_list']) if stats['off_ratio6_list'] else 0,
            'total_goals_scored': stats['total_goals_scored'],
            'average_goals_scored': average_goals_scored
        })

    return pd.DataFrame(data)

# ====================== ELO评分算法实现 ======================
def initialize_elo_scores(team_positions_df):
    """初始化球队ELO分数"""
    teams = team_positions_df['team_name'].unique().tolist()
    team_elo = {team: 1500 for team in teams}
    for team in teams:
        team_data = team_positions_df[team_positions_df['team_name'] == team]
        rank = team_data['points_per_game'].rank().iloc[0]
        team_elo[team] += (20 * (len(teams) - rank))
    return team_elo

def update_elo_scores(elo_scores, home_team, away_team, home_score, away_score, K=30):
    """更新ELO分数"""
    home_elo, away_elo = elo_scores[home_team], elo_scores[away_team]
    expected_home = 1 / (1 + 10 ** ((away_elo - home_elo) / 400))
    expected_away = 1 / (1 + 10 ** ((home_elo - away_elo) / 400))

    if home_score > away_score:
        elo_scores[home_team] += K * (1 - expected_home)
        elo_scores[away_team] += K * (0 - expected_away)
    elif home_score < away_score:
        elo_scores[home_team] += K * (0 - expected_home)
        elo_scores[away_team] += K * (1 - expected_away)
    else:
        elo_scores[home_team] += K * (0.5 - expected_home)
        elo_scores[away_team] += K * (0.5 - expected_away)
    return elo_scores

# ====================== 数据加载函数（含聚类） ======================
def load_all_league_data(base_path, leagues, seasons):
    """加载所有联赛数据并进行预处理，使用聚类质心作为比赛锚点"""
    all_team_positions, all_match_positions = [], []
    global_cluster_centroid_positions = {}

    for country_name, league_name in leagues:
        for season in seasons:
            print(f"加载数据: {country_name} - {league_name} - {season}")
            team_file = os.path.join(base_path, f"{country_name}-{league_name}-teams-{season}-stats.csv")
            match_file = os.path.join(base_path, f"{country_name}-{league_name}-matches-{season}-stats.csv")
            if not os.path.exists(team_file) or not os.path.exists(match_file):
                print(f"警告: {country_name} - {league_name} - {season} 文件缺失")
                continue

            team_df = pd.read_csv(team_file)
            match_df = pd.read_csv(match_file)

            # 统一球队名称格式
            team_df['team_name'] = team_df.get('common_name', team_df.get('team_name', None)).str.strip().str.lower()
            match_df['home_team_name'] = match_df['home_team_name'].str.strip().str.lower()
            match_df['away_team_name'] = match_df['away_team_name'].str.strip().str.lower()

            team_names = team_df['team_name'].unique()
            original_match_count = len(match_df)
            match_df = match_df[
                match_df['home_team_name'].isin(team_names) & match_df['away_team_name'].isin(team_names)]
            if len(match_df) < original_match_count:
                print(f"警告: 过滤了 {original_match_count - len(match_df)} 场比赛")

            if match_df.empty:
                print("警告: 无有效比赛数据")
                continue

            # 计算防守和进攻统计
            defensive_stats_df = compute_defensive_stats(match_df, team_df)
            offensive_stats_df = compute_offensive_stats(match_df, team_df)
            if defensive_stats_df.empty or offensive_stats_df.empty:
                print("警告: 未计算出防守或进攻统计")
                continue

            team_df = team_df.merge(defensive_stats_df, on='team_name', how='left')
            team_df = team_df.merge(offensive_stats_df, on='team_name', how='left')

            for col in ['ratio1', 'ratio2', 'ratio3', 'ratio4', 'ratio5', 'ratio6', 'total_goals_conceded', 'average_goals_conceded',
                        'off_ratio1', 'off_ratio2', 'off_ratio3', 'off_ratio4', 'off_ratio5', 'off_ratio6', 'total_goals_scored', 'average_goals_scored']:
                if col not in team_df.columns:
                    print(f"警告: {col} 列缺失，设为0")
                    team_df[col] = 0

            # 归一化防守得分（修复拼写错误）
            if 'total_goals_conceded' in team_df.columns and team_df['total_goals_conceded'].max() != team_df['total_goals_conceded'].min():
                team_df['normalized_defense_score'] = (team_df['total_goals_conceded'].max() - team_df['total_goals_conceded']) / (
                    team_df['total_goals_conceded'].max() - team_df['total_goals_conceded'].min() + 1e-8)
            else:
                team_df['normalized_defense_score'] = 0  # 修复变量名

            # PCA降维（防守和进攻数据）
            defensive_columns = ['total_goals_conceded', 'ratio1', 'ratio2', 'ratio3', 'ratio4', 'ratio5', 'ratio6', 'average_goals_conceded']
            offensive_columns = ['total_goals_scored', 'off_ratio1', 'off_ratio2', 'off_ratio3', 'off_ratio4', 'off_ratio5', 'off_ratio6', 'average_goals_scored']
            team_df_defensive = team_df[defensive_columns].fillna(0)
            kf = KFold(n_splits=5, shuffle=True, random_state=42)
            pca_results = []
            for train_idx, _ in kf.split(team_df_defensive):
                train_data = team_df_defensive.iloc[train_idx]
                scaler = StandardScaler()
                X_scaled = scaler.fit_transform(train_data)
                pca = PCA(n_components=2)
                X_pca = pca.fit_transform(X_scaled)
                pca_results.append(X_pca)
            X_pca_avg = np.mean([np.pad(r, ((0, len(team_df_defensive) - len(r)), (0, 0)), 'constant') for r in pca_results], axis=0)

            team_positions = pd.DataFrame({
                'team_name': team_df['team_name'], 'PC1': X_pca_avg[:, 0], 'PC2': X_pca_avg[:, 1],
                'points_per_game': team_df['points_per_game'], 'league': league_name, 'season': season,
                'ratio1': team_df['ratio1'], 'ratio2': team_df['ratio2'], 'ratio3': team_df['ratio3'],
                'ratio4': team_df['ratio4'], 'ratio5': team_df['ratio5'], 'ratio6': team_df['ratio6'],
                'off_ratio1': team_df['off_ratio1'], 'off_ratio2': team_df['off_ratio2'], 'off_ratio3': team_df['off_ratio3'],
                'off_ratio4': team_df['off_ratio4'], 'off_ratio5': team_df['off_ratio5'], 'off_ratio6': team_df['off_ratio6'],
                'normalized_defense_score': team_df['normalized_defense_score'],
                'total_goals_conceded': team_df['total_goals_conceded'],
                'average_goals_conceded': team_df['average_goals_conceded'],
                'total_goals_scored': team_df['total_goals_scored'],
                'average_goals_scored': team_df['average_goals_scored']
            })
            team_positions['team_season'] = league_name + '_' + team_positions['team_name'] + '_' + team_positions['season']
            all_team_positions.append(team_positions)

            # 比赛数据聚类
            match_df = match_df.drop(columns=['timestamp', 'date_GMT', 'status', 'attendance', 'referee', 'stadium_name', 'Game Week'], errors='ignore')
            numeric_cols = match_df.select_dtypes(include=[np.number]).columns
            match_df[numeric_cols] = match_df[numeric_cols].fillna(match_df[numeric_cols].mean())
            scaler = StandardScaler()
            X_scaled = scaler.fit_transform(match_df[numeric_cols])

            # 选择最佳簇数 k
            silhouette_scores = []
            max_k = min(10, len(X_scaled) // 2)
            for k in range(2, max_k + 1):
                kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
                cluster_labels = kmeans.fit_predict(X_scaled)
                silhouette_avg = silhouette_score(X_scaled, cluster_labels)
                silhouette_scores.append(silhouette_avg)
            if silhouette_scores:
                best_k = np.argmax(silhouette_scores) + 2
            else:
                best_k = 2

            # 聚类
            kmeans = KMeans(n_clusters=best_k, random_state=42, n_init=10)
            cluster_labels = kmeans.fit_predict(X_scaled)
            match_df['cluster_id'] = cluster_labels

            # 计算簇质心并降维
            centroids = kmeans.cluster_centers_
            if len(centroids) > 0:
                pca_centroids = PCA(n_components=2).fit_transform(centroids)
                cluster_centroid_positions = {i: pca_centroids[i] for i in range(best_k)}
                global_cluster_centroid_positions[f"{league_name}_{season}"] = cluster_centroid_positions

            # 存储比赛数据
            match_positions = pd.DataFrame({
                'home_team_name': match_df['home_team_name'], 'away_team_name': match_df['away_team_name'],
                'cluster_id': match_df['cluster_id'], 'league': league_name, 'season': season
            })
            all_match_positions.append(match_positions)

    return pd.concat(all_team_positions, ignore_index=True), pd.concat(all_match_positions, ignore_index=True), global_cluster_centroid_positions

# ====================== 损失函数 ======================
def compute_total_loss(positions, match_home_idx, match_away_idx, match_cluster_ids, cluster_centroid_positions, points_per_game, rank_scale,
                       def_ratios, w_def, off_ratios, w_off, normalized_defense_score, lambda_defense, lambda_offense,
                       lambda_supervision, lambda_reg, elo_scores):
    """计算总损失，包括匹配损失、防守损失、进攻损失和监督损失"""
    epsilon = 1e-8
    if tf.shape(match_home_idx)[0] == 0:
        return tf.constant(0.0, dtype=tf.float32)

    # 匹配损失
    home_pos = tf.gather(positions, match_home_idx)
    away_pos = tf.gather(positions, match_away_idx)
    match_target_pos = tf.gather(cluster_centroid_positions, match_cluster_ids)
    dist_home = tf.norm(home_pos - match_target_pos + epsilon, axis=1)
    dist_away = tf.norm(away_pos - match_target_pos + epsilon, axis=1)
    all_distances = tf.concat([dist_home, dist_away], axis=0)
    dist_range = tf.reduce_max(all_distances) - tf.reduce_min(all_distances) + epsilon
    dist_home_norm = (dist_home - tf.reduce_min(all_distances)) / dist_range
    dist_away_norm = (dist_away - tf.reduce_min(all_distances)) / dist_range

    home_elo = tf.gather(elo_scores, match_home_idx)
    away_elo = tf.gather(elo_scores, match_away_idx)
    elo_diff = tf.abs(home_elo - away_elo)
    weight = 1.0 / (1.0 + elo_diff * rank_scale + epsilon)
    match_loss = tf.reduce_mean(weight * (dist_home_norm + dist_away_norm))

    # 防守损失
    w_def = tf.abs(w_def)
    defense_target = -tf.reduce_sum(w_def * def_ratios, axis=1)
    defense_loss = tf.reduce_mean(tf.square(positions[:, 1] - defense_target))

    # 进攻损失
    w_off = tf.abs(w_off)
    offense_target = tf.reduce_sum(w_off * off_ratios, axis=1)
    offense_loss = tf.reduce_mean(tf.square(positions[:, 0] - offense_target))

    # 监督损失
    supervision_loss = tf.reduce_mean(tf.square(defense_target - normalized_defense_score))

    # 正则化
    regularization_loss = lambda_reg * (tf.reduce_sum(tf.square(w_def)) + tf.reduce_sum(tf.square(w_off)))

    total_loss = (match_loss + lambda_defense * defense_loss + lambda_offense * offense_loss +
                  lambda_supervision * supervision_loss + regularization_loss)
    return tf.where(tf.math.is_nan(total_loss) | tf.math.is_inf(total_loss), 0.0, total_loss)

# ====================== Adam优化函数 ======================
def adam_optimize_positions(team_positions_df, match_positions_df, cluster_centroid_positions, initial_lr=0.001, decay_steps=20000, decay_rate=0.9,
                            clipnorm=0.5, iterations=100000, verbose_interval=1000, random_seed=42, lambda_defense=0.1,
                            lambda_offense=0.1, lambda_supervision=0.1, lambda_reg=0.01, w_def=None, w_off=None):
    """使用Adam优化球队位置"""
    team_seasons = team_positions_df['team_season'].unique()
    team_season_to_idx = {t: i for i, t in enumerate(team_seasons)}

    elo_scores_dict = initialize_elo_scores(team_positions_df)
    team_names = [t.split('_')[1] for t in team_seasons]
    elo_scores = tf.convert_to_tensor([elo_scores_dict[name] for name in team_names], dtype=tf.float32)

    team_positions_df = team_positions_df.set_index('team_season')
    init_positions = team_positions_df[['PC1', 'PC2']].values
    def_ratios = team_positions_df[['ratio1', 'ratio2', 'ratio3', 'ratio4', 'ratio5', 'ratio6', 'total_goals_conceded', 'average_goals_conceded']].values
    off_ratios = team_positions_df[['off_ratio1', 'off_ratio2', 'off_ratio3', 'off_ratio4', 'off_ratio5', 'off_ratio6', 'total_goals_scored', 'average_goals_scored']].values

    scaler_pos = StandardScaler()
    scaler_def = StandardScaler()
    scaler_off = StandardScaler()
    positions_scaled = scaler_pos.fit_transform(init_positions)
    def_ratios_scaled = scaler_def.fit_transform(def_ratios)
    off_ratios_scaled = scaler_off.fit_transform(off_ratios)

    positions = tf.Variable(positions_scaled, dtype=tf.float32)
    def_ratios = tf.constant(def_ratios_scaled, dtype=tf.float32)
    off_ratios = tf.constant(off_ratios_scaled, dtype=tf.float32)
    normalized_defense_score = tf.constant(team_positions_df['normalized_defense_score'].values, dtype=tf.float32)
    points_per_game = tf.constant(team_positions_df['points_per_game'].values, dtype=tf.float32)

    match_array = []
    for _, row in match_positions_df.iterrows():
        home_key = f"{row['league']}_{row['home_team_name']}_{row['season']}"
        away_key = f"{row['league']}_{row['away_team_name']}_{row['season']}"
        if home_key in team_season_to_idx and away_key in team_season_to_idx:
            match_array.append([team_season_to_idx[home_key], team_season_to_idx[away_key], row['cluster_id']])
    match_array = np.array(match_array, dtype=np.float32)
    if len(match_array) == 0:
        print("警告: 无有效比赛数据")
        return [], team_positions_df.reset_index(), None, None, None

    match_home_idx = tf.constant(match_array[:, 0], dtype=tf.int32)
    match_away_idx = tf.constant(match_array[:, 1], dtype=tf.int32)
    match_cluster_ids = tf.constant(match_array[:, 2], dtype=tf.int32)

    # 将所有联赛和赛季的簇质心合并为一个张量
    all_centroids = []
    cluster_id_map = {}
    current_id = 0
    for league_season, centroids_dict in cluster_centroid_positions.items():
        for cid, pos in centroids_dict.items():
            cluster_id_map[(league_season, cid)] = current_id
            all_centroids.append(pos)
            current_id += 1
    cluster_centroid_positions_tf = tf.constant(np.array(all_centroids), dtype=tf.float32)

    # 调整 match_cluster_ids 以匹配全局 cluster_id
    adjusted_cluster_ids = []
    for _, row in match_positions_df.iterrows():
        league_season = f"{row['league']}_{row['season']}"
        if league_season in cluster_centroid_positions and row['cluster_id'] in cluster_centroid_positions[league_season]:
            adjusted_cluster_ids.append(cluster_id_map[(league_season, row['cluster_id'])])
    match_cluster_ids = tf.constant(adjusted_cluster_ids, dtype=tf.int32)

    tf.random.set_seed(random_seed)
    rank_scale = tf.Variable(1.0, dtype=tf.float32)
    w_def = tf.Variable(np.abs(w_def) if w_def is not None else np.ones(8, dtype=np.float32) / 8, dtype=tf.float32)
    w_off = tf.Variable(np.abs(w_off) if w_off is not None else np.ones(8, dtype=np.float32) / 8, dtype=tf.float32)
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(initial_lr, decay_steps, decay_rate)
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule, clipnorm=clipnorm)

    losses, best_loss = [], float('inf')
    best_positions, best_rank_scale, best_w_def, best_w_off = positions.numpy().copy(), 1.0, w_def.numpy().copy(), w_off.numpy().copy()

    for i in range(iterations):
        with tf.GradientTape() as tape:
            loss = compute_total_loss(positions, match_home_idx, match_away_idx, match_cluster_ids, cluster_centroid_positions_tf, points_per_game,
                                      rank_scale, def_ratios, w_def, off_ratios, w_off, normalized_defense_score,
                                      lambda_defense, lambda_offense, lambda_supervision, lambda_reg, elo_scores)
        grads = tape.gradient(loss, [positions, rank_scale, w_def, w_off])
        if any(g is None for g in grads):
            print(f"警告: 迭代 {i + 1} 梯度为None")
            continue
        optimizer.apply_gradients(zip(grads, [positions, rank_scale, w_def, w_off]))
        loss_val = float(loss.numpy())
        losses.append(loss_val)

        if loss_val < best_loss:
            best_loss = loss_val
            best_positions, best_rank_scale, best_w_def, best_w_off = (positions.numpy().copy(), float(rank_scale.numpy()),
                                                                       w_def.numpy().copy(), w_off.numpy().copy())

        if (i + 1) % verbose_interval == 0:
            print(f"迭代 {i + 1}/{iterations}, 损失 = {loss_val:.4f}, rank_scale = {rank_scale.numpy():.4f}, 最佳损失 = {best_loss:.4f}")

    positions.assign(best_positions)
    rank_scale.assign(best_rank_scale)
    w_def.assign(best_w_def)
    w_off.assign(best_w_off)
    final_pos = scaler_pos.inverse_transform(positions.numpy())
    for idx, team_season in enumerate(team_seasons):
        team_positions_df.loc[team_season, 'PC1'] = final_pos[idx, 0]
        team_positions_df.loc[team_season, 'PC2'] = final_pos[idx, 1]
    team_positions_df = team_positions_df.reset_index()
    return losses, team_positions_df, best_rank_scale, best_w_def, best_w_off

# ====================== 随机搜索超参数函数 ======================
def random_search_hyperparameters(team_positions, match_positions, cluster_centroid_positions, w_def, w_off, n_iter=10, random_state=42):
    """随机搜索最佳超参数"""
    np.random.seed(random_state)
    best_loss, best_params = float('inf'), None

    for _ in range(n_iter):
        params = {
            'lambda_defense': np.random.uniform(0.01, 0.2),
            'lambda_offense': np.random.uniform(0.01, 0.2),
            'lambda_supervision': np.random.uniform(0.01, 0.2),
            'lambda_reg': np.random.uniform(0.001, 0.02)
        }
        print(f"\n随机搜索: {params}")

        losses, _, _, _, _ = adam_optimize_positions(
            team_positions.copy(), match_positions.copy(), cluster_centroid_positions, w_def=w_def, w_off=w_off, **params
        )
        if losses and losses[-1] < best_loss:
            best_loss = losses[-1]
            best_params = params

    print(f"\n最佳超参数: {best_params}, 最佳损失: {best_loss:.4f}")
    return best_params

# ====================== 可视化函数 ======================
def visualize_team_evolution_by_league_static(team_positions_df, seasons_order):
    """按联赛可视化球队演变"""
    output_dir = "/Users/peixuanma/Downloads/Output_Graphs"
    os.makedirs(output_dir, exist_ok=True)

    for league in team_positions_df['league'].unique():
        league_df = team_positions_df[team_positions_df['league'] == league].copy()
        valid_teams = league_df.groupby("team_name").filter(lambda x: x['season'].nunique() == len(seasons_order))['team_name'].unique()
        if not valid_teams.size:
            valid_teams = league_df['team_name'].unique()
        valid_df = league_df[league_df['team_name'].isin(valid_teams)].sort_values(['team_name', 'season'])

        plt.figure(figsize=(10, 8))
        plt.title(f"{league} - 球队演变 (进攻-防守)")
        plt.xlabel("PC1 (进攻)")
        plt.ylabel("PC2 (防守)")
        plt.grid(True)

        for team in valid_df['team_name'].unique():
            sub = valid_df[valid_df['team_name'] == team]
            if 'PC1' in sub.columns and 'PC2' in sub.columns:
                plt.plot(sub['PC1'], sub['PC2'], marker='o', label=team)
                for _, row in sub.iterrows():
                    plt.text(row['PC1'], row['PC2'], row['season'], fontsize=8, ha='right')

        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        plt.tight_layout()
        filename = os.path.join(output_dir, f"{league}_evolution.png")
        plt.savefig(filename, dpi=150)
        plt.close()
        print(f"保存 {league} 图 -> {filename}")

# ====================== 主函数 ======================
if __name__ == "__main__":
    base_path = '/Users/peixuanma/Downloads/data1'
    leagues = [
        ("england", "premier-league"), ("germany", "bundesliga"), ("spain", "la-liga"),
        ("france", "ligue-1"), ("france", "ligue-2"), ("italy", "serie-a"), ("netherlands", "eredivisie"),
        ("portugal", "ligapro"), ("denmark", "superliga"), ("england", "championship"), ("spain", "segunda-division"),
        ("switzerland", "super-league"), ("portugal", "liga-nos"), ("italy", "serie-b"), ("germany", "2-bundesliga"),
        ("scotland", "premiership"), ("belgium", "pro-league"), ("austria", "bundesliga"),
    ]
    seasons = [
        "2013-to-2014", "2014-to-2015", "2015-to-2016", "2016-to-2017", "2017-to-2018",
        "2018-to-2019", "2019-to-2020", "2020-to-2021", "2021-to-2022", "2022-to-2023", "2023-to-2024"
    ]

    # 手动输入防守和进攻权重（示例值）
    w_def = np.array([
        0.12714323, 0.11415731, 0.04532705, 0.23075414, 0.03240472, 0.14205644, 0.13323908, 0.17491804
    ], dtype=np.float32)

    w_off = np.array([
        0.07438711, 0.07787083, 0.08495551, 0.22353454, 0.08152269, 0.08466186, 0.16022788, 0.21283953
    ], dtype=np.float32)

    # 加载数据
    print("===== 加载数据 =====")
    all_team_positions, all_match_positions, cluster_centroid_positions = load_all_league_data(base_path, leagues, seasons)

    # 随机搜索超参数
    print("\n===== 随机搜索超参数 =====")
    best_params = random_search_hyperparameters(all_team_positions, all_match_positions, cluster_centroid_positions, w_def, w_off)

    # 最终训练
    print("\n===== 最终训练 =====")
    final_losses, final_team_positions, final_rank_scale, final_w_def, final_w_off = adam_optimize_positions(
        all_team_positions.copy(), all_match_positions.copy(), cluster_centroid_positions, w_def=w_def, w_off=w_off, **best_params
    )
    if final_losses:
        final_team_positions.to_csv("trained_team_positions.csv", index=False)
        print(f"最终损失: {final_losses[-1]:.4f}")
        print(f"最终防守权重: {final_w_def}")
        print(f"最终进攻权重: {final_w_off}")

    # 可视化
    print("\n===== 可视化 =====")
    visualize_team_evolution_by_league_static(final_team_positions, seasons)

    print("\n完成！")
# Out:
# scikit-learn 版本: 1.4.2
# ===== 加载数据 =====
# 加载数据: england - premier-league - 2013-to-2014
# 加载数据: england - premier-league - 2014-to-2015
# 加载数据: england - premier-league - 2015-to-2016
# 加载数据: england - premier-league - 2016-to-2017
# 加载数据: england - premier-league - 2017-to-2018
# 加载数据: england - premier-league - 2018-to-2019
# 加载数据: england - premier-league - 2019-to-2020
# 加载数据: england - premier-league - 2020-to-2021
# 加载数据: england - premier-league - 2021-to-2022
# 加载数据: england - premier-league - 2022-to-2023
# 加载数据: england - premier-league - 2023-to-2024
# 加载数据: germany - bundesliga - 2013-to-2014
# 加载数据: germany - bundesliga - 2014-to-2015
# 加载数据: germany - bundesliga - 2015-to-2016
# 加载数据: germany - bundesliga - 2016-to-2017
# 加载数据: germany - bundesliga - 2017-to-2018
# 加载数据: germany - bundesliga - 2018-to-2019
# 加载数据: germany - bundesliga - 2019-to-2020
# 加载数据: germany - bundesliga - 2020-to-2021
# 加载数据: germany - bundesliga - 2021-to-2022
# 加载数据: germany - bundesliga - 2022-to-2023
# 加载数据: germany - bundesliga - 2023-to-2024
# 加载数据: spain - la-liga - 2013-to-2014
# 加载数据: spain - la-liga - 2014-to-2015
# 加载数据: spain - la-liga - 2015-to-2016
# 加载数据: spain - la-liga - 2016-to-2017
# 加载数据: spain - la-liga - 2017-to-2018
# 加载数据: spain - la-liga - 2018-to-2019
# 加载数据: spain - la-liga - 2019-to-2020
# 加载数据: spain - la-liga - 2020-to-2021
# 加载数据: spain - la-liga - 2021-to-2022
# 加载数据: spain - la-liga - 2022-to-2023
# 加载数据: spain - la-liga - 2023-to-2024
# 加载数据: france - ligue-1 - 2013-to-2014
# 加载数据: france - ligue-1 - 2014-to-2015
# 加载数据: france - ligue-1 - 2015-to-2016
# 加载数据: france - ligue-1 - 2016-to-2017
# 加载数据: france - ligue-1 - 2017-to-2018
# 加载数据: france - ligue-1 - 2018-to-2019
# 加载数据: france - ligue-1 - 2019-to-2020
# 警告: france - ligue-1 - 2019-to-2020 文件缺失
# 加载数据: france - ligue-1 - 2020-to-2021
# 加载数据: france - ligue-1 - 2021-to-2022
# 加载数据: france - ligue-1 - 2022-to-2023
# 加载数据: france - ligue-1 - 2023-to-2024
# 加载数据: france - ligue-2 - 2013-to-2014
# 加载数据: france - ligue-2 - 2014-to-2015
# 加载数据: france - ligue-2 - 2015-to-2016
# 加载数据: france - ligue-2 - 2016-to-2017
# 加载数据: france - ligue-2 - 2017-to-2018
# 加载数据: france - ligue-2 - 2018-to-2019
# 加载数据: france - ligue-2 - 2019-to-2020
# 警告: france - ligue-2 - 2019-to-2020 文件缺失
# 加载数据: france - ligue-2 - 2020-to-2021
# 加载数据: france - ligue-2 - 2021-to-2022
# 加载数据: france - ligue-2 - 2022-to-2023
# 加载数据: france - ligue-2 - 2023-to-2024
# 加载数据: italy - serie-a - 2013-to-2014
# 加载数据: italy - serie-a - 2014-to-2015
# 加载数据: italy - serie-a - 2015-to-2016
# 加载数据: italy - serie-a - 2016-to-2017
# 加载数据: italy - serie-a - 2017-to-2018
# 加载数据: italy - serie-a - 2018-to-2019
# 加载数据: italy - serie-a - 2019-to-2020
# 加载数据: italy - serie-a - 2020-to-2021
# 加载数据: italy - serie-a - 2021-to-2022
# 加载数据: italy - serie-a - 2022-to-2023
# 加载数据: italy - serie-a - 2023-to-2024
# 加载数据: netherlands - eredivisie - 2013-to-2014
# 加载数据: netherlands - eredivisie - 2014-to-2015
# 加载数据: netherlands - eredivisie - 2015-to-2016
# 加载数据: netherlands - eredivisie - 2016-to-2017
# 加载数据: netherlands - eredivisie - 2017-to-2018
# 加载数据: netherlands - eredivisie - 2018-to-2019
# 加载数据: netherlands - eredivisie - 2019-to-2020
# 加载数据: netherlands - eredivisie - 2020-to-2021
# 加载数据: netherlands - eredivisie - 2021-to-2022
# 加载数据: netherlands - eredivisie - 2022-to-2023
# 加载数据: netherlands - eredivisie - 2023-to-2024
# 加载数据: portugal - ligapro - 2013-to-2014
# 警告: portugal - ligapro - 2013-to-2014 文件缺失
# 加载数据: portugal - ligapro - 2014-to-2015
# 加载数据: portugal - ligapro - 2015-to-2016
# 加载数据: portugal - ligapro - 2016-to-2017
# 加载数据: portugal - ligapro - 2017-to-2018
# 加载数据: portugal - ligapro - 2018-to-2019
# 加载数据: portugal - ligapro - 2019-to-2020
# 加载数据: portugal - ligapro - 2020-to-2021
# 加载数据: portugal - ligapro - 2021-to-2022
# 加载数据: portugal - ligapro - 2022-to-2023
# 加载数据: portugal - ligapro - 2023-to-2024
# 加载数据: denmark - superliga - 2013-to-2014
# 加载数据: denmark - superliga - 2014-to-2015
# 加载数据: denmark - superliga - 2015-to-2016
# 加载数据: denmark - superliga - 2016-to-2017
# 加载数据: denmark - superliga - 2017-to-2018
# 加载数据: denmark - superliga - 2018-to-2019
# 加载数据: denmark - superliga - 2019-to-2020
# 加载数据: denmark - superliga - 2020-to-2021
# 加载数据: denmark - superliga - 2021-to-2022
# 加载数据: denmark - superliga - 2022-to-2023
# 加载数据: denmark - superliga - 2023-to-2024
# 加载数据: england - championship - 2013-to-2014
# 加载数据: england - championship - 2014-to-2015
# 加载数据: england - championship - 2015-to-2016
# 加载数据: england - championship - 2016-to-2017
# 加载数据: england - championship - 2017-to-2018
# 加载数据: england - championship - 2018-to-2019
# 加载数据: england - championship - 2019-to-2020
# 加载数据: england - championship - 2020-to-2021
# 加载数据: england - championship - 2021-to-2022
# 加载数据: england - championship - 2022-to-2023
# 加载数据: england - championship - 2023-to-2024
# 加载数据: spain - segunda-division - 2013-to-2014
# 加载数据: spain - segunda-division - 2014-to-2015
# 加载数据: spain - segunda-division - 2015-to-2016
# 加载数据: spain - segunda-division - 2016-to-2017
# 加载数据: spain - segunda-division - 2017-to-2018
# 加载数据: spain - segunda-division - 2018-to-2019
# 加载数据: spain - segunda-division - 2019-to-2020
# 加载数据: spain - segunda-division - 2020-to-2021
# 加载数据: spain - segunda-division - 2021-to-2022
# 加载数据: spain - segunda-division - 2022-to-2023
# 加载数据: spain - segunda-division - 2023-to-2024
# 加载数据: switzerland - super-league - 2013-to-2014
# 加载数据: switzerland - super-league - 2014-to-2015
# 加载数据: switzerland - super-league - 2015-to-2016
# 加载数据: switzerland - super-league - 2016-to-2017
# 加载数据: switzerland - super-league - 2017-to-2018
# 加载数据: switzerland - super-league - 2018-to-2019
# 加载数据: switzerland - super-league - 2019-to-2020
# 加载数据: switzerland - super-league - 2020-to-2021
# 加载数据: switzerland - super-league - 2021-to-2022
# 加载数据: switzerland - super-league - 2022-to-2023
# 加载数据: switzerland - super-league - 2023-to-2024
# 加载数据: portugal - liga-nos - 2013-to-2014
# 加载数据: portugal - liga-nos - 2014-to-2015
# 加载数据: portugal - liga-nos - 2015-to-2016
# 加载数据: portugal - liga-nos - 2016-to-2017
# 加载数据: portugal - liga-nos - 2017-to-2018
# 加载数据: portugal - liga-nos - 2018-to-2019
# 加载数据: portugal - liga-nos - 2019-to-2020
# 加载数据: portugal - liga-nos - 2020-to-2021
# 加载数据: portugal - liga-nos - 2021-to-2022
# 加载数据: portugal - liga-nos - 2022-to-2023
# 加载数据: portugal - liga-nos - 2023-to-2024
# 加载数据: italy - serie-b - 2013-to-2014
# 加载数据: italy - serie-b - 2014-to-2015
# 加载数据: italy - serie-b - 2015-to-2016
# 加载数据: italy - serie-b - 2016-to-2017
# 加载数据: italy - serie-b - 2017-to-2018
# 加载数据: italy - serie-b - 2018-to-2019
# 加载数据: italy - serie-b - 2019-to-2020
# 加载数据: italy - serie-b - 2020-to-2021
# 加载数据: italy - serie-b - 2021-to-2022
# 加载数据: italy - serie-b - 2022-to-2023
# 加载数据: italy - serie-b - 2023-to-2024
# 加载数据: germany - 2-bundesliga - 2013-to-2014
# 加载数据: germany - 2-bundesliga - 2014-to-2015
# 加载数据: germany - 2-bundesliga - 2015-to-2016
# 加载数据: germany - 2-bundesliga - 2016-to-2017
# 加载数据: germany - 2-bundesliga - 2017-to-2018
# 加载数据: germany - 2-bundesliga - 2018-to-2019
# 加载数据: germany - 2-bundesliga - 2019-to-2020
# 加载数据: germany - 2-bundesliga - 2020-to-2021
# 加载数据: germany - 2-bundesliga - 2021-to-2022
# 加载数据: germany - 2-bundesliga - 2022-to-2023
# 加载数据: germany - 2-bundesliga - 2023-to-2024
# 加载数据: scotland - premiership - 2013-to-2014
# 加载数据: scotland - premiership - 2014-to-2015
# 加载数据: scotland - premiership - 2015-to-2016
# 加载数据: scotland - premiership - 2016-to-2017
# 加载数据: scotland - premiership - 2017-to-2018
# 加载数据: scotland - premiership - 2018-to-2019
# 加载数据: scotland - premiership - 2019-to-2020
# 加载数据: scotland - premiership - 2020-to-2021
# 加载数据: scotland - premiership - 2021-to-2022
# 加载数据: scotland - premiership - 2022-to-2023
# 加载数据: scotland - premiership - 2023-to-2024
# 加载数据: belgium - pro-league - 2013-to-2014
# 警告: belgium - pro-league - 2013-to-2014 文件缺失
# 加载数据: belgium - pro-league - 2014-to-2015
# 警告: belgium - pro-league - 2014-to-2015 文件缺失
# 加载数据: belgium - pro-league - 2015-to-2016
# 加载数据: belgium - pro-league - 2016-to-2017
# 加载数据: belgium - pro-league - 2017-to-2018
# 加载数据: belgium - pro-league - 2018-to-2019
# 加载数据: belgium - pro-league - 2019-to-2020
# 加载数据: belgium - pro-league - 2020-to-2021
# 加载数据: belgium - pro-league - 2021-to-2022
# 加载数据: belgium - pro-league - 2022-to-2023
# 加载数据: belgium - pro-league - 2023-to-2024
# 加载数据: austria - bundesliga - 2013-to-2014
# 加载数据: austria - bundesliga - 2014-to-2015
# 加载数据: austria - bundesliga - 2015-to-2016
# 加载数据: austria - bundesliga - 2016-to-2017
# 加载数据: austria - bundesliga - 2017-to-2018
# 加载数据: austria - bundesliga - 2018-to-2019
# 加载数据: austria - bundesliga - 2019-to-2020
# 加载数据: austria - bundesliga - 2020-to-2021
# 加载数据: austria - bundesliga - 2021-to-2022
# 加载数据: austria - bundesliga - 2022-to-2023
# 加载数据: austria - bundesliga - 2023-to-2024
#
# ===== 随机搜索超参数 =====
#
# 随机搜索: {'lambda_defense': 0.08116262258099888, 'lambda_offense': 0.19063571821788408, 'lambda_supervision': 0.14907884894416698, 'lambda_reg': 0.012374511199743695}
# 迭代 1000/100000, 损失 = 0.2025, rank_scale = 1.7235, 最佳损失 = 0.2025
# 迭代 2000/100000, 损失 = 0.1367, rank_scale = 2.2355, 最佳损失 = 0.1367
# 迭代 3000/100000, 损失 = 0.1121, rank_scale = 2.6914, 最佳损失 = 0.1121
# 迭代 4000/100000, 损失 = 0.1010, rank_scale = 3.1336, 最佳损失 = 0.1010
# 迭代 5000/100000, 损失 = 0.0946, rank_scale = 3.5822, 最佳损失 = 0.0946
# 迭代 6000/100000, 损失 = 0.0900, rank_scale = 4.0476, 最佳损失 = 0.0900
# 迭代 7000/100000, 损失 = 0.0865, rank_scale = 4.5349, 最佳损失 = 0.0865
# 迭代 8000/100000, 损失 = 0.0838, rank_scale = 5.0475, 最佳损失 = 0.0838
# 迭代 9000/100000, 损失 = 0.0816, rank_scale = 5.5875, 最佳损失 = 0.0816
# 迭代 10000/100000, 损失 = 0.0800, rank_scale = 6.1556, 最佳损失 = 0.0800
# 迭代 11000/100000, 损失 = 0.0788, rank_scale = 6.7526, 最佳损失 = 0.0788
# 迭代 12000/100000, 损失 = 0.0780, rank_scale = 7.3804, 最佳损失 = 0.0780
# 迭代 13000/100000, 损失 = 0.0774, rank_scale = 8.0437, 最佳损失 = 0.0774
# 迭代 14000/100000, 损失 = 0.0769, rank_scale = 8.7353, 最佳损失 = 0.0769
# 迭代 15000/100000, 损失 = 0.0765, rank_scale = 9.4468, 最佳损失 = 0.0765
# 迭代 16000/100000, 损失 = 0.0762, rank_scale = 10.1719, 最佳损失 = 0.0762
# 迭代 17000/100000, 损失 = 0.0759, rank_scale = 10.9069, 最佳损失 = 0.0759
# 迭代 18000/100000, 损失 = 0.0757, rank_scale = 11.6498, 最佳损失 = 0.0757
# 迭代 19000/100000, 损失 = 0.0756, rank_scale = 12.3997, 最佳损失 = 0.0756
# 迭代 20000/100000, 损失 = 0.0756, rank_scale = 13.1567, 最佳损失 = 0.0756
# 迭代 21000/100000, 损失 = 0.0755, rank_scale = 13.9213, 最佳损失 = 0.0755
# 迭代 22000/100000, 损失 = 0.0755, rank_scale = 14.6931, 最佳损失 = 0.0755
# 迭代 23000/100000, 损失 = 0.0754, rank_scale = 15.4700, 最佳损失 = 0.0754
# 迭代 24000/100000, 损失 = 0.0754, rank_scale = 16.2496, 最佳损失 = 0.0754
# 迭代 25000/100000, 损失 = 0.0753, rank_scale = 17.0304, 最佳损失 = 0.0753
# 迭代 26000/100000, 损失 = 0.0753, rank_scale = 17.8124, 最佳损失 = 0.0753
# 迭代 27000/100000, 损失 = 0.0753, rank_scale = 18.5929, 最佳损失 = 0.0753
# 迭代 28000/100000, 损失 = 0.0752, rank_scale = 19.3730, 最佳损失 = 0.0752
# 迭代 29000/100000, 损失 = 0.0752, rank_scale = 20.1523, 最佳损失 = 0.0752
# 迭代 30000/100000, 损失 = 0.0752, rank_scale = 20.9302, 最佳损失 = 0.0752
# 迭代 31000/100000, 损失 = 0.0752, rank_scale = 21.7065, 最佳损失 = 0.0751
# 迭代 32000/100000, 损失 = 0.0751, rank_scale = 22.4808, 最佳损失 = 0.0751
# 迭代 33000/100000, 损失 = 0.0751, rank_scale = 23.2530, 最佳损失 = 0.0751
# 迭代 34000/100000, 损失 = 0.0751, rank_scale = 24.0229, 最佳损失 = 0.0751
# 迭代 35000/100000, 损失 = 0.0751, rank_scale = 24.7905, 最佳损失 = 0.0751
# 迭代 36000/100000, 损失 = 0.0750, rank_scale = 25.5555, 最佳损失 = 0.0750
# 迭代 37000/100000, 损失 = 0.0750, rank_scale = 26.3177, 最佳损失 = 0.0750
# 迭代 38000/100000, 损失 = 0.0750, rank_scale = 27.0772, 最佳损失 = 0.0750
# 迭代 39000/100000, 损失 = 0.0750, rank_scale = 27.8336, 最佳损失 = 0.0750
# 迭代 40000/100000, 损失 = 0.0750, rank_scale = 28.5870, 最佳损失 = 0.0750
# 迭代 41000/100000, 损失 = 0.0750, rank_scale = 29.3374, 最佳损失 = 0.0750
# 迭代 42000/100000, 损失 = 0.0749, rank_scale = 30.0843, 最佳损失 = 0.0749
# 迭代 43000/100000, 损失 = 0.0749, rank_scale = 30.8280, 最佳损失 = 0.0749
# 迭代 44000/100000, 损失 = 0.0749, rank_scale = 31.5685, 最佳损失 = 0.0749
# 迭代 45000/100000, 损失 = 0.0749, rank_scale = 32.3055, 最佳损失 = 0.0749
# 迭代 46000/100000, 损失 = 0.0749, rank_scale = 33.0388, 最佳损失 = 0.0749
# 迭代 47000/100000, 损失 = 0.0749, rank_scale = 33.7688, 最佳损失 = 0.0749
# 迭代 48000/100000, 损失 = 0.0749, rank_scale = 34.4953, 最佳损失 = 0.0749
# 迭代 49000/100000, 损失 = 0.0749, rank_scale = 35.2180, 最佳损失 = 0.0749
# 迭代 50000/100000, 损失 = 0.0748, rank_scale = 35.9371, 最佳损失 = 0.0748
# 迭代 51000/100000, 损失 = 0.0748, rank_scale = 36.6526, 最佳损失 = 0.0748
# 迭代 52000/100000, 损失 = 0.0748, rank_scale = 37.3644, 最佳损失 = 0.0748
# 迭代 53000/100000, 损失 = 0.0748, rank_scale = 38.0724, 最佳损失 = 0.0748
# 迭代 54000/100000, 损失 = 0.0748, rank_scale = 38.7766, 最佳损失 = 0.0748
# 迭代 55000/100000, 损失 = 0.0748, rank_scale = 39.4771, 最佳损失 = 0.0748
# 迭代 56000/100000, 损失 = 0.0748, rank_scale = 40.1737, 最佳损失 = 0.0748
# 迭代 57000/100000, 损失 = 0.0748, rank_scale = 40.8666, 最佳损失 = 0.0748
# 迭代 58000/100000, 损失 = 0.0748, rank_scale = 41.5556, 最佳损失 = 0.0748
# 迭代 59000/100000, 损失 = 0.0748, rank_scale = 42.2407, 最佳损失 = 0.0748
# 迭代 60000/100000, 损失 = 0.0748, rank_scale = 42.9221, 最佳损失 = 0.0748
# 迭代 61000/100000, 损失 = 0.0748, rank_scale = 43.5996, 最佳损失 = 0.0748
# 迭代 62000/100000, 损失 = 0.0748, rank_scale = 44.2733, 最佳损失 = 0.0748
# 迭代 63000/100000, 损失 = 0.0748, rank_scale = 44.9430, 最佳损失 = 0.0747
# 迭代 64000/100000, 损失 = 0.0747, rank_scale = 45.6089, 最佳损失 = 0.0747
# 迭代 65000/100000, 损失 = 0.0747, rank_scale = 46.2709, 最佳损失 = 0.0747
# 迭代 66000/100000, 损失 = 0.0747, rank_scale = 46.9291, 最佳损失 = 0.0747
# 迭代 67000/100000, 损失 = 0.0747, rank_scale = 47.5834, 最佳损失 = 0.0747
# 迭代 68000/100000, 损失 = 0.0747, rank_scale = 48.2338, 最佳损失 = 0.0747
# 迭代 69000/100000, 损失 = 0.0747, rank_scale = 48.8803, 最佳损失 = 0.0747
# 迭代 70000/100000, 损失 = 0.0747, rank_scale = 49.5231, 最佳损失 = 0.0747
# 迭代 71000/100000, 损失 = 0.0747, rank_scale = 50.1619, 最佳损失 = 0.0747
# 迭代 72000/100000, 损失 = 0.0747, rank_scale = 50.7969, 最佳损失 = 0.0747
# 迭代 73000/100000, 损失 = 0.0747, rank_scale = 51.4281, 最佳损失 = 0.0747
# 迭代 74000/100000, 损失 = 0.0747, rank_scale = 52.0555, 最佳损失 = 0.0747
# 迭代 75000/100000, 损失 = 0.0747, rank_scale = 52.6790, 最佳损失 = 0.0747
# 迭代 76000/100000, 损失 = 0.0747, rank_scale = 53.2987, 最佳损失 = 0.0747
# 迭代 77000/100000, 损失 = 0.0747, rank_scale = 53.9147, 最佳损失 = 0.0747
# 迭代 78000/100000, 损失 = 0.0747, rank_scale = 54.5269, 最佳损失 = 0.0747
# 迭代 79000/100000, 损失 = 0.0747, rank_scale = 55.1352, 最佳损失 = 0.0747
# 迭代 80000/100000, 损失 = 0.0747, rank_scale = 55.7398, 最佳损失 = 0.0747
# 迭代 81000/100000, 损失 = 0.0747, rank_scale = 56.3406, 最佳损失 = 0.0747
# 迭代 82000/100000, 损失 = 0.0747, rank_scale = 56.9377, 最佳损失 = 0.0747
# 迭代 83000/100000, 损失 = 0.0747, rank_scale = 57.5311, 最佳损失 = 0.0747
# 迭代 84000/100000, 损失 = 0.0747, rank_scale = 58.1208, 最佳损失 = 0.0747
# 迭代 85000/100000, 损失 = 0.0747, rank_scale = 58.7067, 最佳损失 = 0.0747
# 迭代 86000/100000, 损失 = 0.0747, rank_scale = 59.2889, 最佳损失 = 0.0746
# 迭代 87000/100000, 损失 = 0.0747, rank_scale = 59.8676, 最佳损失 = 0.0746
# 迭代 88000/100000, 损失 = 0.0746, rank_scale = 60.4425, 最佳损失 = 0.0746
# 迭代 89000/100000, 损失 = 0.0746, rank_scale = 61.0139, 最佳损失 = 0.0746
# 迭代 90000/100000, 损失 = 0.0746, rank_scale = 61.5816, 最佳损失 = 0.0746
# 迭代 91000/100000, 损失 = 0.0746, rank_scale = 62.1458, 最佳损失 = 0.0746
# 迭代 92000/100000, 损失 = 0.0746, rank_scale = 62.7064, 最佳损失 = 0.0746
# 迭代 93000/100000, 损失 = 0.0746, rank_scale = 63.2633, 最佳损失 = 0.0746
# 迭代 94000/100000, 损失 = 0.0746, rank_scale = 63.8166, 最佳损失 = 0.0746
# 迭代 95000/100000, 损失 = 0.0746, rank_scale = 64.3663, 最佳损失 = 0.0746
# 迭代 96000/100000, 损失 = 0.0746, rank_scale = 64.9136, 最佳损失 = 0.0746
# 迭代 97000/100000, 损失 = 0.0746, rank_scale = 65.4552, 最佳损失 = 0.0746
# 迭代 98000/100000, 损失 = 0.0746, rank_scale = 65.9963, 最佳损失 = 0.0746
# 迭代 99000/100000, 损失 = 0.0746, rank_scale = 66.5303, 最佳损失 = 0.0746
# 迭代 100000/100000, 损失 = 0.0746, rank_scale = 67.0644, 最佳损失 = 0.0746
#
# 随机搜索: {'lambda_defense': 0.039643541684062936, 'lambda_offense': 0.039638958863878505, 'lambda_supervision': 0.021035886311957897, 'lambda_reg': 0.01745734676972377}
# 迭代 1000/100000, 损失 = 0.1103, rank_scale = 1.7193, 最佳损失 = 0.1103
# 迭代 2000/100000, 损失 = 0.0818, rank_scale = 2.2275, 最佳损失 = 0.0818
# 迭代 3000/100000, 损失 = 0.0682, rank_scale = 2.6799, 最佳损失 = 0.0682
# 迭代 4000/100000, 损失 = 0.0599, rank_scale = 3.1177, 最佳损失 = 0.0599
# 迭代 5000/100000, 损失 = 0.0540, rank_scale = 3.5598, 最佳损失 = 0.0540
# 迭代 6000/100000, 损失 = 0.0493, rank_scale = 4.0164, 最佳损失 = 0.0493
# 迭代 7000/100000, 损失 = 0.0454, rank_scale = 4.4930, 最佳损失 = 0.0454
# 迭代 8000/100000, 损失 = 0.0422, rank_scale = 4.9924, 最佳损失 = 0.0422
# 迭代 9000/100000, 损失 = 0.0395, rank_scale = 5.5155, 最佳损失 = 0.0395
# 迭代 10000/100000, 损失 = 0.0377, rank_scale = 6.0652, 最佳损失 = 0.0376
# 迭代 11000/100000, 损失 = 0.0364, rank_scale = 6.6501, 最佳损失 = 0.0364
# 迭代 12000/100000, 损失 = 0.0353, rank_scale = 7.2653, 最佳损失 = 0.0353
# 迭代 13000/100000, 损失 = 0.0344, rank_scale = 7.9046, 最佳损失 = 0.0344
# 迭代 14000/100000, 损失 = 0.0337, rank_scale = 8.5634, 最佳损失 = 0.0337
# 迭代 15000/100000, 损失 = 0.0330, rank_scale = 9.2384, 最佳损失 = 0.0330
# 迭代 16000/100000, 损失 = 0.0325, rank_scale = 9.9272, 最佳损失 = 0.0325
# 迭代 17000/100000, 损失 = 0.0321, rank_scale = 10.6281, 最佳损失 = 0.0321
# 迭代 18000/100000, 损失 = 0.0318, rank_scale = 11.3401, 最佳损失 = 0.0318
# 迭代 19000/100000, 损失 = 0.0315, rank_scale = 12.0626, 最佳损失 = 0.0315
# 迭代 20000/100000, 损失 = 0.0313, rank_scale = 12.7960, 最佳损失 = 0.0313
# 迭代 21000/100000, 损失 = 0.0311, rank_scale = 13.5410, 最佳损失 = 0.0311
# 迭代 22000/100000, 损失 = 0.0309, rank_scale = 14.2961, 最佳损失 = 0.0309
# 迭代 23000/100000, 损失 = 0.0307, rank_scale = 15.0578, 最佳损失 = 0.0307
# 迭代 24000/100000, 损失 = 0.0304, rank_scale = 15.8225, 最佳损失 = 0.0304
# 迭代 25000/100000, 损失 = 0.0302, rank_scale = 16.5891, 最佳损失 = 0.0302
# 迭代 26000/100000, 损失 = 0.0300, rank_scale = 17.3558, 最佳损失 = 0.0300
# 迭代 27000/100000, 损失 = 0.0298, rank_scale = 18.1226, 最佳损失 = 0.0298
# 迭代 28000/100000, 损失 = 0.0297, rank_scale = 18.8882, 最佳损失 = 0.0296
# 迭代 29000/100000, 损失 = 0.0295, rank_scale = 19.6531, 最佳损失 = 0.0295
# 迭代 30000/100000, 损失 = 0.0293, rank_scale = 20.4164, 最佳损失 = 0.0293
# 迭代 31000/100000, 损失 = 0.0292, rank_scale = 21.1786, 最佳损失 = 0.0292
# 迭代 32000/100000, 损失 = 0.0290, rank_scale = 21.9388, 最佳损失 = 0.0290
# 迭代 33000/100000, 损失 = 0.0289, rank_scale = 22.6971, 最佳损失 = 0.0289
# 迭代 34000/100000, 损失 = 0.0287, rank_scale = 23.4533, 最佳损失 = 0.0287
# 迭代 35000/100000, 损失 = 0.0286, rank_scale = 24.2067, 最佳损失 = 0.0286
# 迭代 36000/100000, 损失 = 0.0285, rank_scale = 24.9576, 最佳损失 = 0.0285
# 迭代 37000/100000, 损失 = 0.0284, rank_scale = 25.7072, 最佳损失 = 0.0284
# 迭代 38000/100000, 损失 = 0.0284, rank_scale = 26.4568, 最佳损失 = 0.0284
# 迭代 39000/100000, 损失 = 0.0283, rank_scale = 27.2050, 最佳损失 = 0.0283
# 迭代 40000/100000, 损失 = 0.0283, rank_scale = 27.9502, 最佳损失 = 0.0283
# 迭代 41000/100000, 损失 = 0.0283, rank_scale = 28.6924, 最佳损失 = 0.0283
# 迭代 42000/100000, 损失 = 0.0282, rank_scale = 29.4311, 最佳损失 = 0.0282
# 迭代 43000/100000, 损失 = 0.0282, rank_scale = 30.1661, 最佳损失 = 0.0282
# 迭代 44000/100000, 损失 = 0.0282, rank_scale = 30.8975, 最佳损失 = 0.0282
# 迭代 45000/100000, 损失 = 0.0282, rank_scale = 31.6251, 最佳损失 = 0.0282
# 迭代 46000/100000, 损失 = 0.0282, rank_scale = 32.3487, 最佳损失 = 0.0282
# 迭代 47000/100000, 损失 = 0.0281, rank_scale = 33.0685, 最佳损失 = 0.0281
# 迭代 48000/100000, 损失 = 0.0281, rank_scale = 33.7844, 最佳损失 = 0.0281
# 迭代 49000/100000, 损失 = 0.0281, rank_scale = 34.4962, 最佳损失 = 0.0281
# 迭代 50000/100000, 损失 = 0.0281, rank_scale = 35.2042, 最佳损失 = 0.0281
# 迭代 51000/100000, 损失 = 0.0281, rank_scale = 35.9080, 最佳损失 = 0.0281
# 迭代 52000/100000, 损失 = 0.0281, rank_scale = 36.6079, 最佳损失 = 0.0281
# 迭代 53000/100000, 损失 = 0.0281, rank_scale = 37.3036, 最佳损失 = 0.0281
# 迭代 54000/100000, 损失 = 0.0281, rank_scale = 37.9953, 最佳损失 = 0.0280
# 迭代 55000/100000, 损失 = 0.0280, rank_scale = 38.6828, 最佳损失 = 0.0280
# 迭代 56000/100000, 损失 = 0.0280, rank_scale = 39.3662, 最佳损失 = 0.0280
# 迭代 57000/100000, 损失 = 0.0280, rank_scale = 40.0453, 最佳损失 = 0.0280
# 迭代 58000/100000, 损失 = 0.0280, rank_scale = 40.7200, 最佳损失 = 0.0280
# 迭代 59000/100000, 损失 = 0.0280, rank_scale = 41.3905, 最佳损失 = 0.0280
# 迭代 60000/100000, 损失 = 0.0280, rank_scale = 42.0569, 最佳损失 = 0.0280
# 迭代 61000/100000, 损失 = 0.0280, rank_scale = 42.7191, 最佳损失 = 0.0280
# 迭代 62000/100000, 损失 = 0.0280, rank_scale = 43.3770, 最佳损失 = 0.0280
# 迭代 63000/100000, 损失 = 0.0280, rank_scale = 44.0307, 最佳损失 = 0.0280
# 迭代 64000/100000, 损失 = 0.0280, rank_scale = 44.6802, 最佳损失 = 0.0280
# 迭代 65000/100000, 损失 = 0.0280, rank_scale = 45.3256, 最佳损失 = 0.0280
# 迭代 66000/100000, 损失 = 0.0280, rank_scale = 45.9665, 最佳损失 = 0.0280
# 迭代 67000/100000, 损失 = 0.0280, rank_scale = 46.6032, 最佳损失 = 0.0280
# 迭代 68000/100000, 损失 = 0.0280, rank_scale = 47.2356, 最佳损失 = 0.0279
# 迭代 69000/100000, 损失 = 0.0279, rank_scale = 47.8638, 最佳损失 = 0.0279
# 迭代 70000/100000, 损失 = 0.0279, rank_scale = 48.4879, 最佳损失 = 0.0279
# 迭代 71000/100000, 损失 = 0.0279, rank_scale = 49.1078, 最佳损失 = 0.0279
# 迭代 72000/100000, 损失 = 0.0279, rank_scale = 49.7235, 最佳损失 = 0.0279
# 迭代 73000/100000, 损失 = 0.0279, rank_scale = 50.3351, 最佳损失 = 0.0279
# 迭代 74000/100000, 损失 = 0.0279, rank_scale = 50.9425, 最佳损失 = 0.0279
# 迭代 75000/100000, 损失 = 0.0279, rank_scale = 51.5459, 最佳损失 = 0.0279
# 迭代 76000/100000, 损失 = 0.0279, rank_scale = 52.1451, 最佳损失 = 0.0279
# 迭代 77000/100000, 损失 = 0.0279, rank_scale = 52.7399, 最佳损失 = 0.0279
# 迭代 78000/100000, 损失 = 0.0279, rank_scale = 53.3307, 最佳损失 = 0.0279
# 迭代 79000/100000, 损失 = 0.0279, rank_scale = 53.9174, 最佳损失 = 0.0279
# 迭代 80000/100000, 损失 = 0.0279, rank_scale = 54.5000, 最佳损失 = 0.0279
# 迭代 81000/100000, 损失 = 0.0279, rank_scale = 55.0786, 最佳损失 = 0.0279
# 迭代 82000/100000, 损失 = 0.0279, rank_scale = 55.6532, 最佳损失 = 0.0279
# 迭代 83000/100000, 损失 = 0.0279, rank_scale = 56.2238, 最佳损失 = 0.0279
# 迭代 84000/100000, 损失 = 0.0279, rank_scale = 56.7904, 最佳损失 = 0.0279
# 迭代 85000/100000, 损失 = 0.0279, rank_scale = 57.3531, 最佳损失 = 0.0279
# 迭代 86000/100000, 损失 = 0.0279, rank_scale = 57.9117, 最佳损失 = 0.0279
# 迭代 87000/100000, 损失 = 0.0279, rank_scale = 58.4665, 最佳损失 = 0.0278
# 迭代 88000/100000, 损失 = 0.0278, rank_scale = 59.0174, 最佳损失 = 0.0278
# 迭代 89000/100000, 损失 = 0.0278, rank_scale = 59.5644, 最佳损失 = 0.0278
# 迭代 90000/100000, 损失 = 0.0278, rank_scale = 60.1075, 最佳损失 = 0.0278
# 迭代 91000/100000, 损失 = 0.0278, rank_scale = 60.6467, 最佳损失 = 0.0278
# 迭代 92000/100000, 损失 = 0.0278, rank_scale = 61.1822, 最佳损失 = 0.0278
# 迭代 93000/100000, 损失 = 0.0278, rank_scale = 61.7139, 最佳损失 = 0.0278
# 迭代 94000/100000, 损失 = 0.0278, rank_scale = 62.2418, 最佳损失 = 0.0278
# 迭代 95000/100000, 损失 = 0.0278, rank_scale = 62.7658, 最佳损失 = 0.0278
# 迭代 96000/100000, 损失 = 0.0278, rank_scale = 63.2862, 最佳损失 = 0.0278
# 迭代 97000/100000, 损失 = 0.0278, rank_scale = 63.8030, 最佳损失 = 0.0278
# 迭代 98000/100000, 损失 = 0.0278, rank_scale = 64.3156, 最佳损失 = 0.0278
# 迭代 99000/100000, 损失 = 0.0278, rank_scale = 64.8268, 最佳损失 = 0.0278
# 迭代 100000/100000, 损失 = 0.0278, rank_scale = 65.3306, 最佳损失 = 0.0278
#
# 随机搜索: {'lambda_defense': 0.12421185223120967, 'lambda_offense': 0.14453378978124864, 'lambda_supervision': 0.013911053916202466, 'lambda_reg': 0.019428287191077892}
# 迭代 1000/100000, 损失 = 0.1659, rank_scale = 1.7228, 最佳损失 = 0.1659
# 迭代 2000/100000, 损失 = 0.1014, rank_scale = 2.2341, 最佳损失 = 0.1014
# 迭代 3000/100000, 损失 = 0.0770, rank_scale = 2.6896, 最佳损失 = 0.0770
# 迭代 4000/100000, 损失 = 0.0659, rank_scale = 3.1320, 最佳损失 = 0.0659
# 迭代 5000/100000, 损失 = 0.0597, rank_scale = 3.5809, 最佳损失 = 0.0597
# 迭代 6000/100000, 损失 = 0.0556, rank_scale = 4.0470, 最佳损失 = 0.0556
# 迭代 7000/100000, 损失 = 0.0526, rank_scale = 4.5365, 最佳损失 = 0.0526
# 迭代 8000/100000, 损失 = 0.0502, rank_scale = 5.0529, 最佳损失 = 0.0502
# 迭代 9000/100000, 损失 = 0.0484, rank_scale = 5.5974, 最佳损失 = 0.0484
# 迭代 10000/100000, 损失 = 0.0470, rank_scale = 6.1700, 最佳损失 = 0.0470
# 迭代 11000/100000, 损失 = 0.0459, rank_scale = 6.7704, 最佳损失 = 0.0459
# 迭代 12000/100000, 损失 = 0.0451, rank_scale = 7.3988, 最佳损失 = 0.0451
# 迭代 13000/100000, 损失 = 0.0447, rank_scale = 8.0571, 最佳损失 = 0.0447
# 迭代 14000/100000, 损失 = 0.0444, rank_scale = 8.7492, 最佳损失 = 0.0444
# 迭代 15000/100000, 损失 = 0.0441, rank_scale = 9.4689, 最佳损失 = 0.0441
# 迭代 16000/100000, 损失 = 0.0439, rank_scale = 10.2085, 最佳损失 = 0.0439
# 迭代 17000/100000, 损失 = 0.0438, rank_scale = 10.9617, 最佳损失 = 0.0438
# 迭代 18000/100000, 损失 = 0.0437, rank_scale = 11.7241, 最佳损失 = 0.0437
# 迭代 19000/100000, 损失 = 0.0436, rank_scale = 12.4931, 最佳损失 = 0.0436
# 迭代 20000/100000, 损失 = 0.0435, rank_scale = 13.2670, 最佳损失 = 0.0435
# 迭代 21000/100000, 损失 = 0.0434, rank_scale = 14.0445, 最佳损失 = 0.0434
# 迭代 22000/100000, 损失 = 0.0434, rank_scale = 14.8248, 最佳损失 = 0.0434
# 迭代 23000/100000, 损失 = 0.0434, rank_scale = 15.6070, 最佳损失 = 0.0434
# 迭代 24000/100000, 损失 = 0.0433, rank_scale = 16.3904, 最佳损失 = 0.0433
# 迭代 25000/100000, 损失 = 0.0433, rank_scale = 17.1743, 最佳损失 = 0.0433
# 迭代 26000/100000, 损失 = 0.0433, rank_scale = 17.9583, 最佳损失 = 0.0433
# 迭代 27000/100000, 损失 = 0.0432, rank_scale = 18.7422, 最佳损失 = 0.0432
# 迭代 28000/100000, 损失 = 0.0432, rank_scale = 19.5253, 最佳损失 = 0.0432
# 迭代 29000/100000, 损失 = 0.0432, rank_scale = 20.3073, 最佳损失 = 0.0432
# 迭代 30000/100000, 损失 = 0.0432, rank_scale = 21.0879, 最佳损失 = 0.0432
# 迭代 31000/100000, 损失 = 0.0431, rank_scale = 21.8669, 最佳损失 = 0.0431
# 迭代 32000/100000, 损失 = 0.0431, rank_scale = 22.6440, 最佳损失 = 0.0431
# 迭代 33000/100000, 损失 = 0.0431, rank_scale = 23.4192, 最佳损失 = 0.0431
# 迭代 34000/100000, 损失 = 0.0431, rank_scale = 24.1922, 最佳损失 = 0.0431
# 迭代 35000/100000, 损失 = 0.0431, rank_scale = 24.9628, 最佳损失 = 0.0431
# 迭代 36000/100000, 损失 = 0.0431, rank_scale = 25.7308, 最佳损失 = 0.0431
# 迭代 37000/100000, 损失 = 0.0431, rank_scale = 26.4963, 最佳损失 = 0.0431
# 迭代 38000/100000, 损失 = 0.0431, rank_scale = 27.2588, 最佳损失 = 0.0431
# 迭代 39000/100000, 损失 = 0.0431, rank_scale = 28.0187, 最佳损失 = 0.0431
# 迭代 40000/100000, 损失 = 0.0431, rank_scale = 28.7752, 最佳损失 = 0.0430
# 迭代 41000/100000, 损失 = 0.0430, rank_scale = 29.5290, 最佳损失 = 0.0430
# 迭代 42000/100000, 损失 = 0.0430, rank_scale = 30.2795, 最佳损失 = 0.0430
# 迭代 43000/100000, 损失 = 0.0430, rank_scale = 31.0267, 最佳损失 = 0.0430
# 迭代 44000/100000, 损失 = 0.0430, rank_scale = 31.7707, 最佳损失 = 0.0430
# 迭代 45000/100000, 损失 = 0.0430, rank_scale = 32.5114, 最佳损失 = 0.0430
# 迭代 46000/100000, 损失 = 0.0430, rank_scale = 33.2485, 最佳损失 = 0.0430
# 迭代 47000/100000, 损失 = 0.0430, rank_scale = 33.9823, 最佳损失 = 0.0430
# 迭代 48000/100000, 损失 = 0.0430, rank_scale = 34.7126, 最佳损失 = 0.0430
# 迭代 49000/100000, 损失 = 0.0430, rank_scale = 35.4395, 最佳损失 = 0.0430
# 迭代 50000/100000, 损失 = 0.0430, rank_scale = 36.1627, 最佳损失 = 0.0430
# 迭代 51000/100000, 损失 = 0.0430, rank_scale = 36.8824, 最佳损失 = 0.0430
# 迭代 52000/100000, 损失 = 0.0430, rank_scale = 37.5984, 最佳损失 = 0.0430
# 迭代 53000/100000, 损失 = 0.0430, rank_scale = 38.3109, 最佳损失 = 0.0430
# 迭代 54000/100000, 损失 = 0.0430, rank_scale = 39.0197, 最佳损失 = 0.0430
# 迭代 55000/100000, 损失 = 0.0430, rank_scale = 39.7249, 最佳损失 = 0.0430
# 迭代 56000/100000, 损失 = 0.0430, rank_scale = 40.4264, 最佳损失 = 0.0430
# 迭代 57000/100000, 损失 = 0.0430, rank_scale = 41.1241, 最佳损失 = 0.0430
# 迭代 58000/100000, 损失 = 0.0430, rank_scale = 41.8182, 最佳损失 = 0.0430
# 迭代 59000/100000, 损失 = 0.0430, rank_scale = 42.5084, 最佳损失 = 0.0430
# 迭代 60000/100000, 损失 = 0.0430, rank_scale = 43.1950, 最佳损失 = 0.0430
# 迭代 61000/100000, 损失 = 0.0430, rank_scale = 43.8778, 最佳损失 = 0.0430
# 迭代 62000/100000, 损失 = 0.0430, rank_scale = 44.5568, 最佳损失 = 0.0430
# 迭代 63000/100000, 损失 = 0.0430, rank_scale = 45.2321, 最佳损失 = 0.0430
# 迭代 64000/100000, 损失 = 0.0430, rank_scale = 45.9035, 最佳损失 = 0.0430
# 迭代 65000/100000, 损失 = 0.0430, rank_scale = 46.5713, 最佳损失 = 0.0429
# 迭代 66000/100000, 损失 = 0.0429, rank_scale = 47.2353, 最佳损失 = 0.0429
# 迭代 67000/100000, 损失 = 0.0429, rank_scale = 47.8956, 最佳损失 = 0.0429
# 迭代 68000/100000, 损失 = 0.0429, rank_scale = 48.5521, 最佳损失 = 0.0429
# 迭代 69000/100000, 损失 = 0.0429, rank_scale = 49.2049, 最佳损失 = 0.0429
# 迭代 70000/100000, 损失 = 0.0429, rank_scale = 49.8539, 最佳损失 = 0.0429
# 迭代 71000/100000, 损失 = 0.0429, rank_scale = 50.4992, 最佳损失 = 0.0429
# 迭代 72000/100000, 损失 = 0.0429, rank_scale = 51.1408, 最佳损失 = 0.0429
# 迭代 73000/100000, 损失 = 0.0429, rank_scale = 51.7786, 最佳损失 = 0.0429
# 迭代 74000/100000, 损失 = 0.0429, rank_scale = 52.4128, 最佳损失 = 0.0429
# 迭代 75000/100000, 损失 = 0.0429, rank_scale = 53.0432, 最佳损失 = 0.0429
# 迭代 76000/100000, 损失 = 0.0429, rank_scale = 53.6700, 最佳损失 = 0.0429
# 迭代 77000/100000, 损失 = 0.0429, rank_scale = 54.2931, 最佳损失 = 0.0429
# 迭代 78000/100000, 损失 = 0.0429, rank_scale = 54.9125, 最佳损失 = 0.0429
# 迭代 79000/100000, 损失 = 0.0429, rank_scale = 55.5283, 最佳损失 = 0.0429
# 迭代 80000/100000, 损失 = 0.0429, rank_scale = 56.1404, 最佳损失 = 0.0429
# 迭代 81000/100000, 损失 = 0.0429, rank_scale = 56.7489, 最佳损失 = 0.0429
# 迭代 82000/100000, 损失 = 0.0429, rank_scale = 57.3538, 最佳损失 = 0.0429
# 迭代 83000/100000, 损失 = 0.0429, rank_scale = 57.9551, 最佳损失 = 0.0429
# 迭代 84000/100000, 损失 = 0.0429, rank_scale = 58.5529, 最佳损失 = 0.0429
# 迭代 85000/100000, 损失 = 0.0429, rank_scale = 59.1470, 最佳损失 = 0.0429
# 迭代 86000/100000, 损失 = 0.0429, rank_scale = 59.7377, 最佳损失 = 0.0429
# 迭代 87000/100000, 损失 = 0.0429, rank_scale = 60.3247, 最佳损失 = 0.0429
# 迭代 88000/100000, 损失 = 0.0429, rank_scale = 60.9083, 最佳损失 = 0.0429
# 迭代 89000/100000, 损失 = 0.0429, rank_scale = 61.4882, 最佳损失 = 0.0429
# 迭代 90000/100000, 损失 = 0.0429, rank_scale = 62.0644, 最佳损失 = 0.0429
# 迭代 91000/100000, 损失 = 0.0429, rank_scale = 62.6372, 最佳损失 = 0.0429
# 迭代 92000/100000, 损失 = 0.0429, rank_scale = 63.2066, 最佳损失 = 0.0429
# 迭代 93000/100000, 损失 = 0.0429, rank_scale = 63.7725, 最佳损失 = 0.0429
# 迭代 94000/100000, 损失 = 0.0429, rank_scale = 64.3371, 最佳损失 = 0.0429
# 迭代 95000/100000, 损失 = 0.0429, rank_scale = 64.8941, 最佳损失 = 0.0429
# 迭代 96000/100000, 损失 = 0.0429, rank_scale = 65.4511, 最佳损失 = 0.0429
# 迭代 97000/100000, 损失 = 0.0429, rank_scale = 66.0023, 最佳损失 = 0.0429
# 迭代 98000/100000, 损失 = 0.0429, rank_scale = 66.5516, 最佳损失 = 0.0429
# 迭代 99000/100000, 损失 = 0.0429, rank_scale = 67.0972, 最佳损失 = 0.0429
# 迭代 100000/100000, 损失 = 0.0429, rank_scale = 67.6389, 最佳损失 = 0.0429
#
# 随机搜索: {'lambda_defense': 0.16816410175208013, 'lambda_offense': 0.05034443102887247, 'lambda_supervision': 0.04454674376934912, 'lambda_reg': 0.004484685687215243}
# 迭代 1000/100000, 损失 = 0.1604, rank_scale = 1.7203, 最佳损失 = 0.1604
# 迭代 2000/100000, 损失 = 0.1052, rank_scale = 2.2298, 最佳损失 = 0.1052
# 迭代 3000/100000, 损失 = 0.0832, rank_scale = 2.6841, 最佳损失 = 0.0832
# 迭代 4000/100000, 损失 = 0.0725, rank_scale = 3.1252, 最佳损失 = 0.0725
# 迭代 5000/100000, 损失 = 0.0663, rank_scale = 3.5725, 最佳损失 = 0.0663
# 迭代 6000/100000, 损失 = 0.0620, rank_scale = 4.0365, 最佳损失 = 0.0620
# 迭代 7000/100000, 损失 = 0.0589, rank_scale = 4.5232, 最佳损失 = 0.0589
# 迭代 8000/100000, 损失 = 0.0565, rank_scale = 5.0361, 最佳损失 = 0.0565
# 迭代 9000/100000, 损失 = 0.0546, rank_scale = 5.5773, 最佳损失 = 0.0546
# 迭代 10000/100000, 损失 = 0.0531, rank_scale = 6.1481, 最佳损失 = 0.0531
# 迭代 11000/100000, 损失 = 0.0518, rank_scale = 6.7499, 最佳损失 = 0.0518
# 迭代 12000/100000, 损失 = 0.0508, rank_scale = 7.3860, 最佳损失 = 0.0508
# 迭代 13000/100000, 损失 = 0.0499, rank_scale = 8.0606, 最佳损失 = 0.0499
# 迭代 14000/100000, 损失 = 0.0490, rank_scale = 8.7641, 最佳损失 = 0.0490
# 迭代 15000/100000, 损失 = 0.0481, rank_scale = 9.4867, 最佳损失 = 0.0481
# 迭代 16000/100000, 损失 = 0.0472, rank_scale = 10.2219, 最佳损失 = 0.0472
# 迭代 17000/100000, 损失 = 0.0464, rank_scale = 10.9656, 最佳损失 = 0.0464
# 迭代 18000/100000, 损失 = 0.0457, rank_scale = 11.7150, 最佳损失 = 0.0457
# 迭代 19000/100000, 损失 = 0.0451, rank_scale = 12.4683, 最佳损失 = 0.0451
# 迭代 20000/100000, 损失 = 0.0445, rank_scale = 13.2245, 最佳损失 = 0.0445
# 迭代 21000/100000, 损失 = 0.0440, rank_scale = 13.9824, 最佳损失 = 0.0440
# 迭代 22000/100000, 损失 = 0.0435, rank_scale = 14.7415, 最佳损失 = 0.0435
# 迭代 23000/100000, 损失 = 0.0432, rank_scale = 15.5016, 最佳损失 = 0.0432
# 迭代 24000/100000, 损失 = 0.0429, rank_scale = 16.2620, 最佳损失 = 0.0429
# 迭代 25000/100000, 损失 = 0.0427, rank_scale = 17.0230, 最佳损失 = 0.0427
# 迭代 26000/100000, 损失 = 0.0425, rank_scale = 17.7840, 最佳损失 = 0.0425
# 迭代 27000/100000, 损失 = 0.0424, rank_scale = 18.5451, 最佳损失 = 0.0424
# 迭代 28000/100000, 损失 = 0.0423, rank_scale = 19.3076, 最佳损失 = 0.0423
# 迭代 29000/100000, 损失 = 0.0422, rank_scale = 20.0705, 最佳损失 = 0.0422
# 迭代 30000/100000, 损失 = 0.0422, rank_scale = 20.8350, 最佳损失 = 0.0422
# 迭代 31000/100000, 损失 = 0.0422, rank_scale = 21.6011, 最佳损失 = 0.0422
# 迭代 32000/100000, 损失 = 0.0422, rank_scale = 22.3694, 最佳损失 = 0.0422
# 迭代 33000/100000, 损失 = 0.0422, rank_scale = 23.1392, 最佳损失 = 0.0422
# 迭代 34000/100000, 损失 = 0.0421, rank_scale = 23.9081, 最佳损失 = 0.0421
# 迭代 35000/100000, 损失 = 0.0421, rank_scale = 24.6757, 最佳损失 = 0.0421
# 迭代 36000/100000, 损失 = 0.0421, rank_scale = 25.4411, 最佳损失 = 0.0421
# 迭代 37000/100000, 损失 = 0.0421, rank_scale = 26.2036, 最佳损失 = 0.0421
# 迭代 38000/100000, 损失 = 0.0421, rank_scale = 26.9635, 最佳损失 = 0.0421
# 迭代 39000/100000, 损失 = 0.0421, rank_scale = 27.7201, 最佳损失 = 0.0421
# 迭代 40000/100000, 损失 = 0.0421, rank_scale = 28.4738, 最佳损失 = 0.0421
# 迭代 41000/100000, 损失 = 0.0421, rank_scale = 29.2243, 最佳损失 = 0.0421
# 迭代 42000/100000, 损失 = 0.0421, rank_scale = 29.9714, 最佳损失 = 0.0421
# 迭代 43000/100000, 损失 = 0.0421, rank_scale = 30.7151, 最佳损失 = 0.0421
# 迭代 44000/100000, 损失 = 0.0421, rank_scale = 31.4555, 最佳损失 = 0.0421
# 迭代 45000/100000, 损失 = 0.0421, rank_scale = 32.1925, 最佳损失 = 0.0421
# 迭代 46000/100000, 损失 = 0.0421, rank_scale = 32.9258, 最佳损失 = 0.0421
# 迭代 47000/100000, 损失 = 0.0421, rank_scale = 33.6554, 最佳损失 = 0.0421
# 迭代 48000/100000, 损失 = 0.0421, rank_scale = 34.3815, 最佳损失 = 0.0421
# 迭代 49000/100000, 损失 = 0.0420, rank_scale = 35.1039, 最佳损失 = 0.0420
# 迭代 50000/100000, 损失 = 0.0420, rank_scale = 35.8225, 最佳损失 = 0.0420
# 迭代 51000/100000, 损失 = 0.0420, rank_scale = 36.5374, 最佳损失 = 0.0420
# 迭代 52000/100000, 损失 = 0.0420, rank_scale = 37.2486, 最佳损失 = 0.0420
# 迭代 53000/100000, 损失 = 0.0420, rank_scale = 37.9560, 最佳损失 = 0.0420
# 迭代 54000/100000, 损失 = 0.0420, rank_scale = 38.6595, 最佳损失 = 0.0420
# 迭代 55000/100000, 损失 = 0.0420, rank_scale = 39.3592, 最佳损失 = 0.0420
# 迭代 56000/100000, 损失 = 0.0420, rank_scale = 40.0551, 最佳损失 = 0.0420
# 迭代 57000/100000, 损失 = 0.0420, rank_scale = 40.7471, 最佳损失 = 0.0420
# 迭代 58000/100000, 损失 = 0.0420, rank_scale = 41.4352, 最佳损失 = 0.0420
# 迭代 59000/100000, 损失 = 0.0420, rank_scale = 42.1195, 最佳损失 = 0.0420
# 迭代 60000/100000, 损失 = 0.0420, rank_scale = 42.7999, 最佳损失 = 0.0420
# 迭代 61000/100000, 损失 = 0.0420, rank_scale = 43.4763, 最佳损失 = 0.0420
# 迭代 62000/100000, 损失 = 0.0420, rank_scale = 44.1489, 最佳损失 = 0.0420
# 迭代 63000/100000, 损失 = 0.0420, rank_scale = 44.8176, 最佳损失 = 0.0420
# 迭代 64000/100000, 损失 = 0.0420, rank_scale = 45.4823, 最佳损失 = 0.0420
# 迭代 65000/100000, 损失 = 0.0420, rank_scale = 46.1432, 最佳损失 = 0.0420
# 迭代 66000/100000, 损失 = 0.0420, rank_scale = 46.8002, 最佳损失 = 0.0420
# 迭代 67000/100000, 损失 = 0.0420, rank_scale = 47.4532, 最佳损失 = 0.0420
# 迭代 68000/100000, 损失 = 0.0420, rank_scale = 48.1024, 最佳损失 = 0.0420
# 迭代 69000/100000, 损失 = 0.0420, rank_scale = 48.7477, 最佳损失 = 0.0420
# 迭代 70000/100000, 损失 = 0.0420, rank_scale = 49.3890, 最佳损失 = 0.0420
# 迭代 71000/100000, 损失 = 0.0420, rank_scale = 50.0265, 最佳损失 = 0.0420
# 迭代 72000/100000, 损失 = 0.0420, rank_scale = 50.6601, 最佳损失 = 0.0420
# 迭代 73000/100000, 损失 = 0.0420, rank_scale = 51.2899, 最佳损失 = 0.0420
# 迭代 74000/100000, 损失 = 0.0420, rank_scale = 51.9158, 最佳损失 = 0.0420
# 迭代 75000/100000, 损失 = 0.0420, rank_scale = 52.5379, 最佳损失 = 0.0420
# 迭代 76000/100000, 损失 = 0.0420, rank_scale = 53.1561, 最佳损失 = 0.0420
# 迭代 77000/100000, 损失 = 0.0420, rank_scale = 53.7705, 最佳损失 = 0.0420
# 迭代 78000/100000, 损失 = 0.0420, rank_scale = 54.3811, 最佳损失 = 0.0420
# 迭代 79000/100000, 损失 = 0.0420, rank_scale = 54.9879, 最佳损失 = 0.0420
# 迭代 80000/100000, 损失 = 0.0420, rank_scale = 55.5909, 最佳损失 = 0.0419
# 迭代 81000/100000, 损失 = 0.0420, rank_scale = 56.1901, 最佳损失 = 0.0419
# 迭代 82000/100000, 损失 = 0.0419, rank_scale = 56.7856, 最佳损失 = 0.0419
# 迭代 83000/100000, 损失 = 0.0419, rank_scale = 57.3773, 最佳损失 = 0.0419
# 迭代 84000/100000, 损失 = 0.0419, rank_scale = 57.9653, 最佳损失 = 0.0419
# 迭代 85000/100000, 损失 = 0.0419, rank_scale = 58.5495, 最佳损失 = 0.0419
# 迭代 86000/100000, 损失 = 0.0419, rank_scale = 59.1301, 最佳损失 = 0.0419
# 迭代 87000/100000, 损失 = 0.0419, rank_scale = 59.7070, 最佳损失 = 0.0419
# 迭代 88000/100000, 损失 = 0.0419, rank_scale = 60.2803, 最佳损失 = 0.0419
# 迭代 89000/100000, 损失 = 0.0419, rank_scale = 60.8499, 最佳损失 = 0.0419
# 迭代 90000/100000, 损失 = 0.0419, rank_scale = 61.4159, 最佳损失 = 0.0419
# 迭代 91000/100000, 损失 = 0.0419, rank_scale = 61.9783, 最佳损失 = 0.0419
# 迭代 92000/100000, 损失 = 0.0419, rank_scale = 62.5372, 最佳损失 = 0.0419
# 迭代 93000/100000, 损失 = 0.0419, rank_scale = 63.0925, 最佳损失 = 0.0419
# 迭代 94000/100000, 损失 = 0.0419, rank_scale = 63.6443, 最佳损失 = 0.0419
# 迭代 95000/100000, 损失 = 0.0419, rank_scale = 64.1937, 最佳损失 = 0.0419
# 迭代 96000/100000, 损失 = 0.0419, rank_scale = 64.7374, 最佳损失 = 0.0419
# 迭代 97000/100000, 损失 = 0.0419, rank_scale = 65.2790, 最佳损失 = 0.0419
# 迭代 98000/100000, 损失 = 0.0419, rank_scale = 65.8165, 最佳损失 = 0.0419
# 迭代 99000/100000, 损失 = 0.0419, rank_scale = 66.3506, 最佳损失 = 0.0419
# 迭代 100000/100000, 损失 = 0.0419, rank_scale = 66.8820, 最佳损失 = 0.0419
#
# 随机搜索: {'lambda_defense': 0.06780602616231217, 'lambda_offense': 0.1097037220101252, 'lambda_supervision': 0.092069553542002, 'lambda_reg': 0.006533353663762796}
# 迭代 1000/100000, 损失 = 0.1594, rank_scale = 1.7222, 最佳损失 = 0.1594
# 迭代 2000/100000, 损失 = 0.1118, rank_scale = 2.2329, 最佳损失 = 0.1118
# 迭代 3000/100000, 损失 = 0.0925, rank_scale = 2.6873, 最佳损失 = 0.0925
# 迭代 4000/100000, 损失 = 0.0828, rank_scale = 3.1276, 最佳损失 = 0.0828
# 迭代 5000/100000, 损失 = 0.0768, rank_scale = 3.5732, 最佳损失 = 0.0768
# 迭代 6000/100000, 损失 = 0.0725, rank_scale = 4.0347, 最佳损失 = 0.0725
# 迭代 7000/100000, 损失 = 0.0691, rank_scale = 4.5183, 最佳损失 = 0.0691
# 迭代 8000/100000, 损失 = 0.0663, rank_scale = 5.0270, 最佳损失 = 0.0663
# 迭代 9000/100000, 损失 = 0.0642, rank_scale = 5.5623, 最佳损失 = 0.0642
# 迭代 10000/100000, 损失 = 0.0624, rank_scale = 6.1245, 最佳损失 = 0.0624
# 迭代 11000/100000, 损失 = 0.0610, rank_scale = 6.7133, 最佳损失 = 0.0610
# 迭代 12000/100000, 损失 = 0.0601, rank_scale = 7.3335, 最佳损失 = 0.0601
# 迭代 13000/100000, 损失 = 0.0594, rank_scale = 7.9835, 最佳损失 = 0.0594
# 迭代 14000/100000, 损失 = 0.0589, rank_scale = 8.6581, 最佳损失 = 0.0589
# 迭代 15000/100000, 损失 = 0.0584, rank_scale = 9.3542, 最佳损失 = 0.0584
# 迭代 16000/100000, 损失 = 0.0580, rank_scale = 10.0698, 最佳损失 = 0.0580
# 迭代 17000/100000, 损失 = 0.0577, rank_scale = 10.8017, 最佳损失 = 0.0577
# 迭代 18000/100000, 损失 = 0.0574, rank_scale = 11.5450, 最佳损失 = 0.0574
# 迭代 19000/100000, 损失 = 0.0572, rank_scale = 12.2962, 最佳损失 = 0.0572
# 迭代 20000/100000, 损失 = 0.0570, rank_scale = 13.0535, 最佳损失 = 0.0570
# 迭代 21000/100000, 损失 = 0.0569, rank_scale = 13.8164, 最佳损失 = 0.0569
# 迭代 22000/100000, 损失 = 0.0568, rank_scale = 14.5844, 最佳损失 = 0.0568
# 迭代 23000/100000, 损失 = 0.0568, rank_scale = 15.3566, 最佳损失 = 0.0568
# 迭代 24000/100000, 损失 = 0.0567, rank_scale = 16.1318, 最佳损失 = 0.0567
# 迭代 25000/100000, 损失 = 0.0566, rank_scale = 16.9081, 最佳损失 = 0.0566
# 迭代 26000/100000, 损失 = 0.0566, rank_scale = 17.6851, 最佳损失 = 0.0566
# 迭代 27000/100000, 损失 = 0.0565, rank_scale = 18.4617, 最佳损失 = 0.0565
# 迭代 28000/100000, 损失 = 0.0565, rank_scale = 19.2380, 最佳损失 = 0.0565
# 迭代 29000/100000, 损失 = 0.0565, rank_scale = 20.0135, 最佳损失 = 0.0564
# 迭代 30000/100000, 损失 = 0.0564, rank_scale = 20.7878, 最佳损失 = 0.0564
# 迭代 31000/100000, 损失 = 0.0564, rank_scale = 21.5603, 最佳损失 = 0.0564
# 迭代 32000/100000, 损失 = 0.0563, rank_scale = 22.3310, 最佳损失 = 0.0563
# 迭代 33000/100000, 损失 = 0.0563, rank_scale = 23.0994, 最佳损失 = 0.0563
# 迭代 34000/100000, 损失 = 0.0563, rank_scale = 23.8656, 最佳损失 = 0.0562
# 迭代 35000/100000, 损失 = 0.0562, rank_scale = 24.6295, 最佳损失 = 0.0562
# 迭代 36000/100000, 损失 = 0.0562, rank_scale = 25.3909, 最佳损失 = 0.0562
# 迭代 37000/100000, 损失 = 0.0562, rank_scale = 26.1494, 最佳损失 = 0.0561
# 迭代 38000/100000, 损失 = 0.0561, rank_scale = 26.9051, 最佳损失 = 0.0561
# 迭代 39000/100000, 损失 = 0.0561, rank_scale = 27.6577, 最佳损失 = 0.0561
# 迭代 40000/100000, 损失 = 0.0561, rank_scale = 28.4075, 最佳损失 = 0.0561
# 迭代 41000/100000, 损失 = 0.0560, rank_scale = 29.1541, 最佳损失 = 0.0560
# 迭代 42000/100000, 损失 = 0.0560, rank_scale = 29.8972, 最佳损失 = 0.0560
# 迭代 43000/100000, 损失 = 0.0560, rank_scale = 30.6370, 最佳损失 = 0.0560
# 迭代 44000/100000, 损失 = 0.0560, rank_scale = 31.3735, 最佳损失 = 0.0560
# 迭代 45000/100000, 损失 = 0.0559, rank_scale = 32.1067, 最佳损失 = 0.0559
# 迭代 46000/100000, 损失 = 0.0559, rank_scale = 32.8361, 最佳损失 = 0.0559
# 迭代 47000/100000, 损失 = 0.0559, rank_scale = 33.5619, 最佳损失 = 0.0559
# 迭代 48000/100000, 损失 = 0.0559, rank_scale = 34.2841, 最佳损失 = 0.0559
# 迭代 49000/100000, 损失 = 0.0559, rank_scale = 35.0026, 最佳损失 = 0.0559
# 迭代 50000/100000, 损失 = 0.0558, rank_scale = 35.7174, 最佳损失 = 0.0558
# 迭代 51000/100000, 损失 = 0.0558, rank_scale = 36.4285, 最佳损失 = 0.0558
# 迭代 52000/100000, 损失 = 0.0558, rank_scale = 37.1357, 最佳损失 = 0.0558
# 迭代 53000/100000, 损失 = 0.0558, rank_scale = 37.8391, 最佳损失 = 0.0558
# 迭代 54000/100000, 损失 = 0.0558, rank_scale = 38.5388, 最佳损失 = 0.0558
# 迭代 55000/100000, 损失 = 0.0558, rank_scale = 39.2345, 最佳损失 = 0.0558
# 迭代 56000/100000, 损失 = 0.0558, rank_scale = 39.9264, 最佳损失 = 0.0557
# 迭代 57000/100000, 损失 = 0.0557, rank_scale = 40.6144, 最佳损失 = 0.0557
# 迭代 58000/100000, 损失 = 0.0557, rank_scale = 41.2986, 最佳损失 = 0.0557
# 迭代 59000/100000, 损失 = 0.0557, rank_scale = 41.9788, 最佳损失 = 0.0557
# 迭代 60000/100000, 损失 = 0.0557, rank_scale = 42.6551, 最佳损失 = 0.0557
# 迭代 61000/100000, 损失 = 0.0557, rank_scale = 43.3275, 最佳损失 = 0.0557
# 迭代 62000/100000, 损失 = 0.0557, rank_scale = 43.9960, 最佳损失 = 0.0557
# 迭代 63000/100000, 损失 = 0.0557, rank_scale = 44.6606, 最佳损失 = 0.0557
# 迭代 64000/100000, 损失 = 0.0557, rank_scale = 45.3211, 最佳损失 = 0.0557
# 迭代 65000/100000, 损失 = 0.0557, rank_scale = 45.9777, 最佳损失 = 0.0557
# 迭代 66000/100000, 损失 = 0.0557, rank_scale = 46.6303, 最佳损失 = 0.0556
# 迭代 67000/100000, 损失 = 0.0556, rank_scale = 47.2789, 最佳损失 = 0.0556
# 迭代 68000/100000, 损失 = 0.0556, rank_scale = 47.9235, 最佳损失 = 0.0556
# 迭代 69000/100000, 损失 = 0.0556, rank_scale = 48.5641, 最佳损失 = 0.0556
# 迭代 70000/100000, 损失 = 0.0556, rank_scale = 49.2007, 最佳损失 = 0.0556
# 迭代 71000/100000, 损失 = 0.0556, rank_scale = 49.8333, 最佳损失 = 0.0556
# 迭代 72000/100000, 损失 = 0.0556, rank_scale = 50.4621, 最佳损失 = 0.0556
# 迭代 73000/100000, 损失 = 0.0556, rank_scale = 51.0869, 最佳损失 = 0.0556
# 迭代 74000/100000, 损失 = 0.0556, rank_scale = 51.7079, 最佳损失 = 0.0556
# 迭代 75000/100000, 损失 = 0.0556, rank_scale = 52.3248, 最佳损失 = 0.0556
# 迭代 76000/100000, 损失 = 0.0556, rank_scale = 52.9378, 最佳损失 = 0.0556
# 迭代 77000/100000, 损失 = 0.0556, rank_scale = 53.5469, 最佳损失 = 0.0556
# 迭代 78000/100000, 损失 = 0.0556, rank_scale = 54.1522, 最佳损失 = 0.0556
# 迭代 79000/100000, 损失 = 0.0556, rank_scale = 54.7536, 最佳损失 = 0.0555
# 迭代 80000/100000, 损失 = 0.0556, rank_scale = 55.3512, 最佳损失 = 0.0555
# 迭代 81000/100000, 损失 = 0.0555, rank_scale = 55.9450, 最佳损失 = 0.0555
# 迭代 82000/100000, 损失 = 0.0555, rank_scale = 56.5348, 最佳损失 = 0.0555
# 迭代 83000/100000, 损失 = 0.0555, rank_scale = 57.1208, 最佳损失 = 0.0555
# 迭代 84000/100000, 损失 = 0.0555, rank_scale = 57.7031, 最佳损失 = 0.0555
# 迭代 85000/100000, 损失 = 0.0555, rank_scale = 58.2816, 最佳损失 = 0.0555
# 迭代 86000/100000, 损失 = 0.0555, rank_scale = 58.8563, 最佳损失 = 0.0555
# 迭代 87000/100000, 损失 = 0.0555, rank_scale = 59.4272, 最佳损失 = 0.0555
# 迭代 88000/100000, 损失 = 0.0555, rank_scale = 59.9944, 最佳损失 = 0.0555
# 迭代 89000/100000, 损失 = 0.0555, rank_scale = 60.5580, 最佳损失 = 0.0555
# 迭代 90000/100000, 损失 = 0.0555, rank_scale = 61.1179, 最佳损失 = 0.0555
# 迭代 91000/100000, 损失 = 0.0555, rank_scale = 61.6741, 最佳损失 = 0.0555
# 迭代 92000/100000, 损失 = 0.0555, rank_scale = 62.2266, 最佳损失 = 0.0555
# 迭代 93000/100000, 损失 = 0.0555, rank_scale = 62.7755, 最佳损失 = 0.0555
# 迭代 94000/100000, 损失 = 0.0555, rank_scale = 63.3208, 最佳损失 = 0.0555
# 迭代 95000/100000, 损失 = 0.0555, rank_scale = 63.8624, 最佳损失 = 0.0555
# 迭代 96000/100000, 损失 = 0.0555, rank_scale = 64.3996, 最佳损失 = 0.0555
# 迭代 97000/100000, 损失 = 0.0555, rank_scale = 64.9336, 最佳损失 = 0.0555
# 迭代 98000/100000, 损失 = 0.0555, rank_scale = 65.4650, 最佳损失 = 0.0555
# 迭代 99000/100000, 损失 = 0.0555, rank_scale = 65.9915, 最佳损失 = 0.0555
# 迭代 100000/100000, 损失 = 0.0555, rank_scale = 66.5168, 最佳损失 = 0.0555
#
# 随机搜索: {'lambda_defense': 0.1262520499972521, 'lambda_offense': 0.036503833523887946, 'lambda_supervision': 0.06550748322169145, 'lambda_reg': 0.007960875022580142}
# 迭代 1000/100000, 损失 = 0.1487, rank_scale = 1.7193, 最佳损失 = 0.1487
# 迭代 2000/100000, 损失 = 0.1040, rank_scale = 2.2278, 最佳损失 = 0.1040
# 迭代 3000/100000, 损失 = 0.0854, rank_scale = 2.6811, 最佳损失 = 0.0854
# 迭代 4000/100000, 损失 = 0.0757, rank_scale = 3.1208, 最佳损失 = 0.0757
# 迭代 5000/100000, 损失 = 0.0696, rank_scale = 3.5662, 最佳损失 = 0.0696
# 迭代 6000/100000, 损失 = 0.0653, rank_scale = 4.0278, 最佳损失 = 0.0653
# 迭代 7000/100000, 损失 = 0.0620, rank_scale = 4.5114, 最佳损失 = 0.0620
# 迭代 8000/100000, 损失 = 0.0593, rank_scale = 5.0203, 最佳损失 = 0.0593
# 迭代 9000/100000, 损失 = 0.0571, rank_scale = 5.5553, 最佳损失 = 0.0571
# 迭代 10000/100000, 损失 = 0.0554, rank_scale = 6.1172, 最佳损失 = 0.0554
# 迭代 11000/100000, 损失 = 0.0541, rank_scale = 6.7071, 最佳损失 = 0.0541
# 迭代 12000/100000, 损失 = 0.0533, rank_scale = 7.3333, 最佳损失 = 0.0533
# 迭代 13000/100000, 损失 = 0.0526, rank_scale = 7.9950, 最佳损失 = 0.0526
# 迭代 14000/100000, 损失 = 0.0518, rank_scale = 8.6869, 最佳损失 = 0.0518
# 迭代 15000/100000, 损失 = 0.0511, rank_scale = 9.4024, 最佳损失 = 0.0511
# 迭代 16000/100000, 损失 = 0.0503, rank_scale = 10.1339, 最佳损失 = 0.0503
# 迭代 17000/100000, 损失 = 0.0496, rank_scale = 10.8760, 最佳损失 = 0.0496
# 迭代 18000/100000, 损失 = 0.0489, rank_scale = 11.6248, 最佳损失 = 0.0489
# 迭代 19000/100000, 损失 = 0.0482, rank_scale = 12.3780, 最佳损失 = 0.0482
# 迭代 20000/100000, 损失 = 0.0476, rank_scale = 13.1341, 最佳损失 = 0.0476
# 迭代 21000/100000, 损失 = 0.0470, rank_scale = 13.8919, 最佳损失 = 0.0470
# 迭代 22000/100000, 损失 = 0.0465, rank_scale = 14.6508, 最佳损失 = 0.0465
# 迭代 23000/100000, 损失 = 0.0461, rank_scale = 15.4100, 最佳损失 = 0.0461
# 迭代 24000/100000, 损失 = 0.0457, rank_scale = 16.1691, 最佳损失 = 0.0457
# 迭代 25000/100000, 损失 = 0.0454, rank_scale = 16.9282, 最佳损失 = 0.0454
# 迭代 26000/100000, 损失 = 0.0451, rank_scale = 17.6873, 最佳损失 = 0.0451
# 迭代 27000/100000, 损失 = 0.0449, rank_scale = 18.4448, 最佳损失 = 0.0449
# 迭代 28000/100000, 损失 = 0.0447, rank_scale = 19.2020, 最佳损失 = 0.0447
# 迭代 29000/100000, 损失 = 0.0446, rank_scale = 19.9592, 最佳损失 = 0.0446
# 迭代 30000/100000, 损失 = 0.0445, rank_scale = 20.7165, 最佳损失 = 0.0445
# 迭代 31000/100000, 损失 = 0.0445, rank_scale = 21.4737, 最佳损失 = 0.0445
# 迭代 32000/100000, 损失 = 0.0444, rank_scale = 22.2309, 最佳损失 = 0.0444
# 迭代 33000/100000, 损失 = 0.0444, rank_scale = 22.9894, 最佳损失 = 0.0444
# 迭代 34000/100000, 损失 = 0.0444, rank_scale = 23.7491, 最佳损失 = 0.0444
# 迭代 35000/100000, 损失 = 0.0444, rank_scale = 24.5101, 最佳损失 = 0.0444
# 迭代 36000/100000, 损失 = 0.0444, rank_scale = 25.2711, 最佳损失 = 0.0444
# 迭代 37000/100000, 损失 = 0.0443, rank_scale = 26.0299, 最佳损失 = 0.0443
# 迭代 38000/100000, 损失 = 0.0443, rank_scale = 26.7862, 最佳损失 = 0.0443
# 迭代 39000/100000, 损失 = 0.0443, rank_scale = 27.5396, 最佳损失 = 0.0443
# 迭代 40000/100000, 损失 = 0.0443, rank_scale = 28.2899, 最佳损失 = 0.0443
# 迭代 41000/100000, 损失 = 0.0443, rank_scale = 29.0367, 最佳损失 = 0.0443
# 迭代 42000/100000, 损失 = 0.0443, rank_scale = 29.7802, 最佳损失 = 0.0443
# 迭代 43000/100000, 损失 = 0.0443, rank_scale = 30.5203, 最佳损失 = 0.0443
# 迭代 44000/100000, 损失 = 0.0443, rank_scale = 31.2569, 最佳损失 = 0.0443
# 迭代 45000/100000, 损失 = 0.0443, rank_scale = 31.9899, 最佳损失 = 0.0443
# 迭代 46000/100000, 损失 = 0.0442, rank_scale = 32.7192, 最佳损失 = 0.0442
# 迭代 47000/100000, 损失 = 0.0442, rank_scale = 33.4449, 最佳损失 = 0.0442
# 迭代 48000/100000, 损失 = 0.0442, rank_scale = 34.1668, 最佳损失 = 0.0442
# 迭代 49000/100000, 损失 = 0.0442, rank_scale = 34.8848, 最佳损失 = 0.0442
# 迭代 50000/100000, 损失 = 0.0442, rank_scale = 35.5990, 最佳损失 = 0.0442
# 迭代 51000/100000, 损失 = 0.0442, rank_scale = 36.3094, 最佳损失 = 0.0442
# 迭代 52000/100000, 损失 = 0.0442, rank_scale = 37.0160, 最佳损失 = 0.0442
# 迭代 53000/100000, 损失 = 0.0442, rank_scale = 37.7187, 最佳损失 = 0.0442
# 迭代 54000/100000, 损失 = 0.0442, rank_scale = 38.4173, 最佳损失 = 0.0442
# 迭代 55000/100000, 损失 = 0.0442, rank_scale = 39.1121, 最佳损失 = 0.0442
# 迭代 56000/100000, 损失 = 0.0442, rank_scale = 39.8029, 最佳损失 = 0.0442
# 迭代 57000/100000, 损失 = 0.0442, rank_scale = 40.4897, 最佳损失 = 0.0442
# 迭代 58000/100000, 损失 = 0.0442, rank_scale = 41.1724, 最佳损失 = 0.0442
# 迭代 59000/100000, 损失 = 0.0442, rank_scale = 41.8511, 最佳损失 = 0.0442
# 迭代 60000/100000, 损失 = 0.0442, rank_scale = 42.5257, 最佳损失 = 0.0442
# 迭代 61000/100000, 损失 = 0.0441, rank_scale = 43.1963, 最佳损失 = 0.0441
# 迭代 62000/100000, 损失 = 0.0441, rank_scale = 43.8629, 最佳损失 = 0.0441
# 迭代 63000/100000, 损失 = 0.0441, rank_scale = 44.5255, 最佳损失 = 0.0441
# 迭代 64000/100000, 损失 = 0.0441, rank_scale = 45.1840, 最佳损失 = 0.0441
# 迭代 65000/100000, 损失 = 0.0441, rank_scale = 45.8386, 最佳损失 = 0.0441
# 迭代 66000/100000, 损失 = 0.0441, rank_scale = 46.4890, 最佳损失 = 0.0441
# 迭代 67000/100000, 损失 = 0.0441, rank_scale = 47.1355, 最佳损失 = 0.0441
# 迭代 68000/100000, 损失 = 0.0441, rank_scale = 47.7779, 最佳损失 = 0.0441
# 迭代 69000/100000, 损失 = 0.0441, rank_scale = 48.4162, 最佳损失 = 0.0441
# 迭代 70000/100000, 损失 = 0.0441, rank_scale = 49.0507, 最佳损失 = 0.0441
# 迭代 71000/100000, 损失 = 0.0441, rank_scale = 49.6810, 最佳损失 = 0.0441
# 迭代 72000/100000, 损失 = 0.0441, rank_scale = 50.3074, 最佳损失 = 0.0441
# 迭代 73000/100000, 损失 = 0.0441, rank_scale = 50.9297, 最佳损失 = 0.0441
# 迭代 74000/100000, 损失 = 0.0441, rank_scale = 51.5482, 最佳损失 = 0.0441
# 迭代 75000/100000, 损失 = 0.0441, rank_scale = 52.1625, 最佳损失 = 0.0441
# 迭代 76000/100000, 损失 = 0.0441, rank_scale = 52.7730, 最佳损失 = 0.0441
# 迭代 77000/100000, 损失 = 0.0441, rank_scale = 53.3794, 最佳损失 = 0.0441
# 迭代 78000/100000, 损失 = 0.0441, rank_scale = 53.9819, 最佳损失 = 0.0441
# 迭代 79000/100000, 损失 = 0.0441, rank_scale = 54.5804, 最佳损失 = 0.0441
# 迭代 80000/100000, 损失 = 0.0441, rank_scale = 55.1750, 最佳损失 = 0.0441
# 迭代 81000/100000, 损失 = 0.0441, rank_scale = 55.7658, 最佳损失 = 0.0441
# 迭代 82000/100000, 损失 = 0.0441, rank_scale = 56.3527, 最佳损失 = 0.0441
# 迭代 83000/100000, 损失 = 0.0441, rank_scale = 56.9357, 最佳损失 = 0.0441
# 迭代 84000/100000, 损失 = 0.0441, rank_scale = 57.5149, 最佳损失 = 0.0441
# ...
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 super-league 图 -> /Users/peixuanma/Downloads/Output_Graphs/super-league_evolution.png
# 保存 liga-nos 图 -> /Users/peixuanma/Downloads/Output_Graphs/liga-nos_evolution.png
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 serie-b 图 -> /Users/peixuanma/Downloads/Output_Graphs/serie-b_evolution.png
# 保存 2-bundesliga 图 -> /Users/peixuanma/Downloads/Output_Graphs/2-bundesliga_evolution.png
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 premiership 图 -> /Users/peixuanma/Downloads/Output_Graphs/premiership_evolution.png
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:500: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/588551932.py:502: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 pro-league 图 -> /Users/peixuanma/Downloads/Output_Graphs/pro-league_evolution.png
#
# 完成！

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.model_selection import KFold
import sklearn

print(f"scikit-learn 版本: {sklearn.__version__}")

# ====================== 计算防守统计数据 ======================
def compute_defensive_stats(match_df, team_positions_df):
    """计算球队的防守统计数据，包括6种比率、总失球数和平均失球数"""
    epsilon = 1e-8  # 提高数值稳定性
    team_stats = {}
    for team in team_positions_df['team_name'].unique():
        team_stats[team] = {
            'total_goals_conceded': 0, 'ratio1_list': [], 'ratio2_list': [], 'ratio3_list': [],
            'ratio4_list': [], 'ratio5_list': [], 'ratio6_list': [], 'num_matches': 0
        }

    # 主场比赛统计
    for idx, row in match_df.iterrows():
        home_team, away_team = row['home_team_name'], row['away_team_name']
        if home_team not in team_stats or away_team not in team_stats:
            print(f"警告: 主队 {home_team} 或客队 {away_team} 未找到，跳过比赛 {idx}")
            continue
        if row['Pre-Match PPG (Away)'] > 0:
            team_stats[home_team]['ratio1_list'].append(
                row['away_team_goal_count'] / (row['Pre-Match PPG (Away)'] + epsilon))
        if row['away_team_corner_count'] > 0:
            team_stats[home_team]['ratio2_list'].append(
                row['away_team_goal_count'] / (row['away_team_corner_count'] + epsilon))
        denominator = row['home_team_yellow_cards'] + row['home_team_red_cards'] + row['home_team_fouls'] + epsilon
        team_stats[home_team]['ratio3_list'].append(row['away_team_goal_count'] / denominator)
        if row['team_b_xg'] > 0:
            team_stats[home_team]['ratio4_list'].append(row['away_team_goal_count'] / (row['team_b_xg'] + epsilon))
        shots_total = row['away_team_shots_on_target'] + row['away_team_shots_off_target'] + epsilon
        team_stats[home_team]['ratio5_list'].append(row['away_team_goal_count'] / shots_total)
        if row['away_team_possession'] > 0:
            team_stats[home_team]['ratio6_list'].append(
                row['away_team_goal_count'] / (row['away_team_possession'] + epsilon))
        team_stats[home_team]['total_goals_conceded'] += row['away_team_goal_count']
        team_stats[home_team]['num_matches'] += 1

    # 客场比赛统计
    for idx, row in match_df.iterrows():
        away_team = row['away_team_name']
        if away_team not in team_stats:
            print(f"警告: 客队 {away_team} 未找到，跳过比赛 {idx}")
            continue
        team_stats[away_team]['total_goals_conceded'] += row['home_team_goal_count']
        team_stats[away_team]['num_matches'] += 1

    # 汇总数据
    data = []
    for team, stats in team_stats.items():
        num_matches = stats['num_matches']
        average_goals_conceded = stats['total_goals_conceded'] / num_matches if num_matches > 0 else 0
        data.append({
            'team_name': team,
            'ratio1': np.mean(stats['ratio1_list']) if stats['ratio1_list'] else 0,
            'ratio2': np.mean(stats['ratio2_list']) if stats['ratio2_list'] else 0,
            'ratio3': np.mean(stats['ratio3_list']) if stats['ratio3_list'] else 0,
            'ratio4': np.mean(stats['ratio4_list']) if stats['ratio4_list'] else 0,
            'ratio5': np.mean(stats['ratio5_list']) if stats['ratio5_list'] else 0,
            'ratio6': np.mean(stats['ratio6_list']) if stats['ratio6_list'] else 0,
            'total_goals_conceded': stats['total_goals_conceded'],
            'average_goals_conceded': average_goals_conceded
        })

    return pd.DataFrame(data)

# ====================== 计算进攻统计数据 ======================
def compute_offensive_stats(match_df, team_positions_df):
    """计算球队的进攻统计数据，包括6种比率、总进球数和平均进球数"""
    epsilon = 1e-8  # 提高数值稳定性
    team_stats = {}
    for team in team_positions_df['team_name'].unique():
        team_stats[team] = {
            'total_goals_scored': 0, 'off_ratio1_list': [], 'off_ratio2_list': [], 'off_ratio3_list': [],
            'off_ratio4_list': [], 'off_ratio5_list': [], 'off_ratio6_list': [], 'num_matches': 0
        }

    # 主场比赛统计
    for idx, row in match_df.iterrows():
        home_team, away_team = row['home_team_name'], row['away_team_name']
        if home_team not in team_stats or away_team not in team_stats:
            continue
        if row['Pre-Match PPG (Home)'] > 0:
            team_stats[home_team]['off_ratio1_list'].append(
                row['home_team_goal_count'] / (row['Pre-Match PPG (Home)'] + epsilon))
        if row['home_team_corner_count'] > 0:
            team_stats[home_team]['off_ratio2_list'].append(
                row['home_team_goal_count'] / (row['home_team_corner_count'] + epsilon))
        denominator = row['away_team_yellow_cards'] + row['away_team_red_cards'] + row['away_team_fouls'] + epsilon
        team_stats[home_team]['off_ratio3_list'].append(row['home_team_goal_count'] / denominator)
        if row['team_a_xg'] > 0:
            team_stats[home_team]['off_ratio4_list'].append(row['home_team_goal_count'] / (row['team_a_xg'] + epsilon))
        shots_total = row['home_team_shots_on_target'] + row['home_team_shots_off_target'] + epsilon
        team_stats[home_team]['off_ratio5_list'].append(row['home_team_goal_count'] / shots_total)
        if row['home_team_possession'] > 0:
            team_stats[home_team]['off_ratio6_list'].append(
                row['home_team_goal_count'] / (row['home_team_possession'] + epsilon))
        team_stats[home_team]['total_goals_scored'] += row['home_team_goal_count']
        team_stats[home_team]['num_matches'] += 1

    # 客场比赛统计
    for idx, row in match_df.iterrows():
        away_team = row['away_team_name']
        if away_team not in team_stats:
            continue
        team_stats[away_team]['total_goals_scored'] += row['away_team_goal_count']
        team_stats[away_team]['num_matches'] += 1

    # 汇总数据
    data = []
    for team, stats in team_stats.items():
        num_matches = stats['num_matches']
        average_goals_scored = stats['total_goals_scored'] / num_matches if num_matches > 0 else 0
        data.append({
            'team_name': team,
            'off_ratio1': np.mean(stats['off_ratio1_list']) if stats['off_ratio1_list'] else 0,
            'off_ratio2': np.mean(stats['off_ratio2_list']) if stats['off_ratio2_list'] else 0,
            'off_ratio3': np.mean(stats['off_ratio3_list']) if stats['off_ratio3_list'] else 0,
            'off_ratio4': np.mean(stats['off_ratio4_list']) if stats['off_ratio4_list'] else 0,
            'off_ratio5': np.mean(stats['off_ratio5_list']) if stats['off_ratio5_list'] else 0,
            'off_ratio6': np.mean(stats['off_ratio6_list']) if stats['off_ratio6_list'] else 0,
            'total_goals_scored': stats['total_goals_scored'],
            'average_goals_scored': average_goals_scored
        })

    return pd.DataFrame(data)

# ====================== ELO评分算法实现 ======================
def initialize_elo_scores(team_positions_df):
    """初始化球队ELO分数"""
    teams = team_positions_df['team_name'].unique().tolist()
    team_elo = {team: 1500 for team in teams}
    for team in teams:
        team_data = team_positions_df[team_positions_df['team_name'] == team]
        rank = team_data['points_per_game'].rank().iloc[0]
        team_elo[team] += (20 * (len(teams) - rank))
    return team_elo

def update_elo_scores(elo_scores, home_team, away_team, home_score, away_score, K=30):
    """更新ELO分数"""
    home_elo, away_elo = elo_scores[home_team], elo_scores[away_team]
    expected_home = 1 / (1 + 10 ** ((away_elo - home_elo) / 400))
    expected_away = 1 / (1 + 10 ** ((home_elo - away_elo) / 400))

    if home_score > away_score:
        elo_scores[home_team] += K * (1 - expected_home)
        elo_scores[away_team] += K * (0 - expected_away)
    elif home_score < away_score:
        elo_scores[home_team] += K * (0 - expected_home)
        elo_scores[away_team] += K * (1 - expected_away)
    else:
        elo_scores[home_team] += K * (0.5 - expected_home)
        elo_scores[away_team] += K * (0.5 - expected_away)
    return elo_scores

# ====================== 数据加载函数（含聚类） ======================
def load_all_league_data(base_path, leagues, seasons):
    """加载所有联赛数据并进行预处理，使用聚类质心作为比赛锚点"""
    all_team_positions, all_match_positions = [], []
    global_cluster_centroid_positions = {}

    for country_name, league_name in leagues:
        for season in seasons:
            print(f"加载数据: {country_name} - {league_name} - {season}")
            team_file = os.path.join(base_path, f"{country_name}-{league_name}-teams-{season}-stats.csv")
            match_file = os.path.join(base_path, f"{country_name}-{league_name}-matches-{season}-stats.csv")
            if not os.path.exists(team_file) or not os.path.exists(match_file):
                print(f"警告: {country_name} - {league_name} - {season} 文件缺失")
                continue

            team_df = pd.read_csv(team_file)
            match_df = pd.read_csv(match_file)

            # 统一球队名称格式
            team_df['team_name'] = team_df.get('common_name', team_df.get('team_name', None)).str.strip().str.lower()
            match_df['home_team_name'] = match_df['home_team_name'].str.strip().str.lower()
            match_df['away_team_name'] = match_df['away_team_name'].str.strip().str.lower()

            team_names = team_df['team_name'].unique()
            original_match_count = len(match_df)
            match_df = match_df[
                match_df['home_team_name'].isin(team_names) & match_df['away_team_name'].isin(team_names)]
            if len(match_df) < original_match_count:
                print(f"警告: 过滤了 {original_match_count - len(match_df)} 场比赛")

            if match_df.empty:
                print("警告: 无有效比赛数据")
                continue

            # 计算防守和进攻统计
            defensive_stats_df = compute_defensive_stats(match_df, team_df)
            offensive_stats_df = compute_offensive_stats(match_df, team_df)
            if defensive_stats_df.empty or offensive_stats_df.empty:
                print("警告: 未计算出防守或进攻统计")
                continue

            team_df = team_df.merge(defensive_stats_df, on='team_name', how='left')
            team_df = team_df.merge(offensive_stats_df, on='team_name', how='left')

            for col in ['ratio1', 'ratio2', 'ratio3', 'ratio4', 'ratio5', 'ratio6', 'total_goals_conceded', 'average_goals_conceded',
                        'off_ratio1', 'off_ratio2', 'off_ratio3', 'off_ratio4', 'off_ratio5', 'off_ratio6', 'total_goals_scored', 'average_goals_scored']:
                if col not in team_df.columns:
                    print(f"警告: {col} 列缺失，设为0")
                    team_df[col] = 0

            # 归一化防守得分
            if 'total_goals_conceded' in team_df.columns and team_df['total_goals_conceded'].max() != team_df['total_goals_conceded'].min():
                team_df['normalized_defense_score'] = (team_df['total_goals_conceded'].max() - team_df['total_goals_conceded']) / (
                    team_df['total_goals_conceded'].max() - team_df['total_goals_conceded'].min() + 1e-8)
            else:
                team_df['normalized_defense_score'] = 0

            # PCA降维（防守和进攻数据）
            defensive_columns = ['total_goals_conceded', 'ratio1', 'ratio2', 'ratio3', 'ratio4', 'ratio5', 'ratio6', 'average_goals_conceded']
            offensive_columns = ['total_goals_scored', 'off_ratio1', 'off_ratio2', 'off_ratio3', 'off_ratio4', 'off_ratio5', 'off_ratio6', 'average_goals_scored']
            team_df_defensive = team_df[defensive_columns].fillna(0)
            kf = KFold(n_splits=5, shuffle=True, random_state=42)
            pca_results = []
            for train_idx, _ in kf.split(team_df_defensive):
                train_data = team_df_defensive.iloc[train_idx]
                scaler = StandardScaler()
                X_scaled = scaler.fit_transform(train_data)
                pca = PCA(n_components=2)
                X_pca = pca.fit_transform(X_scaled)
                pca_results.append(X_pca)
            X_pca_avg = np.mean([np.pad(r, ((0, len(team_df_defensive) - len(r)), (0, 0)), 'constant') for r in pca_results], axis=0)

            team_positions = pd.DataFrame({
                'team_name': team_df['team_name'], 'PC1': X_pca_avg[:, 0], 'PC2': X_pca_avg[:, 1],
                'points_per_game': team_df['points_per_game'], 'league': league_name, 'season': season,
                'ratio1': team_df['ratio1'], 'ratio2': team_df['ratio2'], 'ratio3': team_df['ratio3'],
                'ratio4': team_df['ratio4'], 'ratio5': team_df['ratio5'], 'ratio6': team_df['ratio6'],
                'off_ratio1': team_df['off_ratio1'], 'off_ratio2': team_df['off_ratio2'], 'off_ratio3': team_df['off_ratio3'],
                'off_ratio4': team_df['off_ratio4'], 'off_ratio5': team_df['off_ratio5'], 'off_ratio6': team_df['off_ratio6'],
                'normalized_defense_score': team_df['normalized_defense_score'],
                'total_goals_conceded': team_df['total_goals_conceded'],
                'average_goals_conceded': team_df['average_goals_conceded'],
                'total_goals_scored': team_df['total_goals_scored'],
                'average_goals_scored': team_df['average_goals_scored']
            })
            team_positions['team_season'] = league_name + '_' + team_positions['team_name'] + '_' + team_positions['season']
            all_team_positions.append(team_positions)

            # 比赛数据聚类
            match_df = match_df.drop(columns=['timestamp', 'date_GMT', 'status', 'attendance', 'referee', 'stadium_name', 'Game Week'], errors='ignore')
            numeric_cols = match_df.select_dtypes(include=[np.number]).columns
            match_df[numeric_cols] = match_df[numeric_cols].fillna(match_df[numeric_cols].mean())
            scaler = StandardScaler()
            X_scaled = scaler.fit_transform(match_df[numeric_cols])

            # 选择最佳簇数 k
            silhouette_scores = []
            max_k = min(10, len(X_scaled) // 2)
            for k in range(2, max_k + 1):
                kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
                cluster_labels = kmeans.fit_predict(X_scaled)
                silhouette_avg = silhouette_score(X_scaled, cluster_labels)
                silhouette_scores.append(silhouette_avg)
            if silhouette_scores:
                best_k = np.argmax(silhouette_scores) + 2
            else:
                best_k = 2

            # 聚类
            kmeans = KMeans(n_clusters=best_k, random_state=42, n_init=10)
            cluster_labels = kmeans.fit_predict(X_scaled)
            match_df['cluster_id'] = cluster_labels

            # 计算簇质心并降维
            centroids = kmeans.cluster_centers_
            if len(centroids) > 0:
                pca_centroids = PCA(n_components=2).fit_transform(centroids)
                cluster_centroid_positions = {i: pca_centroids[i] for i in range(best_k)}
                global_cluster_centroid_positions[f"{league_name}_{season}"] = cluster_centroid_positions

            # 存储比赛数据
            match_positions = pd.DataFrame({
                'home_team_name': match_df['home_team_name'], 'away_team_name': match_df['away_team_name'],
                'cluster_id': match_df['cluster_id'], 'league': league_name, 'season': season
            })
            all_match_positions.append(match_positions)

    return pd.concat(all_team_positions, ignore_index=True), pd.concat(all_match_positions, ignore_index=True), global_cluster_centroid_positions

# ====================== 损失函数 ======================
def compute_total_loss(positions, match_home_idx, match_away_idx, match_cluster_ids, cluster_centroid_positions, points_per_game, rank_scale,
                       def_ratios, w_def, off_ratios, w_off, normalized_defense_score, lambda_defense, lambda_offense,
                       lambda_supervision, lambda_reg, elo_scores, home_advantage, match_results):
    """计算总损失，包括匹配损失、防守损失、进攻损失、监督损失和主场优势损失"""
    epsilon = 1e-8
    if tf.shape(match_home_idx)[0] == 0:
        return tf.constant(0.0, dtype=tf.float32)

    # 匹配损失
    home_pos = tf.gather(positions, match_home_idx)
    away_pos = tf.gather(positions, match_away_idx)
    match_target_pos = tf.gather(cluster_centroid_positions, match_cluster_ids)
    dist_home = tf.norm(home_pos - match_target_pos + epsilon, axis=1)
    dist_away = tf.norm(away_pos - match_target_pos + epsilon, axis=1)
    all_distances = tf.concat([dist_home, dist_away], axis=0)
    dist_range = tf.reduce_max(all_distances) - tf.reduce_min(all_distances) + epsilon
    dist_home_norm = (dist_home - tf.reduce_min(all_distances)) / dist_range
    dist_away_norm = (dist_away - tf.reduce_min(all_distances)) / dist_range

    # 在ELO分数计算中加入主场优势
    home_elo = tf.gather(elo_scores, match_home_idx) + home_advantage
    away_elo = tf.gather(elo_scores, match_away_idx)
    elo_diff = tf.abs(home_elo - away_elo)
    weight = 1.0 / (1.0 + elo_diff * rank_scale + epsilon)
    match_loss = tf.reduce_mean(weight * (dist_home_norm + dist_away_norm))

    # 防守损失
    w_def = tf.abs(w_def)
    defense_target = -tf.reduce_sum(w_def * def_ratios, axis=1)
    defense_loss = tf.reduce_mean(tf.square(positions[:, 1] - defense_target))

    # 进攻损失
    w_off = tf.abs(w_off)
    offense_target = tf.reduce_sum(w_off * off_ratios, axis=1)
    offense_loss = tf.reduce_mean(tf.square(positions[:, 0] - offense_target))

    # 监督损失
    supervision_loss = tf.reduce_mean(tf.square(defense_target - normalized_defense_score))

    # 正则化
    regularization_loss = lambda_reg * (tf.reduce_sum(tf.square(w_def)) + tf.reduce_sum(tf.square(w_off)))

    # 主场优势损失：基于比赛结果优化home_advantage
    expected_home = 1 / (1 + 10 ** ((away_elo - home_elo) / 400))
    actual_result = tf.cast(match_results, tf.float32)  # 1: 主胜, 0: 平局或客胜
    home_advantage_loss = tf.reduce_mean(tf.square(expected_home - actual_result))

    total_loss = (match_loss + lambda_defense * defense_loss + lambda_offense * offense_loss +
                  lambda_supervision * supervision_loss + regularization_loss + home_advantage_loss)
    return tf.where(tf.math.is_nan(total_loss) | tf.math.is_inf(total_loss), 0.0, total_loss)

# ====================== Adam优化函数 ======================
def adam_optimize_positions(team_positions_df, match_positions_df, cluster_centroid_positions, initial_lr=0.001, decay_steps=20000, decay_rate=0.9,
                            clipnorm=0.5, iterations=100000, verbose_interval=1000, random_seed=42, lambda_defense=0.1,
                            lambda_offense=0.1, lambda_supervision=0.1, lambda_reg=0.01, w_def=None, w_off=None):
    """使用Adam优化球队位置，新增主场优势参数"""
    team_seasons = team_positions_df['team_season'].unique()
    team_season_to_idx = {t: i for i, t in enumerate(team_seasons)}

    elo_scores_dict = initialize_elo_scores(team_positions_df)
    team_names = [t.split('_')[1] for t in team_seasons]
    elo_scores = tf.convert_to_tensor([elo_scores_dict[name] for name in team_names], dtype=tf.float32)

    team_positions_df = team_positions_df.set_index('team_season')
    init_positions = team_positions_df[['PC1', 'PC2']].values
    def_ratios = team_positions_df[['ratio1', 'ratio2', 'ratio3', 'ratio4', 'ratio5', 'ratio6', 'total_goals_conceded', 'average_goals_conceded']].values
    off_ratios = team_positions_df[['off_ratio1', 'off_ratio2', 'off_ratio3', 'off_ratio4', 'off_ratio5', 'off_ratio6', 'total_goals_scored', 'average_goals_scored']].values

    scaler_pos = StandardScaler()
    scaler_def = StandardScaler()
    scaler_off = StandardScaler()
    positions_scaled = scaler_pos.fit_transform(init_positions)
    def_ratios_scaled = scaler_def.fit_transform(def_ratios)
    off_ratios_scaled = scaler_off.fit_transform(off_ratios)

    positions = tf.Variable(positions_scaled, dtype=tf.float32)
    def_ratios = tf.constant(def_ratios_scaled, dtype=tf.float32)
    off_ratios = tf.constant(off_ratios_scaled, dtype=tf.float32)
    normalized_defense_score = tf.constant(team_positions_df['normalized_defense_score'].values, dtype=tf.float32)
    points_per_game = tf.constant(team_positions_df['points_per_game'].values, dtype=tf.float32)

    # 初始化可学习的主场优势参数
    home_advantage = tf.Variable(50.0, dtype=tf.float32, trainable=True)  # 初始值设为50，可调整

    match_array = []
    match_results = []  # 记录比赛结果用于优化主场优势
    for _, row in match_positions_df.iterrows():
        home_key = f"{row['league']}_{row['home_team_name']}_{row['season']}"
        away_key = f"{row['league']}_{row['away_team_name']}_{row['season']}"
        if home_key in team_season_to_idx and away_key in team_season_to_idx:
            match_array.append([team_season_to_idx[home_key], team_season_to_idx[away_key], row['cluster_id']])
            # 假设match_positions_df有比赛结果列，这里简化为主胜为1，否则为0
            # 需要根据实际数据调整
            result = 1 if row.get('home_team_goal_count', 0) > row.get('away_team_goal_count', 0) else 0
            match_results.append(result)
    match_array = np.array(match_array, dtype=np.float32)
    match_results = np.array(match_results, dtype=np.int32)
    if len(match_array) == 0:
        print("警告: 无有效比赛数据")
        return [], team_positions_df.reset_index(), None, None, None, None

    match_home_idx = tf.constant(match_array[:, 0], dtype=tf.int32)
    match_away_idx = tf.constant(match_array[:, 1], dtype=tf.int32)
    match_cluster_ids = tf.constant(match_array[:, 2], dtype=tf.int32)
    match_results = tf.constant(match_results, dtype=tf.int32)

    # 将所有联赛和赛季的簇质心合并为一个张量
    all_centroids = []
    cluster_id_map = {}
    current_id = 0
    for league_season, centroids_dict in cluster_centroid_positions.items():
        for cid, pos in centroids_dict.items():
            cluster_id_map[(league_season, cid)] = current_id
            all_centroids.append(pos)
            current_id += 1
    cluster_centroid_positions_tf = tf.constant(np.array(all_centroids), dtype=tf.float32)

    # 调整 match_cluster_ids 以匹配全局 cluster_id
    adjusted_cluster_ids = []
    for _, row in match_positions_df.iterrows():
        league_season = f"{row['league']}_{row['season']}"
        if league_season in cluster_centroid_positions and row['cluster_id'] in cluster_centroid_positions[league_season]:
            adjusted_cluster_ids.append(cluster_id_map[(league_season, row['cluster_id'])])
    match_cluster_ids = tf.constant(adjusted_cluster_ids, dtype=tf.int32)

    tf.random.set_seed(random_seed)
    rank_scale = tf.Variable(1.0, dtype=tf.float32)
    w_def = tf.Variable(np.abs(w_def) if w_def is not None else np.ones(8, dtype=np.float32) / 8, dtype=tf.float32)
    w_off = tf.Variable(np.abs(w_off) if w_off is not None else np.ones(8, dtype=np.float32) / 8, dtype=tf.float32)
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(initial_lr, decay_steps, decay_rate)
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule, clipnorm=clipnorm)

    losses, best_loss = [], float('inf')
    best_positions = positions.numpy().copy()
    best_rank_scale, best_w_def, best_w_off, best_home_advantage = 1.0, w_def.numpy().copy(), w_off.numpy().copy(), home_advantage.numpy()

    for i in range(iterations):
        with tf.GradientTape() as tape:
            loss = compute_total_loss(positions, match_home_idx, match_away_idx, match_cluster_ids, cluster_centroid_positions_tf, points_per_game,
                                      rank_scale, def_ratios, w_def, off_ratios, w_off, normalized_defense_score,
                                      lambda_defense, lambda_offense, lambda_supervision, lambda_reg, elo_scores,
                                      home_advantage, match_results)
        grads = tape.gradient(loss, [positions, rank_scale, w_def, w_off, home_advantage])
        if any(g is None for g in grads):
            print(f"警告: 迭代 {i + 1} 梯度为None")
            continue
        optimizer.apply_gradients(zip(grads, [positions, rank_scale, w_def, w_off, home_advantage]))
        loss_val = float(loss.numpy())
        losses.append(loss_val)

        if loss_val < best_loss:
            best_loss = loss_val
            best_positions = positions.numpy().copy()
            best_rank_scale = float(rank_scale.numpy())
            best_w_def = w_def.numpy().copy()
            best_w_off = w_off.numpy().copy()
            best_home_advantage = float(home_advantage.numpy())

        if (i + 1) % verbose_interval == 0:
            print(f"迭代 {i + 1}/{iterations}, 损失 = {loss_val:.4f}, rank_scale = {rank_scale.numpy():.4f}, "
                  f"主场优势 = {home_advantage.numpy():.4f}, 最佳损失 = {best_loss:.4f}")

    positions.assign(best_positions)
    rank_scale.assign(best_rank_scale)
    w_def.assign(best_w_def)
    w_off.assign(best_w_off)
    home_advantage.assign(best_home_advantage)
    final_pos = scaler_pos.inverse_transform(positions.numpy())
    for idx, team_season in enumerate(team_seasons):
        team_positions_df.loc[team_season, 'PC1'] = final_pos[idx, 0]
        team_positions_df.loc[team_season, 'PC2'] = final_pos[idx, 1]
    team_positions_df = team_positions_df.reset_index()
    return losses, team_positions_df, best_rank_scale, best_w_def, best_w_off, best_home_advantage

# ====================== 随机搜索超参数函数 ======================
def random_search_hyperparameters(team_positions, match_positions, cluster_centroid_positions, w_def, w_off, n_iter=10, random_state=42):
    """随机搜索最佳超参数"""
    np.random.seed(random_state)
    best_loss, best_params = float('inf'), None

    for _ in range(n_iter):
        params = {
            'lambda_defense': np.random.uniform(0.01, 0.2),
            'lambda_offense': np.random.uniform(0.01, 0.2),
            'lambda_supervision': np.random.uniform(0.01, 0.2),
            'lambda_reg': np.random.uniform(0.001, 0.02)
        }
        print(f"\n随机搜索: {params}")

        losses, _, _, _, _, _ = adam_optimize_positions(
            team_positions.copy(), match_positions.copy(), cluster_centroid_positions, w_def=w_def, w_off=w_off, **params
        )
        if losses and losses[-1] < best_loss:
            best_loss = losses[-1]
            best_params = params

    print(f"\n最佳超参数: {best_params}, 最佳损失: {best_loss:.4f}")
    return best_params

# ====================== 可视化函数 ======================
def visualize_team_evolution_by_league_static(team_positions_df, seasons_order):
    """按联赛可视化球队演变"""
    output_dir = "/Users/peixuanma/Downloads/Output_Graphs"
    os.makedirs(output_dir, exist_ok=True)

    for league in team_positions_df['league'].unique():
        league_df = team_positions_df[team_positions_df['league'] == league].copy()
        valid_teams = league_df.groupby("team_name").filter(lambda x: x['season'].nunique() == len(seasons_order))['team_name'].unique()
        if not valid_teams.size:
            valid_teams = league_df['team_name'].unique()
        valid_df = league_df[league_df['team_name'].isin(valid_teams)].sort_values(['team_name', 'season'])

        plt.figure(figsize=(10, 8))
        plt.title(f"{league} - 球队演变 (进攻-防守)")
        plt.xlabel("PC1 (进攻)")
        plt.ylabel("PC2 (防守)")
        plt.grid(True)

        for team in valid_df['team_name'].unique():
            sub = valid_df[valid_df['team_name'] == team]
            if 'PC1' in sub.columns and 'PC2' in sub.columns:
                plt.plot(sub['PC1'], sub['PC2'], marker='o', label=team)
                for _, row in sub.iterrows():
                    plt.text(row['PC1'], row['PC2'], row['season'], fontsize=8, ha='right')

        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        plt.tight_layout()
        filename = os.path.join(output_dir, f"{league}_evolution.png")
        plt.savefig(filename, dpi=150)
        plt.close()
        print(f"保存 {league} 图 -> {filename}")

# ====================== 主函数 ======================
if __name__ == "__main__":
    base_path = '/Users/peixuanma/Downloads/data1'
    leagues = [
        ("england", "premier-league"), ("germany", "bundesliga"), ("spain", "la-liga"),
        ("france", "ligue-1"), ("france", "ligue-2"), ("italy", "serie-a"), ("netherlands", "eredivisie"),
        ("portugal", "ligapro"), ("denmark", "superliga"), ("england", "championship"), ("spain", "segunda-division"),
        ("switzerland", "super-league"), ("portugal", "liga-nos"), ("italy", "serie-b"), ("germany", "2-bundesliga"),
        ("scotland", "premiership"), ("belgium", "pro-league"), ("austria", "bundesliga"),
    ]
    seasons = [
        "2013-to-2014", "2014-to-2015", "2015-to-2016", "2016-to-2017", "2017-to-2018",
        "2018-to-2019", "2019-to-2020", "2020-to-2021", "2021-to-2022", "2022-to-2023", "2023-to-2024"
    ]

    # 手动输入防守和进攻权重（示例值）
    w_def = np.array([
        0.12714323, 0.11415731, 0.04532705, 0.23075414, 0.03240472, 0.14205644, 0.13323908, 0.17491804
    ], dtype=np.float32)

    w_off = np.array([
        0.07438711, 0.07787083, 0.08495551, 0.22353454, 0.08152269, 0.08466186, 0.16022788, 0.21283953
    ], dtype=np.float32)

    # 加载数据
    print("===== 加载数据 =====")
    all_team_positions, all_match_positions, cluster_centroid_positions = load_all_league_data(base_path, leagues, seasons)

    # 随机搜索超参数
    print("\n===== 随机搜索超参数 =====")
    best_params = random_search_hyperparameters(all_team_positions, all_match_positions, cluster_centroid_positions, w_def, w_off)

    # 最终训练
    print("\n===== 最终训练 =====")
    final_losses, final_team_positions, final_rank_scale, final_w_def, final_w_off, final_home_advantage = adam_optimize_positions(
        all_team_positions.copy(), all_match_positions.copy(), cluster_centroid_positions, w_def=w_def, w_off=w_off, **best_params
    )
    if final_losses:
        final_team_positions.to_csv("trained_team_positions.csv", index=False)
        print(f"最终损失: {final_losses[-1]:.4f}")
        print(f"最终防守权重: {final_w_def}")
        print(f"最终进攻权重: {final_w_off}")
        print(f"最终主场优势值: {final_home_advantage}")

    # 可视化
    print("\n===== 可视化 =====")
    visualize_team_evolution_by_league_static(final_team_positions, seasons)

    print("\n完成！")
# Out:
# scikit-learn 版本: 1.4.2
# ===== 加载数据 =====
# 加载数据: england - premier-league - 2013-to-2014
# 加载数据: england - premier-league - 2014-to-2015
# 加载数据: england - premier-league - 2015-to-2016
# 加载数据: england - premier-league - 2016-to-2017
# 加载数据: england - premier-league - 2017-to-2018
# 加载数据: england - premier-league - 2018-to-2019
# 加载数据: england - premier-league - 2019-to-2020
# 加载数据: england - premier-league - 2020-to-2021
# 加载数据: england - premier-league - 2021-to-2022
# 加载数据: england - premier-league - 2022-to-2023
# 加载数据: england - premier-league - 2023-to-2024
# 加载数据: germany - bundesliga - 2013-to-2014
# 加载数据: germany - bundesliga - 2014-to-2015
# 加载数据: germany - bundesliga - 2015-to-2016
# 加载数据: germany - bundesliga - 2016-to-2017
# 加载数据: germany - bundesliga - 2017-to-2018
# 加载数据: germany - bundesliga - 2018-to-2019
# 加载数据: germany - bundesliga - 2019-to-2020
# 加载数据: germany - bundesliga - 2020-to-2021
# 加载数据: germany - bundesliga - 2021-to-2022
# 加载数据: germany - bundesliga - 2022-to-2023
# 加载数据: germany - bundesliga - 2023-to-2024
# 加载数据: spain - la-liga - 2013-to-2014
# 加载数据: spain - la-liga - 2014-to-2015
# 加载数据: spain - la-liga - 2015-to-2016
# 加载数据: spain - la-liga - 2016-to-2017
# 加载数据: spain - la-liga - 2017-to-2018
# 加载数据: spain - la-liga - 2018-to-2019
# 加载数据: spain - la-liga - 2019-to-2020
# 加载数据: spain - la-liga - 2020-to-2021
# 加载数据: spain - la-liga - 2021-to-2022
# 加载数据: spain - la-liga - 2022-to-2023
# 加载数据: spain - la-liga - 2023-to-2024
# 加载数据: france - ligue-1 - 2013-to-2014
# 加载数据: france - ligue-1 - 2014-to-2015
# 加载数据: france - ligue-1 - 2015-to-2016
# 加载数据: france - ligue-1 - 2016-to-2017
# 加载数据: france - ligue-1 - 2017-to-2018
# 加载数据: france - ligue-1 - 2018-to-2019
# 加载数据: france - ligue-1 - 2019-to-2020
# 警告: france - ligue-1 - 2019-to-2020 文件缺失
# 加载数据: france - ligue-1 - 2020-to-2021
# 加载数据: france - ligue-1 - 2021-to-2022
# 加载数据: france - ligue-1 - 2022-to-2023
# 加载数据: france - ligue-1 - 2023-to-2024
# 加载数据: france - ligue-2 - 2013-to-2014
# 加载数据: france - ligue-2 - 2014-to-2015
# 加载数据: france - ligue-2 - 2015-to-2016
# 加载数据: france - ligue-2 - 2016-to-2017
# 加载数据: france - ligue-2 - 2017-to-2018
# 加载数据: france - ligue-2 - 2018-to-2019
# 加载数据: france - ligue-2 - 2019-to-2020
# 警告: france - ligue-2 - 2019-to-2020 文件缺失
# 加载数据: france - ligue-2 - 2020-to-2021
# 加载数据: france - ligue-2 - 2021-to-2022
# 加载数据: france - ligue-2 - 2022-to-2023
# 加载数据: france - ligue-2 - 2023-to-2024
# 加载数据: italy - serie-a - 2013-to-2014
# 加载数据: italy - serie-a - 2014-to-2015
# 加载数据: italy - serie-a - 2015-to-2016
# 加载数据: italy - serie-a - 2016-to-2017
# 加载数据: italy - serie-a - 2017-to-2018
# 加载数据: italy - serie-a - 2018-to-2019
# 加载数据: italy - serie-a - 2019-to-2020
# 加载数据: italy - serie-a - 2020-to-2021
# 加载数据: italy - serie-a - 2021-to-2022
# 加载数据: italy - serie-a - 2022-to-2023
# 加载数据: italy - serie-a - 2023-to-2024
# 加载数据: netherlands - eredivisie - 2013-to-2014
# 加载数据: netherlands - eredivisie - 2014-to-2015
# 加载数据: netherlands - eredivisie - 2015-to-2016
# 加载数据: netherlands - eredivisie - 2016-to-2017
# 加载数据: netherlands - eredivisie - 2017-to-2018
# 加载数据: netherlands - eredivisie - 2018-to-2019
# 加载数据: netherlands - eredivisie - 2019-to-2020
# 加载数据: netherlands - eredivisie - 2020-to-2021
# 加载数据: netherlands - eredivisie - 2021-to-2022
# 加载数据: netherlands - eredivisie - 2022-to-2023
# 加载数据: netherlands - eredivisie - 2023-to-2024
# 加载数据: portugal - ligapro - 2013-to-2014
# 警告: portugal - ligapro - 2013-to-2014 文件缺失
# 加载数据: portugal - ligapro - 2014-to-2015
# 加载数据: portugal - ligapro - 2015-to-2016
# 加载数据: portugal - ligapro - 2016-to-2017
# 加载数据: portugal - ligapro - 2017-to-2018
# 加载数据: portugal - ligapro - 2018-to-2019
# 加载数据: portugal - ligapro - 2019-to-2020
# 加载数据: portugal - ligapro - 2020-to-2021
# 加载数据: portugal - ligapro - 2021-to-2022
# 加载数据: portugal - ligapro - 2022-to-2023
# 加载数据: portugal - ligapro - 2023-to-2024
# 加载数据: denmark - superliga - 2013-to-2014
# 加载数据: denmark - superliga - 2014-to-2015
# 加载数据: denmark - superliga - 2015-to-2016
# 加载数据: denmark - superliga - 2016-to-2017
# 加载数据: denmark - superliga - 2017-to-2018
# 加载数据: denmark - superliga - 2018-to-2019
# 加载数据: denmark - superliga - 2019-to-2020
# 加载数据: denmark - superliga - 2020-to-2021
# 加载数据: denmark - superliga - 2021-to-2022
# 加载数据: denmark - superliga - 2022-to-2023
# 加载数据: denmark - superliga - 2023-to-2024
# 加载数据: england - championship - 2013-to-2014
# 加载数据: england - championship - 2014-to-2015
# 加载数据: england - championship - 2015-to-2016
# 加载数据: england - championship - 2016-to-2017
# 加载数据: england - championship - 2017-to-2018
# 加载数据: england - championship - 2018-to-2019
# 加载数据: england - championship - 2019-to-2020
# 加载数据: england - championship - 2020-to-2021
# 加载数据: england - championship - 2021-to-2022
# 加载数据: england - championship - 2022-to-2023
# 加载数据: england - championship - 2023-to-2024
# 加载数据: spain - segunda-division - 2013-to-2014
# 加载数据: spain - segunda-division - 2014-to-2015
# 加载数据: spain - segunda-division - 2015-to-2016
# 加载数据: spain - segunda-division - 2016-to-2017
# 加载数据: spain - segunda-division - 2017-to-2018
# 加载数据: spain - segunda-division - 2018-to-2019
# 加载数据: spain - segunda-division - 2019-to-2020
# 加载数据: spain - segunda-division - 2020-to-2021
# 加载数据: spain - segunda-division - 2021-to-2022
# 加载数据: spain - segunda-division - 2022-to-2023
# 加载数据: spain - segunda-division - 2023-to-2024
# 加载数据: switzerland - super-league - 2013-to-2014
# 加载数据: switzerland - super-league - 2014-to-2015
# 加载数据: switzerland - super-league - 2015-to-2016
# 加载数据: switzerland - super-league - 2016-to-2017
# 加载数据: switzerland - super-league - 2017-to-2018
# 加载数据: switzerland - super-league - 2018-to-2019
# 加载数据: switzerland - super-league - 2019-to-2020
# 加载数据: switzerland - super-league - 2020-to-2021
# 加载数据: switzerland - super-league - 2021-to-2022
# 加载数据: switzerland - super-league - 2022-to-2023
# 加载数据: switzerland - super-league - 2023-to-2024
# 加载数据: portugal - liga-nos - 2013-to-2014
# 加载数据: portugal - liga-nos - 2014-to-2015
# 加载数据: portugal - liga-nos - 2015-to-2016
# 加载数据: portugal - liga-nos - 2016-to-2017
# 加载数据: portugal - liga-nos - 2017-to-2018
# 加载数据: portugal - liga-nos - 2018-to-2019
# 加载数据: portugal - liga-nos - 2019-to-2020
# 加载数据: portugal - liga-nos - 2020-to-2021
# 加载数据: portugal - liga-nos - 2021-to-2022
# 加载数据: portugal - liga-nos - 2022-to-2023
# 加载数据: portugal - liga-nos - 2023-to-2024
# 加载数据: italy - serie-b - 2013-to-2014
# 加载数据: italy - serie-b - 2014-to-2015
# 加载数据: italy - serie-b - 2015-to-2016
# 加载数据: italy - serie-b - 2016-to-2017
# 加载数据: italy - serie-b - 2017-to-2018
# 加载数据: italy - serie-b - 2018-to-2019
# 加载数据: italy - serie-b - 2019-to-2020
# 加载数据: italy - serie-b - 2020-to-2021
# 加载数据: italy - serie-b - 2021-to-2022
# 加载数据: italy - serie-b - 2022-to-2023
# 加载数据: italy - serie-b - 2023-to-2024
# 加载数据: germany - 2-bundesliga - 2013-to-2014
# 加载数据: germany - 2-bundesliga - 2014-to-2015
# 加载数据: germany - 2-bundesliga - 2015-to-2016
# 加载数据: germany - 2-bundesliga - 2016-to-2017
# 加载数据: germany - 2-bundesliga - 2017-to-2018
# 加载数据: germany - 2-bundesliga - 2018-to-2019
# 加载数据: germany - 2-bundesliga - 2019-to-2020
# 加载数据: germany - 2-bundesliga - 2020-to-2021
# 加载数据: germany - 2-bundesliga - 2021-to-2022
# 加载数据: germany - 2-bundesliga - 2022-to-2023
# 加载数据: germany - 2-bundesliga - 2023-to-2024
# 加载数据: scotland - premiership - 2013-to-2014
# 加载数据: scotland - premiership - 2014-to-2015
# 加载数据: scotland - premiership - 2015-to-2016
# 加载数据: scotland - premiership - 2016-to-2017
# 加载数据: scotland - premiership - 2017-to-2018
# 加载数据: scotland - premiership - 2018-to-2019
# 加载数据: scotland - premiership - 2019-to-2020
# 加载数据: scotland - premiership - 2020-to-2021
# 加载数据: scotland - premiership - 2021-to-2022
# 加载数据: scotland - premiership - 2022-to-2023
# 加载数据: scotland - premiership - 2023-to-2024
# 加载数据: belgium - pro-league - 2013-to-2014
# 警告: belgium - pro-league - 2013-to-2014 文件缺失
# 加载数据: belgium - pro-league - 2014-to-2015
# 警告: belgium - pro-league - 2014-to-2015 文件缺失
# 加载数据: belgium - pro-league - 2015-to-2016
# 加载数据: belgium - pro-league - 2016-to-2017
# 加载数据: belgium - pro-league - 2017-to-2018
# 加载数据: belgium - pro-league - 2018-to-2019
# 加载数据: belgium - pro-league - 2019-to-2020
# 加载数据: belgium - pro-league - 2020-to-2021
# 加载数据: belgium - pro-league - 2021-to-2022
# 加载数据: belgium - pro-league - 2022-to-2023
# 加载数据: belgium - pro-league - 2023-to-2024
# 加载数据: austria - bundesliga - 2013-to-2014
# 加载数据: austria - bundesliga - 2014-to-2015
# 加载数据: austria - bundesliga - 2015-to-2016
# 加载数据: austria - bundesliga - 2016-to-2017
# 加载数据: austria - bundesliga - 2017-to-2018
# 加载数据: austria - bundesliga - 2018-to-2019
# 加载数据: austria - bundesliga - 2019-to-2020
# 加载数据: austria - bundesliga - 2020-to-2021
# 加载数据: austria - bundesliga - 2021-to-2022
# 加载数据: austria - bundesliga - 2022-to-2023
# 加载数据: austria - bundesliga - 2023-to-2024
#
# ===== 随机搜索超参数 =====
#
# 随机搜索: {'lambda_defense': 0.08116262258099888, 'lambda_offense': 0.19063571821788408, 'lambda_supervision': 0.14907884894416698, 'lambda_reg': 0.012374511199743695}
# 迭代 1000/100000, 损失 = 0.4706, rank_scale = 1.7960, 主场优势 = 49.2527, 最佳损失 = 0.4706
# 迭代 2000/100000, 损失 = 0.4095, rank_scale = 2.3641, 主场优势 = 48.7438, 最佳损失 = 0.4095
# 迭代 3000/100000, 损失 = 0.3891, rank_scale = 2.8629, 主场优势 = 48.2661, 最佳损失 = 0.3891
# 迭代 4000/100000, 损失 = 0.3814, rank_scale = 3.3485, 主场优势 = 47.7466, 最佳损失 = 0.3814
# 迭代 5000/100000, 损失 = 0.3779, rank_scale = 3.8515, 主场优势 = 47.1470, 最佳损失 = 0.3779
# 迭代 6000/100000, 损失 = 0.3756, rank_scale = 4.3921, 主场优势 = 46.4530, 最佳损失 = 0.3756
# 迭代 7000/100000, 损失 = 0.3738, rank_scale = 4.9838, 主场优势 = 45.6766, 最佳损失 = 0.3738
# 迭代 8000/100000, 损失 = 0.3721, rank_scale = 5.6321, 主场优势 = 44.8472, 最佳损失 = 0.3721
# 迭代 9000/100000, 损失 = 0.3706, rank_scale = 6.3346, 主场优势 = 43.9979, 最佳损失 = 0.3706
# 迭代 10000/100000, 损失 = 0.3692, rank_scale = 7.0849, 主场优势 = 43.1648, 最佳损失 = 0.3692
# 迭代 11000/100000, 损失 = 0.3681, rank_scale = 7.8768, 主场优势 = 42.4018, 最佳损失 = 0.3681
# 迭代 12000/100000, 损失 = 0.3674, rank_scale = 8.7027, 主场优势 = 41.8234, 最佳损失 = 0.3674
# 迭代 13000/100000, 损失 = 0.3670, rank_scale = 9.5401, 主场优势 = 41.5622, 最佳损失 = 0.3670
# 迭代 14000/100000, 损失 = 0.3667, rank_scale = 10.3652, 主场优势 = 41.4896, 最佳损失 = 0.3667
# 迭代 15000/100000, 损失 = 0.3664, rank_scale = 11.1809, 主场优势 = 41.4471, 最佳损失 = 0.3664
# 迭代 16000/100000, 损失 = 0.3662, rank_scale = 11.9944, 主场优势 = 41.4107, 最佳损失 = 0.3662
# 迭代 17000/100000, 损失 = 0.3659, rank_scale = 12.8092, 主场优势 = 41.3781, 最佳损失 = 0.3659
# 迭代 18000/100000, 损失 = 0.3657, rank_scale = 13.6253, 主场优势 = 41.3485, 最佳损失 = 0.3657
# 迭代 19000/100000, 损失 = 0.3656, rank_scale = 14.4429, 主场优势 = 41.3211, 最佳损失 = 0.3656
# 迭代 20000/100000, 损失 = 0.3654, rank_scale = 15.2612, 主场优势 = 41.2954, 最佳损失 = 0.3654
# 迭代 21000/100000, 损失 = 0.3652, rank_scale = 16.0803, 主场优势 = 41.2720, 最佳损失 = 0.3652
# 迭代 22000/100000, 损失 = 0.3651, rank_scale = 16.8986, 主场优势 = 41.2495, 最佳损失 = 0.3651
# 迭代 23000/100000, 损失 = 0.3649, rank_scale = 17.7168, 主场优势 = 41.2284, 最佳损失 = 0.3649
# 迭代 24000/100000, 损失 = 0.3648, rank_scale = 18.5346, 主场优势 = 41.2084, 最佳损失 = 0.3648
# 迭代 25000/100000, 损失 = 0.3647, rank_scale = 19.3509, 主场优势 = 41.1900, 最佳损失 = 0.3647
# 迭代 26000/100000, 损失 = 0.3646, rank_scale = 20.1657, 主场优势 = 41.1720, 最佳损失 = 0.3646
# 迭代 27000/100000, 损失 = 0.3645, rank_scale = 20.9789, 主场优势 = 41.1546, 最佳损失 = 0.3645
# 迭代 28000/100000, 损失 = 0.3644, rank_scale = 21.7902, 主场优势 = 41.1389, 最佳损失 = 0.3644
# 迭代 29000/100000, 损失 = 0.3643, rank_scale = 22.5995, 主场优势 = 41.1231, 最佳损失 = 0.3643
# 迭代 30000/100000, 损失 = 0.3642, rank_scale = 23.4065, 主场优势 = 41.1087, 最佳损失 = 0.3642
# 迭代 31000/100000, 损失 = 0.3641, rank_scale = 24.2109, 主场优势 = 41.0952, 最佳损失 = 0.3641
# 迭代 32000/100000, 损失 = 0.3641, rank_scale = 25.0130, 主场优势 = 41.0814, 最佳损失 = 0.3641
# 迭代 33000/100000, 损失 = 0.3640, rank_scale = 25.8126, 主场优势 = 41.0688, 最佳损失 = 0.3640
# 迭代 34000/100000, 损失 = 0.3639, rank_scale = 26.6091, 主场优势 = 41.0561, 最佳损失 = 0.3639
# 迭代 35000/100000, 损失 = 0.3639, rank_scale = 27.4031, 主场优势 = 41.0444, 最佳损失 = 0.3639
# 迭代 36000/100000, 损失 = 0.3638, rank_scale = 28.1940, 主场优势 = 41.0333, 最佳损失 = 0.3638
# 迭代 37000/100000, 损失 = 0.3637, rank_scale = 28.9820, 主场优势 = 41.0227, 最佳损失 = 0.3637
# 迭代 38000/100000, 损失 = 0.3637, rank_scale = 29.7670, 主场优势 = 41.0123, 最佳损失 = 0.3637
# 迭代 39000/100000, 损失 = 0.3636, rank_scale = 30.5489, 主场优势 = 41.0022, 最佳损失 = 0.3636
# 迭代 40000/100000, 损失 = 0.3636, rank_scale = 31.3278, 主场优势 = 40.9925, 最佳损失 = 0.3636
# 迭代 41000/100000, 损失 = 0.3635, rank_scale = 32.1033, 主场优势 = 40.9829, 最佳损失 = 0.3635
# 迭代 42000/100000, 损失 = 0.3635, rank_scale = 32.8756, 主场优势 = 40.9741, 最佳损失 = 0.3635
# 迭代 43000/100000, 损失 = 0.3634, rank_scale = 33.6448, 主场优势 = 40.9654, 最佳损失 = 0.3634
# 迭代 44000/100000, 损失 = 0.3634, rank_scale = 34.4108, 主场优势 = 40.9573, 最佳损失 = 0.3634
# 迭代 45000/100000, 损失 = 0.3633, rank_scale = 35.1736, 主场优势 = 40.9488, 最佳损失 = 0.3633
# 迭代 46000/100000, 损失 = 0.3633, rank_scale = 35.9328, 主场优势 = 40.9412, 最佳损失 = 0.3633
# 迭代 47000/100000, 损失 = 0.3632, rank_scale = 36.6884, 主场优势 = 40.9333, 最佳损失 = 0.3632
# 迭代 48000/100000, 损失 = 0.3632, rank_scale = 37.4408, 主场优势 = 40.9260, 最佳损失 = 0.3632
# 迭代 49000/100000, 损失 = 0.3632, rank_scale = 38.1899, 主场优势 = 40.9192, 最佳损失 = 0.3632
# 迭代 50000/100000, 损失 = 0.3631, rank_scale = 38.9356, 主场优势 = 40.9117, 最佳损失 = 0.3631
# 迭代 51000/100000, 损失 = 0.3631, rank_scale = 39.6780, 主场优势 = 40.9051, 最佳损失 = 0.3631
# 迭代 52000/100000, 损失 = 0.3631, rank_scale = 40.4171, 主场优势 = 40.8989, 最佳损失 = 0.3631
# 迭代 53000/100000, 损失 = 0.3630, rank_scale = 41.1527, 主场优势 = 40.8922, 最佳损失 = 0.3630
# 迭代 54000/100000, 损失 = 0.3630, rank_scale = 41.8850, 主场优势 = 40.8860, 最佳损失 = 0.3630
# 迭代 55000/100000, 损失 = 0.3630, rank_scale = 42.6136, 主场优势 = 40.8801, 最佳损失 = 0.3630
# 迭代 56000/100000, 损失 = 0.3629, rank_scale = 43.3387, 主场优势 = 40.8744, 最佳损失 = 0.3629
# 迭代 57000/100000, 损失 = 0.3629, rank_scale = 44.0603, 主场优势 = 40.8687, 最佳损失 = 0.3629
# 迭代 58000/100000, 损失 = 0.3629, rank_scale = 44.7786, 主场优势 = 40.8628, 最佳损失 = 0.3629
# 迭代 59000/100000, 损失 = 0.3628, rank_scale = 45.4935, 主场优势 = 40.8580, 最佳损失 = 0.3628
# 迭代 60000/100000, 损失 = 0.3628, rank_scale = 46.2050, 主场优势 = 40.8525, 最佳损失 = 0.3628
# 迭代 61000/100000, 损失 = 0.3628, rank_scale = 46.9132, 主场优势 = 40.8471, 最佳损失 = 0.3628
# 迭代 62000/100000, 损失 = 0.3628, rank_scale = 47.6179, 主场优势 = 40.8421, 最佳损失 = 0.3628
# 迭代 63000/100000, 损失 = 0.3627, rank_scale = 48.3193, 主场优势 = 40.8374, 最佳损失 = 0.3627
# 迭代 64000/100000, 损失 = 0.3627, rank_scale = 49.0174, 主场优势 = 40.8325, 最佳损失 = 0.3627
# 迭代 65000/100000, 损失 = 0.3627, rank_scale = 49.7117, 主场优势 = 40.8276, 最佳损失 = 0.3627
# 迭代 66000/100000, 损失 = 0.3627, rank_scale = 50.4025, 主场优势 = 40.8228, 最佳损失 = 0.3627
# 迭代 67000/100000, 损失 = 0.3627, rank_scale = 51.0901, 主场优势 = 40.8187, 最佳损失 = 0.3627
# 迭代 68000/100000, 损失 = 0.3626, rank_scale = 51.7743, 主场优势 = 40.8139, 最佳损失 = 0.3626
# 迭代 69000/100000, 损失 = 0.3626, rank_scale = 52.4552, 主场优势 = 40.8098, 最佳损失 = 0.3626
# 迭代 70000/100000, 损失 = 0.3626, rank_scale = 53.1328, 主场优势 = 40.8058, 最佳损失 = 0.3626
# 迭代 71000/100000, 损失 = 0.3626, rank_scale = 53.8070, 主场优势 = 40.8019, 最佳损失 = 0.3626
# 迭代 72000/100000, 损失 = 0.3625, rank_scale = 54.4780, 主场优势 = 40.7974, 最佳损失 = 0.3625
# 迭代 73000/100000, 损失 = 0.3625, rank_scale = 55.1456, 主场优势 = 40.7936, 最佳损失 = 0.3625
# 迭代 74000/100000, 损失 = 0.3625, rank_scale = 55.8095, 主场优势 = 40.7902, 最佳损失 = 0.3625
# 迭代 75000/100000, 损失 = 0.3625, rank_scale = 56.4702, 主场优势 = 40.7862, 最佳损失 = 0.3625
# 迭代 76000/100000, 损失 = 0.3625, rank_scale = 57.1276, 主场优势 = 40.7825, 最佳损失 = 0.3625
# 迭代 77000/100000, 损失 = 0.3625, rank_scale = 57.7819, 主场优势 = 40.7790, 最佳损失 = 0.3625
# 迭代 78000/100000, 损失 = 0.3624, rank_scale = 58.4329, 主场优势 = 40.7752, 最佳损失 = 0.3624
# 迭代 79000/100000, 损失 = 0.3624, rank_scale = 59.0807, 主场优势 = 40.7720, 最佳损失 = 0.3624
# 迭代 80000/100000, 损失 = 0.3624, rank_scale = 59.7254, 主场优势 = 40.7689, 最佳损失 = 0.3624
# 迭代 81000/100000, 损失 = 0.3624, rank_scale = 60.3662, 主场优势 = 40.7651, 最佳损失 = 0.3624
# 迭代 82000/100000, 损失 = 0.3624, rank_scale = 61.0039, 主场优势 = 40.7622, 最佳损失 = 0.3624
# 迭代 83000/100000, 损失 = 0.3624, rank_scale = 61.6385, 主场优势 = 40.7593, 最佳损失 = 0.3624
# 迭代 84000/100000, 损失 = 0.3623, rank_scale = 62.2700, 主场优势 = 40.7555, 最佳损失 = 0.3623
# 迭代 85000/100000, 损失 = 0.3623, rank_scale = 62.8984, 主场优势 = 40.7524, 最佳损失 = 0.3623
# 迭代 86000/100000, 损失 = 0.3623, rank_scale = 63.5237, 主场优势 = 40.7497, 最佳损失 = 0.3623
# 迭代 87000/100000, 损失 = 0.3623, rank_scale = 64.1446, 主场优势 = 40.7468, 最佳损失 = 0.3623
# 迭代 88000/100000, 损失 = 0.3623, rank_scale = 64.7626, 主场优势 = 40.7437, 最佳损失 = 0.3623
# 迭代 89000/100000, 损失 = 0.3623, rank_scale = 65.3801, 主场优势 = 40.7408, 最佳损失 = 0.3623
# 迭代 90000/100000, 损失 = 0.3623, rank_scale = 65.9905, 主场优势 = 40.7379, 最佳损失 = 0.3623
# 迭代 91000/100000, 损失 = 0.3622, rank_scale = 66.6008, 主场优势 = 40.7348, 最佳损失 = 0.3622
# 迭代 92000/100000, 损失 = 0.3622, rank_scale = 67.2064, 主场优势 = 40.7326, 最佳损失 = 0.3622
# 迭代 93000/100000, 损失 = 0.3622, rank_scale = 67.8091, 主场优势 = 40.7302, 最佳损失 = 0.3622
# 迭代 94000/100000, 损失 = 0.3622, rank_scale = 68.4107, 主场优势 = 40.7272, 最佳损失 = 0.3622
# 迭代 95000/100000, 损失 = 0.3622, rank_scale = 69.0058, 主场优势 = 40.7246, 最佳损失 = 0.3622
# 迭代 96000/100000, 损失 = 0.3622, rank_scale = 69.6008, 主场优势 = 40.7222, 最佳损失 = 0.3622
# 迭代 97000/100000, 损失 = 0.3622, rank_scale = 70.1909, 主场优势 = 40.7195, 最佳损失 = 0.3622
# 迭代 98000/100000, 损失 = 0.3622, rank_scale = 70.7783, 主场优势 = 40.7174, 最佳损失 = 0.3622
# 迭代 99000/100000, 损失 = 0.3622, rank_scale = 71.3647, 主场优势 = 40.7144, 最佳损失 = 0.3622
# 迭代 100000/100000, 损失 = 0.3621, rank_scale = 71.9445, 主场优势 = 40.7127, 最佳损失 = 0.3621
#
# 随机搜索: {'lambda_defense': 0.039643541684062936, 'lambda_offense': 0.039638958863878505, 'lambda_supervision': 0.021035886311957897, 'lambda_reg': 0.01745734676972377}
# 迭代 1000/100000, 损失 = 0.3810, rank_scale = 1.7943, 主场优势 = 49.2543, 最佳损失 = 0.3810
# 迭代 2000/100000, 损失 = 0.3579, rank_scale = 2.3629, 主场优势 = 48.7448, 最佳损失 = 0.3579
# 迭代 3000/100000, 损失 = 0.3492, rank_scale = 2.8568, 主场优势 = 48.2685, 最佳损失 = 0.3492
# 迭代 4000/100000, 损失 = 0.3451, rank_scale = 3.3304, 主场优势 = 47.7521, 最佳损失 = 0.3451
# 迭代 5000/100000, 损失 = 0.3425, rank_scale = 3.8103, 主场优势 = 47.1552, 最佳损失 = 0.3425
# 迭代 6000/100000, 损失 = 0.3405, rank_scale = 4.3132, 主场优势 = 46.4609, 最佳损失 = 0.3405
# 迭代 7000/100000, 损失 = 0.3387, rank_scale = 4.8520, 主场优势 = 45.6785, 最佳损失 = 0.3387
# 迭代 8000/100000, 损失 = 0.3370, rank_scale = 5.4390, 主场优势 = 44.8363, 最佳损失 = 0.3370
# 迭代 9000/100000, 损失 = 0.3354, rank_scale = 6.0844, 主场优势 = 43.9684, 最佳损失 = 0.3354
# 迭代 10000/100000, 损失 = 0.3340, rank_scale = 6.7930, 主场优势 = 43.1072, 最佳损失 = 0.3340
# 迭代 11000/100000, 损失 = 0.3328, rank_scale = 7.5620, 主场优势 = 42.2994, 最佳损失 = 0.3328
# 迭代 12000/100000, 损失 = 0.3320, rank_scale = 8.3820, 主场优势 = 41.6482, 最佳损失 = 0.3320
# 迭代 13000/100000, 损失 = 0.3316, rank_scale = 9.2248, 主场优势 = 41.3243, 最佳损失 = 0.3316
# 迭代 14000/100000, 损失 = 0.3314, rank_scale = 10.0533, 主场优势 = 41.2437, 最佳损失 = 0.3314
# 迭代 15000/100000, 损失 = 0.3311, rank_scale = 10.8691, 主场优势 = 41.2064, 最佳损失 = 0.3311
# 迭代 16000/100000, 损失 = 0.3310, rank_scale = 11.6816, 主场优势 = 41.1756, 最佳损失 = 0.3310
# 迭代 17000/100000, 损失 = 0.3308, rank_scale = 12.4952, 主场优势 = 41.1487, 最佳损失 = 0.3308
# 迭代 18000/100000, 损失 = 0.3306, rank_scale = 13.3107, 主场优势 = 41.1248, 最佳损失 = 0.3306
# 迭代 19000/100000, 损失 = 0.3305, rank_scale = 14.1281, 主场优势 = 41.1029, 最佳损失 = 0.3305
# 迭代 20000/100000, 损失 = 0.3303, rank_scale = 14.9469, 主场优势 = 41.0834, 最佳损失 = 0.3303
# 迭代 21000/100000, 损失 = 0.3302, rank_scale = 15.7665, 主场优势 = 41.0649, 最佳损失 = 0.3302
# 迭代 22000/100000, 损失 = 0.3301, rank_scale = 16.5866, 主场优势 = 41.0475, 最佳损失 = 0.3301
# 迭代 23000/100000, 损失 = 0.3300, rank_scale = 17.4068, 主场优势 = 41.0315, 最佳损失 = 0.3300
# 迭代 24000/100000, 损失 = 0.3299, rank_scale = 18.2250, 主场优势 = 41.0161, 最佳损失 = 0.3299
# 迭代 25000/100000, 损失 = 0.3298, rank_scale = 19.0428, 主场优势 = 41.0013, 最佳损失 = 0.3298
# 迭代 26000/100000, 损失 = 0.3297, rank_scale = 19.8591, 主场优势 = 40.9877, 最佳损失 = 0.3297
# 迭代 27000/100000, 损失 = 0.3296, rank_scale = 20.6736, 主场优势 = 40.9751, 最佳损失 = 0.3296
# 迭代 28000/100000, 损失 = 0.3295, rank_scale = 21.4860, 主场优势 = 40.9624, 最佳损失 = 0.3295
# 迭代 29000/100000, 损失 = 0.3294, rank_scale = 22.2963, 主场优势 = 40.9510, 最佳损失 = 0.3294
# 迭代 30000/100000, 损失 = 0.3294, rank_scale = 23.1042, 主场优势 = 40.9394, 最佳损失 = 0.3294
# 迭代 31000/100000, 损失 = 0.3293, rank_scale = 23.9099, 主场优势 = 40.9284, 最佳损失 = 0.3293
# 迭代 32000/100000, 损失 = 0.3292, rank_scale = 24.7129, 主场优势 = 40.9184, 最佳损失 = 0.3292
# 迭代 33000/100000, 损失 = 0.3292, rank_scale = 25.5131, 主场优势 = 40.9084, 最佳损失 = 0.3292
# 迭代 34000/100000, 损失 = 0.3291, rank_scale = 26.3107, 主场优势 = 40.8988, 最佳损失 = 0.3291
# 迭代 35000/100000, 损失 = 0.3291, rank_scale = 27.1052, 主场优势 = 40.8893, 最佳损失 = 0.3291
# 迭代 36000/100000, 损失 = 0.3290, rank_scale = 27.8969, 主场优势 = 40.8803, 最佳损失 = 0.3290
# 迭代 37000/100000, 损失 = 0.3290, rank_scale = 28.6855, 主场优势 = 40.8719, 最佳损失 = 0.3290
# 迭代 38000/100000, 损失 = 0.3289, rank_scale = 29.4710, 主场优势 = 40.8637, 最佳损失 = 0.3289
# 迭代 39000/100000, 损失 = 0.3289, rank_scale = 30.2536, 主场优势 = 40.8558, 最佳损失 = 0.3289
# 迭代 40000/100000, 损失 = 0.3288, rank_scale = 31.0328, 主场优势 = 40.8479, 最佳损失 = 0.3288
# 迭代 41000/100000, 损失 = 0.3288, rank_scale = 31.8089, 主场优势 = 40.8410, 最佳损失 = 0.3288
# 迭代 42000/100000, 损失 = 0.3287, rank_scale = 32.5818, 主场优势 = 40.8336, 最佳损失 = 0.3287
# 迭代 43000/100000, 损失 = 0.3287, rank_scale = 33.3514, 主场优势 = 40.8267, 最佳损失 = 0.3287
# 迭代 44000/100000, 损失 = 0.3287, rank_scale = 34.1179, 主场优势 = 40.8200, 最佳损失 = 0.3287
# 迭代 45000/100000, 损失 = 0.3286, rank_scale = 34.8808, 主场优势 = 40.8132, 最佳损失 = 0.3286
# 迭代 46000/100000, 损失 = 0.3286, rank_scale = 35.6402, 主场优势 = 40.8075, 最佳损失 = 0.3286
# 迭代 47000/100000, 损失 = 0.3286, rank_scale = 36.3962, 主场优势 = 40.8008, 最佳损失 = 0.3286
# 迭代 48000/100000, 损失 = 0.3285, rank_scale = 37.1489, 主场优势 = 40.7952, 最佳损失 = 0.3285
# 迭代 49000/100000, 损失 = 0.3285, rank_scale = 37.8983, 主场优势 = 40.7894, 最佳损失 = 0.3285
# 迭代 50000/100000, 损失 = 0.3285, rank_scale = 38.6443, 主场优势 = 40.7836, 最佳损失 = 0.3285
# 迭代 51000/100000, 损失 = 0.3284, rank_scale = 39.3869, 主场优势 = 40.7784, 最佳损失 = 0.3284
# 迭代 52000/100000, 损失 = 0.3284, rank_scale = 40.1261, 主场优势 = 40.7729, 最佳损失 = 0.3284
# 迭代 53000/100000, 损失 = 0.3284, rank_scale = 40.8620, 主场优势 = 40.7678, 最佳损失 = 0.3284
# 迭代 54000/100000, 损失 = 0.3284, rank_scale = 41.5944, 主场优势 = 40.7631, 最佳损失 = 0.3284
# 迭代 55000/100000, 损失 = 0.3283, rank_scale = 42.3230, 主场优势 = 40.7582, 最佳损失 = 0.3283
# 迭代 56000/100000, 损失 = 0.3283, rank_scale = 43.0482, 主场优势 = 40.7534, 最佳损失 = 0.3283
# 迭代 57000/100000, 损失 = 0.3283, rank_scale = 43.7700, 主场优势 = 40.7486, 最佳损失 = 0.3283
# 迭代 58000/100000, 损失 = 0.3283, rank_scale = 44.4884, 主场优势 = 40.7444, 最佳损失 = 0.3283
# 迭代 59000/100000, 损失 = 0.3282, rank_scale = 45.2034, 主场优势 = 40.7398, 最佳损失 = 0.3282
# 迭代 60000/100000, 损失 = 0.3282, rank_scale = 45.9150, 主场优势 = 40.7356, 最佳损失 = 0.3282
# 迭代 61000/100000, 损失 = 0.3282, rank_scale = 46.6232, 主场优势 = 40.7315, 最佳损失 = 0.3282
# 迭代 62000/100000, 损失 = 0.3282, rank_scale = 47.3279, 主场优势 = 40.7271, 最佳损失 = 0.3282
# 迭代 63000/100000, 损失 = 0.3281, rank_scale = 48.0294, 主场优势 = 40.7232, 最佳损失 = 0.3281
# 迭代 64000/100000, 损失 = 0.3281, rank_scale = 48.7274, 主场优势 = 40.7195, 最佳损失 = 0.3281
# 迭代 65000/100000, 损失 = 0.3281, rank_scale = 49.4217, 主场优势 = 40.7155, 最佳损失 = 0.3281
# 迭代 66000/100000, 损失 = 0.3281, rank_scale = 50.1125, 主场优势 = 40.7123, 最佳损失 = 0.3281
# 迭代 67000/100000, 损失 = 0.3281, rank_scale = 50.8000, 主场优势 = 40.7084, 最佳损失 = 0.3281
# 迭代 68000/100000, 损失 = 0.3280, rank_scale = 51.4841, 主场优势 = 40.7044, 最佳损失 = 0.3280
# 迭代 69000/100000, 损失 = 0.3280, rank_scale = 52.1649, 主场优势 = 40.7015, 最佳损失 = 0.3280
# 迭代 70000/100000, 损失 = 0.3280, rank_scale = 52.8423, 主场优势 = 40.6979, 最佳损失 = 0.3280
# 迭代 71000/100000, 损失 = 0.3280, rank_scale = 53.5165, 主场优势 = 40.6948, 最佳损失 = 0.3280
# 迭代 72000/100000, 损失 = 0.3280, rank_scale = 54.1873, 主场优势 = 40.6913, 最佳损失 = 0.3280
# 迭代 73000/100000, 损失 = 0.3280, rank_scale = 54.8549, 主场优势 = 40.6879, 最佳损失 = 0.3280
# 迭代 74000/100000, 损失 = 0.3279, rank_scale = 55.5187, 主场优势 = 40.6849, 最佳损失 = 0.3279
# 迭代 75000/100000, 损失 = 0.3279, rank_scale = 56.1792, 主场优势 = 40.6824, 最佳损失 = 0.3279
# 迭代 76000/100000, 损失 = 0.3279, rank_scale = 56.8364, 主场优势 = 40.6792, 最佳损失 = 0.3279
# 迭代 77000/100000, 损失 = 0.3279, rank_scale = 57.4904, 主场优势 = 40.6762, 最佳损失 = 0.3279
# 迭代 78000/100000, 损失 = 0.3279, rank_scale = 58.1412, 主场优势 = 40.6733, 最佳损失 = 0.3279
# 迭代 79000/100000, 损失 = 0.3279, rank_scale = 58.7888, 主场优势 = 40.6705, 最佳损失 = 0.3279
# 迭代 80000/100000, 损失 = 0.3279, rank_scale = 59.4333, 主场优势 = 40.6674, 最佳损失 = 0.3279
# 迭代 81000/100000, 损失 = 0.3278, rank_scale = 60.0741, 主场优势 = 40.6646, 最佳损失 = 0.3278
# 迭代 82000/100000, 损失 = 0.3278, rank_scale = 60.7116, 主场优势 = 40.6627, 最佳损失 = 0.3278
# 迭代 83000/100000, 损失 = 0.3278, rank_scale = 61.3459, 主场优势 = 40.6596, 最佳损失 = 0.3278
# 迭代 84000/100000, 损失 = 0.3278, rank_scale = 61.9771, 主场优势 = 40.6570, 最佳损失 = 0.3278
# 迭代 85000/100000, 损失 = 0.3278, rank_scale = 62.6052, 主场优势 = 40.6543, 最佳损失 = 0.3278
# 迭代 86000/100000, 损失 = 0.3278, rank_scale = 63.2302, 主场优势 = 40.6518, 最佳损失 = 0.3278
# 迭代 87000/100000, 损失 = 0.3278, rank_scale = 63.8520, 主场优势 = 40.6495, 最佳损失 = 0.3278
# 迭代 88000/100000, 损失 = 0.3278, rank_scale = 64.4702, 主场优势 = 40.6470, 最佳损失 = 0.3278
# 迭代 89000/100000, 损失 = 0.3277, rank_scale = 65.0870, 主场优势 = 40.6449, 最佳损失 = 0.3277
# 迭代 90000/100000, 损失 = 0.3277, rank_scale = 65.6973, 主场优势 = 40.6422, 最佳损失 = 0.3277
# 迭代 91000/100000, 损失 = 0.3277, rank_scale = 66.3077, 主场优势 = 40.6401, 最佳损失 = 0.3277
# 迭代 92000/100000, 损失 = 0.3277, rank_scale = 66.9125, 主场优势 = 40.6382, 最佳损失 = 0.3277
# 迭代 93000/100000, 损失 = 0.3277, rank_scale = 67.5153, 主场优势 = 40.6358, 最佳损失 = 0.3277
# 迭代 94000/100000, 损失 = 0.3277, rank_scale = 68.1160, 主场优势 = 40.6336, 最佳损失 = 0.3277
# 迭代 95000/100000, 损失 = 0.3277, rank_scale = 68.7111, 主场优势 = 40.6316, 最佳损失 = 0.3277
# 迭代 96000/100000, 损失 = 0.3277, rank_scale = 69.3062, 主场优势 = 40.6295, 最佳损失 = 0.3277
# 迭代 97000/100000, 损失 = 0.3277, rank_scale = 69.8953, 主场优势 = 40.6272, 最佳损失 = 0.3277
# 迭代 98000/100000, 损失 = 0.3276, rank_scale = 70.4828, 主场优势 = 40.6255, 最佳损失 = 0.3276
# 迭代 99000/100000, 损失 = 0.3276, rank_scale = 71.0682, 主场优势 = 40.6234, 最佳损失 = 0.3276
# 迭代 100000/100000, 损失 = 0.3276, rank_scale = 71.6481, 主场优势 = 40.6215, 最佳损失 = 0.3276
#
# 随机搜索: {'lambda_defense': 0.12421185223120967, 'lambda_offense': 0.14453378978124864, 'lambda_supervision': 0.013911053916202466, 'lambda_reg': 0.019428287191077892}
# 迭代 1000/100000, 损失 = 0.4344, rank_scale = 1.7961, 主场优势 = 49.2526, 最佳损失 = 0.4344
# 迭代 2000/100000, 损失 = 0.3746, rank_scale = 2.3645, 主场优势 = 48.7436, 最佳损失 = 0.3746
# 迭代 3000/100000, 损失 = 0.3543, rank_scale = 2.8660, 主场优势 = 48.2645, 最佳损失 = 0.3543
# 迭代 4000/100000, 损失 = 0.3464, rank_scale = 3.3582, 主场优势 = 47.7430, 最佳损失 = 0.3464
# 迭代 5000/100000, 损失 = 0.3425, rank_scale = 3.8712, 主场优势 = 47.1417, 最佳损失 = 0.3425
# 迭代 6000/100000, 损失 = 0.3400, rank_scale = 4.4262, 主场优势 = 46.4476, 最佳损失 = 0.3400
# 迭代 7000/100000, 损失 = 0.3380, rank_scale = 5.0350, 主场优势 = 45.6735, 最佳损失 = 0.3380
# 迭代 8000/100000, 损失 = 0.3362, rank_scale = 5.6990, 主场优势 = 44.8484, 最佳损失 = 0.3362
# 迭代 9000/100000, 损失 = 0.3347, rank_scale = 6.4127, 主场优势 = 44.0060, 最佳损失 = 0.3347
# 迭代 10000/100000, 损失 = 0.3333, rank_scale = 7.1697, 主场优势 = 43.1817, 最佳损失 = 0.3333
# 迭代 11000/100000, 损失 = 0.3322, rank_scale = 7.9649, 主场优势 = 42.4327, 最佳损失 = 0.3322
# 迭代 12000/100000, 损失 = 0.3315, rank_scale = 8.7914, 主场优势 = 41.8764, 最佳损失 = 0.3315
# 迭代 13000/100000, 损失 = 0.3311, rank_scale = 9.6270, 主场优势 = 41.6314, 最佳损失 = 0.3311
# 迭代 14000/100000, 损失 = 0.3308, rank_scale = 10.4505, 主场优势 = 41.5593, 最佳损失 = 0.3308
# 迭代 15000/100000, 损失 = 0.3305, rank_scale = 11.2654, 主场优势 = 41.5143, 最佳损失 = 0.3305
# 迭代 16000/100000, 损失 = 0.3303, rank_scale = 12.0789, 主场优势 = 41.4757, 最佳损失 = 0.3303
# 迭代 17000/100000, 损失 = 0.3300, rank_scale = 12.8931, 主场优势 = 41.4409, 最佳损失 = 0.3300
# 迭代 18000/100000, 损失 = 0.3298, rank_scale = 13.7089, 主场优势 = 41.4092, 最佳损失 = 0.3298
# 迭代 19000/100000, 损失 = 0.3296, rank_scale = 14.5260, 主场优势 = 41.3798, 最佳损失 = 0.3296
# 迭代 20000/100000, 损失 = 0.3294, rank_scale = 15.3441, 主场优势 = 41.3526, 最佳损失 = 0.3294
# 迭代 21000/100000, 损失 = 0.3293, rank_scale = 16.1623, 主场优势 = 41.3268, 最佳损失 = 0.3293
# 迭代 22000/100000, 损失 = 0.3291, rank_scale = 16.9806, 主场优势 = 41.3032, 最佳损失 = 0.3291
# 迭代 23000/100000, 损失 = 0.3290, rank_scale = 17.7988, 主场优势 = 41.2805, 最佳损失 = 0.3290
# 迭代 24000/100000, 损失 = 0.3288, rank_scale = 18.6157, 主场优势 = 41.2592, 最佳损失 = 0.3288
# 迭代 25000/100000, 损失 = 0.3287, rank_scale = 19.4318, 主场优势 = 41.2389, 最佳损失 = 0.3287
# 迭代 26000/100000, 损失 = 0.3286, rank_scale = 20.2463, 主场优势 = 41.2201, 最佳损失 = 0.3286
# 迭代 27000/100000, 损失 = 0.3285, rank_scale = 21.0590, 主场优势 = 41.2021, 最佳损失 = 0.3285
# 迭代 28000/100000, 损失 = 0.3284, rank_scale = 21.8700, 主场优势 = 41.1849, 最佳损失 = 0.3284
# 迭代 29000/100000, 损失 = 0.3283, rank_scale = 22.6790, 主场优势 = 41.1683, 最佳损失 = 0.3283
# 迭代 30000/100000, 损失 = 0.3282, rank_scale = 23.4855, 主场优势 = 41.1527, 最佳损失 = 0.3282
# 迭代 31000/100000, 损失 = 0.3281, rank_scale = 24.2897, 主场优势 = 41.1382, 最佳损失 = 0.3281
# 迭代 32000/100000, 损失 = 0.3280, rank_scale = 25.0915, 主场优势 = 41.1236, 最佳损失 = 0.3280
# 迭代 33000/100000, 损失 = 0.3280, rank_scale = 25.8907, 主场优势 = 41.1100, 最佳损失 = 0.3280
# 迭代 34000/100000, 损失 = 0.3279, rank_scale = 26.6871, 主场优势 = 41.0971, 最佳损失 = 0.3279
# 迭代 35000/100000, 损失 = 0.3278, rank_scale = 27.4808, 主场优势 = 41.0848, 最佳损失 = 0.3278
# 迭代 36000/100000, 损失 = 0.3278, rank_scale = 28.2715, 主场优势 = 41.0726, 最佳损失 = 0.3278
# 迭代 37000/100000, 损失 = 0.3277, rank_scale = 29.0593, 主场优势 = 41.0611, 最佳损失 = 0.3277
# 迭代 38000/100000, 损失 = 0.3276, rank_scale = 29.8441, 主场优势 = 41.0502, 最佳损失 = 0.3276
# 迭代 39000/100000, 损失 = 0.3276, rank_scale = 30.6257, 主场优势 = 41.0393, 最佳损失 = 0.3276
# 迭代 40000/100000, 损失 = 0.3275, rank_scale = 31.4044, 主场优势 = 41.0296, 最佳损失 = 0.3275
# 迭代 41000/100000, 损失 = 0.3275, rank_scale = 32.1798, 主场优势 = 41.0198, 最佳损失 = 0.3275
# 迭代 42000/100000, 损失 = 0.3274, rank_scale = 32.9519, 主场优势 = 41.0102, 最佳损失 = 0.3274
# 迭代 43000/100000, 损失 = 0.3274, rank_scale = 33.7210, 主场优势 = 41.0009, 最佳损失 = 0.3274
# 迭代 44000/100000, 损失 = 0.3273, rank_scale = 34.4868, 主场优势 = 40.9919, 最佳损失 = 0.3273
# 迭代 45000/100000, 损失 = 0.3273, rank_scale = 35.2494, 主场优势 = 40.9830, 最佳损失 = 0.3273
# 迭代 46000/100000, 损失 = 0.3272, rank_scale = 36.0086, 主场优势 = 40.9752, 最佳损失 = 0.3272
# 迭代 47000/100000, 损失 = 0.3272, rank_scale = 36.7641, 主场优势 = 40.9673, 最佳损失 = 0.3272
# 迭代 48000/100000, 损失 = 0.3272, rank_scale = 37.5164, 主场优势 = 40.9596, 最佳损失 = 0.3272
# 迭代 49000/100000, 损失 = 0.3271, rank_scale = 38.2653, 主场优势 = 40.9517, 最佳损失 = 0.3271
# 迭代 50000/100000, 损失 = 0.3271, rank_scale = 39.0109, 主场优势 = 40.9439, 最佳损失 = 0.3271
# 迭代 51000/100000, 损失 = 0.3270, rank_scale = 39.7532, 主场优势 = 40.9370, 最佳损失 = 0.3270
# 迭代 52000/100000, 损失 = 0.3270, rank_scale = 40.4921, 主场优势 = 40.9302, 最佳损失 = 0.3270
# 迭代 53000/100000, 损失 = 0.3270, rank_scale = 41.2277, 主场优势 = 40.9233, 最佳损失 = 0.3270
# 迭代 54000/100000, 损失 = 0.3269, rank_scale = 41.9599, 主场优势 = 40.9170, 最佳损失 = 0.3269
# 迭代 55000/100000, 损失 = 0.3269, rank_scale = 42.6885, 主场优势 = 40.9106, 最佳损失 = 0.3269
# 迭代 56000/100000, 损失 = 0.3269, rank_scale = 43.4134, 主场优势 = 40.9048, 最佳损失 = 0.3269
# 迭代 57000/100000, 损失 = 0.3268, rank_scale = 44.1350, 主场优势 = 40.8983, 最佳损失 = 0.3268
# 迭代 58000/100000, 损失 = 0.3268, rank_scale = 44.8533, 主场优势 = 40.8925, 最佳损失 = 0.3268
# 迭代 59000/100000, 损失 = 0.3268, rank_scale = 45.5681, 主场优势 = 40.8872, 最佳损失 = 0.3268
# 迭代 60000/100000, 损失 = 0.3268, rank_scale = 46.2796, 主场优势 = 40.8813, 最佳损失 = 0.3268
# 迭代 61000/100000, 损失 = 0.3267, rank_scale = 46.9877, 主场优势 = 40.8757, 最佳损失 = 0.3267
# 迭代 62000/100000, 损失 = 0.3267, rank_scale = 47.6924, 主场优势 = 40.8706, 最佳损失 = 0.3267
# 迭代 63000/100000, 损失 = 0.3267, rank_scale = 48.3938, 主场优势 = 40.8657, 最佳损失 = 0.3267
# 迭代 64000/100000, 损失 = 0.3267, rank_scale = 49.0918, 主场优势 = 40.8602, 最佳损失 = 0.3267
# 迭代 65000/100000, 损失 = 0.3266, rank_scale = 49.7860, 主场优势 = 40.8553, 最佳损失 = 0.3266
# 迭代 66000/100000, 损失 = 0.3266, rank_scale = 50.4769, 主场优势 = 40.8508, 最佳损失 = 0.3266
# 迭代 67000/100000, 损失 = 0.3266, rank_scale = 51.1644, 主场优势 = 40.8460, 最佳损失 = 0.3266
# 迭代 68000/100000, 损失 = 0.3266, rank_scale = 51.8486, 主场优势 = 40.8412, 最佳损失 = 0.3266
# 迭代 69000/100000, 损失 = 0.3265, rank_scale = 52.5295, 主场优势 = 40.8364, 最佳损失 = 0.3265
# 迭代 70000/100000, 损失 = 0.3265, rank_scale = 53.2070, 主场优势 = 40.8325, 最佳损失 = 0.3265
# 迭代 71000/100000, 损失 = 0.3265, rank_scale = 53.8813, 主场优势 = 40.8284, 最佳损失 = 0.3265
# 迭代 72000/100000, 损失 = 0.3265, rank_scale = 54.5523, 主场优势 = 40.8238, 最佳损失 = 0.3265
# 迭代 73000/100000, 损失 = 0.3265, rank_scale = 55.2199, 主场优势 = 40.8198, 最佳损失 = 0.3265
# 迭代 74000/100000, 损失 = 0.3264, rank_scale = 55.8838, 主场优势 = 40.8160, 最佳损失 = 0.3264
# 迭代 75000/100000, 损失 = 0.3264, rank_scale = 56.5445, 主场优势 = 40.8119, 最佳损失 = 0.3264
# 迭代 76000/100000, 损失 = 0.3264, rank_scale = 57.2019, 主场优势 = 40.8081, 最佳损失 = 0.3264
# 迭代 77000/100000, 损失 = 0.3264, rank_scale = 57.8562, 主场优势 = 40.8043, 最佳损失 = 0.3264
# 迭代 78000/100000, 损失 = 0.3264, rank_scale = 58.5072, 主场优势 = 40.8007, 最佳损失 = 0.3264
# 迭代 79000/100000, 损失 = 0.3263, rank_scale = 59.1551, 主场优势 = 40.7972, 最佳损失 = 0.3263
# 迭代 80000/100000, 损失 = 0.3263, rank_scale = 59.7997, 主场优势 = 40.7934, 最佳损失 = 0.3263
# 迭代 81000/100000, 损失 = 0.3260, rank_scale = 60.4276, 主场优势 = 40.7492, 最佳损失 = 0.3260
# 迭代 82000/100000, 损失 = 0.3259, rank_scale = 61.0380, 主场优势 = 40.7231, 最佳损失 = 0.3259
# 迭代 83000/100000, 损失 = 0.3258, rank_scale = 61.6508, 主场优势 = 40.7086, 最佳损失 = 0.3258
# 迭代 84000/100000, 损失 = 0.3258, rank_scale = 62.2695, 主场优势 = 40.7017, 最佳损失 = 0.3258
# 迭代 85000/100000, 损失 = 0.3258, rank_scale = 62.8913, 主场优势 = 40.6978, 最佳损失 = 0.3258
# 迭代 86000/100000, 损失 = 0.3258, rank_scale = 63.5131, 主场优势 = 40.6950, 最佳损失 = 0.3258
# 迭代 87000/100000, 损失 = 0.3258, rank_scale = 64.1340, 主场优势 = 40.6919, 最佳损失 = 0.3258
# 迭代 88000/100000, 损失 = 0.3258, rank_scale = 64.7520, 主场优势 = 40.6889, 最佳损失 = 0.3258
# 迭代 89000/100000, 损失 = 0.3258, rank_scale = 65.3682, 主场优势 = 40.6860, 最佳损失 = 0.3258
# 迭代 90000/100000, 损失 = 0.3257, rank_scale = 65.9785, 主场优势 = 40.6837, 最佳损失 = 0.3257
# 迭代 91000/100000, 损失 = 0.3257, rank_scale = 66.5889, 主场优势 = 40.6811, 最佳损失 = 0.3257
# 迭代 92000/100000, 损失 = 0.3257, rank_scale = 67.1934, 主场优势 = 40.6782, 最佳损失 = 0.3257
# 迭代 93000/100000, 损失 = 0.3257, rank_scale = 67.7961, 主场优势 = 40.6753, 最佳损失 = 0.3257
# 迭代 94000/100000, 损失 = 0.3257, rank_scale = 68.3965, 主场优势 = 40.6727, 最佳损失 = 0.3257
# 迭代 95000/100000, 损失 = 0.3257, rank_scale = 68.9916, 主场优势 = 40.6702, 最佳损失 = 0.3257
# 迭代 96000/100000, 损失 = 0.3257, rank_scale = 69.5867, 主场优势 = 40.6675, 最佳损失 = 0.3257
# 迭代 97000/100000, 损失 = 0.3257, rank_scale = 70.1756, 主场优势 = 40.6651, 最佳损失 = 0.3257
# 迭代 98000/100000, 损失 = 0.3256, rank_scale = 70.7631, 主场优势 = 40.6624, 最佳损失 = 0.3256
# 迭代 99000/100000, 损失 = 0.3256, rank_scale = 71.3483, 主场优势 = 40.6599, 最佳损失 = 0.3256
# 迭代 100000/100000, 损失 = 0.3256, rank_scale = 71.9282, 主场优势 = 40.6578, 最佳损失 = 0.3256
#
# 随机搜索: {'lambda_defense': 0.16816410175208013, 'lambda_offense': 0.05034443102887247, 'lambda_supervision': 0.04454674376934912, 'lambda_reg': 0.004484685687215243}
# 迭代 1000/100000, 损失 = 0.4305, rank_scale = 1.7958, 主场优势 = 49.2531, 最佳损失 = 0.4305
# 迭代 2000/100000, 损失 = 0.3803, rank_scale = 2.3687, 主场优势 = 48.7412, 最佳损失 = 0.3803
# 迭代 3000/100000, 损失 = 0.3625, rank_scale = 2.8751, 主场优势 = 48.2597, 最佳损失 = 0.3625
# 迭代 4000/100000, 损失 = 0.3550, rank_scale = 3.3732, 主场优势 = 47.7362, 最佳损失 = 0.3550
# 迭代 5000/100000, 损失 = 0.3510, rank_scale = 3.8928, 主场优势 = 47.1340, 最佳损失 = 0.3510
# 迭代 6000/100000, 损失 = 0.3483, rank_scale = 4.4479, 主场优势 = 46.4410, 最佳损失 = 0.3483
# 迭代 7000/100000, 损失 = 0.3460, rank_scale = 5.0418, 主场优势 = 45.6679, 最佳损失 = 0.3460
# 迭代 8000/100000, 损失 = 0.3440, rank_scale = 5.6752, 主场优势 = 44.8403, 最佳损失 = 0.3440
# 迭代 9000/100000, 损失 = 0.3422, rank_scale = 6.3464, 主场优势 = 43.9881, 最佳损失 = 0.3422
# 迭代 10000/100000, 损失 = 0.3406, rank_scale = 7.0568, 主场优势 = 43.1434, 最佳损失 = 0.3406
# 迭代 11000/100000, 损失 = 0.3394, rank_scale = 7.8116, 主场优势 = 42.3563, 最佳损失 = 0.3394
# 迭代 12000/100000, 损失 = 0.3386, rank_scale = 8.6115, 主场优势 = 41.7357, 最佳损失 = 0.3386
# 迭代 13000/100000, 损失 = 0.3382, rank_scale = 9.4341, 主场优势 = 41.4327, 最佳损失 = 0.3382
# 迭代 14000/100000, 损失 = 0.3379, rank_scale = 10.2482, 主场优势 = 41.3452, 最佳损失 = 0.3379
# 迭代 15000/100000, 损失 = 0.3377, rank_scale = 11.0569, 主场优势 = 41.3034, 最佳损失 = 0.3377
# 迭代 16000/100000, 损失 = 0.3375, rank_scale = 11.8671, 主场优势 = 41.2703, 最佳损失 = 0.3375
# 迭代 17000/100000, 损失 = 0.3373, rank_scale = 12.6798, 主场优势 = 41.2406, 最佳损失 = 0.3373
# 迭代 18000/100000, 损失 = 0.3371, rank_scale = 13.4948, 主场优势 = 41.2134, 最佳损失 = 0.3371
# 迭代 19000/100000, 损失 = 0.3369, rank_scale = 14.3118, 主场优势 = 41.1895, 最佳损失 = 0.3369
# 迭代 20000/100000, 损失 = 0.3368, rank_scale = 15.1307, 主场优势 = 41.1681, 最佳损失 = 0.3368
# 迭代 21000/100000, 损失 = 0.3367, rank_scale = 15.9508, 主场优势 = 41.1482, 最佳损失 = 0.3367
# 迭代 22000/100000, 损失 = 0.3365, rank_scale = 16.7709, 主场优势 = 41.1293, 最佳损失 = 0.3365
# 迭代 23000/100000, 损失 = 0.3364, rank_scale = 17.5909, 主场优势 = 41.1117, 最佳损失 = 0.3364
# 迭代 24000/100000, 损失 = 0.3363, rank_scale = 18.4092, 主场优势 = 41.0944, 最佳损失 = 0.3363
# 迭代 25000/100000, 损失 = 0.3362, rank_scale = 19.2267, 主场优势 = 41.0783, 最佳损失 = 0.3362
# 迭代 26000/100000, 损失 = 0.3361, rank_scale = 20.0428, 主场优势 = 41.0630, 最佳损失 = 0.3361
# 迭代 27000/100000, 损失 = 0.3360, rank_scale = 20.8571, 主场优势 = 41.0493, 最佳损失 = 0.3360
# 迭代 28000/100000, 损失 = 0.3359, rank_scale = 21.6694, 主场优势 = 41.0354, 最佳损失 = 0.3359
# 迭代 29000/100000, 损失 = 0.3358, rank_scale = 22.4795, 主场优势 = 41.0220, 最佳损失 = 0.3358
# 迭代 30000/100000, 损失 = 0.3358, rank_scale = 23.2874, 主场优势 = 41.0101, 最佳损失 = 0.3358
# 迭代 31000/100000, 损失 = 0.3357, rank_scale = 24.0930, 主场优势 = 40.9974, 最佳损失 = 0.3357
# 迭代 32000/100000, 损失 = 0.3356, rank_scale = 24.8959, 主场优势 = 40.9867, 最佳损失 = 0.3356
# 迭代 33000/100000, 损失 = 0.3356, rank_scale = 25.6961, 主场优势 = 40.9759, 最佳损失 = 0.3356
# 迭代 34000/100000, 损失 = 0.3355, rank_scale = 26.4936, 主场优势 = 40.9649, 最佳损失 = 0.3355
# 迭代 35000/100000, 损失 = 0.3354, rank_scale = 27.2882, 主场优势 = 40.9553, 最佳损失 = 0.3354
# 迭代 36000/100000, 损失 = 0.3354, rank_scale = 28.0799, 主场优势 = 40.9453, 最佳损失 = 0.3354
# 迭代 37000/100000, 损失 = 0.3353, rank_scale = 28.8686, 主场优势 = 40.9361, 最佳损失 = 0.3353
# 迭代 38000/100000, 损失 = 0.3353, rank_scale = 29.6541, 主场优势 = 40.9271, 最佳损失 = 0.3353
# 迭代 39000/100000, 损失 = 0.3352, rank_scale = 30.4367, 主场优势 = 40.9185, 最佳损失 = 0.3352
# 迭代 40000/100000, 损失 = 0.3352, rank_scale = 31.2159, 主场优势 = 40.9105, 最佳损失 = 0.3352
# 迭代 41000/100000, 损失 = 0.3351, rank_scale = 31.9920, 主场优势 = 40.9023, 最佳损失 = 0.3351
# 迭代 42000/100000, 损失 = 0.3351, rank_scale = 32.7649, 主场优势 = 40.8941, 最佳损失 = 0.3351
# 迭代 43000/100000, 损失 = 0.3350, rank_scale = 33.5347, 主场优势 = 40.8870, 最佳损失 = 0.3350
# 迭代 44000/100000, 损失 = 0.3350, rank_scale = 34.3011, 主场优势 = 40.8796, 最佳损失 = 0.3350
# 迭代 45000/100000, 损失 = 0.3350, rank_scale = 35.0641, 主场优势 = 40.8725, 最佳损失 = 0.3350
# 迭代 46000/100000, 损失 = 0.3349, rank_scale = 35.8235, 主场优势 = 40.8658, 最佳损失 = 0.3349
# 迭代 47000/100000, 损失 = 0.3349, rank_scale = 36.5796, 主场优势 = 40.8591, 最佳损失 = 0.3349
# 迭代 48000/100000, 损失 = 0.3348, rank_scale = 37.3324, 主场优势 = 40.8528, 最佳损失 = 0.3348
# 迭代 49000/100000, 损失 = 0.3348, rank_scale = 38.0818, 主场优势 = 40.8462, 最佳损失 = 0.3348
# 迭代 50000/100000, 损失 = 0.3348, rank_scale = 38.8278, 主场优势 = 40.8404, 最佳损失 = 0.3348
# 迭代 51000/100000, 损失 = 0.3347, rank_scale = 39.5705, 主场优势 = 40.8343, 最佳损失 = 0.3347
# 迭代 52000/100000, 损失 = 0.3347, rank_scale = 40.3098, 主场优势 = 40.8285, 最佳损失 = 0.3347
# 迭代 53000/100000, 损失 = 0.3347, rank_scale = 41.0457, 主场优势 = 40.8229, 最佳损失 = 0.3347
# 迭代 54000/100000, 损失 = 0.3347, rank_scale = 41.7781, 主场优势 = 40.8178, 最佳损失 = 0.3347
# 迭代 55000/100000, 损失 = 0.3346, rank_scale = 42.5068, 主场优势 = 40.8122, 最佳损失 = 0.3346
# 迭代 56000/100000, 损失 = 0.3346, rank_scale = 43.2321, 主场优势 = 40.8071, 最佳损失 = 0.3346
# 迭代 57000/100000, 损失 = 0.3346, rank_scale = 43.9539, 主场优势 = 40.8023, 最佳损失 = 0.3346
# 迭代 58000/100000, 损失 = 0.3345, rank_scale = 44.6724, 主场优势 = 40.7973, 最佳损失 = 0.3345
# 迭代 59000/100000, 损失 = 0.3345, rank_scale = 45.3875, 主场优势 = 40.7927, 最佳损失 = 0.3345
# 迭代 60000/100000, 损失 = 0.3345, rank_scale = 46.0992, 主场优势 = 40.7884, 最佳损失 = 0.3345
# 迭代 61000/100000, 损失 = 0.3345, rank_scale = 46.8075, 主场优势 = 40.7837, 最佳损失 = 0.3345
# 迭代 62000/100000, 损失 = 0.3345, rank_scale = 47.5124, 主场优势 = 40.7790, 最佳损失 = 0.3345
# 迭代 63000/100000, 损失 = 0.3344, rank_scale = 48.2139, 主场优势 = 40.7748, 最佳损失 = 0.3344
# 迭代 64000/100000, 损失 = 0.3344, rank_scale = 48.9120, 主场优势 = 40.7700, 最佳损失 = 0.3344
# 迭代 65000/100000, 损失 = 0.3344, rank_scale = 49.6063, 主场优势 = 40.7664, 最佳损失 = 0.3344
# 迭代 66000/100000, 损失 = 0.3344, rank_scale = 50.2973, 主场优势 = 40.7623, 最佳损失 = 0.3344
# 迭代 67000/100000, 损失 = 0.3343, rank_scale = 50.9849, 主场优势 = 40.7583, 最佳损失 = 0.3343
# 迭代 68000/100000, 损失 = 0.3343, rank_scale = 51.6691, 主场优势 = 40.7546, 最佳损失 = 0.3343
# 迭代 69000/100000, 损失 = 0.3343, rank_scale = 52.3501, 主场优势 = 40.7509, 最佳损失 = 0.3343
# 迭代 70000/100000, 损失 = 0.3343, rank_scale = 53.0277, 主场优势 = 40.7472, 最佳损失 = 0.3343
# 迭代 71000/100000, 损失 = 0.3343, rank_scale = 53.7020, 主场优势 = 40.7437, 最佳损失 = 0.3343
# 迭代 72000/100000, 损失 = 0.3343, rank_scale = 54.3731, 主场优势 = 40.7398, 最佳损失 = 0.3343
# 迭代 73000/100000, 损失 = 0.3342, rank_scale = 55.0406, 主场优势 = 40.7367, 最佳损失 = 0.3342
# 迭代 74000/100000, 损失 = 0.3342, rank_scale = 55.7046, 主场优势 = 40.7328, 最佳损失 = 0.3342
# 迭代 75000/100000, 损失 = 0.3342, rank_scale = 56.3652, 主场优势 = 40.7299, 最佳损失 = 0.3342
# 迭代 76000/100000, 损失 = 0.3342, rank_scale = 57.0226, 主场优势 = 40.7270, 最佳损失 = 0.3342
# 迭代 77000/100000, 损失 = 0.3342, rank_scale = 57.6768, 主场优势 = 40.7232, 最佳损失 = 0.3342
# 迭代 78000/100000, 损失 = 0.3342, rank_scale = 58.3278, 主场优势 = 40.7200, 最佳损失 = 0.3342
# 迭代 79000/100000, 损失 = 0.3341, rank_scale = 58.9756, 主场优势 = 40.7171, 最佳损失 = 0.3341
# 迭代 80000/100000, 损失 = 0.3341, rank_scale = 59.6202, 主场优势 = 40.7143, 最佳损失 = 0.3341
# 迭代 81000/100000, 损失 = 0.3341, rank_scale = 60.2611, 主场优势 = 40.7114, 最佳损失 = 0.3341
# 迭代 82000/100000, 损失 = 0.3341, rank_scale = 60.8988, 主场优势 = 40.7086, 最佳损失 = 0.3341
# 迭代 83000/100000, 损失 = 0.3341, rank_scale = 61.5333, 主场优势 = 40.7056, 最佳损失 = 0.3341
# 迭代 84000/100000, 损失 = 0.3341, rank_scale = 62.1647, 主场优势 = 40.7026, 最佳损失 = 0.3341
# 迭代 85000/100000, 损失 = 0.3341, rank_scale = 62.7930, 主场优势 = 40.6996, 最佳损失 = 0.3341
# 迭代 86000/100000, 损失 = 0.3340, rank_scale = 63.4182, 主场优势 = 40.6968, 最佳损失 = 0.3340
# 迭代 87000/100000, 损失 = 0.3340, rank_scale = 64.0398, 主场优势 = 40.6947, 最佳损失 = 0.3340
# 迭代 88000/100000, 损失 = 0.3340, rank_scale = 64.6578, 主场优势 = 40.6919, 最佳损失 = 0.3340
# 迭代 89000/100000, 损失 = 0.3340, rank_scale = 65.2750, 主场优势 = 40.6894, 最佳损失 = 0.3340
# 迭代 90000/100000, 损失 = 0.3340, rank_scale = 65.8854, 主场优势 = 40.6870, 最佳损失 = 0.3340
# 迭代 91000/100000, 损失 = 0.3340, rank_scale = 66.4957, 主场优势 = 40.6843, 最佳损失 = 0.3340
# 迭代 92000/100000, 损失 = 0.3340, rank_scale = 67.1010, 主场优势 = 40.6820, 最佳损失 = 0.3340
# 迭代 93000/100000, 损失 = 0.3340, rank_scale = 67.7037, 主场优势 = 40.6794, 最佳损失 = 0.3340
# 迭代 94000/100000, 损失 = 0.3339, rank_scale = 68.3050, 主场优势 = 40.6772, 最佳损失 = 0.3339
# 迭代 95000/100000, 损失 = 0.3339, rank_scale = 68.9000, 主场优势 = 40.6753, 最佳损失 = 0.3339
# 迭代 96000/100000, 损失 = 0.3339, rank_scale = 69.4951, 主场优势 = 40.6725, 最佳损失 = 0.3339
# 迭代 97000/100000, 损失 = 0.3339, rank_scale = 70.0849, 主场优势 = 40.6705, 最佳损失 = 0.3339
# 迭代 98000/100000, 损失 = 0.3339, rank_scale = 70.6723, 主场优势 = 40.6683, 最佳损失 = 0.3339
# 迭代 99000/100000, 损失 = 0.3339, rank_scale = 71.2583, 主场优势 = 40.6663, 最佳损失 = 0.3339
# 迭代 100000/100000, 损失 = 0.3339, rank_scale = 71.8382, 主场优势 = 40.6637, 最佳损失 = 0.3339
#
# 随机搜索: {'lambda_defense': 0.06780602616231217, 'lambda_offense': 0.1097037220101252, 'lambda_supervision': 0.092069553542002, 'lambda_reg': 0.006533353663762796}
# 迭代 1000/100000, 损失 = 0.4285, rank_scale = 1.7960, 主场优势 = 49.2528, 最佳损失 = 0.4285
# 迭代 2000/100000, 损失 = 0.3858, rank_scale = 2.3633, 主场优势 = 48.7442, 最佳损失 = 0.3858
# 迭代 3000/100000, 损失 = 0.3711, rank_scale = 2.8582, 主场优势 = 48.2678, 最佳损失 = 0.3711
# 迭代 4000/100000, 损失 = 0.3651, rank_scale = 3.3376, 主场优势 = 47.7502, 最佳损失 = 0.3651
# 迭代 5000/100000, 损失 = 0.3620, rank_scale = 3.8293, 主场优势 = 47.1521, 最佳损失 = 0.3620
# 迭代 6000/100000, 损失 = 0.3599, rank_scale = 4.3535, 主场优势 = 46.4580, 最佳损失 = 0.3599
# 迭代 7000/100000, 损失 = 0.3581, rank_scale = 4.9267, 主场优势 = 45.6790, 最佳损失 = 0.3581
# 迭代 8000/100000, 损失 = 0.3564, rank_scale = 5.5592, 主场优势 = 44.8447, 最佳损失 = 0.3564
# 迭代 9000/100000, 损失 = 0.3549, rank_scale = 6.2513, 主场优势 = 43.9896, 最佳损失 = 0.3549
# 迭代 10000/100000, 损失 = 0.3535, rank_scale = 6.9961, 主场优势 = 43.1485, 最佳损失 = 0.3535
# 迭代 11000/100000, 损失 = 0.3524, rank_scale = 7.7862, 主场优势 = 42.3730, 最佳损失 = 0.3524
# 迭代 12000/100000, 损失 = 0.3517, rank_scale = 8.6132, 主场优势 = 41.7752, 最佳损失 = 0.3517
# 迭代 13000/100000, 损失 = 0.3513, rank_scale = 9.4534, 主场优势 = 41.4990, 最佳损失 = 0.3513
# 迭代 14000/100000, 损失 = 0.3510, rank_scale = 10.2802, 主场优势 = 41.4253, 最佳损失 = 0.3510
# 迭代 15000/100000, 损失 = 0.3507, rank_scale = 11.0964, 主场优势 = 41.3844, 最佳损失 = 0.3507
# 迭代 16000/100000, 损失 = 0.3505, rank_scale = 11.9100, 主场优势 = 41.3497, 最佳损失 = 0.3505
# 迭代 17000/100000, 损失 = 0.3503, rank_scale = 12.7247, 主场优势 = 41.3188, 最佳损失 = 0.3503
# 迭代 18000/100000, 损失 = 0.3501, rank_scale = 13.5408, 主场优势 = 41.2908, 最佳损失 = 0.3501
# 迭代 19000/100000, 损失 = 0.3499, rank_scale = 14.3585, 主场优势 = 41.2648, 最佳损失 = 0.3499
# 迭代 20000/100000, 损失 = 0.3498, rank_scale = 15.1770, 主场优势 = 41.2408, 最佳损失 = 0.3498
# 迭代 21000/100000, 损失 = 0.3496, rank_scale = 15.9962, 主场优势 = 41.2181, 最佳损失 = 0.3496
# 迭代 22000/100000, 损失 = 0.3495, rank_scale = 16.8145, 主场优势 = 41.1977, 最佳损失 = 0.3495
# 迭代 23000/100000, 损失 = 0.3494, rank_scale = 17.6328, 主场优势 = 41.1771, 最佳损失 = 0.3494
# 迭代 24000/100000, 损失 = 0.3492, rank_scale = 18.4509, 主场优势 = 41.1587, 最佳损失 = 0.3492
# 迭代 25000/100000, 损失 = 0.3491, rank_scale = 19.2672, 主场优势 = 41.1409, 最佳损失 = 0.3491
# 迭代 26000/100000, 损失 = 0.3490, rank_scale = 20.0823, 主场优势 = 41.1245, 最佳损失 = 0.3490
# 迭代 27000/100000, 损失 = 0.3489, rank_scale = 20.8958, 主场优势 = 41.1082, 最佳损失 = 0.3489
# 迭代 28000/100000, 损失 = 0.3488, rank_scale = 21.7074, 主场优势 = 41.0931, 最佳损失 = 0.3488
# 迭代 29000/100000, 损失 = 0.3488, rank_scale = 22.5169, 主场优势 = 41.0786, 最佳损失 = 0.3488
# 迭代 30000/100000, 损失 = 0.3487, rank_scale = 23.3242, 主场优势 = 41.0650, 最佳损失 = 0.3487
# 迭代 31000/100000, 损失 = 0.3486, rank_scale = 24.1289, 主场优势 = 41.0514, 最佳损失 = 0.3486
# 迭代 32000/100000, 损失 = 0.3485, rank_scale = 24.9310, 主场优势 = 41.0386, 最佳损失 = 0.3485
# 迭代 33000/100000, 损失 = 0.3485, rank_scale = 25.7308, 主场优势 = 41.0268, 最佳损失 = 0.3485
# 迭代 34000/100000, 损失 = 0.3484, rank_scale = 26.5275, 主场优势 = 41.0151, 最佳损失 = 0.3484
# 迭代 35000/100000, 损失 = 0.3483, rank_scale = 27.3216, 主场优势 = 41.0041, 最佳损失 = 0.3483
# 迭代 36000/100000, 损失 = 0.3483, rank_scale = 28.1126, 主场优势 = 40.9934, 最佳损失 = 0.3483
# 迭代 37000/100000, 损失 = 0.3482, rank_scale = 28.9009, 主场优势 = 40.9835, 最佳损失 = 0.3482
# 迭代 38000/100000, 损失 = 0.3481, rank_scale = 29.6859, 主场优势 = 40.9733, 最佳损失 = 0.3481
# 迭代 39000/100000, 损失 = 0.3481, rank_scale = 30.4679, 主场优势 = 40.9644, 最佳损失 = 0.3481
# 迭代 40000/100000, 损失 = 0.3480, rank_scale = 31.2469, 主场优势 = 40.9545, 最佳损失 = 0.3480
# 迭代 41000/100000, 损失 = 0.3480, rank_scale = 32.0224, 主场优势 = 40.9459, 最佳损失 = 0.3480
# 迭代 42000/100000, 损失 = 0.3479, rank_scale = 32.7949, 主场优势 = 40.9370, 最佳损失 = 0.3479
# 迭代 43000/100000, 损失 = 0.3479, rank_scale = 33.5641, 主场优势 = 40.9294, 最佳损失 = 0.3479
# 迭代 44000/100000, 损失 = 0.3479, rank_scale = 34.3302, 主场优势 = 40.9209, 最佳损失 = 0.3479
# 迭代 45000/100000, 损失 = 0.3478, rank_scale = 35.0930, 主场优势 = 40.9135, 最佳损失 = 0.3478
# 迭代 46000/100000, 损失 = 0.3478, rank_scale = 35.8522, 主场优势 = 40.9058, 最佳损失 = 0.3478
# 迭代 47000/100000, 损失 = 0.3477, rank_scale = 36.6079, 主场优势 = 40.8990, 最佳损失 = 0.3477
# 迭代 48000/100000, 损失 = 0.3477, rank_scale = 37.3604, 主场优势 = 40.8921, 最佳损失 = 0.3477
# 迭代 49000/100000, 损失 = 0.3477, rank_scale = 38.1094, 主场优势 = 40.8847, 最佳损失 = 0.3477
# 迭代 50000/100000, 损失 = 0.3476, rank_scale = 38.8552, 主场优势 = 40.8782, 最佳损失 = 0.3476
# 迭代 51000/100000, 损失 = 0.3476, rank_scale = 39.5976, 主场优势 = 40.8714, 最佳损失 = 0.3476
# 迭代 52000/100000, 损失 = 0.3476, rank_scale = 40.3366, 主场优势 = 40.8657, 最佳损失 = 0.3476
# 迭代 53000/100000, 损失 = 0.3475, rank_scale = 41.0722, 主场优势 = 40.8594, 最佳损失 = 0.3475
# 迭代 54000/100000, 损失 = 0.3475, rank_scale = 41.8045, 主场优势 = 40.8535, 最佳损失 = 0.3475
# 迭代 55000/100000, 损失 = 0.3475, rank_scale = 42.5331, 主场优势 = 40.8479, 最佳损失 = 0.3475
# 迭代 56000/100000, 损失 = 0.3474, rank_scale = 43.2582, 主场优势 = 40.8421, 最佳损失 = 0.3474
# 迭代 57000/100000, 损失 = 0.3474, rank_scale = 43.9799, 主场优势 = 40.8366, 最佳损失 = 0.3474
# 迭代 58000/100000, 损失 = 0.3474, rank_scale = 44.6982, 主场优势 = 40.8315, 最佳损失 = 0.3474
# 迭代 59000/100000, 损失 = 0.3474, rank_scale = 45.4131, 主场优势 = 40.8265, 最佳损失 = 0.3474
# 迭代 60000/100000, 损失 = 0.3473, rank_scale = 46.1246, 主场优势 = 40.8208, 最佳损失 = 0.3473
# 迭代 61000/100000, 损失 = 0.3473, rank_scale = 46.8327, 主场优势 = 40.8159, 最佳损失 = 0.3473
# 迭代 62000/100000, 损失 = 0.3473, rank_scale = 47.5374, 主场优势 = 40.8111, 最佳损失 = 0.3473
# 迭代 63000/100000, 损失 = 0.3473, rank_scale = 48.2388, 主场优势 = 40.8070, 最佳损失 = 0.3473
# 迭代 64000/100000, 损失 = 0.3472, rank_scale = 48.9368, 主场优势 = 40.8022, 最佳损失 = 0.3472
# 迭代 65000/100000, 损失 = 0.3472, rank_scale = 49.6311, 主场优势 = 40.7977, 最佳损失 = 0.3472
# 迭代 66000/100000, 损失 = 0.3472, rank_scale = 50.3219, 主场优势 = 40.7933, 最佳损失 = 0.3472
# 迭代 67000/100000, 损失 = 0.3472, rank_scale = 51.0094, 主场优势 = 40.7888, 最佳损失 = 0.3472
# 迭代 68000/100000, 损失 = 0.3472, rank_scale = 51.6936, 主场优势 = 40.7846, 最佳损失 = 0.3472
# 迭代 69000/100000, 损失 = 0.3471, rank_scale = 52.3744, 主场优势 = 40.7807, 最佳损失 = 0.3471
# 迭代 70000/100000, 损失 = 0.3471, rank_scale = 53.0520, 主场优势 = 40.7770, 最佳损失 = 0.3471
# 迭代 71000/100000, 损失 = 0.3471, rank_scale = 53.7262, 主场优势 = 40.7730, 最佳损失 = 0.3471
# 迭代 72000/100000, 损失 = 0.3471, rank_scale = 54.3972, 主场优势 = 40.7688, 最佳损失 = 0.3471
# ...
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 serie-b 图 -> /Users/peixuanma/Downloads/Output_Graphs/serie-b_evolution.png
# 保存 2-bundesliga 图 -> /Users/peixuanma/Downloads/Output_Graphs/2-bundesliga_evolution.png
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 premiership 图 -> /Users/peixuanma/Downloads/Output_Graphs/premiership_evolution.png
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:523: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_43641/2765968780.py:525: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 pro-league 图 -> /Users/peixuanma/Downloads/Output_Graphs/pro-league_evolution.png
#
# 完成！
