# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, train_test_split, GridSearchCV
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix
from scipy.stats import uniform
import sklearn

print(f"scikit-learn 版本: {sklearn.__version__}")

# ====================== 计算防守统计数据 ======================
def compute_defensive_stats(match_df, team_positions_df):
    """计算球队的防守统计数据，包括6种比率、总失球数和平均失球数"""
    epsilon = 1e-8  # 提高数值稳定性
    team_stats = {}
    for team in team_positions_df['team_name'].unique():
        team_stats[team] = {
            'total_goals_conceded': 0, 'ratio1_list': [], 'ratio2_list': [], 'ratio3_list': [],
            'ratio4_list': [], 'ratio5_list': [], 'ratio6_list': [], 'num_matches': 0
        }

    # 主场比赛统计
    for idx, row in match_df.iterrows():
        home_team, away_team = row['home_team_name'], row['away_team_name']
        if home_team not in team_stats or away_team not in team_stats:
            print(f"警告: 主队 {home_team} 或客队 {away_team} 未找到，跳过比赛 {idx}")
            continue
        if row['Pre-Match PPG (Away)'] > 0:
            team_stats[home_team]['ratio1_list'].append(
                row['away_team_goal_count'] / (row['Pre-Match PPG (Away)'] + epsilon))
        if row['away_team_corner_count'] > 0:
            team_stats[home_team]['ratio2_list'].append(
                row['away_team_goal_count'] / (row['away_team_corner_count'] + epsilon))
        denominator = row['home_team_yellow_cards'] + row['home_team_red_cards'] + row['home_team_fouls'] + epsilon
        team_stats[home_team]['ratio3_list'].append(row['away_team_goal_count'] / denominator)
        # 修改为 'away_xg' 并添加容错
        away_xg = row['away_xg'] if 'away_xg' in match_df.columns else 0
        if away_xg > 0:
            team_stats[home_team]['ratio4_list'].append(row['away_team_goal_count'] / (away_xg + epsilon))
        shots_total = row['away_team_shots_on_target'] + row['away_team_shots_off_target'] + epsilon
        team_stats[home_team]['ratio5_list'].append(row['away_team_goal_count'] / shots_total)
        if row['away_team_possession'] > 0:
            team_stats[home_team]['ratio6_list'].append(
                row['away_team_goal_count'] / (row['away_team_possession'] + epsilon))
        team_stats[home_team]['total_goals_conceded'] += row['away_team_goal_count']
        team_stats[home_team]['num_matches'] += 1

    # 客场比赛统计
    for idx, row in match_df.iterrows():
        away_team = row['away_team_name']
        if away_team not in team_stats:
            print(f"警告: 客队 {away_team} 未找到，跳过比赛 {idx}")
            continue
        team_stats[away_team]['total_goals_conceded'] += row['home_team_goal_count']
        team_stats[away_team]['num_matches'] += 1

    # 汇总数据
    data = []
    for team, stats in team_stats.items():
        num_matches = stats['num_matches']
        average_goals_conceded = stats['total_goals_conceded'] / num_matches if num_matches > 0 else 0
        data.append({
            'team_name': team,
            'ratio1': np.mean(stats['ratio1_list']) if stats['ratio1_list'] else 0,
            'ratio2': np.mean(stats['ratio2_list']) if stats['ratio2_list'] else 0,
            'ratio3': np.mean(stats['ratio3_list']) if stats['ratio3_list'] else 0,
            'ratio4': np.mean(stats['ratio4_list']) if stats['ratio4_list'] else 0,
            'ratio5': np.mean(stats['ratio5_list']) if stats['ratio5_list'] else 0,
            'ratio6': np.mean(stats['ratio6_list']) if stats['ratio6_list'] else 0,
            'total_goals_conceded': stats['total_goals_conceded'],
            'average_goals_conceded': average_goals_conceded
        })

    return pd.DataFrame(data)

# ====================== ELO评分算法实现 ======================
def initialize_elo_scores(team_positions_df):
    """初始化球队ELO分数"""
    teams = team_positions_df['team_name'].unique().tolist()
    team_elo = {team: 1500 for team in teams}
    for team in teams:
        team_data = team_positions_df[team_positions_df['team_name'] == team]
        rank = team_data['points_per_game'].rank().iloc[0]
        team_elo[team] += (20 * (len(teams) - rank))
    return team_elo

def update_elo_scores(elo_scores, home_team, away_team, home_score, away_score, K=30):
    """更新ELO分数"""
    home_elo, away_elo = elo_scores[home_team], elo_scores[away_team]
    expected_home = 1 / (1 + 10 ** ((away_elo - home_elo) / 400))
    expected_away = 1 / (1 + 10 ** ((home_elo - away_elo) / 400))

    if home_score > away_score:
        elo_scores[home_team] += K * (1 - expected_home)
        elo_scores[away_team] += K * (0 - expected_away)
    elif home_score < away_score:
        elo_scores[home_team] += K * (0 - expected_home)
        elo_scores[away_team] += K * (1 - expected_away)
    else:
        elo_scores[home_team] += K * (0.5 - expected_home)
        elo_scores[away_team] += K * (0.5 - expected_away)
    return elo_scores

# **修改后的函数：计算主客场表现差异比值**
def compute_home_away_diff(match_df, team_positions_df, elo_scores):
    """计算每支球队在每个赛季的主客场表现差异比值"""
    epsilon = 1e-8  # 防止除零
    home_away_diff = {}

    for team in team_positions_df['team_name'].unique():
        for season in match_df['season'].unique():
            team_matches = match_df[
                ((match_df['home_team_name'] == team) | (match_df['away_team_name'] == team)) &
                (match_df['season'] == season)
            ]
            if team_matches.empty:
                continue

            opponents = set(team_matches['home_team_name'].unique()) | set(team_matches['away_team_name'].unique())
            opponents.remove(team)

            diff_ratios = []
            weights = []

            for opponent in opponents:
                home_match = team_matches[
                    (team_matches['home_team_name'] == team) & (team_matches['away_team_name'] == opponent)]
                away_match = team_matches[
                    (team_matches['away_team_name'] == team) & (team_matches['home_team_name'] == opponent)]

                if not home_match.empty and not away_match.empty:
                    # 使用 'home_xg' 和 'away_xg'，添加容错处理
                    home_xg = home_match['home_xg'].values[0] if 'home_xg' in home_match.columns else 0  # 主场xG
                    away_xg = away_match['away_xg'].values[0] if 'away_xg' in away_match.columns else 0  # 客场xG
                    home_conceded_xg = home_match['away_xg'].values[0] if 'away_xg' in home_match.columns else 0  # 主场失球xG
                    away_conceded_xg = away_match['home_xg'].values[0] if 'home_xg' in away_match.columns else 0  # 客场失球xG

                    ratio_xg = home_xg / (away_xg + epsilon)  # 主场xG / 客场xG
                    ratio_conceded = home_conceded_xg / (away_conceded_xg + epsilon)  # 主场失球xG / 客场失球xG
                    diff_ratio = (ratio_xg + ratio_conceded) / 2  # 平均差异比值

                    opponent_elo = elo_scores.get(opponent, 1500)  # 获取对手ELO
                    diff_ratios.append(diff_ratio)
                    weights.append(opponent_elo)

            if diff_ratios:
                weighted_diff = np.average(diff_ratios, weights=weights)  # 加权平均
                home_away_diff[f"{team}_{season}"] = weighted_diff
            else:
                home_away_diff[f"{team}_{season}"] = 1.0  # 默认无差异

    return home_away_diff

# ====================== 数据加载函数（含交叉验证） ======================
def load_all_league_data(base_path, leagues, seasons):
    """加载所有联赛数据并进行预处理，同时计算主客场差异"""
    all_team_positions, all_match_positions = [], []
    elo_scores = None  # 将在第一次加载后初始化

    for country_name, league_name in leagues:
        for season in seasons:
            print(f"加载数据: {country_name} - {league_name} - {season}")
            team_file = os.path.join(base_path, f"{country_name}-{league_name}-teams-{season}-stats.csv")
            match_file = os.path.join(base_path, f"{country_name}-{league_name}-matches-{season}-stats.csv")
            if not os.path.exists(team_file) or not os.path.exists(match_file):
                print(f"警告: {country_name} - {league_name} - {season} 文件缺失")
                continue

            team_df = pd.read_csv(team_file)
            match_df = pd.read_csv(match_file)

            # 统一球队名称格式
            team_df['team_name'] = team_df.get('common_name', team_df.get('team_name', None)).str.strip().str.lower()
            match_df['home_team_name'] = match_df['home_team_name'].str.strip().str.lower()
            match_df['away_team_name'] = match_df['away_team_name'].str.strip().str.lower()

            team_names = team_df['team_name'].unique()
            original_match_count = len(match_df)
            match_df = match_df[
                match_df['home_team_name'].isin(team_names) & match_df['away_team_name'].isin(team_names)]
            if len(match_df) < original_match_count:
                print(f"警告: 过滤了 {original_match_count - len(match_df)} 场比赛")

            if match_df.empty:
                print("警告: 无有效比赛数据")
                continue

            # 初始化ELO分数（仅在第一次加载时）
            if elo_scores is None:
                elo_scores = initialize_elo_scores(team_df)

            defensive_stats_df = compute_defensive_stats(match_df, team_df)
            if defensive_stats_df.empty:
                print("警告: 未计算出防守统计")
                continue

            team_df = team_df.merge(defensive_stats_df, on='team_name', how='left')
            for col in ['ratio1', 'ratio2', 'ratio3', 'ratio4', 'ratio5', 'ratio6', 'total_goals_conceded', 'average_goals_conceded']:
                if col not in team_df.columns:
                    print(f"警告: {col} 列缺失，设为0")
                    team_df[col] = 0

            # 归一化防守得分
            if 'total_goals_conceded' in team_df.columns and team_df['total_goals_conceded'].max() != team_df['total_goals_conceded'].min():
                team_df['normalized_defense_score'] = (team_df['total_goals_conceded'].max() - team_df['total_goals_conceded']) / (team_df['total_goals_conceded'].max() - team_df['total_goals_conceded'].min() + 1e-8)
            else:
                team_df['normalized_defense_score'] = 0

            # PCA降维（防守数据）
            defensive_columns = [col for col in team_df.columns if col in [
                'goals_conceded', 'total_goals_conceded', 'ratio1', 'ratio2', 'ratio3', 'ratio4', 'ratio5', 'ratio6',
                'normalized_defense_score'
            ]]
            team_df_defensive = team_df[defensive_columns].fillna(0)
            kf = KFold(n_splits=5, shuffle=True, random_state=42)
            pca_results = []
            for train_idx, _ in kf.split(team_df_defensive):
                train_data = team_df_defensive.iloc[train_idx]
                scaler = StandardScaler()
                X_scaled = scaler.fit_transform(train_data)
                pca = PCA(n_components=2)
                X_pca = pca.fit_transform(X_scaled)
                pca_results.append(X_pca)
            X_pca_avg = np.mean(
                [np.pad(r, ((0, len(team_df_defensive) - len(r)), (0, 0)), 'constant') for r in pca_results], axis=0)

            team_positions = pd.DataFrame({
                'team_name': team_df['team_name'], 'PC1': X_pca_avg[:, 0], 'PC2': X_pca_avg[:, 1],
                'points_per_game': team_df['points_per_game'], 'league': league_name, 'season': season,
                'ratio1': team_df['ratio1'], 'ratio2': team_df['ratio2'], 'ratio3': team_df['ratio3'],
                'ratio4': team_df['ratio4'], 'ratio5': team_df['ratio5'], 'ratio6': team_df['ratio6'],
                'normalized_defense_score': team_df['normalized_defense_score'],
                'total_goals_conceded': team_df['total_goals_conceded'],
                'average_goals_conceded': team_df['average_goals_conceded']
            })
            team_positions['team_season'] = league_name + '_' + team_positions['team_name'] + '_' + team_positions['season']
            all_team_positions.append(team_positions)

            # 比赛数据PCA
            match_df = match_df.drop(
                columns=['timestamp', 'date_GMT', 'status', 'attendance', 'referee', 'stadium_name', 'Game Week'],
                errors='ignore')
            numeric_cols = match_df.select_dtypes(include=[np.number]).columns
            match_df[numeric_cols] = match_df[numeric_cols].fillna(match_df[numeric_cols].mean())
            pca_match_results = []
            for train_idx, _ in kf.split(match_df[numeric_cols]):
                train_data = match_df[numeric_cols].iloc[train_idx]
                scaler = StandardScaler()
                X_scaled = scaler.fit_transform(train_data)
                pca = PCA(n_components=2)
                X_pca = pca.fit_transform(X_scaled)
                pca_match_results.append(X_pca)
            X_pca_match_avg = np.mean(
                [np.pad(r, ((0, len(match_df) - len(r)), (0, 0)), 'constant') for r in pca_match_results], axis=0)

            match_positions = pd.DataFrame({
                'home_team_name': match_df['home_team_name'], 'away_team_name': match_df['away_team_name'],
                'PC1': X_pca_match_avg[:, 0], 'PC2': X_pca_match_avg[:, 1], 'league': league_name, 'season': season
            })
            all_match_positions.append(match_positions)

    all_team_positions_df = pd.concat(all_team_positions, ignore_index=True)
    all_match_positions_df = pd.concat(all_match_positions, ignore_index=True)

    # 计算主客场差异比值并添加到team_positions_df
    home_away_diff = compute_home_away_diff(all_match_positions_df, all_team_positions_df, elo_scores)
    all_team_positions_df['home_away_diff'] = all_team_positions_df['team_season'].map(home_away_diff).fillna(1.0)

    return all_team_positions_df, all_match_positions_df

# ====================== 使用Adaboost优化权重 ======================
def compute_adaboost_weights(team_positions_df):
    """使用Adaboost计算防守比率的最佳权重，并通过交叉验证优化参数"""
    ratios = team_positions_df[['ratio1', 'ratio2', 'ratio3', 'ratio4', 'ratio5', 'ratio6']].replace([np.inf, -np.inf], np.nan).fillna(0)
    correlation_matrix = ratios.corr()
    print("特征相关性矩阵:\n", correlation_matrix)

    scaler = StandardScaler()
    ratios_scaled = scaler.fit_transform(ratios)
    labels = pd.qcut(team_positions_df['average_goals_conceded'], q=2, labels=[0, 1], duplicates='drop').fillna(0).astype(int)

    X_train, X_test, y_train, y_test = train_test_split(ratios_scaled, labels, test_size=0.2, random_state=42)

    ada = AdaBoostClassifier(algorithm='SAMME', random_state=42)
    param_grid = {
        'estimator': [DecisionTreeClassifier(max_depth=5), DecisionTreeClassifier(max_depth=10)],
        'n_estimators': [500, 1000, 1500, 250, 50, 200, 150, 100],
        'learning_rate': [0.01, 0.1, 0.5, 0.05, 0.25]
    }

    grid_search = GridSearchCV(ada, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
    grid_search.fit(X_train, y_train)

    best_params = grid_search.best_params_
    print("最佳参数:", best_params)

    adaboost = AdaBoostClassifier(
        estimator=best_params['estimator'],
        n_estimators=best_params['n_estimators'],
        learning_rate=best_params['learning_rate'],
        algorithm='SAMME',
        random_state=42
    )
    adaboost.fit(X_train, y_train)

    y_pred = adaboost.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, average='weighted')
    roc_auc = roc_auc_score(y_test, adaboost.predict_proba(X_test)[:, 1])
    conf_matrix = confusion_matrix(y_test, y_pred)

    print("测试集准确率:", accuracy)
    print("测试集F1分数:", f1)
    print("测试集ROC-AUC:", roc_auc)
    print("混淆矩阵:\n", conf_matrix)

    feature_importances = np.zeros(6)
    for i, est in enumerate(adaboost.estimators_):
        feature_importances += adaboost.estimator_weights_[i] * est.feature_importances_
    feature_importances /= np.sum(adaboost.estimator_weights_)

    weights = feature_importances / np.sum(feature_importances)
    print(f"计算得到的权重: {weights}")

    return weights.astype(np.float32)

# **修改后的损失函数：加入主客场差异比值**
def compute_total_loss(positions, match_home_idx, match_away_idx, match_PC1, match_PC2, points_per_game, rank_scale,
                       ratios, w, normalized_defense_score, lambda_defense, lambda_supervision, lambda_reg, elo_scores,
                       home_away_diff):
    """计算总损失，考虑主客场表现差异比值"""
    epsilon = 1e-8
    if tf.shape(match_home_idx)[0] == 0:
        return tf.constant(0.0, dtype=tf.float32)

    # 匹配损失
    home_pos = tf.gather(positions, match_home_idx)
    away_pos = tf.gather(positions, match_away_idx)
    match_points = tf.stack([match_PC1, match_PC2], axis=1)
    dist_home = tf.norm(home_pos - match_points + epsilon, axis=1)
    dist_away = tf.norm(away_pos - match_points + epsilon, axis=1)
    all_distances = tf.concat([dist_home, dist_away], axis=0)
    dist_range = tf.reduce_max(all_distances) - tf.reduce_min(all_distances) + epsilon
    dist_home_norm = (dist_home - tf.reduce_min(all_distances)) / dist_range
    dist_away_norm = (dist_away - tf.reduce_min(all_distances)) / dist_range

    # 获取主客场ELO分数和差异比值
    home_elo = tf.gather(elo_scores, match_home_idx)
    away_elo = tf.gather(elo_scores, match_away_idx)
    home_diff = tf.gather(home_away_diff, match_home_idx)  # 主场球队的主客场差异比值
    away_diff = tf.gather(home_away_diff, match_away_idx)  # 客场球队的主客场差异比值

    elo_diff = tf.abs(home_elo - away_elo)
    # 主场权重保持不变，客场权重乘以差异比值
    weight_home = 1.0 / (1.0 + elo_diff * rank_scale + epsilon)
    weight_away = weight_home * away_diff  # 客场权重调整
    # 归一化权重
    total_weight = weight_home + weight_away
    weight_home = weight_home / (total_weight + epsilon)
    weight_away = weight_away / (total_weight + epsilon)

    match_loss = tf.reduce_mean(weight_home * dist_home_norm + weight_away * dist_away_norm)

    # 防守损失
    w = tf.abs(w)
    defense_target = -tf.reduce_sum(w * ratios, axis=1)
    defense_loss = tf.reduce_mean(tf.square(positions[:, 1] - defense_target))

    # 监督损失
    supervision_loss = tf.reduce_mean(tf.square(defense_target - normalized_defense_score))

    # 正则化
    regularization_loss = lambda_reg * tf.reduce_sum(tf.square(w))

    total_loss = match_loss + lambda_defense * defense_loss + lambda_supervision * supervision_loss + regularization_loss
    return tf.where(tf.math.is_nan(total_loss) | tf.math.is_inf(total_loss), 0.0, total_loss)

# **修改后的Adam优化函数**
def adam_optimize_positions(team_positions_df, match_positions_df, initial_lr=0.0005, decay_steps=200000,
                            decay_rate=0.9, clipnorm=0.5, iterations=30000, verbose_interval=1000, random_seed=42,
                            lambda_defense=0.1, lambda_supervision=0.1, lambda_reg=0.01, patience=100, w=None):
    """使用Adam优化球队位置，考虑主客场差异"""
    team_seasons = team_positions_df['team_season'].unique()
    team_season_to_idx = {t: i for i, t in enumerate(team_seasons)}

    elo_scores_dict = initialize_elo_scores(team_positions_df)
    team_names = [t.split('_')[1] for t in team_seasons]
    elo_scores = tf.convert_to_tensor([elo_scores_dict[name] for name in team_names], dtype=tf.float32)

    # 获取主客场差异比值
    home_away_diff = tf.convert_to_tensor(team_positions_df['home_away_diff'].values, dtype=tf.float32)

    team_positions_df = team_positions_df.set_index('team_season')
    init_positions = team_positions_df[['PC1', 'PC2']].values
    ratios = team_positions_df[['ratio1', 'ratio2', 'ratio3', 'ratio4', 'ratio5', 'ratio6']].values
    scaler_pos = StandardScaler()
    scaler_rat = StandardScaler()
    positions_scaled = scaler_pos.fit_transform(init_positions)
    ratios_scaled = scaler_rat.fit_transform(ratios)

    positions = tf.Variable(positions_scaled, dtype=tf.float32)
    ratios = tf.constant(ratios_scaled, dtype=tf.float32)
    normalized_defense_score = tf.constant(team_positions_df['normalized_defense_score'].values, dtype=tf.float32)
    points_per_game = tf.constant(team_positions_df['points_per_game'].values, dtype=tf.float32)

    match_array = [
        [team_season_to_idx[f"{row['league']}_{row['home_team_name']}_{row['season']}"],
         team_season_to_idx[f"{row['league']}_{row['away_team_name']}_{row['season']}"], row['PC1'], row['PC2']]
        for _, row in match_positions_df.iterrows()
        if f"{row['league']}_{row['home_team_name']}_{row['season']}" in team_season_to_idx and
           f"{row['league']}_{row['away_team_name']}_{row['season']}" in team_season_to_idx
    ]
    match_array = np.array(match_array, dtype=np.float32)
    if len(match_array) == 0:
        print("警告: 无有效比赛数据")
        return [], team_positions_df.reset_index(), None, None

    match_home_idx = tf.constant(match_array[:, 0], dtype=tf.int32)
    match_away_idx = tf.constant(match_array[:, 1], dtype=tf.int32)
    match_PC1 = tf.constant(match_array[:, 2], dtype=tf.float32)
    match_PC2 = tf.constant(match_array[:, 3], dtype=tf.float32)

    tf.random.set_seed(random_seed)
    rank_scale = tf.Variable(1.0, dtype=tf.float32)
    w = tf.Variable(np.abs(w) if w is not None else np.ones(6, dtype=np.float32) / 6, dtype=tf.float32)
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(initial_lr, decay_steps, decay_rate)
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule, clipnorm=clipnorm)

    losses, best_loss, patience_counter = [], float('inf'), 0
    best_positions, best_rank_scale, best_w = positions.numpy().copy(), 1.0, w.numpy().copy()

    for i in range(iterations):
        with tf.GradientTape() as tape:
            loss = compute_total_loss(positions, match_home_idx, match_away_idx, match_PC1, match_PC2, points_per_game,
                                      rank_scale, ratios, w, normalized_defense_score, lambda_defense,
                                      lambda_supervision, lambda_reg, elo_scores, home_away_diff)
        grads = tape.gradient(loss, [positions, rank_scale, w])
        if any(g is None for g in grads):
            print(f"警告: 迭代 {i + 1} 梯度为None")
            continue
        optimizer.apply_gradients(zip(grads, [positions, rank_scale, w]))
        loss_val = float(loss.numpy())
        losses.append(loss_val)

        if loss_val < best_loss:
            best_loss = loss_val
            best_positions, best_rank_scale, best_w = positions.numpy().copy(), float(rank_scale.numpy()), w.numpy().copy()
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"早停触发，训练在第 {i + 1} 轮停止")
            break

        if (i + 1) % verbose_interval == 0:
            print(f"迭代 {i + 1}/{iterations}, 损失 = {loss_val:.4f}, rank_scale = {rank_scale.numpy():.4f}")

    positions.assign(best_positions)
    rank_scale.assign(best_rank_scale)
    w.assign(best_w)
    final_pos = scaler_pos.inverse_transform(positions.numpy())
    for idx, team_season in enumerate(team_seasons):
        team_positions_df.loc[team_season, 'PC1'] = final_pos[idx, 0]
        team_positions_df.loc[team_season, 'PC2'] = final_pos[idx, 1]
    team_positions_df = team_positions_df.reset_index()
    return losses, team_positions_df, best_rank_scale, best_w

# ====================== 随机搜索超参数调整 ======================
def random_search_hyperparameters(team_positions, match_positions, w, n_iter=10, random_state=42):
    """随机搜索最佳超参数"""
    np.random.seed(random_state)
    best_loss, best_params = float('inf'), None

    for _ in range(n_iter):
        params = {
            'lambda_defense': uniform(0.01, 0.2).rvs(),
            'lambda_supervision': uniform(0.01, 0.2).rvs(),
            'lambda_reg': uniform(0.001, 0.02).rvs()
        }
        print(f"\n随机搜索: {params}")

        losses, _, _, _ = adam_optimize_positions(
            team_positions.copy(), match_positions.copy(), w=w, **params
        )
        if losses and losses[-1] < best_loss:
            best_loss = losses[-1]
            best_params = params

    print(f"\n最佳超参数: {best_params}, 最佳损失: {best_loss:.4f}")
    return best_params

# ====================== 可视化函数 ======================
def visualize_team_evolution_by_league_static(team_positions_df, seasons_order):
    """按联赛可视化球队演变"""
    output_dir = "/Users/peixuanma/Downloads/Output_Graphs"
    os.makedirs(output_dir, exist_ok=True)

    for league in team_positions_df['league'].unique():
        league_df = team_positions_df[team_positions_df['league'] == league].copy()
        valid_teams = league_df.groupby("team_name").filter(lambda x: x['season'].nunique() == len(seasons_order))['team_name'].unique()
        if not valid_teams.size:
            valid_teams = league_df['team_name'].unique()
        valid_df = league_df[league_df['team_name'].isin(valid_teams)].sort_values(['team_name', 'season'])

        plt.figure(figsize=(10, 8))
        plt.title(f"{league} - 球队演变 (进攻-防守)")
        plt.xlabel("PC1 (进攻)")
        plt.ylabel("PC2 (防守)")
        plt.grid(True)

        for team in valid_df['team_name'].unique():
            sub = valid_df[valid_df['team_name'] == team]
            plt.plot(sub['PC1'], sub['PC2'], marker='o', label=team)
            for _, row in sub.iterrows():
                plt.text(row['PC1'], row['PC2'], row['season'], fontsize=8, ha='right')

        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        plt.tight_layout()
        filename = os.path.join(output_dir, f"{league}_evolution.png")
        plt.savefig(filename, dpi=150)
        plt.close()
        print(f"保存 {league} 图 -> {filename}")

# ====================== 主函数 ======================
if __name__ == "__main__":
    base_path = '/Users/peixuanma/Downloads/data1'
    leagues = [
        ("england", "premier-league"), ("germany", "bundesliga"), ("spain", "la-liga"),
        ("france", "ligue-1"), ("france", "ligue-2"), ("italy", "serie-a"), ("netherlands", "eredivisie"),
        ("portugal", "ligapro"), ("denmark", "superliga"), ("england", "championship"), ("spain", "segunda-division"),
        ("switzerland", "super-league"), ("portugal", "liga-nos"), ("italy", "serie-b"), ("germany", "2-bundesliga"),
        ("scotland", "premiership"), ("belgium", "pro-league"), ("austria", "bundesliga"),
    ]
    seasons = [
        "2013-to-2014", "2014-to-2015", "2015-to-2016", "2016-to-2017", "2017-to-2018",
        "2018-to-2019", "2019-to-2020", "2020-to-2021", "2021-to-2022", "2022-to-2023", "2023-to-2024"
    ]

    # 加载数据
    print("===== 加载数据 =====")
    all_team_positions, all_match_positions = load_all_league_data(base_path, leagues, seasons)

    # 计算Adaboost权重
    print("\n===== 计算Adaboost权重 =====")
    adaboost_weights = compute_adaboost_weights(all_team_positions)
    print("优化后的Adaboost权重:", adaboost_weights)

    # 随机搜索超参数
    print("\n===== 随机搜索超参数 =====")
    best_params = random_search_hyperparameters(all_team_positions, all_match_positions, adaboost_weights)

    # 最终训练
    print("\n===== 最终训练 =====")
    final_losses, final_team_positions, final_rank_scale, final_w = adam_optimize_positions(
        all_team_positions.copy(), all_match_positions.copy(), w=adaboost_weights, **best_params
    )
    if final_losses:
        final_team_positions.to_csv("trained_team_positions.csv", index=False)
        print(f"最终损失: {final_losses[-1]:.4f}")

    # 可视化
    print("\n===== 可视化 =====")
    visualize_team_evolution_by_league_static(final_team_positions, seasons)

    print("\n完成！")
# Out:
# scikit-learn 版本: 1.4.2
# ===== 加载数据 =====
# 加载数据: england - premier-league - 2013-to-2014
# 加载数据: england - premier-league - 2014-to-2015
# 加载数据: england - premier-league - 2015-to-2016
# 加载数据: england - premier-league - 2016-to-2017
# 加载数据: england - premier-league - 2017-to-2018
# 加载数据: england - premier-league - 2018-to-2019
# 加载数据: england - premier-league - 2019-to-2020
# 加载数据: england - premier-league - 2020-to-2021
# 加载数据: england - premier-league - 2021-to-2022
# 加载数据: england - premier-league - 2022-to-2023
# 加载数据: england - premier-league - 2023-to-2024
# 加载数据: germany - bundesliga - 2013-to-2014
# 加载数据: germany - bundesliga - 2014-to-2015
# 加载数据: germany - bundesliga - 2015-to-2016
# 加载数据: germany - bundesliga - 2016-to-2017
# 加载数据: germany - bundesliga - 2017-to-2018
# 加载数据: germany - bundesliga - 2018-to-2019
# 加载数据: germany - bundesliga - 2019-to-2020
# 加载数据: germany - bundesliga - 2020-to-2021
# 加载数据: germany - bundesliga - 2021-to-2022
# 加载数据: germany - bundesliga - 2022-to-2023
# 加载数据: germany - bundesliga - 2023-to-2024
# 加载数据: spain - la-liga - 2013-to-2014
# 加载数据: spain - la-liga - 2014-to-2015
# 加载数据: spain - la-liga - 2015-to-2016
# 加载数据: spain - la-liga - 2016-to-2017
# 加载数据: spain - la-liga - 2017-to-2018
# 加载数据: spain - la-liga - 2018-to-2019
# 加载数据: spain - la-liga - 2019-to-2020
# 加载数据: spain - la-liga - 2020-to-2021
# 加载数据: spain - la-liga - 2021-to-2022
# 加载数据: spain - la-liga - 2022-to-2023
# 加载数据: spain - la-liga - 2023-to-2024
# 加载数据: france - ligue-1 - 2013-to-2014
# 加载数据: france - ligue-1 - 2014-to-2015
# 加载数据: france - ligue-1 - 2015-to-2016
# 加载数据: france - ligue-1 - 2016-to-2017
# 加载数据: france - ligue-1 - 2017-to-2018
# 加载数据: france - ligue-1 - 2018-to-2019
# 加载数据: france - ligue-1 - 2019-to-2020
# 警告: france - ligue-1 - 2019-to-2020 文件缺失
# 加载数据: france - ligue-1 - 2020-to-2021
# 加载数据: france - ligue-1 - 2021-to-2022
# 加载数据: france - ligue-1 - 2022-to-2023
# 加载数据: france - ligue-1 - 2023-to-2024
# 加载数据: france - ligue-2 - 2013-to-2014
# 加载数据: france - ligue-2 - 2014-to-2015
# 加载数据: france - ligue-2 - 2015-to-2016
# 加载数据: france - ligue-2 - 2016-to-2017
# 加载数据: france - ligue-2 - 2017-to-2018
# 加载数据: france - ligue-2 - 2018-to-2019
# 加载数据: france - ligue-2 - 2019-to-2020
# 警告: france - ligue-2 - 2019-to-2020 文件缺失
# 加载数据: france - ligue-2 - 2020-to-2021
# 加载数据: france - ligue-2 - 2021-to-2022
# 加载数据: france - ligue-2 - 2022-to-2023
# 加载数据: france - ligue-2 - 2023-to-2024
# 加载数据: italy - serie-a - 2013-to-2014
# 加载数据: italy - serie-a - 2014-to-2015
# 加载数据: italy - serie-a - 2015-to-2016
# 加载数据: italy - serie-a - 2016-to-2017
# 加载数据: italy - serie-a - 2017-to-2018
# 加载数据: italy - serie-a - 2018-to-2019
# 加载数据: italy - serie-a - 2019-to-2020
# 加载数据: italy - serie-a - 2020-to-2021
# 加载数据: italy - serie-a - 2021-to-2022
# 加载数据: italy - serie-a - 2022-to-2023
# 加载数据: italy - serie-a - 2023-to-2024
# 加载数据: netherlands - eredivisie - 2013-to-2014
# 加载数据: netherlands - eredivisie - 2014-to-2015
# 加载数据: netherlands - eredivisie - 2015-to-2016
# 加载数据: netherlands - eredivisie - 2016-to-2017
# 加载数据: netherlands - eredivisie - 2017-to-2018
# 加载数据: netherlands - eredivisie - 2018-to-2019
# 加载数据: netherlands - eredivisie - 2019-to-2020
# 加载数据: netherlands - eredivisie - 2020-to-2021
# 加载数据: netherlands - eredivisie - 2021-to-2022
# 加载数据: netherlands - eredivisie - 2022-to-2023
# 加载数据: netherlands - eredivisie - 2023-to-2024
# 加载数据: portugal - ligapro - 2013-to-2014
# 警告: portugal - ligapro - 2013-to-2014 文件缺失
# 加载数据: portugal - ligapro - 2014-to-2015
# 加载数据: portugal - ligapro - 2015-to-2016
# 加载数据: portugal - ligapro - 2016-to-2017
# 加载数据: portugal - ligapro - 2017-to-2018
# 加载数据: portugal - ligapro - 2018-to-2019
# 加载数据: portugal - ligapro - 2019-to-2020
# 加载数据: portugal - ligapro - 2020-to-2021
# 加载数据: portugal - ligapro - 2021-to-2022
# 加载数据: portugal - ligapro - 2022-to-2023
# 加载数据: portugal - ligapro - 2023-to-2024
# 加载数据: denmark - superliga - 2013-to-2014
# 加载数据: denmark - superliga - 2014-to-2015
# 加载数据: denmark - superliga - 2015-to-2016
# 加载数据: denmark - superliga - 2016-to-2017
# 加载数据: denmark - superliga - 2017-to-2018
# 加载数据: denmark - superliga - 2018-to-2019
# 加载数据: denmark - superliga - 2019-to-2020
# 加载数据: denmark - superliga - 2020-to-2021
# 加载数据: denmark - superliga - 2021-to-2022
# 加载数据: denmark - superliga - 2022-to-2023
# 加载数据: denmark - superliga - 2023-to-2024
# 加载数据: england - championship - 2013-to-2014
# 加载数据: england - championship - 2014-to-2015
# 加载数据: england - championship - 2015-to-2016
# 加载数据: england - championship - 2016-to-2017
# 加载数据: england - championship - 2017-to-2018
# 加载数据: england - championship - 2018-to-2019
# 加载数据: england - championship - 2019-to-2020
# 加载数据: england - championship - 2020-to-2021
# 加载数据: england - championship - 2021-to-2022
# 加载数据: england - championship - 2022-to-2023
# 加载数据: england - championship - 2023-to-2024
# 加载数据: spain - segunda-division - 2013-to-2014
# 加载数据: spain - segunda-division - 2014-to-2015
# 加载数据: spain - segunda-division - 2015-to-2016
# 加载数据: spain - segunda-division - 2016-to-2017
# 加载数据: spain - segunda-division - 2017-to-2018
# 加载数据: spain - segunda-division - 2018-to-2019
# 加载数据: spain - segunda-division - 2019-to-2020
# 加载数据: spain - segunda-division - 2020-to-2021
# 加载数据: spain - segunda-division - 2021-to-2022
# 加载数据: spain - segunda-division - 2022-to-2023
# 加载数据: spain - segunda-division - 2023-to-2024
# 加载数据: switzerland - super-league - 2013-to-2014
# 加载数据: switzerland - super-league - 2014-to-2015
# 加载数据: switzerland - super-league - 2015-to-2016
# 加载数据: switzerland - super-league - 2016-to-2017
# 加载数据: switzerland - super-league - 2017-to-2018
# 加载数据: switzerland - super-league - 2018-to-2019
# 加载数据: switzerland - super-league - 2019-to-2020
# 加载数据: switzerland - super-league - 2020-to-2021
# 加载数据: switzerland - super-league - 2021-to-2022
# 加载数据: switzerland - super-league - 2022-to-2023
# 加载数据: switzerland - super-league - 2023-to-2024
# 加载数据: portugal - liga-nos - 2013-to-2014
# 加载数据: portugal - liga-nos - 2014-to-2015
# 加载数据: portugal - liga-nos - 2015-to-2016
# 加载数据: portugal - liga-nos - 2016-to-2017
# 加载数据: portugal - liga-nos - 2017-to-2018
# 加载数据: portugal - liga-nos - 2018-to-2019
# 加载数据: portugal - liga-nos - 2019-to-2020
# 加载数据: portugal - liga-nos - 2020-to-2021
# 加载数据: portugal - liga-nos - 2021-to-2022
# 加载数据: portugal - liga-nos - 2022-to-2023
# 加载数据: portugal - liga-nos - 2023-to-2024
# 加载数据: italy - serie-b - 2013-to-2014
# 加载数据: italy - serie-b - 2014-to-2015
# 加载数据: italy - serie-b - 2015-to-2016
# 加载数据: italy - serie-b - 2016-to-2017
# 加载数据: italy - serie-b - 2017-to-2018
# 加载数据: italy - serie-b - 2018-to-2019
# 加载数据: italy - serie-b - 2019-to-2020
# 加载数据: italy - serie-b - 2020-to-2021
# 加载数据: italy - serie-b - 2021-to-2022
# 加载数据: italy - serie-b - 2022-to-2023
# 加载数据: italy - serie-b - 2023-to-2024
# 加载数据: germany - 2-bundesliga - 2013-to-2014
# 加载数据: germany - 2-bundesliga - 2014-to-2015
# 加载数据: germany - 2-bundesliga - 2015-to-2016
# 加载数据: germany - 2-bundesliga - 2016-to-2017
# 加载数据: germany - 2-bundesliga - 2017-to-2018
# 加载数据: germany - 2-bundesliga - 2018-to-2019
# 加载数据: germany - 2-bundesliga - 2019-to-2020
# 加载数据: germany - 2-bundesliga - 2020-to-2021
# 加载数据: germany - 2-bundesliga - 2021-to-2022
# 加载数据: germany - 2-bundesliga - 2022-to-2023
# 加载数据: germany - 2-bundesliga - 2023-to-2024
# 加载数据: scotland - premiership - 2013-to-2014
# 加载数据: scotland - premiership - 2014-to-2015
# 加载数据: scotland - premiership - 2015-to-2016
# 加载数据: scotland - premiership - 2016-to-2017
# 加载数据: scotland - premiership - 2017-to-2018
# 加载数据: scotland - premiership - 2018-to-2019
# 加载数据: scotland - premiership - 2019-to-2020
# 加载数据: scotland - premiership - 2020-to-2021
# 加载数据: scotland - premiership - 2021-to-2022
# 加载数据: scotland - premiership - 2022-to-2023
# 加载数据: scotland - premiership - 2023-to-2024
# 加载数据: belgium - pro-league - 2013-to-2014
# 警告: belgium - pro-league - 2013-to-2014 文件缺失
# 加载数据: belgium - pro-league - 2014-to-2015
# 警告: belgium - pro-league - 2014-to-2015 文件缺失
# 加载数据: belgium - pro-league - 2015-to-2016
# 加载数据: belgium - pro-league - 2016-to-2017
# 加载数据: belgium - pro-league - 2017-to-2018
# 加载数据: belgium - pro-league - 2018-to-2019
# 加载数据: belgium - pro-league - 2019-to-2020
# 加载数据: belgium - pro-league - 2020-to-2021
# 加载数据: belgium - pro-league - 2021-to-2022
# 加载数据: belgium - pro-league - 2022-to-2023
# 加载数据: belgium - pro-league - 2023-to-2024
# 加载数据: austria - bundesliga - 2013-to-2014
# 加载数据: austria - bundesliga - 2014-to-2015
# 加载数据: austria - bundesliga - 2015-to-2016
# 加载数据: austria - bundesliga - 2016-to-2017
# 加载数据: austria - bundesliga - 2017-to-2018
# 加载数据: austria - bundesliga - 2018-to-2019
# 加载数据: austria - bundesliga - 2019-to-2020
# 加载数据: austria - bundesliga - 2020-to-2021
# 加载数据: austria - bundesliga - 2021-to-2022
# 加载数据: austria - bundesliga - 2022-to-2023
# 加载数据: austria - bundesliga - 2023-to-2024
#
# ===== 计算Adaboost权重 =====
# 特征相关性矩阵:
#            ratio1    ratio2    ratio3  ratio4    ratio5    ratio6
# ratio1  1.000000  0.505279  0.037549     NaN  0.032248  0.705822
# ratio2  0.505279  1.000000  0.019284     NaN  0.017985  0.691403
# ratio3  0.037549  0.019284  1.000000     NaN  0.002512  0.041831
# ratio4       NaN       NaN       NaN     NaN       NaN       NaN
# ratio5  0.032248  0.017985  0.002512     NaN  1.000000  0.008483
# ratio6  0.705822  0.691403  0.041831     NaN  0.008483  1.000000
# 最佳参数: {'estimator': DecisionTreeClassifier(max_depth=5), 'learning_rate': 0.01, 'n_estimators': 50}
# 测试集准确率: 0.7732558139534884
# 测试集F1分数: 0.7726779303588033
# 测试集ROC-AUC: 0.842417933940948
# 混淆矩阵:
#  [[291  66]
#  [ 90 241]]
# 计算得到的权重: [1.64121893e-01 1.73187810e-02 1.19424009e-04 0.00000000e+00
#  3.23563347e-03 8.15204268e-01]
# 优化后的Adaboost权重: [1.6412190e-01 1.7318781e-02 1.1942401e-04 0.0000000e+00 3.2356335e-03
#  8.1520426e-01]
#
# ===== 随机搜索超参数 =====
#
# 随机搜索: {'lambda_defense': 0.0849080237694725, 'lambda_supervision': 0.20014286128198325, 'lambda_reg': 0.015639878836228104}
# 迭代 1000/30000, 损失 = 0.2427, rank_scale = 1.0882
# 迭代 2000/30000, 损失 = 0.1918, rank_scale = 1.1993
# 迭代 3000/30000, 损失 = 0.1728, rank_scale = 1.3124
# 迭代 4000/30000, 损失 = 0.1619, rank_scale = 1.4206
# 迭代 5000/30000, 损失 = 0.1545, rank_scale = 1.5251
# 迭代 6000/30000, 损失 = 0.1487, rank_scale = 1.6256
# 迭代 7000/30000, 损失 = 0.1440, rank_scale = 1.7228
# 迭代 8000/30000, 损失 = 0.1398, rank_scale = 1.8175
# 迭代 9000/30000, 损失 = 0.1362, rank_scale = 1.9101
# 迭代 10000/30000, 损失 = 0.1332, rank_scale = 1.9999
# 迭代 11000/30000, 损失 = 0.1306, rank_scale = 2.0870
# 迭代 12000/30000, 损失 = 0.1283, rank_scale = 2.1716
# 迭代 13000/30000, 损失 = 0.1263, rank_scale = 2.2538
# 迭代 14000/30000, 损失 = 0.1245, rank_scale = 2.3343
# 迭代 15000/30000, 损失 = 0.1229, rank_scale = 2.4133
# 迭代 16000/30000, 损失 = 0.1214, rank_scale = 2.4911
# 迭代 17000/30000, 损失 = 0.1201, rank_scale = 2.5665
# 迭代 18000/30000, 损失 = 0.1189, rank_scale = 2.6400
# 迭代 19000/30000, 损失 = 0.1178, rank_scale = 2.7120
# 迭代 20000/30000, 损失 = 0.1168, rank_scale = 2.7828
# 迭代 21000/30000, 损失 = 0.1158, rank_scale = 2.8519
# 迭代 22000/30000, 损失 = 0.1149, rank_scale = 2.9198
# 迭代 23000/30000, 损失 = 0.1141, rank_scale = 2.9863
# 迭代 24000/30000, 损失 = 0.1134, rank_scale = 3.0520
# 迭代 25000/30000, 损失 = 0.1127, rank_scale = 3.1163
# 迭代 26000/30000, 损失 = 0.1120, rank_scale = 3.1794
# 迭代 27000/30000, 损失 = 0.1114, rank_scale = 3.2411
# 迭代 28000/30000, 损失 = 0.1108, rank_scale = 3.3019
# 迭代 29000/30000, 损失 = 0.1103, rank_scale = 3.3622
# 迭代 30000/30000, 损失 = 0.1097, rank_scale = 3.4224
#
# 随机搜索: {'lambda_defense': 0.12973169683940733, 'lambda_supervision': 0.0412037280884873, 'lambda_reg': 0.004119890406724053}
# 迭代 1000/30000, 损失 = 0.2171, rank_scale = 1.0882
# 迭代 2000/30000, 损失 = 0.1607, rank_scale = 1.1996
# 迭代 3000/30000, 损失 = 0.1361, rank_scale = 1.3128
# 迭代 4000/30000, 损失 = 0.1222, rank_scale = 1.4211
# 迭代 5000/30000, 损失 = 0.1129, rank_scale = 1.5256
# 迭代 6000/30000, 损失 = 0.1057, rank_scale = 1.6261
# 迭代 7000/30000, 损失 = 0.0999, rank_scale = 1.7233
# 迭代 8000/30000, 损失 = 0.0950, rank_scale = 1.8181
# 迭代 9000/30000, 损失 = 0.0912, rank_scale = 1.9107
# 迭代 10000/30000, 损失 = 0.0880, rank_scale = 2.0006
# 迭代 11000/30000, 损失 = 0.0853, rank_scale = 2.0879
# 迭代 12000/30000, 损失 = 0.0831, rank_scale = 2.1726
# 迭代 13000/30000, 损失 = 0.0812, rank_scale = 2.2550
# 迭代 14000/30000, 损失 = 0.0796, rank_scale = 2.3357
# 迭代 15000/30000, 损失 = 0.0781, rank_scale = 2.4152
# 迭代 16000/30000, 损失 = 0.0768, rank_scale = 2.4933
# 迭代 17000/30000, 损失 = 0.0757, rank_scale = 2.5690
# 迭代 18000/30000, 损失 = 0.0746, rank_scale = 2.6431
# 迭代 19000/30000, 损失 = 0.0736, rank_scale = 2.7157
# 迭代 20000/30000, 损失 = 0.0727, rank_scale = 2.7871
# 迭代 21000/30000, 损失 = 0.0719, rank_scale = 2.8571
# 迭代 22000/30000, 损失 = 0.0711, rank_scale = 2.9263
# 迭代 23000/30000, 损失 = 0.0704, rank_scale = 2.9945
# 迭代 24000/30000, 损失 = 0.0696, rank_scale = 3.0625
# 迭代 25000/30000, 损失 = 0.0688, rank_scale = 3.1301
# 迭代 26000/30000, 损失 = 0.0680, rank_scale = 3.1969
# 迭代 27000/30000, 损失 = 0.0672, rank_scale = 3.2630
# 迭代 28000/30000, 损失 = 0.0664, rank_scale = 3.3288
# 迭代 29000/30000, 损失 = 0.0657, rank_scale = 3.3944
# 迭代 30000/30000, 损失 = 0.0649, rank_scale = 3.4599
#
# 随机搜索: {'lambda_defense': 0.021616722433639893, 'lambda_supervision': 0.18323522915498705, 'lambda_reg': 0.013022300234864177}
# 迭代 1000/30000, 损失 = 0.1980, rank_scale = 1.0881
# 迭代 2000/30000, 损失 = 0.1646, rank_scale = 1.1990
# 迭代 3000/30000, 损失 = 0.1528, rank_scale = 1.3119
# 迭代 4000/30000, 损失 = 0.1457, rank_scale = 1.4199
# 迭代 5000/30000, 损失 = 0.1408, rank_scale = 1.5242
# 迭代 6000/30000, 损失 = 0.1367, rank_scale = 1.6247
# 迭代 7000/30000, 损失 = 0.1333, rank_scale = 1.7218
# 迭代 8000/30000, 损失 = 0.1302, rank_scale = 1.8166
# 迭代 9000/30000, 损失 = 0.1274, rank_scale = 1.9093
# 迭代 10000/30000, 损失 = 0.1248, rank_scale = 1.9990
# 迭代 11000/30000, 损失 = 0.1225, rank_scale = 2.0860
# 迭代 12000/30000, 损失 = 0.1204, rank_scale = 2.1703
# 迭代 13000/30000, 损失 = 0.1184, rank_scale = 2.2523
# 迭代 14000/30000, 损失 = 0.1166, rank_scale = 2.3326
# 迭代 15000/30000, 损失 = 0.1148, rank_scale = 2.4112
# 迭代 16000/30000, 损失 = 0.1132, rank_scale = 2.4887
# 迭代 17000/30000, 损失 = 0.1117, rank_scale = 2.5636
# 迭代 18000/30000, 损失 = 0.1102, rank_scale = 2.6367
# 迭代 19000/30000, 损失 = 0.1089, rank_scale = 2.7081
# 迭代 20000/30000, 损失 = 0.1076, rank_scale = 2.7782
# 迭代 21000/30000, 损失 = 0.1064, rank_scale = 2.8467
# 迭代 22000/30000, 损失 = 0.1053, rank_scale = 2.9137
# 迭代 23000/30000, 损失 = 0.1043, rank_scale = 2.9795
# 迭代 24000/30000, 损失 = 0.1033, rank_scale = 3.0442
# 迭代 25000/30000, 损失 = 0.1023, rank_scale = 3.1075
# 迭代 26000/30000, 损失 = 0.1014, rank_scale = 3.1695
# 迭代 27000/30000, 损失 = 0.1006, rank_scale = 3.2300
# 迭代 28000/30000, 损失 = 0.0998, rank_scale = 3.2892
# 迭代 29000/30000, 损失 = 0.0990, rank_scale = 3.3476
# 迭代 30000/30000, 损失 = 0.0983, rank_scale = 3.4051
#
# 随机搜索: {'lambda_defense': 0.1516145155592091, 'lambda_supervision': 0.014116898859160489, 'lambda_reg': 0.020398197043239887}
# 迭代 1000/30000, 损失 = 0.2244, rank_scale = 1.0883
# 迭代 2000/30000, 损失 = 0.1607, rank_scale = 1.1997
# 迭代 3000/30000, 损失 = 0.1328, rank_scale = 1.3129
# 迭代 4000/30000, 损失 = 0.1173, rank_scale = 1.4212
# 迭代 5000/30000, 损失 = 0.1070, rank_scale = 1.5256
# 迭代 6000/30000, 损失 = 0.0992, rank_scale = 1.6261
# 迭代 7000/30000, 损失 = 0.0929, rank_scale = 1.7233
# 迭代 8000/30000, 损失 = 0.0878, rank_scale = 1.8181
# 迭代 9000/30000, 损失 = 0.0837, rank_scale = 1.9107
# 迭代 10000/30000, 损失 = 0.0803, rank_scale = 2.0005
# 迭代 11000/30000, 损失 = 0.0777, rank_scale = 2.0875
# 迭代 12000/30000, 损失 = 0.0755, rank_scale = 2.1719
# 迭代 13000/30000, 损失 = 0.0738, rank_scale = 2.2540
# 迭代 14000/30000, 损失 = 0.0722, rank_scale = 2.3345
# 迭代 15000/30000, 损失 = 0.0709, rank_scale = 2.4137
# 迭代 16000/30000, 损失 = 0.0697, rank_scale = 2.4916
# 迭代 17000/30000, 损失 = 0.0686, rank_scale = 2.5673
# 迭代 18000/30000, 损失 = 0.0676, rank_scale = 2.6413
# 迭代 19000/30000, 损失 = 0.0666, rank_scale = 2.7141
# 迭代 20000/30000, 损失 = 0.0657, rank_scale = 2.7859
# 迭代 21000/30000, 损失 = 0.0648, rank_scale = 2.8566
# 迭代 22000/30000, 损失 = 0.0640, rank_scale = 2.9271
# 迭代 23000/30000, 损失 = 0.0631, rank_scale = 2.9970
# 迭代 24000/30000, 损失 = 0.0622, rank_scale = 3.0670
# 迭代 25000/30000, 损失 = 0.0613, rank_scale = 3.1363
# 迭代 26000/30000, 损失 = 0.0604, rank_scale = 3.2046
# 迭代 27000/30000, 损失 = 0.0596, rank_scale = 3.2722
# 迭代 28000/30000, 损失 = 0.0587, rank_scale = 3.3393
# 迭代 29000/30000, 损失 = 0.0579, rank_scale = 3.4062
# 迭代 30000/30000, 损失 = 0.0570, rank_scale = 3.4727
#
# 随机搜索: {'lambda_defense': 0.17648852816008437, 'lambda_supervision': 0.052467822135655234, 'lambda_reg': 0.004636499344142012}
# 迭代 1000/30000, 损失 = 0.2507, rank_scale = 1.0883
# 迭代 2000/30000, 损失 = 0.1799, rank_scale = 1.1998
# 迭代 3000/30000, 损失 = 0.1494, rank_scale = 1.3130
# 迭代 4000/30000, 损失 = 0.1322, rank_scale = 1.4213
# 迭代 5000/30000, 损失 = 0.1208, rank_scale = 1.5257
# 迭代 6000/30000, 损失 = 0.1123, rank_scale = 1.6262
# 迭代 7000/30000, 损失 = 0.1055, rank_scale = 1.7233
# 迭代 8000/30000, 损失 = 0.1001, rank_scale = 1.8180
# 迭代 9000/30000, 损失 = 0.0958, rank_scale = 1.9105
# 迭代 10000/30000, 损失 = 0.0924, rank_scale = 2.0004
# 迭代 11000/30000, 损失 = 0.0898, rank_scale = 2.0875
# 迭代 12000/30000, 损失 = 0.0878, rank_scale = 2.1721
# 迭代 13000/30000, 损失 = 0.0860, rank_scale = 2.2545
# 迭代 14000/30000, 损失 = 0.0845, rank_scale = 2.3353
# 迭代 15000/30000, 损失 = 0.0832, rank_scale = 2.4149
# 迭代 16000/30000, 损失 = 0.0820, rank_scale = 2.4933
# 迭代 17000/30000, 损失 = 0.0809, rank_scale = 2.5695
# 迭代 18000/30000, 损失 = 0.0799, rank_scale = 2.6443
# 迭代 19000/30000, 损失 = 0.0789, rank_scale = 2.7182
# 迭代 20000/30000, 损失 = 0.0779, rank_scale = 2.7916
# 迭代 21000/30000, 损失 = 0.0770, rank_scale = 2.8645
# 迭代 22000/30000, 损失 = 0.0760, rank_scale = 2.9371
# 迭代 23000/30000, 损失 = 0.0750, rank_scale = 3.0090
# 迭代 24000/30000, 损失 = 0.0740, rank_scale = 3.0808
# 迭代 25000/30000, 损失 = 0.0731, rank_scale = 3.1519
# 迭代 26000/30000, 损失 = 0.0721, rank_scale = 3.2218
# 迭代 27000/30000, 损失 = 0.0712, rank_scale = 3.2909
# 迭代 28000/30000, 损失 = 0.0703, rank_scale = 3.3595
# 迭代 29000/30000, 损失 = 0.0694, rank_scale = 3.4279
# 迭代 30000/30000, 损失 = 0.0685, rank_scale = 3.4956
#
# 随机搜索: {'lambda_defense': 0.046680901970686764, 'lambda_supervision': 0.07084844859190755, 'lambda_reg': 0.011495128632644756}
# 迭代 1000/30000, 损失 = 0.1738, rank_scale = 1.0881
# 迭代 2000/30000, 损失 = 0.1400, rank_scale = 1.1994
# 迭代 3000/30000, 损失 = 0.1259, rank_scale = 1.3124
# 迭代 4000/30000, 损失 = 0.1175, rank_scale = 1.4205
# 迭代 5000/30000, 损失 = 0.1117, rank_scale = 1.5250
# 迭代 6000/30000, 损失 = 0.1070, rank_scale = 1.6255
# 迭代 7000/30000, 损失 = 0.1031, rank_scale = 1.7228
# 迭代 8000/30000, 损失 = 0.0996, rank_scale = 1.8177
# 迭代 9000/30000, 损失 = 0.0964, rank_scale = 1.9103
# 迭代 10000/30000, 损失 = 0.0936, rank_scale = 2.0001
# 迭代 11000/30000, 损失 = 0.0911, rank_scale = 2.0871
# 迭代 12000/30000, 损失 = 0.0889, rank_scale = 2.1715
# 迭代 13000/30000, 损失 = 0.0869, rank_scale = 2.2536
# 迭代 14000/30000, 损失 = 0.0851, rank_scale = 2.3339
# 迭代 15000/30000, 损失 = 0.0833, rank_scale = 2.4127
# 迭代 16000/30000, 损失 = 0.0818, rank_scale = 2.4902
# 迭代 17000/30000, 损失 = 0.0803, rank_scale = 2.5653
# 迭代 18000/30000, 损失 = 0.0790, rank_scale = 2.6385
# 迭代 19000/30000, 损失 = 0.0777, rank_scale = 2.7102
# 迭代 20000/30000, 损失 = 0.0765, rank_scale = 2.7805
# 迭代 21000/30000, 损失 = 0.0755, rank_scale = 2.8492
# 迭代 22000/30000, 损失 = 0.0744, rank_scale = 2.9166
# 迭代 23000/30000, 损失 = 0.0735, rank_scale = 2.9826
# 迭代 24000/30000, 损失 = 0.0726, rank_scale = 3.0477
# 迭代 25000/30000, 损失 = 0.0718, rank_scale = 3.1112
# 迭代 26000/30000, 损失 = 0.0710, rank_scale = 3.1735
# 迭代 27000/30000, 损失 = 0.0702, rank_scale = 3.2343
# 迭代 28000/30000, 损失 = 0.0696, rank_scale = 3.2940
# 迭代 29000/30000, 损失 = 0.0689, rank_scale = 3.3527
# 迭代 30000/30000, 损失 = 0.0683, rank_scale = 3.4107
#
# 随机搜索: {'lambda_defense': 0.09638900372842316, 'lambda_supervision': 0.06824582803960838, 'lambda_reg': 0.013237057894447589}
# 迭代 1000/30000, 损失 = 0.2062, rank_scale = 1.0882
# 迭代 2000/30000, 损失 = 0.1572, rank_scale = 1.1995
# 迭代 3000/30000, 损失 = 0.1367, rank_scale = 1.3127
# 迭代 4000/30000, 损失 = 0.1251, rank_scale = 1.4209
# 迭代 5000/30000, 损失 = 0.1172, rank_scale = 1.5254
# 迭代 6000/30000, 损失 = 0.1111, rank_scale = 1.6259
# 迭代 7000/30000, 损失 = 0.1060, rank_scale = 1.7231
# 迭代 8000/30000, 损失 = 0.1017, rank_scale = 1.8178
# 迭代 9000/30000, 损失 = 0.0980, rank_scale = 1.9104
# 迭代 10000/30000, 损失 = 0.0948, rank_scale = 2.0001
# 迭代 11000/30000, 损失 = 0.0922, rank_scale = 2.0871
# 迭代 12000/30000, 损失 = 0.0900, rank_scale = 2.1716
# 迭代 13000/30000, 损失 = 0.0881, rank_scale = 2.2537
# 迭代 14000/30000, 损失 = 0.0863, rank_scale = 2.3342
# 迭代 15000/30000, 损失 = 0.0848, rank_scale = 2.4132
# 迭代 16000/30000, 损失 = 0.0834, rank_scale = 2.4909
# 迭代 17000/30000, 损失 = 0.0821, rank_scale = 2.5662
# 迭代 18000/30000, 损失 = 0.0809, rank_scale = 2.6398
# 迭代 19000/30000, 损失 = 0.0798, rank_scale = 2.7118
# 迭代 20000/30000, 损失 = 0.0788, rank_scale = 2.7826
# 迭代 21000/30000, 损失 = 0.0779, rank_scale = 2.8517
# 迭代 22000/30000, 损失 = 0.0771, rank_scale = 2.9197
# 迭代 23000/30000, 损失 = 0.0763, rank_scale = 2.9864
# 迭代 24000/30000, 损失 = 0.0756, rank_scale = 3.0523
# 迭代 25000/30000, 损失 = 0.0750, rank_scale = 3.1168
# 迭代 26000/30000, 损失 = 0.0743, rank_scale = 3.1802
# 迭代 27000/30000, 损失 = 0.0737, rank_scale = 3.2426
# 迭代 28000/30000, 损失 = 0.0731, rank_scale = 3.3044
# 迭代 29000/30000, 损失 = 0.0725, rank_scale = 3.3662
# 迭代 30000/30000, 损失 = 0.0718, rank_scale = 3.4280
#
# 随机搜索: {'lambda_defense': 0.03789877213040837, 'lambda_supervision': 0.06842892970704363, 'lambda_reg': 0.008327236865873834}
# 迭代 1000/30000, 损失 = 0.1665, rank_scale = 1.0882
# 迭代 2000/30000, 损失 = 0.1361, rank_scale = 1.1994
# 迭代 3000/30000, 损失 = 0.1231, rank_scale = 1.3124
# 迭代 4000/30000, 损失 = 0.1152, rank_scale = 1.4206
# 迭代 5000/30000, 损失 = 0.1097, rank_scale = 1.5250
# 迭代 6000/30000, 损失 = 0.1053, rank_scale = 1.6256
# 迭代 7000/30000, 损失 = 0.1015, rank_scale = 1.7228
# 迭代 8000/30000, 损失 = 0.0981, rank_scale = 1.8176
# 迭代 9000/30000, 损失 = 0.0951, rank_scale = 1.9103
# 迭代 10000/30000, 损失 = 0.0923, rank_scale = 2.0001
# 迭代 11000/30000, 损失 = 0.0899, rank_scale = 2.0870
# 迭代 12000/30000, 损失 = 0.0877, rank_scale = 2.1714
# 迭代 13000/30000, 损失 = 0.0857, rank_scale = 2.2534
# 迭代 14000/30000, 损失 = 0.0839, rank_scale = 2.3337
# 迭代 15000/30000, 损失 = 0.0821, rank_scale = 2.4125
# 迭代 16000/30000, 损失 = 0.0805, rank_scale = 2.4899
# 迭代 17000/30000, 损失 = 0.0791, rank_scale = 2.5650
# 迭代 18000/30000, 损失 = 0.0777, rank_scale = 2.6382
# 迭代 19000/30000, 损失 = 0.0764, rank_scale = 2.7098
# 迭代 20000/30000, 损失 = 0.0752, rank_scale = 2.7801
# 迭代 21000/30000, 损失 = 0.0741, rank_scale = 2.8487
# 迭代 22000/30000, 损失 = 0.0731, rank_scale = 2.9161
# 迭代 23000/30000, 损失 = 0.0721, rank_scale = 2.9820
# 迭代 24000/30000, 损失 = 0.0711, rank_scale = 3.0469
# 迭代 25000/30000, 损失 = 0.0703, rank_scale = 3.1105
# 迭代 26000/30000, 损失 = 0.0694, rank_scale = 3.1726
# 迭代 27000/30000, 损失 = 0.0687, rank_scale = 3.2333
# 迭代 28000/30000, 损失 = 0.0679, rank_scale = 3.2928
# 迭代 29000/30000, 损失 = 0.0672, rank_scale = 3.3514
# 迭代 30000/30000, 损失 = 0.0666, rank_scale = 3.4092
#
# 随机搜索: {'lambda_defense': 0.10121399684340719, 'lambda_supervision': 0.16703519227860275, 'lambda_reg': 0.004993475643167195}
# 迭代 1000/30000, 损失 = 0.2412, rank_scale = 1.0882
# 迭代 2000/30000, 损失 = 0.1876, rank_scale = 1.1994
# 迭代 3000/30000, 损失 = 0.1667, rank_scale = 1.3127
# 迭代 4000/30000, 损失 = 0.1547, rank_scale = 1.4209
# 迭代 5000/30000, 损失 = 0.1466, rank_scale = 1.5253
# 迭代 6000/30000, 损失 = 0.1403, rank_scale = 1.6259
# 迭代 7000/30000, 损失 = 0.1352, rank_scale = 1.7230
# 迭代 8000/30000, 损失 = 0.1307, rank_scale = 1.8178
# 迭代 9000/30000, 损失 = 0.1270, rank_scale = 1.9104
# 迭代 10000/30000, 损失 = 0.1239, rank_scale = 2.0002
# 迭代 11000/30000, 损失 = 0.1213, rank_scale = 2.0873
# 迭代 12000/30000, 损失 = 0.1190, rank_scale = 2.1719
# 迭代 13000/30000, 损失 = 0.1171, rank_scale = 2.2542
# 迭代 14000/30000, 损失 = 0.1153, rank_scale = 2.3348
# 迭代 15000/30000, 损失 = 0.1138, rank_scale = 2.4140
# 迭代 16000/30000, 损失 = 0.1124, rank_scale = 2.4919
# 迭代 17000/30000, 损失 = 0.1111, rank_scale = 2.5674
# 迭代 18000/30000, 损失 = 0.1100, rank_scale = 2.6411
# 迭代 19000/30000, 损失 = 0.1089, rank_scale = 2.7133
# 迭代 20000/30000, 损失 = 0.1079, rank_scale = 2.7843
# 迭代 21000/30000, 损失 = 0.1070, rank_scale = 2.8536
# 迭代 22000/30000, 损失 = 0.1062, rank_scale = 2.9218
# 迭代 23000/30000, 损失 = 0.1054, rank_scale = 2.9887
# 迭代 24000/30000, 损失 = 0.1047, rank_scale = 3.0549
# 迭代 25000/30000, 损失 = 0.1041, rank_scale = 3.1197
# 迭代 26000/30000, 损失 = 0.1034, rank_scale = 3.1835
# 迭代 27000/30000, 损失 = 0.1028, rank_scale = 3.2464
# 迭代 28000/30000, 损失 = 0.1021, rank_scale = 3.3090
# 迭代 29000/30000, 损失 = 0.1014, rank_scale = 3.3715
# 迭代 30000/30000, 损失 = 0.1008, rank_scale = 3.4340
#
# 随机搜索: {'lambda_defense': 0.11284688768272232, 'lambda_supervision': 0.1284829137724085, 'lambda_reg': 0.0019290082543999545}
# 迭代 1000/30000, 损失 = 0.2358, rank_scale = 1.0882
# 迭代 2000/30000, 损失 = 0.1803, rank_scale = 1.1995
# 迭代 3000/30000, 损失 = 0.1581, rank_scale = 1.3127
# 迭代 4000/30000, 损失 = 0.1453, rank_scale = 1.4210
# 迭代 5000/30000, 损失 = 0.1367, rank_scale = 1.5255
# 迭代 6000/30000, 损失 = 0.1301, rank_scale = 1.6260
# 迭代 7000/30000, 损失 = 0.1248, rank_scale = 1.7233
# 迭代 8000/30000, 损失 = 0.1203, rank_scale = 1.8184
# 迭代 9000/30000, 损失 = 0.1165, rank_scale = 1.9114
# 迭代 10000/30000, 损失 = 0.1133, rank_scale = 2.0018
# 迭代 11000/30000, 损失 = 0.1106, rank_scale = 2.0894
# 迭代 12000/30000, 损失 = 0.1083, rank_scale = 2.1744
# 迭代 13000/30000, 损失 = 0.1063, rank_scale = 2.2571
# 迭代 14000/30000, 损失 = 0.1046, rank_scale = 2.3382
# 迭代 15000/30000, 损失 = 0.1031, rank_scale = 2.4179
# 迭代 16000/30000, 损失 = 0.1017, rank_scale = 2.4962
# 迭代 17000/30000, 损失 = 0.1005, rank_scale = 2.5721
# 迭代 18000/30000, 损失 = 0.0994, rank_scale = 2.6463
# 迭代 19000/30000, 损失 = 0.0983, rank_scale = 2.7190
# 迭代 20000/30000, 损失 = 0.0974, rank_scale = 2.7905
# 迭代 21000/30000, 损失 = 0.0965, rank_scale = 2.8604
# 迭代 22000/30000, 损失 = 0.0957, rank_scale = 2.9292
# 迭代 23000/30000, 损失 = 0.0950, rank_scale = 2.9967
# 迭代 24000/30000, 损失 = 0.0943, rank_scale = 3.0636
# 迭代 25000/30000, 损失 = 0.0936, rank_scale = 3.1296
# 迭代 26000/30000, 损失 = 0.0929, rank_scale = 3.1948
# 迭代 27000/30000, 损失 = 0.0922, rank_scale = 3.2592
# 迭代 28000/30000, 损失 = 0.0915, rank_scale = 3.3236
# 迭代 29000/30000, 损失 = 0.0908, rank_scale = 3.3877
# 迭代 30000/30000, 损失 = 0.0901, rank_scale = 3.4518
#
# 最佳超参数: {'lambda_defense': 0.1516145155592091, 'lambda_supervision': 0.014116898859160489, 'lambda_reg': 0.020398197043239887}, 最佳损失: 0.0570
#
# ===== 最终训练 =====
# 迭代 1000/30000, 损失 = 0.2244, rank_scale = 1.0883
# 迭代 2000/30000, 损失 = 0.1607, rank_scale = 1.1997
# 迭代 3000/30000, 损失 = 0.1328, rank_scale = 1.3129
# 迭代 4000/30000, 损失 = 0.1173, rank_scale = 1.4212
# 迭代 5000/30000, 损失 = 0.1070, rank_scale = 1.5256
# 迭代 6000/30000, 损失 = 0.0992, rank_scale = 1.6261
# 迭代 7000/30000, 损失 = 0.0929, rank_scale = 1.7233
# 迭代 8000/30000, 损失 = 0.0878, rank_scale = 1.8181
# 迭代 9000/30000, 损失 = 0.0837, rank_scale = 1.9107
# 迭代 10000/30000, 损失 = 0.0803, rank_scale = 2.0005
# 迭代 11000/30000, 损失 = 0.0777, rank_scale = 2.0875
# 迭代 12000/30000, 损失 = 0.0755, rank_scale = 2.1719
# 迭代 13000/30000, 损失 = 0.0738, rank_scale = 2.2540
# 迭代 14000/30000, 损失 = 0.0722, rank_scale = 2.3345
# 迭代 15000/30000, 损失 = 0.0709, rank_scale = 2.4137
# 迭代 16000/30000, 损失 = 0.0697, rank_scale = 2.4916
# 迭代 17000/30000, 损失 = 0.0686, rank_scale = 2.5673
# 迭代 18000/30000, 损失 = 0.0676, rank_scale = 2.6413
# 迭代 19000/30000, 损失 = 0.0666, rank_scale = 2.7141
# 迭代 20000/30000, 损失 = 0.0657, rank_scale = 2.7859
# 迭代 21000/30000, 损失 = 0.0648, rank_scale = 2.8566
# 迭代 22000/30000, 损失 = 0.0640, rank_scale = 2.9271
# 迭代 23000/30000, 损失 = 0.0631, rank_scale = 2.9970
# 迭代 24000/30000, 损失 = 0.0622, rank_scale = 3.0670
# 迭代 25000/30000, 损失 = 0.0613, rank_scale = 3.1363
# 迭代 26000/30000, 损失 = 0.0604, rank_scale = 3.2046
# 迭代 27000/30000, 损失 = 0.0596, rank_scale = 3.2722
# 迭代 28000/30000, 损失 = 0.0587, rank_scale = 3.3393
# 迭代 29000/30000, 损失 = 0.0579, rank_scale = 3.4062
# 迭代 30000/30000, 损失 = 0.0570, rank_scale = 3.4727
# 最终损失: 0.0570
#
# ===== 可视化 =====
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 premier-league 图 -> /Users/peixuanma/Downloads/Output_Graphs/premier-league_evolution.png
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 bundesliga 图 -> /Users/peixuanma/Downloads/Output_Graphs/bundesliga_evolution.png
# 保存 la-liga 图 -> /Users/peixuanma/Downloads/Output_Graphs/la-liga_evolution.png
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 ligue-1 图 -> /Users/peixuanma/Downloads/Output_Graphs/ligue-1_evolution.png
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 ligue-2 图 -> /Users/peixuanma/Downloads/Output_Graphs/ligue-2_evolution.png
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 serie-a 图 -> /Users/peixuanma/Downloads/Output_Graphs/serie-a_evolution.png
# 保存 eredivisie 图 -> /Users/peixuanma/Downloads/Output_Graphs/eredivisie_evolution.png
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 serie-b 图 -> /Users/peixuanma/Downloads/Output_Graphs/serie-b_evolution.png
# 保存 2-bundesliga 图 -> /Users/peixuanma/Downloads/Output_Graphs/2-bundesliga_evolution.png
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 premiership 图 -> /Users/peixuanma/Downloads/Output_Graphs/premiership_evolution.png
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:525: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_51151/1896384135.py:527: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 pro-league 图 -> /Users/peixuanma/Downloads/Output_Graphs/pro-league_evolution.png
#
# 完成！

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, train_test_split, GridSearchCV
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix
from scipy.stats import uniform
import sklearn

print(f"scikit-learn 版本: {sklearn.__version__}")

# ====================== 计算防守统计数据 ======================
def compute_defensive_stats(match_df, team_positions_df):
    """计算球队的防守统计数据，包括6种比率、总失球数和平均失球数"""
    epsilon = 1e-8  # 提高数值稳定性
    team_stats = {}
    for team in team_positions_df['team_name'].unique():
        team_stats[team] = {
            'total_goals_conceded': 0, 'ratio1_list': [], 'ratio2_list': [], 'ratio3_list': [],
            'ratio4_list': [], 'ratio5_list': [], 'ratio6_list': [], 'num_matches': 0
        }

    # 主场比赛统计
    for idx, row in match_df.iterrows():
        home_team, away_team = row['home_team_name'], row['away_team_name']
        if home_team not in team_stats or away_team not in team_stats:
            print(f"警告: 主队 {home_team} 或客队 {away_team} 未找到，跳过比赛 {idx}")
            continue
        if row['Pre-Match PPG (Away)'] > 0:
            team_stats[home_team]['ratio1_list'].append(
                row['away_team_goal_count'] / (row['Pre-Match PPG (Away)'] + epsilon))
        if row['away_team_corner_count'] > 0:
            team_stats[home_team]['ratio2_list'].append(
                row['away_team_goal_count'] / (row['away_team_corner_count'] + epsilon))
        denominator = row['home_team_yellow_cards'] + row['home_team_red_cards'] + row['home_team_fouls'] + epsilon
        team_stats[home_team]['ratio3_list'].append(row['away_team_goal_count'] / denominator)
        if row['team_b_xg'] > 0:
            team_stats[home_team]['ratio4_list'].append(row['away_team_goal_count'] / (row['team_b_xg'] + epsilon))
        shots_total = row['away_team_shots_on_target'] + row['away_team_shots_off_target'] + epsilon
        team_stats[home_team]['ratio5_list'].append(row['away_team_goal_count'] / shots_total)
        if row['away_team_possession'] > 0:
            team_stats[home_team]['ratio6_list'].append(
                row['away_team_goal_count'] / (row['away_team_possession'] + epsilon))
        team_stats[home_team]['total_goals_conceded'] += row['away_team_goal_count']
        team_stats[home_team]['num_matches'] += 1  # 记录主场比赛场次

    # 客场比赛统计
    for idx, row in match_df.iterrows():
        away_team = row['away_team_name']
        if away_team not in team_stats:
            print(f"警告: 客队 {away_team} 未找到，跳过比赛 {idx}")
            continue
        team_stats[away_team]['total_goals_conceded'] += row['home_team_goal_count']
        team_stats[away_team]['num_matches'] += 1  # 记录客场比赛场次

    # 汇总数据
    data = []
    for team, stats in team_stats.items():
        num_matches = stats['num_matches']
        average_goals_conceded = stats['total_goals_conceded'] / num_matches if num_matches > 0 else 0
        data.append({
            'team_name': team,
            'ratio1': np.mean(stats['ratio1_list']) if stats['ratio1_list'] else 0,
            'ratio2': np.mean(stats['ratio2_list']) if stats['ratio2_list'] else 0,
            'ratio3': np.mean(stats['ratio3_list']) if stats['ratio3_list'] else 0,
            'ratio4': np.mean(stats['ratio4_list']) if stats['ratio4_list'] else 0,
            'ratio5': np.mean(stats['ratio5_list']) if stats['ratio5_list'] else 0,
            'ratio6': np.mean(stats['ratio6_list']) if stats['ratio6_list'] else 0,
            'total_goals_conceded': stats['total_goals_conceded'],
            'average_goals_conceded': average_goals_conceded
        })

    return pd.DataFrame(data)

# ====================== ELO评分算法实现 ======================
def initialize_elo_scores(team_positions_df):
    """初始化球队ELO分数"""
    teams = team_positions_df['team_name'].unique().tolist()
    team_elo = {team: 1500 for team in teams}
    for team in teams:
        team_data = team_positions_df[team_positions_df['team_name'] == team]
        rank = team_data['points_per_game'].rank().iloc[0]
        team_elo[team] += (20 * (len(teams) - rank))
    return team_elo

def update_elo_scores(elo_scores, home_team, away_team, home_score, away_score, K=30):
    """更新ELO分数"""
    home_elo, away_elo = elo_scores[home_team], elo_scores[away_team]
    expected_home = 1 / (1 + 10 ** ((away_elo - home_elo) / 400))
    expected_away = 1 / (1 + 10 ** ((home_elo - away_elo) / 400))

    if home_score > away_score:
        elo_scores[home_team] += K * (1 - expected_home)
        elo_scores[away_team] += K * (0 - expected_away)
    elif home_score < away_score:
        elo_scores[home_team] += K * (0 - expected_home)
        elo_scores[away_team] += K * (1 - expected_away)
    else:
        elo_scores[home_team] += K * (0.5 - expected_home)
        elo_scores[away_team] += K * (0.5 - expected_away)
    return elo_scores

# ====================== 数据加载函数（含交叉验证） ======================
def load_all_league_data(base_path, leagues, seasons):
    """加载所有联赛数据并进行预处理"""
    all_team_positions, all_match_positions = [], []
    for country_name, league_name in leagues:
        for season in seasons:
            print(f"加载数据: {country_name} - {league_name} - {season}")
            team_file = os.path.join(base_path, f"{country_name}-{league_name}-teams-{season}-stats.csv")
            match_file = os.path.join(base_path, f"{country_name}-{league_name}-matches-{season}-stats.csv")
            if not os.path.exists(team_file) or not os.path.exists(match_file):
                print(f"警告: {country_name} - {league_name} - {season} 文件缺失")
                continue

            team_df = pd.read_csv(team_file)
            match_df = pd.read_csv(match_file)

            # 统一球队名称格式
            team_df['team_name'] = team_df.get('common_name', team_df.get('team_name', None)).str.strip().str.lower()
            match_df['home_team_name'] = match_df['home_team_name'].str.strip().str.lower()
            match_df['away_team_name'] = match_df['away_team_name'].str.strip().str.lower()

            team_names = team_df['team_name'].unique()
            original_match_count = len(match_df)
            match_df = match_df[
                match_df['home_team_name'].isin(team_names) & match_df['away_team_name'].isin(team_names)]
            if len(match_df) < original_match_count:
                print(f"警告: 过滤了 {original_match_count - len(match_df)} 场比赛")

            if match_df.empty:
                print("警告: 无有效比赛数据")
                continue

            defensive_stats_df = compute_defensive_stats(match_df, team_df)
            if defensive_stats_df.empty:
                print("警告: 未计算出防守统计")
                continue

            team_df = team_df.merge(defensive_stats_df, on='team_name', how='left')
            for col in ['ratio1', 'ratio2', 'ratio3', 'ratio4', 'ratio5', 'ratio6', 'total_goals_conceded', 'average_goals_conceded']:
                if col not in team_df.columns:
                    print(f"警告: {col} 列缺失，设为0")
                    team_df[col] = 0

            # 归一化防守得分
            if 'total_goals_conceded' in team_df.columns and team_df['total_goals_conceded'].max() != team_df[
                'total_goals_conceded'].min():
                team_df['normalized_defense_score'] = (team_df['total_goals_conceded'].max() - team_df[
                    'total_goals_conceded']) / (team_df['total_goals_conceded'].max() - team_df[
                    'total_goals_conceded'].min() + 1e-8)
            else:
                team_df['normalized_defense_score'] = 0

            # PCA降维（防守数据）
            defensive_columns = [col for col in team_df.columns if col in [
                'goals_conceded', 'total_goals_conceded', 'ratio1', 'ratio2', 'ratio3', 'ratio4', 'ratio5', 'ratio6',
                'normalized_defense_score'
            ]]
            team_df_defensive = team_df[defensive_columns].fillna(0)
            kf = KFold(n_splits=5, shuffle=True, random_state=42)
            pca_results = []
            for train_idx, _ in kf.split(team_df_defensive):
                train_data = team_df_defensive.iloc[train_idx]
                scaler = StandardScaler()
                X_scaled = scaler.fit_transform(train_data)
                pca = PCA(n_components=2)
                X_pca = pca.fit_transform(X_scaled)
                pca_results.append(X_pca)
            X_pca_avg = np.mean(
                [np.pad(r, ((0, len(team_df_defensive) - len(r)), (0, 0)), 'constant') for r in pca_results], axis=0)

            team_positions = pd.DataFrame({
                'team_name': team_df['team_name'], 'PC1': X_pca_avg[:, 0], 'PC2': X_pca_avg[:, 1],
                'points_per_game': team_df['points_per_game'], 'league': league_name, 'season': season,
                'ratio1': team_df['ratio1'], 'ratio2': team_df['ratio2'], 'ratio3': team_df['ratio3'],
                'ratio4': team_df['ratio4'], 'ratio5': team_df['ratio5'], 'ratio6': team_df['ratio6'],
                'normalized_defense_score': team_df['normalized_defense_score'],
                'total_goals_conceded': team_df['total_goals_conceded'],
                'average_goals_conceded': team_df['average_goals_conceded']
            })
            team_positions['team_season'] = league_name + '_' + team_positions['team_name'] + '_' + team_positions[
                'season']
            all_team_positions.append(team_positions)

            # 比赛数据PCA
            match_df = match_df.drop(
                columns=['timestamp', 'date_GMT', 'status', 'attendance', 'referee', 'stadium_name', 'Game Week'],
                errors='ignore')
            numeric_cols = match_df.select_dtypes(include=[np.number]).columns
            match_df[numeric_cols] = match_df[numeric_cols].fillna(match_df[numeric_cols].mean())
            pca_match_results = []
            for train_idx, _ in kf.split(match_df[numeric_cols]):
                train_data = match_df[numeric_cols].iloc[train_idx]
                scaler = StandardScaler()
                X_scaled = scaler.fit_transform(train_data)
                pca = PCA(n_components=2)
                X_pca = pca.fit_transform(X_scaled)
                pca_match_results.append(X_pca)
            X_pca_match_avg = np.mean(
                [np.pad(r, ((0, len(match_df) - len(r)), (0, 0)), 'constant') for r in pca_match_results], axis=0)

            match_positions = pd.DataFrame({
                'home_team_name': match_df['home_team_name'], 'away_team_name': match_df['away_team_name'],
                'PC1': X_pca_match_avg[:, 0], 'PC2': X_pca_match_avg[:, 1], 'league': league_name, 'season': season
            })
            all_match_positions.append(match_positions)

    return pd.concat(all_team_positions, ignore_index=True), pd.concat(all_match_positions, ignore_index=True)

# ====================== 使用Adaboost优化权重 ======================
def compute_adaboost_weights(team_positions_df):
    """使用Adaboost计算防守比率的最佳权重，并通过交叉验证优化参数"""
    # 数据预处理
    ratios = team_positions_df[['ratio1', 'ratio2', 'ratio3', 'ratio4', 'ratio5', 'ratio6']].replace([np.inf, -np.inf],
                                                                                                     np.nan).fillna(0)

    # 检查特征相关性
    correlation_matrix = ratios.corr()
    print("特征相关性矩阵:\n", correlation_matrix)

    scaler = StandardScaler()
    ratios_scaled = scaler.fit_transform(ratios)

    # 将平均失球数分箱为两个分类标签
    labels = pd.qcut(team_positions_df['average_goals_conceded'], q=2, labels=[0, 1], duplicates='drop').fillna(0).astype(int)

    # 划分训练集和测试集
    X_train, X_test, y_train, y_test = train_test_split(ratios_scaled, labels, test_size=0.2, random_state=42)

    # 定义Adaboost模型和参数网格
    ada = AdaBoostClassifier(algorithm='SAMME', random_state=42)
    param_grid = {
        'estimator': [DecisionTreeClassifier(max_depth=5), DecisionTreeClassifier(max_depth=10)],  # 增加深度
        'n_estimators': [500, 1000, 1500,250,50,200,150,100],  # 增加弱分类器数量
        'learning_rate': [0.01, 0.1, 0.5,0.05,0.25]  # 更广泛的学习率
    }

    # 使用网格搜索进行交叉验证
    grid_search = GridSearchCV(ada, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
    grid_search.fit(X_train, y_train)

    # 输出最佳参数
    best_params = grid_search.best_params_
    print("最佳参数:", best_params)

    # 使用最佳参数重新训练模型
    adaboost = AdaBoostClassifier(
        estimator=best_params['estimator'],
        n_estimators=best_params['n_estimators'],
        learning_rate=best_params['learning_rate'],
        algorithm='SAMME',
        random_state=42
    )
    adaboost.fit(X_train, y_train)

    # 在测试集上评估模型
    y_pred = adaboost.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, average='weighted')
    roc_auc = roc_auc_score(y_test, adaboost.predict_proba(X_test)[:, 1])
    conf_matrix = confusion_matrix(y_test, y_pred)

    print("测试集准确率:", accuracy)
    print("测试集F1分数:", f1)
    print("测试集ROC-AUC:", roc_auc)
    print("混淆矩阵:\n", conf_matrix)

    # 计算特征重要性并加权
    feature_importances = np.zeros(6)
    for i, est in enumerate(adaboost.estimators_):
        feature_importances += adaboost.estimator_weights_[i] * est.feature_importances_
    feature_importances /= np.sum(adaboost.estimator_weights_)

    weights = feature_importances / np.sum(feature_importances)
    print(f"计算得到的权重: {weights}")

    return weights.astype(np.float32)

# ====================== 损失函数 ======================
def compute_total_loss(positions, match_home_idx, match_away_idx, match_PC1, match_PC2, points_per_game, rank_scale,
                       ratios, w, normalized_defense_score, lambda_defense, lambda_supervision, lambda_reg, elo_scores):
    """计算总损失，包括匹配损失、防守损失和监督损失"""
    epsilon = 1e-8
    if tf.shape(match_home_idx)[0] == 0:
        return tf.constant(0.0, dtype=tf.float32)

    # 匹配损失
    home_pos = tf.gather(positions, match_home_idx)
    away_pos = tf.gather(positions, match_away_idx)
    match_points = tf.stack([match_PC1, match_PC2], axis=1)
    dist_home = tf.norm(home_pos - match_points + epsilon, axis=1)
    dist_away = tf.norm(away_pos - match_points + epsilon, axis=1)
    all_distances = tf.concat([dist_home, dist_away], axis=0)
    dist_range = tf.reduce_max(all_distances) - tf.reduce_min(all_distances) + epsilon
    dist_home_norm = (dist_home - tf.reduce_min(all_distances)) / dist_range
    dist_away_norm = (dist_away - tf.reduce_min(all_distances)) / dist_range

    home_elo = tf.gather(elo_scores, match_home_idx)
    away_elo = tf.gather(elo_scores, match_away_idx)
    elo_diff = tf.abs(home_elo - away_elo)
    weight = 1.0 / (1.0 + elo_diff * rank_scale + epsilon)
    match_loss = tf.reduce_mean(weight * (dist_home_norm + dist_away_norm))

    # 防守损失
    w = tf.abs(w)  # 确保权重非负
    defense_target = -tf.reduce_sum(w * ratios, axis=1)
    defense_loss = tf.reduce_mean(tf.square(positions[:, 1] - defense_target))

    # 监督损失
    supervision_loss = tf.reduce_mean(tf.square(defense_target - normalized_defense_score))

    # 正则化
    regularization_loss = lambda_reg * tf.reduce_sum(tf.square(w))

    total_loss = match_loss + lambda_defense * defense_loss + lambda_supervision * supervision_loss + regularization_loss
    return tf.where(tf.math.is_nan(total_loss) | tf.math.is_inf(total_loss), 0.0, total_loss)

# ====================== Adam优化函数 ======================
def adam_optimize_positions(team_positions_df, match_positions_df, initial_lr=0.0005, decay_steps=200000,
                            decay_rate=0.9,
                            clipnorm=0.5, iterations=30000, verbose_interval=1000, random_seed=42, lambda_defense=0.1,
                            lambda_supervision=0.1, lambda_reg=0.01, patience=100, w=None):
    """使用Adam优化球队位置"""
    team_seasons = team_positions_df['team_season'].unique()
    team_season_to_idx = {t: i for i, t in enumerate(team_seasons)}

    elo_scores_dict = initialize_elo_scores(team_positions_df)
    team_names = [t.split('_')[1] for t in team_seasons]
    elo_scores = tf.convert_to_tensor([elo_scores_dict[name] for name in team_names], dtype=tf.float32)

    team_positions_df = team_positions_df.set_index('team_season')
    init_positions = team_positions_df[['PC1', 'PC2']].values
    ratios = team_positions_df[['ratio1', 'ratio2', 'ratio3', 'ratio4', 'ratio5', 'ratio6']].values
    scaler_pos = StandardScaler()
    scaler_rat = StandardScaler()
    positions_scaled = scaler_pos.fit_transform(init_positions)
    ratios_scaled = scaler_rat.fit_transform(ratios)

    positions = tf.Variable(positions_scaled, dtype=tf.float32)
    ratios = tf.constant(ratios_scaled, dtype=tf.float32)
    normalized_defense_score = tf.constant(team_positions_df['normalized_defense_score'].values, dtype=tf.float32)
    points_per_game = tf.constant(team_positions_df['points_per_game'].values, dtype=tf.float32)

    match_array = [
        [team_season_to_idx[f"{row['league']}_{row['home_team_name']}_{row['season']}"],
         team_season_to_idx[f"{row['league']}_{row['away_team_name']}_{row['season']}"], row['PC1'], row['PC2']]
        for _, row in match_positions_df.iterrows()
        if f"{row['league']}_{row['home_team_name']}_{row['season']}" in team_season_to_idx and
           f"{row['league']}_{row['away_team_name']}_{row['season']}" in team_season_to_idx
    ]
    match_array = np.array(match_array, dtype=np.float32)
    if len(match_array) == 0:
        print("警告: 无有效比赛数据")
        return [], team_positions_df.reset_index(), None, None

    match_home_idx = tf.constant(match_array[:, 0], dtype=tf.int32)
    match_away_idx = tf.constant(match_array[:, 1], dtype=tf.int32)
    match_PC1 = tf.constant(match_array[:, 2], dtype=tf.float32)
    match_PC2 = tf.constant(match_array[:, 3], dtype=tf.float32)

    tf.random.set_seed(random_seed)
    rank_scale = tf.Variable(1.0, dtype=tf.float32)
    w = tf.Variable(np.abs(w) if w is not None else np.ones(6, dtype=np.float32) / 6, dtype=tf.float32)
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(initial_lr, decay_steps, decay_rate)
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule, clipnorm=clipnorm)

    losses, best_loss, patience_counter = [], float('inf'), 0
    best_positions, best_rank_scale, best_w = positions.numpy().copy(), 1.0, w.numpy().copy()

    for i in range(iterations):
        with tf.GradientTape() as tape:
            loss = compute_total_loss(positions, match_home_idx, match_away_idx, match_PC1, match_PC2, points_per_game,
                                      rank_scale, ratios, w, normalized_defense_score, lambda_defense,
                                      lambda_supervision, lambda_reg, elo_scores)
        grads = tape.gradient(loss, [positions, rank_scale, w])
        if any(g is None for g in grads):
            print(f"警告: 迭代 {i + 1} 梯度为None")
            continue
        optimizer.apply_gradients(zip(grads, [positions, rank_scale, w]))
        loss_val = float(loss.numpy())
        losses.append(loss_val)

        if loss_val < best_loss:
            best_loss = loss_val
            best_positions, best_rank_scale, best_w = positions.numpy().copy(), float(
                rank_scale.numpy()), w.numpy().copy()
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"早停触发，训练在第 {i + 1} 轮停止")
            break

        if (i + 1) % verbose_interval == 0:
            print(f"迭代 {i + 1}/{iterations}, 损失 = {loss_val:.4f}, rank_scale = {rank_scale.numpy():.4f}")

    positions.assign(best_positions)
    rank_scale.assign(best_rank_scale)
    w.assign(best_w)
    final_pos = scaler_pos.inverse_transform(positions.numpy())
    for idx, team_season in enumerate(team_seasons):
        team_positions_df.loc[team_season, 'PC1'] = final_pos[idx, 0]
        team_positions_df.loc[team_season, 'PC2'] = final_pos[idx, 1]
    team_positions_df = team_positions_df.reset_index()
    return losses, team_positions_df, best_rank_scale, best_w

# ====================== 随机搜索超参数调整 ======================
def random_search_hyperparameters(team_positions, match_positions, w, n_iter=10, random_state=42):
    """随机搜索最佳超参数"""
    np.random.seed(random_state)
    best_loss, best_params = float('inf'), None

    for _ in range(n_iter):
        params = {
            'lambda_defense': uniform(0.01, 0.2).rvs(),
            'lambda_supervision': uniform(0.01, 0.2).rvs(),
            'lambda_reg': uniform(0.001, 0.02).rvs()
        }
        print(f"\n随机搜索: {params}")

        losses, _, _, _ = adam_optimize_positions(
            team_positions.copy(), match_positions.copy(), w=w, **params
        )
        if losses and losses[-1] < best_loss:
            best_loss = losses[-1]
            best_params = params

    print(f"\n最佳超参数: {best_params}, 最佳损失: {best_loss:.4f}")
    return best_params

# ====================== 可视化函数 ======================
def visualize_team_evolution_by_league_static(team_positions_df, seasons_order):
    """按联赛可视化球队演变"""
    output_dir = "/Users/peixuanma/Downloads/Output_Graphs"
    os.makedirs(output_dir, exist_ok=True)

    for league in team_positions_df['league'].unique():
        league_df = team_positions_df[team_positions_df['league'] == league].copy()
        valid_teams = league_df.groupby("team_name").filter(lambda x: x['season'].nunique() == len(seasons_order))[
            'team_name'].unique()
        if not valid_teams.size:
            valid_teams = league_df['team_name'].unique()
        valid_df = league_df[league_df['team_name'].isin(valid_teams)].sort_values(['team_name', 'season'])

        plt.figure(figsize=(10, 8))
        plt.title(f"{league} - 球队演变 (进攻-防守)")
        plt.xlabel("PC1 (进攻)")
        plt.ylabel("PC2 (防守)")
        plt.grid(True)

        for team in valid_df['team_name'].unique():
            sub = valid_df[valid_df['team_name'] == team]
            plt.plot(sub['PC1'], sub['PC2'], marker='o', label=team)
            for _, row in sub.iterrows():
                plt.text(row['PC1'], row['PC2'], row['season'], fontsize=8, ha='right')

        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        plt.tight_layout()
        filename = os.path.join(output_dir, f"{league}_evolution.png")
        plt.savefig(filename, dpi=150)
        plt.close()
        print(f"保存 {league} 图 -> {filename}")

# ====================== 主函数 ======================
if __name__ == "__main__":
    base_path = '/Users/peixuanma/Downloads/data1'
    leagues = [
        ("england", "premier-league"), ("germany", "bundesliga"), ("spain", "la-liga"),
        ("france", "ligue-1"), ("france", "ligue-2"),("italy", "serie-a"), ("netherlands", "eredivisie"),
        ("portugal", "ligapro"), ("denmark", "superliga"), ("england", "championship"),("spain", "segunda-division"),("switzerland","super-league"),
        ("portugal", "liga-nos"), ("italy", "serie-b"), ("germany", "2-bundesliga"),("scotland","premiership"),("belgium","pro-league"),("austria","bundesliga"),
    ]
    seasons = [
        "2013-to-2014", "2014-to-2015", "2015-to-2016", "2016-to-2017", "2017-to-2018",
        "2018-to-2019", "2019-to-2020","2020-to-2021", "2021-to-2022", "2022-to-2023", "2023-to-2024"
    ]

    # 加载数据
    print("===== 加载数据 =====")
    all_team_positions, all_match_positions = load_all_league_data(base_path, leagues, seasons)

    # 计算Adaboost权重
    print("\n===== 计算Adaboost权重 =====")
    adaboost_weights = compute_adaboost_weights(all_team_positions)
    print("优化后的Adaboost权重:", adaboost_weights)

    # 随机搜索超参数
    print("\n===== 随机搜索超参数 =====")
    best_params = random_search_hyperparameters(all_team_positions, all_match_positions, adaboost_weights)

    # 最终训练
    print("\n===== 最终训练 =====")
    final_losses, final_team_positions, final_rank_scale, final_w = adam_optimize_positions(
        all_team_positions.copy(), all_match_positions.copy(), w=adaboost_weights, **best_params
    )
    if final_losses:
        final_team_positions.to_csv("trained_team_positions.csv", index=False)
        print(f"最终损失: {final_losses[-1]:.4f}")

    # 可视化
    print("\n===== 可视化 =====")
    visualize_team_evolution_by_league_static(final_team_positions, seasons)

    print("\n完成！")
# Out:
# scikit-learn 版本: 1.4.2
# ===== 加载数据 =====
# 加载数据: england - premier-league - 2013-to-2014
# 加载数据: england - premier-league - 2014-to-2015
# 加载数据: england - premier-league - 2015-to-2016
# 加载数据: england - premier-league - 2016-to-2017
# 加载数据: england - premier-league - 2017-to-2018
# 加载数据: england - premier-league - 2018-to-2019
# 加载数据: england - premier-league - 2019-to-2020
# 加载数据: england - premier-league - 2020-to-2021
# 加载数据: england - premier-league - 2021-to-2022
# 加载数据: england - premier-league - 2022-to-2023
# 加载数据: england - premier-league - 2023-to-2024
# 加载数据: germany - bundesliga - 2013-to-2014
# 加载数据: germany - bundesliga - 2014-to-2015
# 加载数据: germany - bundesliga - 2015-to-2016
# 加载数据: germany - bundesliga - 2016-to-2017
# 加载数据: germany - bundesliga - 2017-to-2018
# 加载数据: germany - bundesliga - 2018-to-2019
# 加载数据: germany - bundesliga - 2019-to-2020
# 加载数据: germany - bundesliga - 2020-to-2021
# 加载数据: germany - bundesliga - 2021-to-2022
# 加载数据: germany - bundesliga - 2022-to-2023
# 加载数据: germany - bundesliga - 2023-to-2024
# 加载数据: spain - la-liga - 2013-to-2014
# 加载数据: spain - la-liga - 2014-to-2015
# 加载数据: spain - la-liga - 2015-to-2016
# 加载数据: spain - la-liga - 2016-to-2017
# 加载数据: spain - la-liga - 2017-to-2018
# 加载数据: spain - la-liga - 2018-to-2019
# 加载数据: spain - la-liga - 2019-to-2020
# 加载数据: spain - la-liga - 2020-to-2021
# 加载数据: spain - la-liga - 2021-to-2022
# 加载数据: spain - la-liga - 2022-to-2023
# 加载数据: spain - la-liga - 2023-to-2024
# 加载数据: france - ligue-1 - 2013-to-2014
# 加载数据: france - ligue-1 - 2014-to-2015
# 加载数据: france - ligue-1 - 2015-to-2016
# 加载数据: france - ligue-1 - 2016-to-2017
# 加载数据: france - ligue-1 - 2017-to-2018
# 加载数据: france - ligue-1 - 2018-to-2019
# 加载数据: france - ligue-1 - 2019-to-2020
# 警告: france - ligue-1 - 2019-to-2020 文件缺失
# 加载数据: france - ligue-1 - 2020-to-2021
# 加载数据: france - ligue-1 - 2021-to-2022
# 加载数据: france - ligue-1 - 2022-to-2023
# 加载数据: france - ligue-1 - 2023-to-2024
# 加载数据: france - ligue-2 - 2013-to-2014
# 加载数据: france - ligue-2 - 2014-to-2015
# 加载数据: france - ligue-2 - 2015-to-2016
# 加载数据: france - ligue-2 - 2016-to-2017
# 加载数据: france - ligue-2 - 2017-to-2018
# 加载数据: france - ligue-2 - 2018-to-2019
# 加载数据: france - ligue-2 - 2019-to-2020
# 警告: france - ligue-2 - 2019-to-2020 文件缺失
# 加载数据: france - ligue-2 - 2020-to-2021
# 加载数据: france - ligue-2 - 2021-to-2022
# 加载数据: france - ligue-2 - 2022-to-2023
# 加载数据: france - ligue-2 - 2023-to-2024
# 加载数据: italy - serie-a - 2013-to-2014
# 加载数据: italy - serie-a - 2014-to-2015
# 加载数据: italy - serie-a - 2015-to-2016
# 加载数据: italy - serie-a - 2016-to-2017
# 加载数据: italy - serie-a - 2017-to-2018
# 加载数据: italy - serie-a - 2018-to-2019
# 加载数据: italy - serie-a - 2019-to-2020
# 加载数据: italy - serie-a - 2020-to-2021
# 加载数据: italy - serie-a - 2021-to-2022
# 加载数据: italy - serie-a - 2022-to-2023
# 加载数据: italy - serie-a - 2023-to-2024
# 加载数据: netherlands - eredivisie - 2013-to-2014
# 加载数据: netherlands - eredivisie - 2014-to-2015
# 加载数据: netherlands - eredivisie - 2015-to-2016
# 加载数据: netherlands - eredivisie - 2016-to-2017
# 加载数据: netherlands - eredivisie - 2017-to-2018
# 加载数据: netherlands - eredivisie - 2018-to-2019
# 加载数据: netherlands - eredivisie - 2019-to-2020
# 加载数据: netherlands - eredivisie - 2020-to-2021
# 加载数据: netherlands - eredivisie - 2021-to-2022
# 加载数据: netherlands - eredivisie - 2022-to-2023
# 加载数据: netherlands - eredivisie - 2023-to-2024
# 加载数据: portugal - ligapro - 2013-to-2014
# 警告: portugal - ligapro - 2013-to-2014 文件缺失
# 加载数据: portugal - ligapro - 2014-to-2015
# 加载数据: portugal - ligapro - 2015-to-2016
# 加载数据: portugal - ligapro - 2016-to-2017
# 加载数据: portugal - ligapro - 2017-to-2018
# 加载数据: portugal - ligapro - 2018-to-2019
# 加载数据: portugal - ligapro - 2019-to-2020
# 加载数据: portugal - ligapro - 2020-to-2021
# 加载数据: portugal - ligapro - 2021-to-2022
# 加载数据: portugal - ligapro - 2022-to-2023
# 加载数据: portugal - ligapro - 2023-to-2024
# 加载数据: denmark - superliga - 2013-to-2014
# 加载数据: denmark - superliga - 2014-to-2015
# 加载数据: denmark - superliga - 2015-to-2016
# 加载数据: denmark - superliga - 2016-to-2017
# 加载数据: denmark - superliga - 2017-to-2018
# 加载数据: denmark - superliga - 2018-to-2019
# 加载数据: denmark - superliga - 2019-to-2020
# 警告: denmark - superliga - 2019-to-2020 文件缺失
# 加载数据: denmark - superliga - 2020-to-2021
# 加载数据: denmark - superliga - 2021-to-2022
# 加载数据: denmark - superliga - 2022-to-2023
# 加载数据: denmark - superliga - 2023-to-2024
# 加载数据: england - championship - 2013-to-2014
# 加载数据: england - championship - 2014-to-2015
# 加载数据: england - championship - 2015-to-2016
# 加载数据: england - championship - 2016-to-2017
# 加载数据: england - championship - 2017-to-2018
# 加载数据: england - championship - 2018-to-2019
# 加载数据: england - championship - 2019-to-2020
# 警告: england - championship - 2019-to-2020 文件缺失
# 加载数据: england - championship - 2020-to-2021
# 加载数据: england - championship - 2021-to-2022
# 加载数据: england - championship - 2022-to-2023
# 加载数据: england - championship - 2023-to-2024
# 加载数据: spain - segunda-division - 2013-to-2014
# 加载数据: spain - segunda-division - 2014-to-2015
# 加载数据: spain - segunda-division - 2015-to-2016
# 加载数据: spain - segunda-division - 2016-to-2017
# 加载数据: spain - segunda-division - 2017-to-2018
# 加载数据: spain - segunda-division - 2018-to-2019
# 加载数据: spain - segunda-division - 2019-to-2020
# 加载数据: spain - segunda-division - 2020-to-2021
# 加载数据: spain - segunda-division - 2021-to-2022
# 加载数据: spain - segunda-division - 2022-to-2023
# 加载数据: spain - segunda-division - 2023-to-2024
# 加载数据: switzerland - super-league - 2013-to-2014
# 加载数据: switzerland - super-league - 2014-to-2015
# 加载数据: switzerland - super-league - 2015-to-2016
# 加载数据: switzerland - super-league - 2016-to-2017
# 加载数据: switzerland - super-league - 2017-to-2018
# 加载数据: switzerland - super-league - 2018-to-2019
# 加载数据: switzerland - super-league - 2019-to-2020
# 加载数据: switzerland - super-league - 2020-to-2021
# 加载数据: switzerland - super-league - 2021-to-2022
# 加载数据: switzerland - super-league - 2022-to-2023
# 加载数据: switzerland - super-league - 2023-to-2024
# 加载数据: portugal - liga-nos - 2013-to-2014
# 加载数据: portugal - liga-nos - 2014-to-2015
# 加载数据: portugal - liga-nos - 2015-to-2016
# 加载数据: portugal - liga-nos - 2016-to-2017
# 加载数据: portugal - liga-nos - 2017-to-2018
# 加载数据: portugal - liga-nos - 2018-to-2019
# 加载数据: portugal - liga-nos - 2019-to-2020
# 加载数据: portugal - liga-nos - 2020-to-2021
# 加载数据: portugal - liga-nos - 2021-to-2022
# 加载数据: portugal - liga-nos - 2022-to-2023
# 加载数据: portugal - liga-nos - 2023-to-2024
# 加载数据: italy - serie-b - 2013-to-2014
# 加载数据: italy - serie-b - 2014-to-2015
# 加载数据: italy - serie-b - 2015-to-2016
# 加载数据: italy - serie-b - 2016-to-2017
# 加载数据: italy - serie-b - 2017-to-2018
# 加载数据: italy - serie-b - 2018-to-2019
# 加载数据: italy - serie-b - 2019-to-2020
# 加载数据: italy - serie-b - 2020-to-2021
# 加载数据: italy - serie-b - 2021-to-2022
# 加载数据: italy - serie-b - 2022-to-2023
# 加载数据: italy - serie-b - 2023-to-2024
# 加载数据: germany - 2-bundesliga - 2013-to-2014
# 加载数据: germany - 2-bundesliga - 2014-to-2015
# 加载数据: germany - 2-bundesliga - 2015-to-2016
# 加载数据: germany - 2-bundesliga - 2016-to-2017
# 加载数据: germany - 2-bundesliga - 2017-to-2018
# 加载数据: germany - 2-bundesliga - 2018-to-2019
# 加载数据: germany - 2-bundesliga - 2019-to-2020
# 加载数据: germany - 2-bundesliga - 2020-to-2021
# 加载数据: germany - 2-bundesliga - 2021-to-2022
# 加载数据: germany - 2-bundesliga - 2022-to-2023
# 加载数据: germany - 2-bundesliga - 2023-to-2024
# 加载数据: scotland - premiership - 2013-to-2014
# 加载数据: scotland - premiership - 2014-to-2015
# 加载数据: scotland - premiership - 2015-to-2016
# 加载数据: scotland - premiership - 2016-to-2017
# 加载数据: scotland - premiership - 2017-to-2018
# 加载数据: scotland - premiership - 2018-to-2019
# 加载数据: scotland - premiership - 2019-to-2020
# 加载数据: scotland - premiership - 2020-to-2021
# 加载数据: scotland - premiership - 2021-to-2022
# 加载数据: scotland - premiership - 2022-to-2023
# 加载数据: scotland - premiership - 2023-to-2024
# 加载数据: belgium - pro-league - 2013-to-2014
# 警告: belgium - pro-league - 2013-to-2014 文件缺失
# 加载数据: belgium - pro-league - 2014-to-2015
# 警告: belgium - pro-league - 2014-to-2015 文件缺失
# 加载数据: belgium - pro-league - 2015-to-2016
# 加载数据: belgium - pro-league - 2016-to-2017
# 加载数据: belgium - pro-league - 2017-to-2018
# 加载数据: belgium - pro-league - 2018-to-2019
# 加载数据: belgium - pro-league - 2019-to-2020
# 加载数据: belgium - pro-league - 2020-to-2021
# 加载数据: belgium - pro-league - 2021-to-2022
# 加载数据: belgium - pro-league - 2022-to-2023
# 加载数据: belgium - pro-league - 2023-to-2024
# 加载数据: austria - bundesliga - 2013-to-2014
# 加载数据: austria - bundesliga - 2014-to-2015
# 加载数据: austria - bundesliga - 2015-to-2016
# 加载数据: austria - bundesliga - 2016-to-2017
# 加载数据: austria - bundesliga - 2017-to-2018
# 加载数据: austria - bundesliga - 2018-to-2019
# 加载数据: austria - bundesliga - 2019-to-2020
# 加载数据: austria - bundesliga - 2020-to-2021
# 加载数据: austria - bundesliga - 2021-to-2022
# 加载数据: austria - bundesliga - 2022-to-2023
# 加载数据: austria - bundesliga - 2023-to-2024
#
# ===== 计算Adaboost权重 =====
# 特征相关性矩阵:
#            ratio1    ratio2    ratio3    ratio4    ratio5    ratio6
# ratio1  1.000000  0.508161  0.033766  0.163999  0.032882  0.706597
# ratio2  0.508161  1.000000  0.019794  0.281190  0.017768  0.693462
# ratio3  0.033766  0.019794  1.000000  0.019268  0.003773  0.036416
# ratio4  0.163999  0.281190  0.019268  1.000000 -0.079970  0.363883
# ratio5  0.032882  0.017768  0.003773 -0.079970  1.000000  0.008842
# ratio6  0.706597  0.693462  0.036416  0.363883  0.008842  1.000000
# 最佳参数: {'estimator': DecisionTreeClassifier(max_depth=5), 'learning_rate': 0.05, 'n_estimators': 500}
# 测试集准确率: 0.7808823529411765
# 测试集F1分数: 0.7809188448246667
# 测试集ROC-AUC: 0.8609276396090687
# 混淆矩阵:
#  [[262  69]
#  [ 80 269]]
# 计算得到的权重: [0.30570289 0.0610465  0.00174872 0.05235879 0.00685736 0.57228573]
# 优化后的Adaboost权重: [0.3057029  0.0610465  0.00174872 0.05235879 0.00685736 0.5722857 ]
#
# ===== 随机搜索超参数 =====
#
# 随机搜索: {'lambda_defense': 0.0849080237694725, 'lambda_supervision': 0.20014286128198325, 'lambda_reg': 0.015639878836228104}
# 迭代 1000/300000, 损失 = 0.1358, rank_scale = 1.4109
# 迭代 2000/300000, 损失 = 0.1100, rank_scale = 1.7359
# 迭代 3000/300000, 损失 = 0.0971, rank_scale = 2.0356
# 迭代 4000/300000, 损失 = 0.0895, rank_scale = 2.3320
# 迭代 5000/300000, 损失 = 0.0847, rank_scale = 2.6350
# 迭代 6000/300000, 损失 = 0.0814, rank_scale = 2.9492
# 迭代 7000/300000, 损失 = 0.0790, rank_scale = 3.2765
# 迭代 8000/300000, 损失 = 0.0774, rank_scale = 3.6173
# 迭代 9000/300000, 损失 = 0.0762, rank_scale = 3.9711
# 迭代 10000/300000, 损失 = 0.0753, rank_scale = 4.3377
# 迭代 11000/300000, 损失 = 0.0745, rank_scale = 4.7170
# 迭代 12000/300000, 损失 = 0.0740, rank_scale = 5.1068
# 迭代 13000/300000, 损失 = 0.0735, rank_scale = 5.5048
# 迭代 14000/300000, 损失 = 0.0730, rank_scale = 5.9093
# 迭代 15000/300000, 损失 = 0.0727, rank_scale = 6.3193
# 迭代 16000/300000, 损失 = 0.0723, rank_scale = 6.7337
# 迭代 17000/300000, 损失 = 0.0720, rank_scale = 7.1521
# 迭代 18000/300000, 损失 = 0.0716, rank_scale = 7.5739
# 迭代 19000/300000, 损失 = 0.0713, rank_scale = 7.9987
# 迭代 20000/300000, 损失 = 0.0710, rank_scale = 8.4261
# 迭代 21000/300000, 损失 = 0.0708, rank_scale = 8.8560
# 迭代 22000/300000, 损失 = 0.0705, rank_scale = 9.2880
# 迭代 23000/300000, 损失 = 0.0702, rank_scale = 9.7218
# 迭代 24000/300000, 损失 = 0.0700, rank_scale = 10.1572
# 迭代 25000/300000, 损失 = 0.0698, rank_scale = 10.5944
# 迭代 26000/300000, 损失 = 0.0696, rank_scale = 11.0330
# 迭代 27000/300000, 损失 = 0.0694, rank_scale = 11.4730
# 迭代 28000/300000, 损失 = 0.0692, rank_scale = 11.9142
# 迭代 29000/300000, 损失 = 0.0690, rank_scale = 12.3567
# 迭代 30000/300000, 损失 = 0.0688, rank_scale = 12.8003
# 迭代 31000/300000, 损失 = 0.0686, rank_scale = 13.2448
# 迭代 32000/300000, 损失 = 0.0684, rank_scale = 13.6902
# 迭代 33000/300000, 损失 = 0.0683, rank_scale = 14.1365
# 迭代 34000/300000, 损失 = 0.0681, rank_scale = 14.5835
# 迭代 35000/300000, 损失 = 0.0680, rank_scale = 15.0309
# 迭代 36000/300000, 损失 = 0.0678, rank_scale = 15.4791
# 迭代 37000/300000, 损失 = 0.0677, rank_scale = 15.9276
# 迭代 38000/300000, 损失 = 0.0676, rank_scale = 16.3761
# 迭代 39000/300000, 损失 = 0.0674, rank_scale = 16.8262
# 迭代 40000/300000, 损失 = 0.0673, rank_scale = 17.2764
# 迭代 41000/300000, 损失 = 0.0672, rank_scale = 17.7265
# 迭代 42000/300000, 损失 = 0.0670, rank_scale = 18.1766
# 迭代 43000/300000, 损失 = 0.0669, rank_scale = 18.6268
# 迭代 44000/300000, 损失 = 0.0668, rank_scale = 19.0769
# 迭代 45000/300000, 损失 = 0.0667, rank_scale = 19.5270
# 迭代 46000/300000, 损失 = 0.0666, rank_scale = 19.9772
# 迭代 47000/300000, 损失 = 0.0665, rank_scale = 20.4273
# 迭代 48000/300000, 损失 = 0.0664, rank_scale = 20.8774
# 迭代 49000/300000, 损失 = 0.0663, rank_scale = 21.3276
# 迭代 50000/300000, 损失 = 0.0662, rank_scale = 21.7777
# 迭代 51000/300000, 损失 = 0.0661, rank_scale = 22.2278
# 迭代 52000/300000, 损失 = 0.0660, rank_scale = 22.6764
# 迭代 53000/300000, 损失 = 0.0659, rank_scale = 23.1246
# 迭代 54000/300000, 损失 = 0.0658, rank_scale = 23.5729
# 迭代 55000/300000, 损失 = 0.0657, rank_scale = 24.0211
# 迭代 56000/300000, 损失 = 0.0657, rank_scale = 24.4693
# 迭代 57000/300000, 损失 = 0.0656, rank_scale = 24.9161
# 迭代 58000/300000, 损失 = 0.0655, rank_scale = 25.3624
# 迭代 59000/300000, 损失 = 0.0654, rank_scale = 25.8088
# 迭代 60000/300000, 损失 = 0.0654, rank_scale = 26.2549
# 迭代 61000/300000, 损失 = 0.0653, rank_scale = 26.6993
# 迭代 62000/300000, 损失 = 0.0652, rank_scale = 27.1437
# 迭代 63000/300000, 损失 = 0.0651, rank_scale = 27.5878
# 迭代 64000/300000, 损失 = 0.0651, rank_scale = 28.0303
# 迭代 65000/300000, 损失 = 0.0650, rank_scale = 28.4728
# 迭代 66000/300000, 损失 = 0.0649, rank_scale = 28.9144
# 迭代 67000/300000, 损失 = 0.0649, rank_scale = 29.3550
# 迭代 68000/300000, 损失 = 0.0648, rank_scale = 29.7955
# 迭代 69000/300000, 损失 = 0.0648, rank_scale = 30.2342
# 迭代 70000/300000, 损失 = 0.0647, rank_scale = 30.6728
# 迭代 71000/300000, 损失 = 0.0646, rank_scale = 31.1099
# 迭代 72000/300000, 损失 = 0.0646, rank_scale = 31.5467
# 迭代 73000/300000, 损失 = 0.0645, rank_scale = 31.9820
# 迭代 74000/300000, 损失 = 0.0645, rank_scale = 32.4169
# 迭代 75000/300000, 损失 = 0.0644, rank_scale = 32.8518
# 迭代 76000/300000, 损失 = 0.0644, rank_scale = 33.2837
# 迭代 77000/300000, 损失 = 0.0643, rank_scale = 33.7147
# 迭代 78000/300000, 损失 = 0.0643, rank_scale = 34.1458
# 迭代 79000/300000, 损失 = 0.0642, rank_scale = 34.5762
# 迭代 80000/300000, 损失 = 0.0642, rank_scale = 35.0034
# 迭代 81000/300000, 损失 = 0.0641, rank_scale = 35.4307
# 迭代 82000/300000, 损失 = 0.0641, rank_scale = 35.8579
# 迭代 83000/300000, 损失 = 0.0640, rank_scale = 36.2822
# 迭代 84000/300000, 损失 = 0.0640, rank_scale = 36.7056
# 迭代 85000/300000, 损失 = 0.0639, rank_scale = 37.1291
# 迭代 86000/300000, 损失 = 0.0639, rank_scale = 37.5502
# 迭代 87000/300000, 损失 = 0.0638, rank_scale = 37.9698
# 迭代 88000/300000, 损失 = 0.0638, rank_scale = 38.3894
# 迭代 89000/300000, 损失 = 0.0638, rank_scale = 38.8069
# 迭代 90000/300000, 损失 = 0.0637, rank_scale = 39.2227
# 迭代 91000/300000, 损失 = 0.0637, rank_scale = 39.6385
# 迭代 92000/300000, 损失 = 0.0636, rank_scale = 40.0517
# 迭代 93000/300000, 损失 = 0.0636, rank_scale = 40.4637
# 迭代 94000/300000, 损失 = 0.0636, rank_scale = 40.8757
# 迭代 95000/300000, 损失 = 0.0635, rank_scale = 41.2844
# 迭代 96000/300000, 损失 = 0.0635, rank_scale = 41.6926
# 迭代 97000/300000, 损失 = 0.0634, rank_scale = 42.1003
# 迭代 98000/300000, 损失 = 0.0634, rank_scale = 42.5047
# 迭代 99000/300000, 损失 = 0.0634, rank_scale = 42.9090
# 迭代 100000/300000, 损失 = 0.0633, rank_scale = 43.3115
# 迭代 101000/300000, 损失 = 0.0633, rank_scale = 43.7121
# 迭代 102000/300000, 损失 = 0.0633, rank_scale = 44.1126
# 迭代 103000/300000, 损失 = 0.0632, rank_scale = 44.5098
# 迭代 104000/300000, 损失 = 0.0632, rank_scale = 44.9066
# 迭代 105000/300000, 损失 = 0.0632, rank_scale = 45.3020
# 迭代 106000/300000, 损失 = 0.0631, rank_scale = 45.6949
# 迭代 107000/300000, 损失 = 0.0631, rank_scale = 46.0878
# 迭代 108000/300000, 损失 = 0.0631, rank_scale = 46.4774
# 迭代 109000/300000, 损失 = 0.0631, rank_scale = 46.8665
# 迭代 110000/300000, 损失 = 0.0630, rank_scale = 47.2541
# 迭代 111000/300000, 损失 = 0.0630, rank_scale = 47.6394
# 迭代 112000/300000, 损失 = 0.0630, rank_scale = 48.0246
# 迭代 113000/300000, 损失 = 0.0629, rank_scale = 48.4062
# 迭代 114000/300000, 损失 = 0.0629, rank_scale = 48.7877
# 迭代 115000/300000, 损失 = 0.0629, rank_scale = 49.1669
# 迭代 116000/300000, 损失 = 0.0629, rank_scale = 49.5446
# 迭代 117000/300000, 损失 = 0.0628, rank_scale = 49.9214
# 迭代 118000/300000, 损失 = 0.0628, rank_scale = 50.2952
# 迭代 119000/300000, 损失 = 0.0628, rank_scale = 50.6691
# 迭代 120000/300000, 损失 = 0.0628, rank_scale = 51.0395
# 迭代 121000/300000, 损失 = 0.0627, rank_scale = 51.4096
# 迭代 122000/300000, 损失 = 0.0627, rank_scale = 51.7775
# 迭代 123000/300000, 损失 = 0.0627, rank_scale = 52.1437
# 迭代 124000/300000, 损失 = 0.0627, rank_scale = 52.5090
# 迭代 125000/300000, 损失 = 0.0626, rank_scale = 52.8714
# 迭代 126000/300000, 损失 = 0.0626, rank_scale = 53.2338
# 迭代 127000/300000, 损失 = 0.0626, rank_scale = 53.5927
# 迭代 128000/300000, 损失 = 0.0626, rank_scale = 53.9513
# 迭代 129000/300000, 损失 = 0.0625, rank_scale = 54.3074
# 迭代 130000/300000, 损失 = 0.0625, rank_scale = 54.6622
# 迭代 131000/300000, 损失 = 0.0625, rank_scale = 55.0158
# 迭代 132000/300000, 损失 = 0.0625, rank_scale = 55.3667
# 迭代 133000/300000, 损失 = 0.0624, rank_scale = 55.7175
# 迭代 134000/300000, 损失 = 0.0624, rank_scale = 56.0647
# 迭代 135000/300000, 损失 = 0.0624, rank_scale = 56.4118
# 迭代 136000/300000, 损失 = 0.0624, rank_scale = 56.7561
# 迭代 137000/300000, 损失 = 0.0624, rank_scale = 57.0995
# 迭代 138000/300000, 损失 = 0.0623, rank_scale = 57.4411
# 迭代 139000/300000, 损失 = 0.0623, rank_scale = 57.7806
# 迭代 140000/300000, 损失 = 0.0623, rank_scale = 58.1195
# 迭代 141000/300000, 损失 = 0.0623, rank_scale = 58.4552
# 迭代 142000/300000, 损失 = 0.0623, rank_scale = 58.7909
# 迭代 143000/300000, 损失 = 0.0622, rank_scale = 59.1233
# 迭代 144000/300000, 损失 = 0.0622, rank_scale = 59.4552
# 迭代 145000/300000, 损失 = 0.0622, rank_scale = 59.7850
# 迭代 146000/300000, 损失 = 0.0622, rank_scale = 60.1131
# 迭代 147000/300000, 损失 = 0.0622, rank_scale = 60.4403
# 迭代 148000/300000, 损失 = 0.0622, rank_scale = 60.7645
# 迭代 149000/300000, 损失 = 0.0621, rank_scale = 61.0888
# 迭代 150000/300000, 损失 = 0.0621, rank_scale = 61.4096
# 迭代 151000/300000, 损失 = 0.0621, rank_scale = 61.7300
# 迭代 152000/300000, 损失 = 0.0621, rank_scale = 62.0483
# 迭代 153000/300000, 损失 = 0.0621, rank_scale = 62.3649
# 迭代 154000/300000, 损失 = 0.0621, rank_scale = 62.6807
# 迭代 155000/300000, 损失 = 0.0620, rank_scale = 62.9935
# 迭代 156000/300000, 损失 = 0.0620, rank_scale = 63.3063
# 迭代 157000/300000, 损失 = 0.0620, rank_scale = 63.6159
# 迭代 158000/300000, 损失 = 0.0620, rank_scale = 63.9249
# 迭代 159000/300000, 损失 = 0.0620, rank_scale = 64.2310
# 迭代 160000/300000, 损失 = 0.0620, rank_scale = 64.5362
# 迭代 161000/300000, 损失 = 0.0619, rank_scale = 64.8414
# 迭代 162000/300000, 损失 = 0.0619, rank_scale = 65.1466
# 迭代 163000/300000, 损失 = 0.0619, rank_scale = 65.4455
# 迭代 164000/300000, 损失 = 0.0619, rank_scale = 65.7431
# 迭代 165000/300000, 损失 = 0.0619, rank_scale = 66.0406
# 迭代 166000/300000, 损失 = 0.0619, rank_scale = 66.3382
# 迭代 167000/300000, 损失 = 0.0619, rank_scale = 66.6357
# 迭代 168000/300000, 损失 = 0.0618, rank_scale = 66.9265
# 迭代 169000/300000, 损失 = 0.0618, rank_scale = 67.2165
# 迭代 170000/300000, 损失 = 0.0618, rank_scale = 67.5064
# 迭代 171000/300000, 损失 = 0.0618, rank_scale = 67.7963
# 迭代 172000/300000, 损失 = 0.0618, rank_scale = 68.0862
# 迭代 173000/300000, 损失 = 0.0618, rank_scale = 68.3694
# 迭代 174000/300000, 损失 = 0.0618, rank_scale = 68.6517
# 迭代 175000/300000, 损失 = 0.0617, rank_scale = 68.9340
# 迭代 176000/300000, 损失 = 0.0617, rank_scale = 69.2163
# 迭代 177000/300000, 损失 = 0.0617, rank_scale = 69.4986
# 迭代 178000/300000, 损失 = 0.0617, rank_scale = 69.7754
# 迭代 179000/300000, 损失 = 0.0617, rank_scale = 70.0501
# 迭代 180000/300000, 损失 = 0.0617, rank_scale = 70.3247
# 迭代 181000/300000, 损失 = 0.0617, rank_scale = 70.5994
# 迭代 182000/300000, 损失 = 0.0617, rank_scale = 70.8741
# 迭代 183000/300000, 损失 = 0.0616, rank_scale = 71.1453
# 迭代 184000/300000, 损失 = 0.0616, rank_scale = 71.4123
# 迭代 185000/300000, 损失 = 0.0616, rank_scale = 71.6793
# 迭代 186000/300000, 损失 = 0.0616, rank_scale = 71.9464
# 迭代 187000/300000, 损失 = 0.0616, rank_scale = 72.2134
# 迭代 188000/300000, 损失 = 0.0616, rank_scale = 72.4801
# 迭代 189000/300000, 损失 = 0.0616, rank_scale = 72.7395
# 迭代 190000/300000, 损失 = 0.0616, rank_scale = 72.9989
# 迭代 191000/300000, 损失 = 0.0615, rank_scale = 73.2583
# 迭代 192000/300000, 损失 = 0.0615, rank_scale = 73.5177
# 迭代 193000/300000, 损失 = 0.0615, rank_scale = 73.7771
# 迭代 194000/300000, 损失 = 0.0615, rank_scale = 74.0332
# 迭代 195000/300000, 损失 = 0.0615, rank_scale = 74.2849
# 迭代 196000/300000, 损失 = 0.0615, rank_scale = 74.5367
# 迭代 197000/300000, 损失 = 0.0615, rank_scale = 74.7885
# 迭代 198000/300000, 损失 = 0.0615, rank_scale = 75.0402
# 迭代 199000/300000, 损失 = 0.0615, rank_scale = 75.2920
# 迭代 200000/300000, 损失 = 0.0614, rank_scale = 75.5389
# 迭代 201000/300000, 损失 = 0.0614, rank_scale = 75.7830
# 迭代 202000/300000, 损失 = 0.0614, rank_scale = 76.0272
# 迭代 203000/300000, 损失 = 0.0614, rank_scale = 76.2713
# 迭代 204000/300000, 损失 = 0.0614, rank_scale = 76.5154
# 迭代 205000/300000, 损失 = 0.0614, rank_scale = 76.7596
# 迭代 206000/300000, 损失 = 0.0614, rank_scale = 76.9990
# 迭代 207000/300000, 损失 = 0.0614, rank_scale = 77.2355
# 迭代 208000/300000, 损失 = 0.0614, rank_scale = 77.4720
# 迭代 209000/300000, 损失 = 0.0614, rank_scale = 77.7085
# 迭代 210000/300000, 损失 = 0.0613, rank_scale = 77.9450
# 迭代 211000/300000, 损失 = 0.0613, rank_scale = 78.1816
# 迭代 212000/300000, 损失 = 0.0613, rank_scale = 78.4154
# 迭代 213000/300000, 损失 = 0.0613, rank_scale = 78.6443
# 迭代 214000/300000, 损失 = 0.0613, rank_scale = 78.8732
# 迭代 215000/300000, 损失 = 0.0613, rank_scale = 79.1020
# 迭代 216000/300000, 损失 = 0.0613, rank_scale = 79.3309
# 迭代 217000/300000, 损失 = 0.0613, rank_scale = 79.5598
# 迭代 218000/300000, 损失 = 0.0613, rank_scale = 79.7887
# 迭代 219000/300000, 损失 = 0.0613, rank_scale = 80.0113
# 迭代 220000/300000, 损失 = 0.0613, rank_scale = 80.2325
# 迭代 221000/300000, 损失 = 0.0612, rank_scale = 80.4538
# 迭代 222000/300000, 损失 = 0.0612, rank_scale = 80.6750
# 迭代 223000/300000, 损失 = 0.0612, rank_scale = 80.8963
# 迭代 224000/300000, 损失 = 0.0612, rank_scale = 81.1175
# 迭代 225000/300000, 损失 = 0.0612, rank_scale = 81.3388
# 迭代 226000/300000, 损失 = 0.0612, rank_scale = 81.5526
# 迭代 227000/300000, 损失 = 0.0612, rank_scale = 81.7662
# 迭代 228000/300000, 损失 = 0.0612, rank_scale = 81.9798
# 迭代 229000/300000, 损失 = 0.0612, rank_scale = 82.1934
# 迭代 230000/300000, 损失 = 0.0612, rank_scale = 82.4071
# 迭代 231000/300000, 损失 = 0.0612, rank_scale = 82.6207
# 迭代 232000/300000, 损失 = 0.0611, rank_scale = 82.8343
# 迭代 233000/300000, 损失 = 0.0611, rank_scale = 83.0412
# 迭代 234000/300000, 损失 = 0.0611, rank_scale = 83.2472
# 迭代 235000/300000, 损失 = 0.0611, rank_scale = 83.4532
# 迭代 236000/300000, 损失 = 0.0611, rank_scale = 83.6592
# 迭代 237000/300000, 损失 = 0.0611, rank_scale = 83.8652
# 迭代 238000/300000, 损失 = 0.0611, rank_scale = 84.0712
# 迭代 239000/300000, 损失 = 0.0611, rank_scale = 84.2771
# 迭代 240000/300000, 损失 = 0.0611, rank_scale = 84.4792
# 迭代 241000/300000, 损失 = 0.0611, rank_scale = 84.6775
# 迭代 242000/300000, 损失 = 0.0611, rank_scale = 84.8759
# 迭代 243000/300000, 损失 = 0.0611, rank_scale = 85.0743
# 迭代 244000/300000, 损失 = 0.0611, rank_scale = 85.2726
# 迭代 245000/300000, 损失 = 0.0610, rank_scale = 85.4710
# 迭代 246000/300000, 损失 = 0.0610, rank_scale = 85.6694
# 迭代 247000/300000, 损失 = 0.0610, rank_scale = 85.8677
# 迭代 248000/300000, 损失 = 0.0610, rank_scale = 86.0611
# 迭代 249000/300000, 损失 = 0.0610, rank_scale = 86.2519
# 迭代 250000/300000, 损失 = 0.0610, rank_scale = 86.4426
# 迭代 251000/300000, 损失 = 0.0610, rank_scale = 86.6334
# 迭代 252000/300000, 损失 = 0.0610, rank_scale = 86.8241
# 迭代 253000/300000, 损失 = 0.0610, rank_scale = 87.0148
# 迭代 254000/300000, 损失 = 0.0610, rank_scale = 87.2056
# 迭代 255000/300000, 损失 = 0.0610, rank_scale = 87.3963
# 迭代 256000/300000, 损失 = 0.0610, rank_scale = 87.5852
# 迭代 257000/300000, 损失 = 0.0610, rank_scale = 87.7683
# 迭代 258000/300000, 损失 = 0.0610, rank_scale = 87.9514
# 迭代 259000/300000, 损失 = 0.0610, rank_scale = 88.1345
# 迭代 260000/300000, 损失 = 0.0609, rank_scale = 88.3176
# 迭代 261000/300000, 损失 = 0.0609, rank_scale = 88.5007
# 迭代 262000/300000, 损失 = 0.0609, rank_scale = 88.6838
# 迭代 263000/300000, 损失 = 0.0609, rank_scale = 88.8670
# 迭代 264000/300000, 损失 = 0.0609, rank_scale = 89.0501
# 迭代 265000/300000, 损失 = 0.0609, rank_scale = 89.2318
# 迭代 266000/300000, 损失 = 0.0609, rank_scale = 89.4073
# 迭代 267000/300000, 损失 = 0.0609, rank_scale = 89.5828
# 迭代 268000/300000, 损失 = 0.0609, rank_scale = 89.7582
# 迭代 269000/300000, 损失 = 0.0609, rank_scale = 89.9337
# 迭代 270000/300000, 损失 = 0.0609, rank_scale = 90.1092
# 迭代 271000/300000, 损失 = 0.0609, rank_scale = 90.2847
# 迭代 272000/300000, 损失 = 0.0609, rank_scale = 90.4601
# 迭代 273000/300000, 损失 = 0.0609, rank_scale = 90.6356
# 迭代 274000/300000, 损失 = 0.0609, rank_scale = 90.8111
# 迭代 275000/300000, 损失 = 0.0608, rank_scale = 90.9823
# 迭代 276000/300000, 损失 = 0.0608, rank_scale = 91.1501
# 迭代 277000/300000, 损失 = 0.0608, rank_scale = 91.3179
# 迭代 278000/300000, 损失 = 0.0608, rank_scale = 91.4858
# 迭代 279000/300000, 损失 = 0.0608, rank_scale = 91.6536
# 迭代 280000/300000, 损失 = 0.0608, rank_scale = 91.8215
# 迭代 281000/300000, 损失 = 0.0608, rank_scale = 91.9893
# 迭代 282000/300000, 损失 = 0.0608, rank_scale = 92.1572
# 迭代 283000/300000, 损失 = 0.0608, rank_scale = 92.3250
# 迭代 284000/300000, 损失 = 0.0608, rank_scale = 92.4929
# 迭代 285000/300000, 损失 = 0.0608, rank_scale = 92.6572
# 迭代 286000/300000, 损失 = 0.0608, rank_scale = 92.8175
# 迭代 287000/300000, 损失 = 0.0608, rank_scale = 92.9777
# 迭代 288000/300000, 损失 = 0.0608, rank_scale = 93.1379
# 迭代 289000/300000, 损失 = 0.0608, rank_scale = 93.2981
# 迭代 290000/300000, 损失 = 0.0608, rank_scale = 93.4583
# 迭代 291000/300000, 损失 = 0.0608, rank_scale = 93.6185
# 迭代 292000/300000, 损失 = 0.0607, rank_scale = 93.7788
# 迭代 293000/300000, 损失 = 0.0607, rank_scale = 93.9390
# 迭代 294000/300000, 损失 = 0.0607, rank_scale = 94.0992
# 迭代 295000/300000, 损失 = 0.0607, rank_scale = 94.2594
# 迭代 296000/300000, 损失 = 0.0607, rank_scale = 94.4122
# 迭代 297000/300000, 损失 = 0.0607, rank_scale = 94.5648
# 迭代 298000/300000, 损失 = 0.0607, rank_scale = 94.7174
# 迭代 299000/300000, 损失 = 0.0607, rank_scale = 94.8700
# 迭代 300000/300000, 损失 = 0.0607, rank_scale = 95.0226
#
# 随机搜索: {'lambda_defense': 0.12973169683940733, 'lambda_supervision': 0.0412037280884873, 'lambda_reg': 0.004119890406724053}
# 迭代 1000/300000, 损失 = 0.1137, rank_scale = 1.4110
# 迭代 2000/300000, 损失 = 0.0776, rank_scale = 1.7363
# 迭代 3000/300000, 损失 = 0.0592, rank_scale = 2.0363
# 迭代 4000/300000, 损失 = 0.0482, rank_scale = 2.3331
# 迭代 5000/300000, 损失 = 0.0413, rank_scale = 2.6373
# 迭代 6000/300000, 损失 = 0.0368, rank_scale = 2.9539
# 迭代 7000/300000, 损失 = 0.0337, rank_scale = 3.2854
# 迭代 8000/300000, 损失 = 0.0316, rank_scale = 3.6321
# 迭代 9000/300000, 损失 = 0.0300, rank_scale = 3.9921
# 迭代 10000/300000, 损失 = 0.0289, rank_scale = 4.3635
# 迭代 11000/300000, 损失 = 0.0281, rank_scale = 4.7443
# 迭代 12000/300000, 损失 = 0.0274, rank_scale = 5.1332
# 迭代 13000/300000, 损失 = 0.0269, rank_scale = 5.5293
# 迭代 14000/300000, 损失 = 0.0265, rank_scale = 5.9316
# 迭代 15000/300000, 损失 = 0.0261, rank_scale = 6.3392
# 迭代 16000/300000, 损失 = 0.0257, rank_scale = 6.7513
# 迭代 17000/300000, 损失 = 0.0253, rank_scale = 7.1674
# 迭代 18000/300000, 损失 = 0.0250, rank_scale = 7.5869
# 迭代 19000/300000, 损失 = 0.0247, rank_scale = 8.0096
# 迭代 20000/300000, 损失 = 0.0244, rank_scale = 8.4351
# 迭代 21000/300000, 损失 = 0.0241, rank_scale = 8.8632
# 迭代 22000/300000, 损失 = 0.0238, rank_scale = 9.2937
# 迭代 23000/300000, 损失 = 0.0236, rank_scale = 9.7264
# 迭代 24000/300000, 损失 = 0.0233, rank_scale = 10.1612
# 迭代 25000/300000, 损失 = 0.0231, rank_scale = 10.5977
# 迭代 26000/300000, 损失 = 0.0229, rank_scale = 11.0360
# 迭代 27000/300000, 损失 = 0.0227, rank_scale = 11.4757
# 迭代 28000/300000, 损失 = 0.0225, rank_scale = 11.9168
# 迭代 29000/300000, 损失 = 0.0223, rank_scale = 12.3591
# 迭代 30000/300000, 损失 = 0.0221, rank_scale = 12.8025
# 迭代 31000/300000, 损失 = 0.0220, rank_scale = 13.2469
# 迭代 32000/300000, 损失 = 0.0218, rank_scale = 13.6922
# 迭代 33000/300000, 损失 = 0.0216, rank_scale = 14.1384
# 迭代 34000/300000, 损失 = 0.0215, rank_scale = 14.5853
# 迭代 35000/300000, 损失 = 0.0213, rank_scale = 15.0326
# 迭代 36000/300000, 损失 = 0.0212, rank_scale = 15.4808
# 迭代 37000/300000, 损失 = 0.0210, rank_scale = 15.9290
# 迭代 38000/300000, 损失 = 0.0209, rank_scale = 16.3774
# 迭代 39000/300000, 损失 = 0.0208, rank_scale = 16.8274
# 迭代 40000/300000, 损失 = 0.0207, rank_scale = 17.2775
# 迭代 41000/300000, 损失 = 0.0205, rank_scale = 17.7276
# 迭代 42000/300000, 损失 = 0.0204, rank_scale = 18.1778
# 迭代 43000/300000, 损失 = 0.0203, rank_scale = 18.6279
# 迭代 44000/300000, 损失 = 0.0202, rank_scale = 19.0781
# 迭代 45000/300000, 损失 = 0.0201, rank_scale = 19.5282
# 迭代 46000/300000, 损失 = 0.0200, rank_scale = 19.9783
# 迭代 47000/300000, 损失 = 0.0199, rank_scale = 20.4285
# 迭代 48000/300000, 损失 = 0.0197, rank_scale = 20.8786
# 迭代 49000/300000, 损失 = 0.0196, rank_scale = 21.3287
# 迭代 50000/300000, 损失 = 0.0196, rank_scale = 21.7789
# 迭代 51000/300000, 损失 = 0.0195, rank_scale = 22.2289
# 迭代 52000/300000, 损失 = 0.0194, rank_scale = 22.6772
# 迭代 53000/300000, 损失 = 0.0193, rank_scale = 23.1254
# 迭代 54000/300000, 损失 = 0.0192, rank_scale = 23.5736
# 迭代 55000/300000, 损失 = 0.0191, rank_scale = 24.0218
# 迭代 56000/300000, 损失 = 0.0190, rank_scale = 24.4701
# 迭代 57000/300000, 损失 = 0.0189, rank_scale = 24.9165
# 迭代 58000/300000, 损失 = 0.0189, rank_scale = 25.3628
# 迭代 59000/300000, 损失 = 0.0188, rank_scale = 25.8092
# 迭代 60000/300000, 损失 = 0.0187, rank_scale = 26.2549
# 迭代 61000/300000, 损失 = 0.0186, rank_scale = 26.6993
# 迭代 62000/300000, 损失 = 0.0186, rank_scale = 27.1437
# 迭代 63000/300000, 损失 = 0.0185, rank_scale = 27.5876
# 迭代 64000/300000, 损失 = 0.0184, rank_scale = 28.0301
# 迭代 65000/300000, 损失 = 0.0184, rank_scale = 28.4726
# 迭代 66000/300000, 损失 = 0.0183, rank_scale = 28.9138
# 迭代 67000/300000, 损失 = 0.0182, rank_scale = 29.3544
# 迭代 68000/300000, 损失 = 0.0182, rank_scale = 29.7946
# 迭代 69000/300000, 损失 = 0.0181, rank_scale = 30.2333
# 迭代 70000/300000, 损失 = 0.0181, rank_scale = 30.6720
# 迭代 71000/300000, 损失 = 0.0180, rank_scale = 31.1088
# 迭代 72000/300000, 损失 = 0.0179, rank_scale = 31.5456
# 迭代 73000/300000, 损失 = 0.0179, rank_scale = 31.9807
# 迭代 74000/300000, 损失 = 0.0178, rank_scale = 32.4155
# 迭代 75000/300000, 损失 = 0.0178, rank_scale = 32.8504
# 迭代 76000/300000, 损失 = 0.0177, rank_scale = 33.2816
# 迭代 77000/300000, 损失 = 0.0177, rank_scale = 33.7126
# 迭代 78000/300000, 损失 = 0.0176, rank_scale = 34.1437
# 迭代 79000/300000, 损失 = 0.0176, rank_scale = 34.5736
# 迭代 80000/300000, 损失 = 0.0175, rank_scale = 35.0008
# 迭代 81000/300000, 损失 = 0.0175, rank_scale = 35.4281
# 迭代 82000/300000, 损失 = 0.0174, rank_scale = 35.8553
# 迭代 83000/300000, 损失 = 0.0174, rank_scale = 36.2788
# 迭代 84000/300000, 损失 = 0.0173, rank_scale = 36.7023
# 迭代 85000/300000, 损失 = 0.0173, rank_scale = 37.1257
# 迭代 86000/300000, 损失 = 0.0172, rank_scale = 37.5461
# 迭代 87000/300000, 损失 = 0.0172, rank_scale = 37.9657
# 迭代 88000/300000, 损失 = 0.0172, rank_scale = 38.3853
# 迭代 89000/300000, 损失 = 0.0171, rank_scale = 38.8021
# 迭代 90000/300000, 损失 = 0.0171, rank_scale = 39.2179
# 迭代 91000/300000, 损失 = 0.0170, rank_scale = 39.6337
# 迭代 92000/300000, 损失 = 0.0170, rank_scale = 40.0463
# 迭代 93000/300000, 损失 = 0.0170, rank_scale = 40.4583
# 迭代 94000/300000, 损失 = 0.0169, rank_scale = 40.8701
# 迭代 95000/300000, 损失 = 0.0169, rank_scale = 41.2783
# 迭代 96000/300000, 损失 = 0.0168, rank_scale = 41.6864
# 迭代 97000/300000, 损失 = 0.0168, rank_scale = 42.0934
# 迭代 98000/300000, 损失 = 0.0168, rank_scale = 42.4978
# 迭代 99000/300000, 损失 = 0.0167, rank_scale = 42.9021
# 迭代 100000/300000, 损失 = 0.0167, rank_scale = 43.3039
# 迭代 101000/300000, 损失 = 0.0167, rank_scale = 43.7045
# 迭代 102000/300000, 损失 = 0.0166, rank_scale = 44.1047
# 迭代 103000/300000, 损失 = 0.0166, rank_scale = 44.5014
# 迭代 104000/300000, 损失 = 0.0166, rank_scale = 44.8981
# 迭代 105000/300000, 损失 = 0.0165, rank_scale = 45.2927
# 迭代 106000/300000, 损失 = 0.0165, rank_scale = 45.6856
# 迭代 107000/300000, 损失 = 0.0165, rank_scale = 46.0782
# 迭代 108000/300000, 损失 = 0.0164, rank_scale = 46.4673
# 迭代 109000/300000, 损失 = 0.0164, rank_scale = 46.8564
# 迭代 110000/300000, 损失 = 0.0164, rank_scale = 47.2431
# 迭代 111000/300000, 损失 = 0.0164, rank_scale = 47.6284
# 迭代 112000/300000, 损失 = 0.0163, rank_scale = 48.0129
# 迭代 113000/300000, 损失 = 0.0163, rank_scale = 48.3943
# 迭代 114000/300000, 损失 = 0.0163, rank_scale = 48.7758
# 迭代 115000/300000, 损失 = 0.0162, rank_scale = 49.1541
# 迭代 116000/300000, 损失 = 0.0162, rank_scale = 49.5318
# 迭代 117000/300000, 损失 = 0.0162, rank_scale = 49.9078
# 迭代 118000/300000, 损失 = 0.0162, rank_scale = 50.2816
# 迭代 119000/300000, 损失 = 0.0161, rank_scale = 50.6551
# 迭代 120000/300000, 损失 = 0.0161, rank_scale = 51.0251
# 迭代 121000/300000, 损失 = 0.0161, rank_scale = 51.3951
# 迭代 122000/300000, 损失 = 0.0161, rank_scale = 51.7621
# 迭代 123000/300000, 损失 = 0.0160, rank_scale = 52.1283
# 迭代 124000/300000, 损失 = 0.0160, rank_scale = 52.4927
# 迭代 125000/300000, 损失 = 0.0160, rank_scale = 52.8551
# 迭代 126000/300000, 损失 = 0.0160, rank_scale = 53.2168
# 迭代 127000/300000, 损失 = 0.0159, rank_scale = 53.5754
# 迭代 128000/300000, 损失 = 0.0159, rank_scale = 53.9340
# 迭代 129000/300000, 损失 = 0.0159, rank_scale = 54.2892
# 迭代 130000/300000, 损失 = 0.0159, rank_scale = 54.6440
# 迭代 131000/300000, 损失 = 0.0159, rank_scale = 54.9964
# 迭代 132000/300000, 损失 = 0.0158, rank_scale = 55.3474
# 迭代 133000/300000, 损失 = 0.0158, rank_scale = 55.6971
# 迭代 134000/300000, 损失 = 0.0158, rank_scale = 56.0443
# 迭代 135000/300000, 损失 = 0.0158, rank_scale = 56.3914
# 迭代 136000/300000, 损失 = 0.0158, rank_scale = 56.7348
# 迭代 137000/300000, 损失 = 0.0157, rank_scale = 57.0781
# 迭代 138000/300000, 损失 = 0.0157, rank_scale = 57.4188
# 迭代 139000/300000, 损失 = 0.0157, rank_scale = 57.7583
# 迭代 140000/300000, 损失 = 0.0157, rank_scale = 58.0962
# 迭代 141000/300000, 损失 = 0.0157, rank_scale = 58.4319
# 迭代 142000/300000, 损失 = 0.0156, rank_scale = 58.7673
# 迭代 143000/300000, 损失 = 0.0156, rank_scale = 59.0991
# 迭代 144000/300000, 损失 = 0.0156, rank_scale = 59.4310
# 迭代 145000/300000, 损失 = 0.0156, rank_scale = 59.7598
# 迭代 146000/300000, 损失 = 0.0156, rank_scale = 60.0878
# 迭代 147000/300000, 损失 = 0.0155, rank_scale = 60.4141
# 迭代 148000/300000, 损失 = 0.0155, rank_scale = 60.7383
# 迭代 149000/300000, 损失 = 0.0155, rank_scale = 61.0621
# 迭代 150000/300000, 损失 = 0.0155, rank_scale = 61.3825
# 迭代 151000/300000, 损失 = 0.0155, rank_scale = 61.7029
# 迭代 152000/300000, 损失 = 0.0155, rank_scale = 62.0204
# 迭代 153000/300000, 损失 = 0.0154, rank_scale = 62.3370
# 迭代 154000/300000, 损失 = 0.0154, rank_scale = 62.6522
# 迭代 155000/300000, 损失 = 0.0154, rank_scale = 62.9650
# 迭代 156000/300000, 损失 = 0.0154, rank_scale = 63.2777
# 迭代 157000/300000, 损失 = 0.0154, rank_scale = 63.5867
# 迭代 158000/300000, 损失 = 0.0153, rank_scale = 63.8957
# 迭代 159000/300000, 损失 = 0.0153, rank_scale = 64.2020
# 迭代 160000/300000, 损失 = 0.0153, rank_scale = 64.5072
# 迭代 161000/300000, 损失 = 0.0153, rank_scale = 64.8124
# 迭代 162000/300000, 损失 = 0.0153, rank_scale = 65.1167
# 迭代 163000/300000, 损失 = 0.0153, rank_scale = 65.4143
# 迭代 164000/300000, 损失 = 0.0153, rank_scale = 65.7118
# 迭代 165000/300000, 损失 = 0.0152, rank_scale = 66.0094
# 迭代 166000/300000, 损失 = 0.0152, rank_scale = 66.3069
# 迭代 167000/300000, 损失 = 0.0152, rank_scale = 66.6032
# 迭代 168000/300000, 损失 = 0.0152, rank_scale = 66.8931
# 迭代 169000/300000, 损失 = 0.0152, rank_scale = 67.1830
# 迭代 170000/300000, 损失 = 0.0152, rank_scale = 67.4729
# 迭代 171000/300000, 损失 = 0.0152, rank_scale = 67.7629
# 迭代 172000/300000, 损失 = 0.0151, rank_scale = 68.0516
# 迭代 173000/300000, 损失 = 0.0151, rank_scale = 68.3339
# 迭代 174000/300000, 损失 = 0.0151, rank_scale = 68.6162
# 迭代 175000/300000, 损失 = 0.0151, rank_scale = 68.8985
# 迭代 176000/300000, 损失 = 0.0151, rank_scale = 69.1808
# 迭代 177000/300000, 损失 = 0.0151, rank_scale = 69.4630
# 迭代 178000/300000, 损失 = 0.0151, rank_scale = 69.7379
# 迭代 179000/300000, 损失 = 0.0150, rank_scale = 70.0125
# 迭代 180000/300000, 损失 = 0.0150, rank_scale = 70.2872
# 迭代 181000/300000, 损失 = 0.0150, rank_scale = 70.5619
# 迭代 182000/300000, 损失 = 0.0150, rank_scale = 70.8365
# 迭代 183000/300000, 损失 = 0.0150, rank_scale = 71.1062
# 迭代 184000/300000, 损失 = 0.0150, rank_scale = 71.3733
# 迭代 185000/300000, 损失 = 0.0150, rank_scale = 71.6403
# 迭代 186000/300000, 损失 = 0.0150, rank_scale = 71.9073
# 迭代 187000/300000, 损失 = 0.0149, rank_scale = 72.1743
# 迭代 188000/300000, 损失 = 0.0149, rank_scale = 72.4408
# 迭代 189000/300000, 损失 = 0.0149, rank_scale = 72.7002
# 迭代 190000/300000, 损失 = 0.0149, rank_scale = 72.9596
# 迭代 191000/300000, 损失 = 0.0149, rank_scale = 73.2190
# 迭代 192000/300000, 损失 = 0.0149, rank_scale = 73.4784
# 迭代 193000/300000, 损失 = 0.0149, rank_scale = 73.7378
# 迭代 194000/300000, 损失 = 0.0149, rank_scale = 73.9945
# 迭代 195000/300000, 损失 = 0.0149, rank_scale = 74.2462
# 迭代 196000/300000, 损失 = 0.0148, rank_scale = 74.4980
# 迭代 197000/300000, 损失 = 0.0148, rank_scale = 74.7498
# 迭代 198000/300000, 损失 = 0.0148, rank_scale = 75.0015
# 迭代 199000/300000, 损失 = 0.0148, rank_scale = 75.2533
# 迭代 200000/300000, 损失 = 0.0148, rank_scale = 75.4997
# 迭代 201000/300000, 损失 = 0.0148, rank_scale = 75.7439
# 迭代 202000/300000, 损失 = 0.0148, rank_scale = 75.9880
# 迭代 203000/300000, 损失 = 0.0148, rank_scale = 76.2321
# 迭代 204000/300000, 损失 = 0.0148, rank_scale = 76.4763
# 迭代 205000/300000, 损失 = 0.0147, rank_scale = 76.7204
# 迭代 206000/300000, 损失 = 0.0147, rank_scale = 76.9583
# 迭代 207000/300000, 损失 = 0.0147, rank_scale = 77.1948
# 迭代 208000/300000, 损失 = 0.0147, rank_scale = 77.4313
# 迭代 209000/300000, 损失 = 0.0147, rank_scale = 77.6678
# 迭代 210000/300000, 损失 = 0.0147, rank_scale = 77.9043
# 迭代 211000/300000, 损失 = 0.0147, rank_scale = 78.1408
# 迭代 212000/300000, 损失 = 0.0147, rank_scale = 78.3726
# 迭代 213000/300000, 损失 = 0.0147, rank_scale = 78.6014
# 迭代 214000/300000, 损失 = 0.0147, rank_scale = 78.8303
# 迭代 215000/300000, 损失 = 0.0146, rank_scale = 79.0592
# 迭代 216000/300000, 损失 = 0.0146, rank_scale = 79.2881
# 迭代 217000/300000, 损失 = 0.0146, rank_scale = 79.5170
# 迭代 218000/300000, 损失 = 0.0146, rank_scale = 79.7451
# 迭代 219000/300000, 损失 = 0.0146, rank_scale = 79.9664
# 迭代 220000/300000, 损失 = 0.0146, rank_scale = 80.1876
# 迭代 221000/300000, 损失 = 0.0146, rank_scale = 80.4089
# 迭代 222000/300000, 损失 = 0.0146, rank_scale = 80.6301
# 迭代 223000/300000, 损失 = 0.0146, rank_scale = 80.8514
# 迭代 224000/300000, 损失 = 0.0146, rank_scale = 81.0726
# 迭代 225000/300000, 损失 = 0.0146, rank_scale = 81.2921
# 迭代 226000/300000, 损失 = 0.0146, rank_scale = 81.5057
# 迭代 227000/300000, 损失 = 0.0145, rank_scale = 81.7193
# 迭代 228000/300000, 损失 = 0.0145, rank_scale = 81.9330
# 迭代 229000/300000, 损失 = 0.0145, rank_scale = 82.1466
# 迭代 230000/300000, 损失 = 0.0145, rank_scale = 82.3602
# 迭代 231000/300000, 损失 = 0.0145, rank_scale = 82.5738
# 迭代 232000/300000, 损失 = 0.0145, rank_scale = 82.7875
# 迭代 233000/300000, 损失 = 0.0145, rank_scale = 82.9945
# 迭代 234000/300000, 损失 = 0.0145, rank_scale = 83.2005
# 迭代 235000/300000, 损失 = 0.0145, rank_scale = 83.4065
# 迭代 236000/300000, 损失 = 0.0145, rank_scale = 83.6125
# 迭代 237000/300000, 损失 = 0.0145, rank_scale = 83.8185
# 迭代 238000/300000, 损失 = 0.0144, rank_scale = 84.0245
# 迭代 239000/300000, 损失 = 0.0144, rank_scale = 84.2305
# 迭代 240000/300000, 损失 = 0.0144, rank_scale = 84.4330
# 迭代 241000/300000, 损失 = 0.0144, rank_scale = 84.6314
# 迭代 242000/300000, 损失 = 0.0144, rank_scale = 84.8298
# 迭代 243000/300000, 损失 = 0.0144, rank_scale = 85.0281
# 迭代 244000/300000, 损失 = 0.0144, rank_scale = 85.2265
# 迭代 245000/300000, 损失 = 0.0144, rank_scale = 85.4249
# 迭代 246000/300000, 损失 = 0.0144, rank_scale = 85.6232
# 迭代 247000/300000, 损失 = 0.0144, rank_scale = 85.8216
# 迭代 248000/300000, 损失 = 0.0144, rank_scale = 86.0143
# 迭代 249000/300000, 损失 = 0.0144, rank_scale = 86.2050
# 迭代 250000/300000, 损失 = 0.0144, rank_scale = 86.3957
# 迭代 251000/300000, 损失 = 0.0143, rank_scale = 86.5865
# 迭代 252000/300000, 损失 = 0.0143, rank_scale = 86.7772
# 迭代 253000/300000, 损失 = 0.0143, rank_scale = 86.9679
# 迭代 254000/300000, 损失 = 0.0143, rank_scale = 87.1587
# 迭代 255000/300000, 损失 = 0.0143, rank_scale = 87.3494
# 迭代 256000/300000, 损失 = 0.0143, rank_scale = 87.5366
# 迭代 257000/300000, 损失 = 0.0143, rank_scale = 87.7197
# 迭代 258000/300000, 损失 = 0.0143, rank_scale = 87.9028
# 迭代 259000/300000, 损失 = 0.0143, rank_scale = 88.0859
# 迭代 260000/300000, 损失 = 0.0143, rank_scale = 88.2690
# 迭代 261000/300000, 损失 = 0.0143, rank_scale = 88.4521
# 迭代 262000/300000, 损失 = 0.0143, rank_scale = 88.6352
# 迭代 263000/300000, 损失 = 0.0143, rank_scale = 88.8183
# 迭代 264000/300000, 损失 = 0.0143, rank_scale = 89.0014
# 迭代 265000/300000, 损失 = 0.0143, rank_scale = 89.1799
# 迭代 266000/300000, 损失 = 0.0142, rank_scale = 89.3554
# 迭代 267000/300000, 损失 = 0.0142, rank_scale = 89.5309
# 迭代 268000/300000, 损失 = 0.0142, rank_scale = 89.7063
# 迭代 269000/300000, 损失 = 0.0142, rank_scale = 89.8818
# 迭代 270000/300000, 损失 = 0.0142, rank_scale = 90.0573
# 迭代 271000/300000, 损失 = 0.0142, rank_scale = 90.2328
# 迭代 272000/300000, 损失 = 0.0142, rank_scale = 90.4082
# 迭代 273000/300000, 损失 = 0.0142, rank_scale = 90.5837
# 迭代 274000/300000, 损失 = 0.0142, rank_scale = 90.7583
# 迭代 275000/300000, 损失 = 0.0142, rank_scale = 90.9262
# 迭代 276000/300000, 损失 = 0.0142, rank_scale = 91.0940
# 迭代 277000/300000, 损失 = 0.0142, rank_scale = 91.2619
# 迭代 278000/300000, 损失 = 0.0142, rank_scale = 91.4297
# 迭代 279000/300000, 损失 = 0.0142, rank_scale = 91.5976
# 迭代 280000/300000, 损失 = 0.0142, rank_scale = 91.7654
# 迭代 281000/300000, 损失 = 0.0142, rank_scale = 91.9333
# 迭代 282000/300000, 损失 = 0.0142, rank_scale = 92.1011
# 迭代 283000/300000, 损失 = 0.0141, rank_scale = 92.2690
# 迭代 284000/300000, 损失 = 0.0141, rank_scale = 92.4368
# 迭代 285000/300000, 损失 = 0.0141, rank_scale = 92.5993
# 迭代 286000/300000, 损失 = 0.0141, rank_scale = 92.7595
# 迭代 287000/300000, 损失 = 0.0141, rank_scale = 92.9197
# 迭代 288000/300000, 损失 = 0.0141, rank_scale = 93.0799
# 迭代 289000/300000, 损失 = 0.0141, rank_scale = 93.2402
# 迭代 290000/300000, 损失 = 0.0141, rank_scale = 93.4004
# 迭代 291000/300000, 损失 = 0.0141, rank_scale = 93.5606
# 迭代 292000/300000, 损失 = 0.0141, rank_scale = 93.7208
# 迭代 293000/300000, 损失 = 0.0141, rank_scale = 93.8810
# 迭代 294000/300000, 损失 = 0.0141, rank_scale = 94.0412
# 迭代 295000/300000, 损失 = 0.0141, rank_scale = 94.1991
# 迭代 296000/300000, 损失 = 0.0141, rank_scale = 94.3517
# 迭代 297000/300000, 损失 = 0.0141, rank_scale = 94.5043
# 迭代 298000/300000, 损失 = 0.0141, rank_scale = 94.6569
# 迭代 299000/300000, 损失 = 0.0141, rank_scale = 94.8094
# 迭代 300000/300000, 损失 = 0.0141, rank_scale = 94.9620
#
# 随机搜索: {'lambda_defense': 0.021616722433639893, 'lambda_supervision': 0.18323522915498705, 'lambda_reg': 0.013022300234864177}
# 迭代 1000/300000, 损失 = 0.0943, rank_scale = 1.4109
# 迭代 2000/300000, 损失 = 0.0833, rank_scale = 1.7354
# 迭代 3000/300000, 损失 = 0.0783, rank_scale = 2.0345
# 迭代 4000/300000, 损失 = 0.0754, rank_scale = 2.3302
# 迭代 5000/300000, 损失 = 0.0735, rank_scale = 2.6327
# 迭代 6000/300000, 损失 = 0.0721, rank_scale = 2.9463
# 迭代 7000/300000, 损失 = 0.0709, rank_scale = 3.2723
# 迭代 8000/300000, 损失 = 0.0700, rank_scale = 3.6111
# 迭代 9000/300000, 损失 = 0.0692, rank_scale = 3.9618
# 迭代 10000/300000, 损失 = 0.0685, rank_scale = 4.3236
# 迭代 11000/300000, 损失 = 0.0679, rank_scale = 4.6952
# 迭代 12000/300000, 损失 = 0.0674, rank_scale = 5.0758
# 迭代 13000/300000, 损失 = 0.0670, rank_scale = 5.4645
# 迭代 14000/300000, 损失 = 0.0666, rank_scale = 5.8600
# 迭代 15000/300000, 损失 = 0.0662, rank_scale = 6.2616
# 迭代 16000/300000, 损失 = 0.0659, rank_scale = 6.6685
# 迭代 17000/300000, 损失 = 0.0657, rank_scale = 7.0802
# 迭代 18000/300000, 损失 = 0.0654, rank_scale = 7.4961
# 迭代 19000/300000, 损失 = 0.0652, rank_scale = 7.9158
# 迭代 20000/300000, 损失 = 0.0650, rank_scale = 8.3388
# 迭代 21000/300000, 损失 = 0.0648, rank_scale = 8.7650
# 迭代 22000/300000, 损失 = 0.0646, rank_scale = 9.1941
# 迭代 23000/300000, 损失 = 0.0645, rank_scale = 9.6260
# 迭代 24000/300000, 损失 = 0.0643, rank_scale = 10.0608
# 迭代 25000/300000, 损失 = 0.0642, rank_scale = 10.4990
# 迭代 26000/300000, 损失 = 0.0640, rank_scale = 10.9409
# 迭代 27000/300000, 损失 = 0.0639, rank_scale = 11.3856
# 迭代 28000/300000, 损失 = 0.0637, rank_scale = 11.8321
# 迭代 29000/300000, 损失 = 0.0636, rank_scale = 12.2799
# 迭代 30000/300000, 损失 = 0.0634, rank_scale = 12.7285
# 迭代 31000/300000, 损失 = 0.0633, rank_scale = 13.1777
# 迭代 32000/300000, 损失 = 0.0632, rank_scale = 13.6278
# 迭代 33000/300000, 损失 = 0.0630, rank_scale = 14.0779
# 迭代 34000/300000, 损失 = 0.0629, rank_scale = 14.5289
# 迭代 35000/300000, 损失 = 0.0627, rank_scale = 14.9800
# 迭代 36000/300000, 损失 = 0.0626, rank_scale = 15.4311
# 迭代 37000/300000, 损失 = 0.0625, rank_scale = 15.8826
# 迭代 38000/300000, 损失 = 0.0623, rank_scale = 16.3346
# 迭代 39000/300000, 损失 = 0.0622, rank_scale = 16.7867
# 迭代 40000/300000, 损失 = 0.0621, rank_scale = 17.2387
# 迭代 41000/300000, 损失 = 0.0620, rank_scale = 17.6908
# 迭代 42000/300000, 损失 = 0.0618, rank_scale = 18.1428
# 迭代 43000/300000, 损失 = 0.0617, rank_scale = 18.5948
# 迭代 44000/300000, 损失 = 0.0616, rank_scale = 19.0469
# 迭代 45000/300000, 损失 = 0.0615, rank_scale = 19.4989
# 迭代 46000/300000, 损失 = 0.0614, rank_scale = 19.9510
# 迭代 47000/300000, 损失 = 0.0613, rank_scale = 20.4022
# 迭代 48000/300000, 损失 = 0.0612, rank_scale = 20.8523
# 迭代 49000/300000, 损失 = 0.0611, rank_scale = 21.3025
# 迭代 50000/300000, 损失 = 0.0610, rank_scale = 21.7526
# 迭代 51000/300000, 损失 = 0.0609, rank_scale = 22.2027
# 迭代 52000/300000, 损失 = 0.0608, rank_scale = 22.6529
# 迭代 53000/300000, 损失 = 0.0607, rank_scale = 23.1015
# 迭代 54000/300000, 损失 = 0.0606, rank_scale = 23.5497
# 迭代 55000/300000, 损失 = 0.0605, rank_scale = 23.9979
# 迭代 56000/300000, 损失 = 0.0605, rank_scale = 24.4461
# 迭代 57000/300000, 损失 = 0.0604, rank_scale = 24.8932
# 迭代 58000/300000, 损失 = 0.0603, rank_scale = 25.3395
# 迭代 59000/300000, 损失 = 0.0602, rank_scale = 25.7858
# 迭代 60000/300000, 损失 = 0.0602, rank_scale = 26.2319
# 迭代 61000/300000, 损失 = 0.0601, rank_scale = 26.6763
# 迭代 62000/300000, 损失 = 0.0600, rank_scale = 27.1208
# 迭代 63000/300000, 损失 = 0.0599, rank_scale = 27.5649
# 迭代 64000/300000, 损失 = 0.0599, rank_scale = 28.0074
# 迭代 65000/300000, 损失 = 0.0598, rank_scale = 28.4499
# 迭代 66000/300000, 损失 = 0.0598, rank_scale = 28.8914
# 迭代 67000/300000, 损失 = 0.0597, rank_scale = 29.3320
# 迭代 68000/300000, 损失 = 0.0596, rank_scale = 29.7724
# 迭代 69000/300000, 损失 = 0.0596, rank_scale = 30.2111
# 迭代 70000/300000, 损失 = 0.0595, rank_scale = 30.6498
# 迭代 71000/300000, 损失 = 0.0594, rank_scale = 31.0868
# 迭代 72000/300000, 损失 = 0.0594, rank_scale = 31.5236
# 迭代 73000/300000, 损失 = 0.0593, rank_scale = 31.9588
# 迭代 74000/300000, 损失 = 0.0593, rank_scale = 32.3937
# 迭代 75000/300000, 损失 = 0.0592, rank_scale = 32.8286
# 迭代 76000/300000, 损失 = 0.0592, rank_scale = 33.2603
# 迭代 77000/300000, 损失 = 0.0591, rank_scale = 33.6913
# 迭代 78000/300000, 损失 = 0.0591, rank_scale = 34.1224
# 迭代 79000/300000, 损失 = 0.0590, rank_scale = 34.5527
# 迭代 80000/300000, 损失 = 0.0590, rank_scale = 34.9799
# 迭代 81000/300000, 损失 = 0.0589, rank_scale = 35.4072
# 迭代 82000/300000, 损失 = 0.0589, rank_scale = 35.8344
# 迭代 83000/300000, 损失 = 0.0588, rank_scale = 36.2585
# 迭代 84000/300000, 损失 = 0.0588, rank_scale = 36.6819
# 迭代 85000/300000, 损失 = 0.0588, rank_scale = 37.1053
# 迭代 86000/300000, 损失 = 0.0587, rank_scale = 37.5263
# 迭代 87000/300000, 损失 = 0.0587, rank_scale = 37.9459
# 迭代 88000/300000, 损失 = 0.0586, rank_scale = 38.3655
# 迭代 89000/300000, 损失 = 0.0586, rank_scale = 38.7829
# 迭代 90000/300000, 损失 = 0.0585, rank_scale = 39.1987
# 迭代 91000/300000, 损失 = 0.0585, rank_scale = 39.6145
# 迭代 92000/300000, 损失 = 0.0585, rank_scale = 40.0276
# 迭代 93000/300000, 损失 = 0.0584, rank_scale = 40.4395
# 迭代 94000/300000, 损失 = 0.0584, rank_scale = 40.8515
# 迭代 95000/300000, 损失 = 0.0583, rank_scale = 41.2601
# 迭代 96000/300000, 损失 = 0.0583, rank_scale = 41.6682
# 迭代 97000/300000, 损失 = 0.0583, rank_scale = 42.0758
# 迭代 98000/300000, 损失 = 0.0582, rank_scale = 42.4801
# 迭代 99000/300000, 损失 = 0.0582, rank_scale = 42.8845
# 迭代 100000/300000, 损失 = 0.0582, rank_scale = 43.2868
# 迭代 101000/300000, 损失 = 0.0581, rank_scale = 43.6874
# 迭代 102000/300000, 损失 = 0.0581, rank_scale = 44.0879
# 迭代 103000/300000, 损失 = 0.0581, rank_scale = 44.4849
# 迭代 104000/300000, 损失 = 0.0580, rank_scale = 44.8817
# 迭代 105000/300000, 损失 = 0.0580, rank_scale = 45.2769
# 迭代 106000/300000, 损失 = 0.0580, rank_scale = 45.6698
# 迭代 107000/300000, 损失 = 0.0579, rank_scale = 46.0627
# 迭代 108000/300000, 损失 = 0.0579, rank_scale = 46.4521
# 迭代 109000/300000, 损失 = 0.0579, rank_scale = 46.8412
# 迭代 110000/300000, 损失 = 0.0579, rank_scale = 47.2285
# 迭代 111000/300000, 损失 = 0.0578, rank_scale = 47.6138
# 迭代 112000/300000, 损失 = 0.0578, rank_scale = 47.9989
# 迭代 113000/300000, 损失 = 0.0578, rank_scale = 48.3803
# 迭代 114000/300000, 损失 = 0.0577, rank_scale = 48.7618
# 迭代 115000/300000, 损失 = 0.0577, rank_scale = 49.1408
# 迭代 116000/300000, 损失 = 0.0577, rank_scale = 49.5184
# 迭代 117000/300000, 损失 = 0.0577, rank_scale = 49.8950
# 迭代 118000/300000, 损失 = 0.0576, rank_scale = 50.2688
# 迭代 119000/300000, 损失 = 0.0576, rank_scale = 50.6427
# 迭代 120000/300000, 损失 = 0.0576, rank_scale = 51.0130
# 迭代 121000/300000, 损失 = 0.0576, rank_scale = 51.3830
# 迭代 122000/300000, 损失 = 0.0575, rank_scale = 51.7507
# 迭代 123000/300000, 损失 = 0.0575, rank_scale = 52.1169
# 迭代 124000/300000, 损失 = 0.0575, rank_scale = 52.4820
# 迭代 125000/300000, 损失 = 0.0575, rank_scale = 52.8444
# 迭代 126000/300000, 损失 = 0.0574, rank_scale = 53.2068
# 迭代 127000/300000, 损失 = 0.0574, rank_scale = 53.5654
# 迭代 128000/300000, 损失 = 0.0574, rank_scale = 53.9240
# 迭代 129000/300000, 损失 = 0.0574, rank_scale = 54.2800
# 迭代 130000/300000, 损失 = 0.0574, rank_scale = 54.6348
# 迭代 131000/300000, 损失 = 0.0573, rank_scale = 54.9880
# 迭代 132000/300000, 损失 = 0.0573, rank_scale = 55.3389
# 迭代 133000/300000, 损失 = 0.0573, rank_scale = 55.6895
# 迭代 134000/300000, 损失 = 0.0573, rank_scale = 56.0367
# 迭代 135000/300000, 损失 = 0.0572, rank_scale = 56.3838
# 迭代 136000/300000, 损失 = 0.0572, rank_scale = 56.7278
# 迭代 137000/300000, 损失 = 0.0572, rank_scale = 57.0712
# 迭代 138000/300000, 损失 = 0.0572, rank_scale = 57.4125
# 迭代 139000/300000, 损失 = 0.0572, rank_scale = 57.7520
# 迭代 140000/300000, 损失 = 0.0571, rank_scale = 58.0906
# ...
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 serie-b 图 -> /Users/peixuanma/Downloads/Output_Graphs/serie-b_evolution.png
# 保存 2-bundesliga 图 -> /Users/peixuanma/Downloads/Output_Graphs/2-bundesliga_evolution.png
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 premiership 图 -> /Users/peixuanma/Downloads/Output_Graphs/premiership_evolution.png
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:465: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/135672598.py:467: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 pro-league 图 -> /Users/peixuanma/Downloads/Output_Graphs/pro-league_evolution.png
#
# 完成！

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix
from scipy.stats import uniform
import sklearn

print(f"scikit-learn 版本: {sklearn.__version__}")

# ====================== 计算防守统计数据 ======================
def compute_defensive_stats(match_df, team_positions_df):
    """计算球队的防守统计数据，包括6种比率、总失球数和平均失球数"""
    epsilon = 1e-8  # 提高数值稳定性
    team_stats = {}
    for team in team_positions_df['team_name'].unique():
        team_stats[team] = {
            'total_goals_conceded': 0, 'ratio1_list': [], 'ratio2_list': [], 'ratio3_list': [],
            'ratio4_list': [], 'ratio5_list': [], 'ratio6_list': [], 'num_matches': 0
        }

    # 主场比赛统计
    for idx, row in match_df.iterrows():
        home_team, away_team = row['home_team_name'], row['away_team_name']
        if home_team not in team_stats or away_team not in team_stats:
            print(f"警告: 主队 {home_team} 或客队 {away_team} 未找到，跳过比赛 {idx}")
            continue
        if row['Pre-Match PPG (Away)'] > 0:
            team_stats[home_team]['ratio1_list'].append(
                row['away_team_goal_count'] / (row['Pre-Match PPG (Away)'] + epsilon))
        if row['away_team_corner_count'] > 0:
            team_stats[home_team]['ratio2_list'].append(
                row['away_team_goal_count'] / (row['away_team_corner_count'] + epsilon))
        denominator = row['home_team_yellow_cards'] + row['home_team_red_cards'] + row['home_team_fouls'] + epsilon
        team_stats[home_team]['ratio3_list'].append(row['away_team_goal_count'] / denominator)
        if row['team_b_xg'] > 0:
            team_stats[home_team]['ratio4_list'].append(row['away_team_goal_count'] / (row['team_b_xg'] + epsilon))
        shots_total = row['away_team_shots_on_target'] + row['away_team_shots_off_target'] + epsilon
        team_stats[home_team]['ratio5_list'].append(row['away_team_goal_count'] / shots_total)
        if row['away_team_possession'] > 0:
            team_stats[home_team]['ratio6_list'].append(
                row['away_team_goal_count'] / (row['away_team_possession'] + epsilon))
        team_stats[home_team]['total_goals_conceded'] += row['away_team_goal_count']
        team_stats[home_team]['num_matches'] += 1  # 记录主场比赛场次

    # 客场比赛统计
    for idx, row in match_df.iterrows():
        away_team = row['away_team_name']
        if away_team not in team_stats:
            print(f"警告: 客队 {away_team} 未找到，跳过比赛 {idx}")
            continue
        team_stats[away_team]['total_goals_conceded'] += row['home_team_goal_count']
        team_stats[away_team]['num_matches'] += 1  # 记录客场比赛场次

    # 汇总数据
    data = []
    for team, stats in team_stats.items():
        num_matches = stats['num_matches']
        average_goals_conceded = stats['total_goals_conceded'] / num_matches if num_matches > 0 else 0
        data.append({
            'team_name': team,
            'ratio1': np.mean(stats['ratio1_list']) if stats['ratio1_list'] else 0,
            'ratio2': np.mean(stats['ratio2_list']) if stats['ratio2_list'] else 0,
            'ratio3': np.mean(stats['ratio3_list']) if stats['ratio3_list'] else 0,
            'ratio4': np.mean(stats['ratio4_list']) if stats['ratio4_list'] else 0,
            'ratio5': np.mean(stats['ratio5_list']) if stats['ratio5_list'] else 0,
            'ratio6': np.mean(stats['ratio6_list']) if stats['ratio6_list'] else 0,
            'total_goals_conceded': stats['total_goals_conceded'],
            'average_goals_conceded': average_goals_conceded
        })

    return pd.DataFrame(data)

# ====================== ELO评分算法实现 ======================
def initialize_elo_scores(team_positions_df):
    """初始化球队ELO分数"""
    teams = team_positions_df['team_name'].unique().tolist()
    team_elo = {team: 1500 for team in teams}
    for team in teams:
        team_data = team_positions_df[team_positions_df['team_name'] == team]
        rank = team_data['points_per_game'].rank().iloc[0]
        team_elo[team] += (20 * (len(teams) - rank))
    return team_elo

def update_elo_scores(elo_scores, home_team, away_team, home_score, away_score, K=30):
    """更新ELO分数"""
    home_elo, away_elo = elo_scores[home_team], elo_scores[away_team]
    expected_home = 1 / (1 + 10 ** ((away_elo - home_elo) / 400))
    expected_away = 1 / (1 + 10 ** ((home_elo - away_elo) / 400))

    if home_score > away_score:
        elo_scores[home_team] += K * (1 - expected_home)
        elo_scores[away_team] += K * (0 - expected_away)
    elif home_score < away_score:
        elo_scores[home_team] += K * (0 - expected_home)
        elo_scores[away_team] += K * (1 - expected_away)
    else:
        elo_scores[home_team] += K * (0.5 - expected_home)
        elo_scores[away_team] += K * (0.5 - expected_away)
    return elo_scores

# ====================== 数据加载函数（含交叉验证） ======================
def load_all_league_data(base_path, leagues, seasons):
    """加载所有联赛数据并进行预处理"""
    all_team_positions, all_match_positions = [], []
    for country_name, league_name in leagues:
        for season in seasons:
            print(f"加载数据: {country_name} - {league_name} - {season}")
            team_file = os.path.join(base_path, f"{country_name}-{league_name}-teams-{season}-stats.csv")
            match_file = os.path.join(base_path, f"{country_name}-{league_name}-matches-{season}-stats.csv")
            if not os.path.exists(team_file) or not os.path.exists(match_file):
                print(f"警告: {country_name} - {league_name} - {season} 文件缺失")
                continue

            team_df = pd.read_csv(team_file)
            match_df = pd.read_csv(match_file)

            # 统一球队名称格式
            team_df['team_name'] = team_df.get('common_name', team_df.get('team_name', None)).str.strip().str.lower()
            match_df['home_team_name'] = match_df['home_team_name'].str.strip().str.lower()
            match_df['away_team_name'] = match_df['away_team_name'].str.strip().str.lower()

            team_names = team_df['team_name'].unique()
            original_match_count = len(match_df)
            match_df = match_df[
                match_df['home_team_name'].isin(team_names) & match_df['away_team_name'].isin(team_names)]
            if len(match_df) < original_match_count:
                print(f"警告: 过滤了 {original_match_count - len(match_df)} 场比赛")

            if match_df.empty:
                print("警告: 无有效比赛数据")
                continue

            defensive_stats_df = compute_defensive_stats(match_df, team_df)
            if defensive_stats_df.empty:
                print("警告: 未计算出防守统计")
                continue

            team_df = team_df.merge(defensive_stats_df, on='team_name', how='left')
            for col in ['ratio1', 'ratio2', 'ratio3', 'ratio4', 'ratio5', 'ratio6', 'total_goals_conceded', 'average_goals_conceded']:
                if col not in team_df.columns:
                    print(f"警告: {col} 列缺失，设为0")
                    team_df[col] = 0

            # 归一化防守得分
            if 'total_goals_conceded' in team_df.columns and team_df['total_goals_conceded'].max() != team_df[
                'total_goals_conceded'].min():
                team_df['normalized_defense_score'] = (team_df['total_goals_conceded'].max() - team_df[
                    'total_goals_conceded']) / (team_df['total_goals_conceded'].max() - team_df[
                    'total_goals_conceded'].min() + 1e-8)
            else:
                team_df['normalized_defense_score'] = 0

            # PCA降维（防守数据）
            defensive_columns = [col for col in team_df.columns if col in [
                'goals_conceded', 'total_goals_conceded', 'ratio1', 'ratio2', 'ratio3', 'ratio4', 'ratio5', 'ratio6',
                'normalized_defense_score'
            ]]
            team_df_defensive = team_df[defensive_columns].fillna(0)
            kf = KFold(n_splits=5, shuffle=True, random_state=42)
            pca_results = []
            for train_idx, _ in kf.split(team_df_defensive):
                train_data = team_df_defensive.iloc[train_idx]
                scaler = StandardScaler()
                X_scaled = scaler.fit_transform(train_data)
                pca = PCA(n_components=2)
                X_pca = pca.fit_transform(X_scaled)
                pca_results.append(X_pca)
            X_pca_avg = np.mean(
                [np.pad(r, ((0, len(team_df_defensive) - len(r)), (0, 0)), 'constant') for r in pca_results], axis=0)

            team_positions = pd.DataFrame({
                'team_name': team_df['team_name'], 'PC1': X_pca_avg[:, 0], 'PC2': X_pca_avg[:, 1],
                'points_per_game': team_df['points_per_game'], 'league': league_name, 'season': season,
                'ratio1': team_df['ratio1'], 'ratio2': team_df['ratio2'], 'ratio3': team_df['ratio3'],
                'ratio4': team_df['ratio4'], 'ratio5': team_df['ratio5'], 'ratio6': team_df['ratio6'],
                'normalized_defense_score': team_df['normalized_defense_score'],
                'total_goals_conceded': team_df['total_goals_conceded'],
                'average_goals_conceded': team_df['average_goals_conceded']
            })
            team_positions['team_season'] = league_name + '_' + team_positions['team_name'] + '_' + team_positions[
                'season']
            all_team_positions.append(team_positions)

            # 比赛数据PCA
            match_df = match_df.drop(
                columns=['timestamp', 'date_GMT', 'status', 'attendance', 'referee', 'stadium_name', 'Game Week'],
                errors='ignore')
            numeric_cols = match_df.select_dtypes(include=[np.number]).columns
            match_df[numeric_cols] = match_df[numeric_cols].fillna(match_df[numeric_cols].mean())
            pca_match_results = []
            for train_idx, _ in kf.split(match_df[numeric_cols]):
                train_data = match_df[numeric_cols].iloc[train_idx]
                scaler = StandardScaler()
                X_scaled = scaler.fit_transform(train_data)
                pca = PCA(n_components=2)
                X_pca = pca.fit_transform(X_scaled)
                pca_match_results.append(X_pca)
            X_pca_match_avg = np.mean(
                [np.pad(r, ((0, len(match_df) - len(r)), (0, 0)), 'constant') for r in pca_match_results], axis=0)

            match_positions = pd.DataFrame({
                'home_team_name': match_df['home_team_name'], 'away_team_name': match_df['away_team_name'],
                'PC1': X_pca_match_avg[:, 0], 'PC2': X_pca_match_avg[:, 1], 'league': league_name, 'season': season
            })
            all_match_positions.append(match_positions)

    return pd.concat(all_team_positions, ignore_index=True), pd.concat(all_match_positions, ignore_index=True)

# ====================== 损失函数 ======================
def compute_total_loss(positions, match_home_idx, match_away_idx, match_PC1, match_PC2, points_per_game, rank_scale,
                       ratios, w, normalized_defense_score, lambda_defense, lambda_supervision, lambda_reg, elo_scores):
    """计算总损失，包括匹配损失、防守损失和监督损失"""
    epsilon = 1e-8
    if tf.shape(match_home_idx)[0] == 0:
        return tf.constant(0.0, dtype=tf.float32)

    # 匹配损失
    home_pos = tf.gather(positions, match_home_idx)
    away_pos = tf.gather(positions, match_away_idx)
    match_points = tf.stack([match_PC1, match_PC2], axis=1)
    dist_home = tf.norm(home_pos - match_points + epsilon, axis=1)
    dist_away = tf.norm(away_pos - match_points + epsilon, axis=1)
    all_distances = tf.concat([dist_home, dist_away], axis=0)
    dist_range = tf.reduce_max(all_distances) - tf.reduce_min(all_distances) + epsilon
    dist_home_norm = (dist_home - tf.reduce_min(all_distances)) / dist_range
    dist_away_norm = (dist_away - tf.reduce_min(all_distances)) / dist_range

    home_elo = tf.gather(elo_scores, match_home_idx)
    away_elo = tf.gather(elo_scores, match_away_idx)
    elo_diff = tf.abs(home_elo - away_elo)
    weight = 1.0 / (1.0 + elo_diff * rank_scale + epsilon)
    match_loss = tf.reduce_mean(weight * (dist_home_norm + dist_away_norm))

    # 防守损失
    w = tf.abs(w)  # 确保权重非负
    defense_target = -tf.reduce_sum(w * ratios, axis=1)
    defense_loss = tf.reduce_mean(tf.square(positions[:, 1] - defense_target))

    # 监督损失
    supervision_loss = tf.reduce_mean(tf.square(defense_target - normalized_defense_score))

    # 正则化
    regularization_loss = lambda_reg * tf.reduce_sum(tf.square(w))

    total_loss = match_loss + lambda_defense * defense_loss + lambda_supervision * supervision_loss + regularization_loss
    return tf.where(tf.math.is_nan(total_loss) | tf.math.is_inf(total_loss), 0.0, total_loss)

# ====================== Adam优化函数 ======================
def adam_optimize_positions(team_positions_df, match_positions_df, initial_lr=0.0005, decay_steps=200000,
                            decay_rate=0.9,
                            clipnorm=0.5, iterations=30000, verbose_interval=1000, random_seed=42, lambda_defense=0.1,
                            lambda_supervision=0.1, lambda_reg=0.01, patience=100, w=None):
    """使用Adam优化球队位置"""
    team_seasons = team_positions_df['team_season'].unique()
    team_season_to_idx = {t: i for i, t in enumerate(team_seasons)}

    elo_scores_dict = initialize_elo_scores(team_positions_df)
    team_names = [t.split('_')[1] for t in team_seasons]
    elo_scores = tf.convert_to_tensor([elo_scores_dict[name] for name in team_names], dtype=tf.float32)

    team_positions_df = team_positions_df.set_index('team_season')
    init_positions = team_positions_df[['PC1', 'PC2']].values
    ratios = team_positions_df[['ratio1', 'ratio2', 'ratio3', 'ratio4', 'ratio5', 'ratio6', 'total_goals_conceded', 'average_goals_conceded']].values
    scaler_pos = StandardScaler()
    scaler_rat = StandardScaler()
    positions_scaled = scaler_pos.fit_transform(init_positions)
    ratios_scaled = scaler_rat.fit_transform(ratios)

    positions = tf.Variable(positions_scaled, dtype=tf.float32)
    ratios = tf.constant(ratios_scaled, dtype=tf.float32)
    normalized_defense_score = tf.constant(team_positions_df['normalized_defense_score'].values, dtype=tf.float32)
    points_per_game = tf.constant(team_positions_df['points_per_game'].values, dtype=tf.float32)

    match_array = [
        [team_season_to_idx[f"{row['league']}_{row['home_team_name']}_{row['season']}"],
         team_season_to_idx[f"{row['league']}_{row['away_team_name']}_{row['season']}"], row['PC1'], row['PC2']]
        for _, row in match_positions_df.iterrows()
        if f"{row['league']}_{row['home_team_name']}_{row['season']}" in team_season_to_idx and
           f"{row['league']}_{row['away_team_name']}_{row['season']}" in team_season_to_idx
    ]
    match_array = np.array(match_array, dtype=np.float32)
    if len(match_array) == 0:
        print("警告: 无有效比赛数据")
        return [], team_positions_df.reset_index(), None, None

    match_home_idx = tf.constant(match_array[:, 0], dtype=tf.int32)
    match_away_idx = tf.constant(match_array[:, 1], dtype=tf.int32)
    match_PC1 = tf.constant(match_array[:, 2], dtype=tf.float32)
    match_PC2 = tf.constant(match_array[:, 3], dtype=tf.float32)

    tf.random.set_seed(random_seed)
    rank_scale = tf.Variable(1.0, dtype=tf.float32)
    w = tf.Variable(np.abs(w) if w is not None else np.ones(8, dtype=np.float32) / 8, dtype=tf.float32)
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(initial_lr, decay_steps, decay_rate)
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule, clipnorm=clipnorm)

    losses, best_loss, patience_counter = [], float('inf'), 0
    best_positions, best_rank_scale, best_w = positions.numpy().copy(), 1.0, w.numpy().copy()

    for i in range(iterations):
        with tf.GradientTape() as tape:
            loss = compute_total_loss(positions, match_home_idx, match_away_idx, match_PC1, match_PC2, points_per_game,
                                      rank_scale, ratios, w, normalized_defense_score, lambda_defense,
                                      lambda_supervision, lambda_reg, elo_scores)
        grads = tape.gradient(loss, [positions, rank_scale, w])
        if any(g is None for g in grads):
            print(f"警告: 迭代 {i + 1} 梯度为None")
            continue
        optimizer.apply_gradients(zip(grads, [positions, rank_scale, w]))
        loss_val = float(loss.numpy())
        losses.append(loss_val)

        if loss_val < best_loss:
            best_loss = loss_val
            best_positions, best_rank_scale, best_w = positions.numpy().copy(), float(
                rank_scale.numpy()), w.numpy().copy()
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"早停触发，训练在第 {i + 1} 轮停止")
            break

        if (i + 1) % verbose_interval == 0:
            print(f"迭代 {i + 1}/{iterations}, 损失 = {loss_val:.4f}, rank_scale = {rank_scale.numpy():.4f}")

    positions.assign(best_positions)
    rank_scale.assign(best_rank_scale)
    w.assign(best_w)
    final_pos = scaler_pos.inverse_transform(positions.numpy())
    for idx, team_season in enumerate(team_seasons):
        team_positions_df.loc[team_season, 'PC1'] = final_pos[idx, 0]
        team_positions_df.loc[team_season, 'PC2'] = final_pos[idx, 1]
    team_positions_df = team_positions_df.reset_index()
    return losses, team_positions_df, best_rank_scale, best_w

# ====================== 随机搜索超参数调整 ======================
def random_search_hyperparameters(team_positions, match_positions, w, n_iter=10, random_state=42):
    """随机搜索最佳超参数"""
    np.random.seed(random_state)
    best_loss, best_params = float('inf'), None

    for _ in range(n_iter):
        params = {
            'lambda_defense': uniform(0.01, 0.2).rvs(),
            'lambda_supervision': uniform(0.01, 0.2).rvs(),
            'lambda_reg': uniform(0.001, 0.02).rvs()
        }
        print(f"\n随机搜索: {params}")

        losses, _, _, _ = adam_optimize_positions(
            team_positions.copy(), match_positions.copy(), w=w, **params
        )
        if losses and losses[-1] < best_loss:
            best_loss = losses[-1]
            best_params = params

    print(f"\n最佳超参数: {best_params}, 最佳损失: {best_loss:.4f}")
    return best_params

# ====================== 可视化函数 ======================
def visualize_team_evolution_by_league_static(team_positions_df, seasons_order):
    """按联赛可视化球队演变"""
    output_dir = "/Users/peixuanma/Downloads/Output_Graphs"
    os.makedirs(output_dir, exist_ok=True)

    for league in team_positions_df['league'].unique():
        league_df = team_positions_df[team_positions_df['league'] == league].copy()
        valid_teams = league_df.groupby("team_name").filter(lambda x: x['season'].nunique() == len(seasons_order))[
            'team_name'].unique()
        if not valid_teams.size:
            valid_teams = league_df['team_name'].unique()
        valid_df = league_df[league_df['team_name'].isin(valid_teams)].sort_values(['team_name', 'season'])

        plt.figure(figsize=(10, 8))
        plt.title(f"{league} - 球队演变 (进攻-防守)")
        plt.xlabel("PC1 (进攻)")
        plt.ylabel("PC2 (防守)")
        plt.grid(True)

        for team in valid_df['team_name'].unique():
            sub = valid_df[valid_df['team_name'] == team]
            plt.plot(sub['PC1'], sub['PC2'], marker='o', label=team)
            for _, row in sub.iterrows():
                plt.text(row['PC1'], row['PC2'], row['season'], fontsize=8, ha='right')

        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        plt.tight_layout()
        filename = os.path.join(output_dir, f"{league}_evolution.png")
        plt.savefig(filename, dpi=150)
        plt.close()
        print(f"保存 {league} 图 -> {filename}")

# ====================== 主函数 ======================
if __name__ == "__main__":
    base_path = '/Users/peixuanma/Downloads/data1'
    leagues = [
        ("england", "premier-league"), ("germany", "bundesliga"), ("spain", "la-liga"),
        ("france", "ligue-1"), ("france", "ligue-2"),("italy", "serie-a"), ("netherlands", "eredivisie"),
        ("portugal", "ligapro"), ("denmark", "superliga"), ("england", "championship"),("spain", "segunda-division"),("switzerland","super-league"),
        ("portugal", "liga-nos"), ("italy", "serie-b"), ("germany", "2-bundesliga"),("scotland","premiership"),("belgium","pro-league"),("austria","bundesliga"),
    ]
    seasons = [
        "2013-to-2014", "2014-to-2015", "2015-to-2016", "2016-to-2017", "2017-to-2018",
        "2018-to-2019", "2019-to-2020","2020-to-2021", "2021-to-2022", "2022-to-2023", "2023-to-2024"
    ]

    # 加载数据
    print("===== 加载数据 =====")
    all_team_positions, all_match_positions = load_all_league_data(base_path, leagues, seasons)

    # 人工输入权重
    print("\n===== 输入防守权重 =====")
    feature_names = ['ratio1', 'ratio2', 'ratio3', 'ratio4', 'ratio5', 'ratio6', 'total_goals_conceded', 'average_goals_conceded']
    weights = []
    for i, feature in enumerate(feature_names):
        weight = float(input(f"请输入第 {i+1} 个权重（对应特征: {feature}）: "))
        weights.append(weight)
    weights = np.array(weights, dtype=np.float32)
    weights /= np.sum(weights)  # 归一化权重
    print("输入的归一化权重:", weights)

    # 随机搜索超参数
    print("\n===== 随机搜索超参数 =====")
    best_params = random_search_hyperparameters(all_team_positions, all_match_positions, weights)

    # 最终训练
    print("\n===== 最终训练 =====")
    final_losses, final_team_positions, final_rank_scale, final_w = adam_optimize_positions(
        all_team_positions.copy(), all_match_positions.copy(), w=weights, **best_params
    )
    if final_losses:
        final_team_positions.to_csv("trained_team_positions.csv", index=False)
        print(f"最终损失: {final_losses[-1]:.4f}")

    # 可视化
    print("\n===== 可视化 =====")
    visualize_team_evolution_by_league_static(final_team_positions, seasons)

    print("\n完成！")
# Out:
# scikit-learn 版本: 1.4.2
# ===== 加载数据 =====
# 加载数据: england - premier-league - 2013-to-2014
# 加载数据: england - premier-league - 2014-to-2015
# 加载数据: england - premier-league - 2015-to-2016
# 加载数据: england - premier-league - 2016-to-2017
# 加载数据: england - premier-league - 2017-to-2018
# 加载数据: england - premier-league - 2018-to-2019
# 加载数据: england - premier-league - 2019-to-2020
# 加载数据: england - premier-league - 2020-to-2021
# 加载数据: england - premier-league - 2021-to-2022
# 加载数据: england - premier-league - 2022-to-2023
# 加载数据: england - premier-league - 2023-to-2024
# 加载数据: germany - bundesliga - 2013-to-2014
# 加载数据: germany - bundesliga - 2014-to-2015
# 加载数据: germany - bundesliga - 2015-to-2016
# 加载数据: germany - bundesliga - 2016-to-2017
# 加载数据: germany - bundesliga - 2017-to-2018
# 加载数据: germany - bundesliga - 2018-to-2019
# 加载数据: germany - bundesliga - 2019-to-2020
# 加载数据: germany - bundesliga - 2020-to-2021
# 加载数据: germany - bundesliga - 2021-to-2022
# 加载数据: germany - bundesliga - 2022-to-2023
# 加载数据: germany - bundesliga - 2023-to-2024
# 加载数据: spain - la-liga - 2013-to-2014
# 加载数据: spain - la-liga - 2014-to-2015
# 加载数据: spain - la-liga - 2015-to-2016
# 加载数据: spain - la-liga - 2016-to-2017
# 加载数据: spain - la-liga - 2017-to-2018
# 加载数据: spain - la-liga - 2018-to-2019
# 加载数据: spain - la-liga - 2019-to-2020
# 加载数据: spain - la-liga - 2020-to-2021
# 加载数据: spain - la-liga - 2021-to-2022
# 加载数据: spain - la-liga - 2022-to-2023
# 加载数据: spain - la-liga - 2023-to-2024
# 加载数据: france - ligue-1 - 2013-to-2014
# 加载数据: france - ligue-1 - 2014-to-2015
# 加载数据: france - ligue-1 - 2015-to-2016
# 加载数据: france - ligue-1 - 2016-to-2017
# 加载数据: france - ligue-1 - 2017-to-2018
# 加载数据: france - ligue-1 - 2018-to-2019
# 加载数据: france - ligue-1 - 2019-to-2020
# 警告: france - ligue-1 - 2019-to-2020 文件缺失
# 加载数据: france - ligue-1 - 2020-to-2021
# 加载数据: france - ligue-1 - 2021-to-2022
# 加载数据: france - ligue-1 - 2022-to-2023
# 加载数据: france - ligue-1 - 2023-to-2024
# 加载数据: france - ligue-2 - 2013-to-2014
# 加载数据: france - ligue-2 - 2014-to-2015
# 加载数据: france - ligue-2 - 2015-to-2016
# 加载数据: france - ligue-2 - 2016-to-2017
# 加载数据: france - ligue-2 - 2017-to-2018
# 加载数据: france - ligue-2 - 2018-to-2019
# 加载数据: france - ligue-2 - 2019-to-2020
# 警告: france - ligue-2 - 2019-to-2020 文件缺失
# 加载数据: france - ligue-2 - 2020-to-2021
# 加载数据: france - ligue-2 - 2021-to-2022
# 加载数据: france - ligue-2 - 2022-to-2023
# 加载数据: france - ligue-2 - 2023-to-2024
# 加载数据: italy - serie-a - 2013-to-2014
# 加载数据: italy - serie-a - 2014-to-2015
# 加载数据: italy - serie-a - 2015-to-2016
# 加载数据: italy - serie-a - 2016-to-2017
# 加载数据: italy - serie-a - 2017-to-2018
# 加载数据: italy - serie-a - 2018-to-2019
# 加载数据: italy - serie-a - 2019-to-2020
# 加载数据: italy - serie-a - 2020-to-2021
# 加载数据: italy - serie-a - 2021-to-2022
# 加载数据: italy - serie-a - 2022-to-2023
# 加载数据: italy - serie-a - 2023-to-2024
# 加载数据: netherlands - eredivisie - 2013-to-2014
# 加载数据: netherlands - eredivisie - 2014-to-2015
# 加载数据: netherlands - eredivisie - 2015-to-2016
# 加载数据: netherlands - eredivisie - 2016-to-2017
# 加载数据: netherlands - eredivisie - 2017-to-2018
# 加载数据: netherlands - eredivisie - 2018-to-2019
# 加载数据: netherlands - eredivisie - 2019-to-2020
# 加载数据: netherlands - eredivisie - 2020-to-2021
# 加载数据: netherlands - eredivisie - 2021-to-2022
# 加载数据: netherlands - eredivisie - 2022-to-2023
# 加载数据: netherlands - eredivisie - 2023-to-2024
# 加载数据: portugal - ligapro - 2013-to-2014
# 警告: portugal - ligapro - 2013-to-2014 文件缺失
# 加载数据: portugal - ligapro - 2014-to-2015
# 加载数据: portugal - ligapro - 2015-to-2016
# 加载数据: portugal - ligapro - 2016-to-2017
# 加载数据: portugal - ligapro - 2017-to-2018
# 加载数据: portugal - ligapro - 2018-to-2019
# 加载数据: portugal - ligapro - 2019-to-2020
# 加载数据: portugal - ligapro - 2020-to-2021
# 加载数据: portugal - ligapro - 2021-to-2022
# 加载数据: portugal - ligapro - 2022-to-2023
# 加载数据: portugal - ligapro - 2023-to-2024
# 加载数据: denmark - superliga - 2013-to-2014
# 加载数据: denmark - superliga - 2014-to-2015
# 加载数据: denmark - superliga - 2015-to-2016
# 加载数据: denmark - superliga - 2016-to-2017
# 加载数据: denmark - superliga - 2017-to-2018
# 加载数据: denmark - superliga - 2018-to-2019
# 加载数据: denmark - superliga - 2019-to-2020
# 加载数据: denmark - superliga - 2020-to-2021
# 加载数据: denmark - superliga - 2021-to-2022
# 加载数据: denmark - superliga - 2022-to-2023
# 加载数据: denmark - superliga - 2023-to-2024
# 加载数据: england - championship - 2013-to-2014
# 加载数据: england - championship - 2014-to-2015
# 加载数据: england - championship - 2015-to-2016
# 加载数据: england - championship - 2016-to-2017
# 加载数据: england - championship - 2017-to-2018
# 加载数据: england - championship - 2018-to-2019
# 加载数据: england - championship - 2019-to-2020
# 加载数据: england - championship - 2020-to-2021
# 加载数据: england - championship - 2021-to-2022
# 加载数据: england - championship - 2022-to-2023
# 加载数据: england - championship - 2023-to-2024
# 加载数据: spain - segunda-division - 2013-to-2014
# 加载数据: spain - segunda-division - 2014-to-2015
# 加载数据: spain - segunda-division - 2015-to-2016
# 加载数据: spain - segunda-division - 2016-to-2017
# 加载数据: spain - segunda-division - 2017-to-2018
# 加载数据: spain - segunda-division - 2018-to-2019
# 加载数据: spain - segunda-division - 2019-to-2020
# 加载数据: spain - segunda-division - 2020-to-2021
# 加载数据: spain - segunda-division - 2021-to-2022
# 加载数据: spain - segunda-division - 2022-to-2023
# 加载数据: spain - segunda-division - 2023-to-2024
# 加载数据: switzerland - super-league - 2013-to-2014
# 加载数据: switzerland - super-league - 2014-to-2015
# 加载数据: switzerland - super-league - 2015-to-2016
# 加载数据: switzerland - super-league - 2016-to-2017
# 加载数据: switzerland - super-league - 2017-to-2018
# 加载数据: switzerland - super-league - 2018-to-2019
# 加载数据: switzerland - super-league - 2019-to-2020
# 加载数据: switzerland - super-league - 2020-to-2021
# 加载数据: switzerland - super-league - 2021-to-2022
# 加载数据: switzerland - super-league - 2022-to-2023
# 加载数据: switzerland - super-league - 2023-to-2024
# 加载数据: portugal - liga-nos - 2013-to-2014
# 加载数据: portugal - liga-nos - 2014-to-2015
# 加载数据: portugal - liga-nos - 2015-to-2016
# 加载数据: portugal - liga-nos - 2016-to-2017
# 加载数据: portugal - liga-nos - 2017-to-2018
# 加载数据: portugal - liga-nos - 2018-to-2019
# 加载数据: portugal - liga-nos - 2019-to-2020
# 加载数据: portugal - liga-nos - 2020-to-2021
# 加载数据: portugal - liga-nos - 2021-to-2022
# 加载数据: portugal - liga-nos - 2022-to-2023
# 加载数据: portugal - liga-nos - 2023-to-2024
# 加载数据: italy - serie-b - 2013-to-2014
# 加载数据: italy - serie-b - 2014-to-2015
# 加载数据: italy - serie-b - 2015-to-2016
# 加载数据: italy - serie-b - 2016-to-2017
# 加载数据: italy - serie-b - 2017-to-2018
# 加载数据: italy - serie-b - 2018-to-2019
# 加载数据: italy - serie-b - 2019-to-2020
# 加载数据: italy - serie-b - 2020-to-2021
# 加载数据: italy - serie-b - 2021-to-2022
# 加载数据: italy - serie-b - 2022-to-2023
# 加载数据: italy - serie-b - 2023-to-2024
# 加载数据: germany - 2-bundesliga - 2013-to-2014
# 加载数据: germany - 2-bundesliga - 2014-to-2015
# 加载数据: germany - 2-bundesliga - 2015-to-2016
# 加载数据: germany - 2-bundesliga - 2016-to-2017
# 加载数据: germany - 2-bundesliga - 2017-to-2018
# 加载数据: germany - 2-bundesliga - 2018-to-2019
# 加载数据: germany - 2-bundesliga - 2019-to-2020
# 加载数据: germany - 2-bundesliga - 2020-to-2021
# 加载数据: germany - 2-bundesliga - 2021-to-2022
# 加载数据: germany - 2-bundesliga - 2022-to-2023
# 加载数据: germany - 2-bundesliga - 2023-to-2024
# 加载数据: scotland - premiership - 2013-to-2014
# 加载数据: scotland - premiership - 2014-to-2015
# 加载数据: scotland - premiership - 2015-to-2016
# 加载数据: scotland - premiership - 2016-to-2017
# 加载数据: scotland - premiership - 2017-to-2018
# 加载数据: scotland - premiership - 2018-to-2019
# 加载数据: scotland - premiership - 2019-to-2020
# 加载数据: scotland - premiership - 2020-to-2021
# 加载数据: scotland - premiership - 2021-to-2022
# 加载数据: scotland - premiership - 2022-to-2023
# 加载数据: scotland - premiership - 2023-to-2024
# 加载数据: belgium - pro-league - 2013-to-2014
# 警告: belgium - pro-league - 2013-to-2014 文件缺失
# 加载数据: belgium - pro-league - 2014-to-2015
# 警告: belgium - pro-league - 2014-to-2015 文件缺失
# 加载数据: belgium - pro-league - 2015-to-2016
# 加载数据: belgium - pro-league - 2016-to-2017
# 加载数据: belgium - pro-league - 2017-to-2018
# 加载数据: belgium - pro-league - 2018-to-2019
# 加载数据: belgium - pro-league - 2019-to-2020
# 加载数据: belgium - pro-league - 2020-to-2021
# 加载数据: belgium - pro-league - 2021-to-2022
# 加载数据: belgium - pro-league - 2022-to-2023
# 加载数据: belgium - pro-league - 2023-to-2024
# 加载数据: austria - bundesliga - 2013-to-2014
# 加载数据: austria - bundesliga - 2014-to-2015
# 加载数据: austria - bundesliga - 2015-to-2016
# 加载数据: austria - bundesliga - 2016-to-2017
# 加载数据: austria - bundesliga - 2017-to-2018
# 加载数据: austria - bundesliga - 2018-to-2019
# 加载数据: austria - bundesliga - 2019-to-2020
# 加载数据: austria - bundesliga - 2020-to-2021
# 加载数据: austria - bundesliga - 2021-to-2022
# 加载数据: austria - bundesliga - 2022-to-2023
# 加载数据: austria - bundesliga - 2023-to-2024
#
# ===== 输入防守权重 =====
# 输入的归一化权重: [0.12714323 0.11415731 0.04532705 0.23075414 0.03240472 0.14205644
#  0.13323908 0.17491804]
#
# ===== 随机搜索超参数 =====
#
# 随机搜索: {'lambda_defense': 0.0849080237694725, 'lambda_supervision': 0.20014286128198325, 'lambda_reg': 0.015639878836228104}
# 迭代 1000/300000, 损失 = 0.1270, rank_scale = 1.4106
# 迭代 2000/300000, 损失 = 0.1042, rank_scale = 1.7361
# 迭代 3000/300000, 损失 = 0.0917, rank_scale = 2.0364
# 迭代 4000/300000, 损失 = 0.0842, rank_scale = 2.3333
# 迭代 5000/300000, 损失 = 0.0795, rank_scale = 2.6366
# 迭代 6000/300000, 损失 = 0.0763, rank_scale = 2.9513
# 迭代 7000/300000, 损失 = 0.0741, rank_scale = 3.2789
# 迭代 8000/300000, 损失 = 0.0725, rank_scale = 3.6201
# 迭代 9000/300000, 损失 = 0.0714, rank_scale = 3.9744
# 迭代 10000/300000, 损失 = 0.0705, rank_scale = 4.3412
# 迭代 11000/300000, 损失 = 0.0698, rank_scale = 4.7205
# 迭代 12000/300000, 损失 = 0.0692, rank_scale = 5.1104
# 迭代 13000/300000, 损失 = 0.0687, rank_scale = 5.5085
# 迭代 14000/300000, 损失 = 0.0683, rank_scale = 5.9132
# 迭代 15000/300000, 损失 = 0.0680, rank_scale = 6.3232
# 迭代 16000/300000, 损失 = 0.0676, rank_scale = 6.7377
# 迭代 17000/300000, 损失 = 0.0672, rank_scale = 7.1561
# 迭代 18000/300000, 损失 = 0.0669, rank_scale = 7.5779
# 迭代 19000/300000, 损失 = 0.0666, rank_scale = 8.0027
# 迭代 20000/300000, 损失 = 0.0663, rank_scale = 8.4301
# 迭代 21000/300000, 损失 = 0.0660, rank_scale = 8.8599
# 迭代 22000/300000, 损失 = 0.0657, rank_scale = 9.2918
# 迭代 23000/300000, 损失 = 0.0655, rank_scale = 9.7256
# 迭代 24000/300000, 损失 = 0.0653, rank_scale = 10.1611
# 迭代 25000/300000, 损失 = 0.0650, rank_scale = 10.5983
# 迭代 26000/300000, 损失 = 0.0648, rank_scale = 11.0369
# 迭代 27000/300000, 损失 = 0.0646, rank_scale = 11.4769
# 迭代 28000/300000, 损失 = 0.0644, rank_scale = 11.9182
# 迭代 29000/300000, 损失 = 0.0642, rank_scale = 12.3606
# 迭代 30000/300000, 损失 = 0.0640, rank_scale = 12.8042
# 迭代 31000/300000, 损失 = 0.0639, rank_scale = 13.2488
# 迭代 32000/300000, 损失 = 0.0637, rank_scale = 13.6941
# 迭代 33000/300000, 损失 = 0.0635, rank_scale = 14.1405
# 迭代 34000/300000, 损失 = 0.0634, rank_scale = 14.5875
# 迭代 35000/300000, 损失 = 0.0632, rank_scale = 15.0349
# 迭代 36000/300000, 损失 = 0.0631, rank_scale = 15.4831
# 迭代 37000/300000, 损失 = 0.0629, rank_scale = 15.9316
# 迭代 38000/300000, 损失 = 0.0628, rank_scale = 16.3799
# 迭代 39000/300000, 损失 = 0.0627, rank_scale = 16.8301
# 迭代 40000/300000, 损失 = 0.0625, rank_scale = 17.2802
# 迭代 41000/300000, 损失 = 0.0624, rank_scale = 17.7303
# 迭代 42000/300000, 损失 = 0.0623, rank_scale = 18.1805
# 迭代 43000/300000, 损失 = 0.0622, rank_scale = 18.6306
# 迭代 44000/300000, 损失 = 0.0620, rank_scale = 19.0807
# 迭代 45000/300000, 损失 = 0.0619, rank_scale = 19.5309
# 迭代 46000/300000, 损失 = 0.0618, rank_scale = 19.9810
# 迭代 47000/300000, 损失 = 0.0617, rank_scale = 20.4312
# 迭代 48000/300000, 损失 = 0.0616, rank_scale = 20.8813
# 迭代 49000/300000, 损失 = 0.0615, rank_scale = 21.3314
# 迭代 50000/300000, 损失 = 0.0614, rank_scale = 21.7816
# 迭代 51000/300000, 损失 = 0.0613, rank_scale = 22.2317
# 迭代 52000/300000, 损失 = 0.0612, rank_scale = 22.6802
# 迭代 53000/300000, 损失 = 0.0611, rank_scale = 23.1285
# 迭代 54000/300000, 损失 = 0.0611, rank_scale = 23.5767
# 迭代 55000/300000, 损失 = 0.0610, rank_scale = 24.0249
# 迭代 56000/300000, 损失 = 0.0609, rank_scale = 24.4732
# 迭代 57000/300000, 损失 = 0.0608, rank_scale = 24.9199
# 迭代 58000/300000, 损失 = 0.0607, rank_scale = 25.3662
# 迭代 59000/300000, 损失 = 0.0607, rank_scale = 25.8126
# 迭代 60000/300000, 损失 = 0.0606, rank_scale = 26.2586
# 迭代 61000/300000, 损失 = 0.0605, rank_scale = 26.7030
# 迭代 62000/300000, 损失 = 0.0604, rank_scale = 27.1474
# 迭代 63000/300000, 损失 = 0.0604, rank_scale = 27.5914
# 迭代 64000/300000, 损失 = 0.0603, rank_scale = 28.0340
# 迭代 65000/300000, 损失 = 0.0602, rank_scale = 28.4765
# 迭代 66000/300000, 损失 = 0.0602, rank_scale = 28.9180
# 迭代 67000/300000, 损失 = 0.0601, rank_scale = 29.3586
# 迭代 68000/300000, 损失 = 0.0600, rank_scale = 29.7990
# 迭代 69000/300000, 损失 = 0.0600, rank_scale = 30.2377
# 迭代 70000/300000, 损失 = 0.0599, rank_scale = 30.6764
# 迭代 71000/300000, 损失 = 0.0599, rank_scale = 31.1134
# 迭代 72000/300000, 损失 = 0.0598, rank_scale = 31.5502
# 迭代 73000/300000, 损失 = 0.0597, rank_scale = 31.9855
# 迭代 74000/300000, 损失 = 0.0597, rank_scale = 32.4204
# 迭代 75000/300000, 损失 = 0.0596, rank_scale = 32.8553
# 迭代 76000/300000, 损失 = 0.0596, rank_scale = 33.2870
# 迭代 77000/300000, 损失 = 0.0595, rank_scale = 33.7180
# 迭代 78000/300000, 损失 = 0.0595, rank_scale = 34.1491
# 迭代 79000/300000, 损失 = 0.0594, rank_scale = 34.5794
# 迭代 80000/300000, 损失 = 0.0594, rank_scale = 35.0067
# 迭代 81000/300000, 损失 = 0.0593, rank_scale = 35.4339
# 迭代 82000/300000, 损失 = 0.0593, rank_scale = 35.8612
# 迭代 83000/300000, 损失 = 0.0592, rank_scale = 36.2854
# 迭代 84000/300000, 损失 = 0.0592, rank_scale = 36.7088
# 迭代 85000/300000, 损失 = 0.0591, rank_scale = 37.1322
# 迭代 86000/300000, 损失 = 0.0591, rank_scale = 37.5532
# 迭代 87000/300000, 损失 = 0.0591, rank_scale = 37.9729
# 迭代 88000/300000, 损失 = 0.0590, rank_scale = 38.3925
# 迭代 89000/300000, 损失 = 0.0590, rank_scale = 38.8098
# 迭代 90000/300000, 损失 = 0.0589, rank_scale = 39.2256
# 迭代 91000/300000, 损失 = 0.0589, rank_scale = 39.6414
# 迭代 92000/300000, 损失 = 0.0588, rank_scale = 40.0546
# 迭代 93000/300000, 损失 = 0.0588, rank_scale = 40.4666
# 迭代 94000/300000, 损失 = 0.0588, rank_scale = 40.8786
# 迭代 95000/300000, 损失 = 0.0587, rank_scale = 41.2872
# 迭代 96000/300000, 损失 = 0.0587, rank_scale = 41.6953
# 迭代 97000/300000, 损失 = 0.0587, rank_scale = 42.1029
# 迭代 98000/300000, 损失 = 0.0586, rank_scale = 42.5073
# 迭代 99000/300000, 损失 = 0.0586, rank_scale = 42.9117
# 迭代 100000/300000, 损失 = 0.0586, rank_scale = 43.3142
# 迭代 101000/300000, 损失 = 0.0585, rank_scale = 43.7147
# 迭代 102000/300000, 损失 = 0.0585, rank_scale = 44.1153
# 迭代 103000/300000, 损失 = 0.0585, rank_scale = 44.5124
# 迭代 104000/300000, 损失 = 0.0584, rank_scale = 44.9091
# 迭代 105000/300000, 损失 = 0.0584, rank_scale = 45.3044
# 迭代 106000/300000, 损失 = 0.0584, rank_scale = 45.6973
# 迭代 107000/300000, 损失 = 0.0583, rank_scale = 46.0902
# 迭代 108000/300000, 损失 = 0.0583, rank_scale = 46.4797
# 迭代 109000/300000, 损失 = 0.0583, rank_scale = 46.8688
# 迭代 110000/300000, 损失 = 0.0582, rank_scale = 47.2563
# 迭代 111000/300000, 损失 = 0.0582, rank_scale = 47.6416
# 迭代 112000/300000, 损失 = 0.0582, rank_scale = 48.0267
# 迭代 113000/300000, 损失 = 0.0581, rank_scale = 48.4082
# 迭代 114000/300000, 损失 = 0.0581, rank_scale = 48.7897
# 迭代 115000/300000, 损失 = 0.0581, rank_scale = 49.1688
# 迭代 116000/300000, 损失 = 0.0581, rank_scale = 49.5464
# 迭代 117000/300000, 损失 = 0.0580, rank_scale = 49.9231
# 迭代 118000/300000, 损失 = 0.0580, rank_scale = 50.2969
# 迭代 119000/300000, 损失 = 0.0580, rank_scale = 50.6707
# 迭代 120000/300000, 损失 = 0.0580, rank_scale = 51.0411
# 迭代 121000/300000, 损失 = 0.0579, rank_scale = 51.4111
# 迭代 122000/300000, 损失 = 0.0579, rank_scale = 51.7788
# 迭代 123000/300000, 损失 = 0.0579, rank_scale = 52.1451
# 迭代 124000/300000, 损失 = 0.0579, rank_scale = 52.5102
# 迭代 125000/300000, 损失 = 0.0578, rank_scale = 52.8726
# 迭代 126000/300000, 损失 = 0.0578, rank_scale = 53.2350
# 迭代 127000/300000, 损失 = 0.0578, rank_scale = 53.5937
# 迭代 128000/300000, 损失 = 0.0578, rank_scale = 53.9523
# 迭代 129000/300000, 损失 = 0.0577, rank_scale = 54.3084
# 迭代 130000/300000, 损失 = 0.0577, rank_scale = 54.6631
# 迭代 131000/300000, 损失 = 0.0577, rank_scale = 55.0164
# 迭代 132000/300000, 损失 = 0.0577, rank_scale = 55.3674
# 迭代 133000/300000, 损失 = 0.0577, rank_scale = 55.7181
# 迭代 134000/300000, 损失 = 0.0576, rank_scale = 56.0652
# 迭代 135000/300000, 损失 = 0.0576, rank_scale = 56.4123
# 迭代 136000/300000, 损失 = 0.0576, rank_scale = 56.7565
# 迭代 137000/300000, 损失 = 0.0576, rank_scale = 57.0998
# 迭代 138000/300000, 损失 = 0.0576, rank_scale = 57.4413
# 迭代 139000/300000, 损失 = 0.0575, rank_scale = 57.7808
# 迭代 140000/300000, 损失 = 0.0575, rank_scale = 58.1196
# 迭代 141000/300000, 损失 = 0.0575, rank_scale = 58.4553
# 迭代 142000/300000, 损失 = 0.0575, rank_scale = 58.7910
# 迭代 143000/300000, 损失 = 0.0575, rank_scale = 59.1233
# 迭代 144000/300000, 损失 = 0.0574, rank_scale = 59.4552
# 迭代 145000/300000, 损失 = 0.0574, rank_scale = 59.7849
# 迭代 146000/300000, 损失 = 0.0574, rank_scale = 60.1129
# 迭代 147000/300000, 损失 = 0.0574, rank_scale = 60.4399
# 迭代 148000/300000, 损失 = 0.0574, rank_scale = 60.7642
# 迭代 149000/300000, 损失 = 0.0573, rank_scale = 61.0884
# 迭代 150000/300000, 损失 = 0.0573, rank_scale = 61.4090
# 迭代 151000/300000, 损失 = 0.0573, rank_scale = 61.7295
# 迭代 152000/300000, 损失 = 0.0573, rank_scale = 62.0476
# 迭代 153000/300000, 损失 = 0.0573, rank_scale = 62.3642
# 迭代 154000/300000, 损失 = 0.0573, rank_scale = 62.6798
# 迭代 155000/300000, 损失 = 0.0572, rank_scale = 62.9926
# 迭代 156000/300000, 损失 = 0.0572, rank_scale = 63.3054
# 迭代 157000/300000, 损失 = 0.0572, rank_scale = 63.6148
# 迭代 158000/300000, 损失 = 0.0572, rank_scale = 63.9238
# 迭代 159000/300000, 损失 = 0.0572, rank_scale = 64.2299
# 迭代 160000/300000, 损失 = 0.0572, rank_scale = 64.5351
# 迭代 161000/300000, 损失 = 0.0571, rank_scale = 64.8403
# 迭代 162000/300000, 损失 = 0.0571, rank_scale = 65.1454
# 迭代 163000/300000, 损失 = 0.0571, rank_scale = 65.4441
# 迭代 164000/300000, 损失 = 0.0571, rank_scale = 65.7416
# 迭代 165000/300000, 损失 = 0.0571, rank_scale = 66.0392
# 迭代 166000/300000, 损失 = 0.0571, rank_scale = 66.3367
# 迭代 167000/300000, 损失 = 0.0571, rank_scale = 66.6343
# 迭代 168000/300000, 损失 = 0.0570, rank_scale = 66.9246
# 迭代 169000/300000, 损失 = 0.0570, rank_scale = 67.2145
# 迭代 170000/300000, 损失 = 0.0570, rank_scale = 67.5045
# 迭代 171000/300000, 损失 = 0.0570, rank_scale = 67.7944
# 迭代 172000/300000, 损失 = 0.0570, rank_scale = 68.0843
# 迭代 173000/300000, 损失 = 0.0570, rank_scale = 68.3672
# 迭代 174000/300000, 损失 = 0.0570, rank_scale = 68.6495
# 迭代 175000/300000, 损失 = 0.0569, rank_scale = 68.9318
# 迭代 176000/300000, 损失 = 0.0569, rank_scale = 69.2141
# 迭代 177000/300000, 损失 = 0.0569, rank_scale = 69.4963
# 迭代 178000/300000, 损失 = 0.0569, rank_scale = 69.7727
# 迭代 179000/300000, 损失 = 0.0569, rank_scale = 70.0473
# 迭代 180000/300000, 损失 = 0.0569, rank_scale = 70.3220
# 迭代 181000/300000, 损失 = 0.0569, rank_scale = 70.5966
# 迭代 182000/300000, 损失 = 0.0569, rank_scale = 70.8713
# 迭代 183000/300000, 损失 = 0.0568, rank_scale = 71.1419
# 迭代 184000/300000, 损失 = 0.0568, rank_scale = 71.4089
# 迭代 185000/300000, 损失 = 0.0568, rank_scale = 71.6759
# 迭代 186000/300000, 损失 = 0.0568, rank_scale = 71.9430
# 迭代 187000/300000, 损失 = 0.0568, rank_scale = 72.2100
# 迭代 188000/300000, 损失 = 0.0568, rank_scale = 72.4762
# 迭代 189000/300000, 损失 = 0.0568, rank_scale = 72.7356
# 迭代 190000/300000, 损失 = 0.0568, rank_scale = 72.9950
# 迭代 191000/300000, 损失 = 0.0567, rank_scale = 73.2544
# 迭代 192000/300000, 损失 = 0.0567, rank_scale = 73.5138
# 迭代 193000/300000, 损失 = 0.0567, rank_scale = 73.7732
# 迭代 194000/300000, 损失 = 0.0567, rank_scale = 74.0287
# 迭代 195000/300000, 损失 = 0.0567, rank_scale = 74.2805
# 迭代 196000/300000, 损失 = 0.0567, rank_scale = 74.5323
# 迭代 197000/300000, 损失 = 0.0567, rank_scale = 74.7840
# 迭代 198000/300000, 损失 = 0.0567, rank_scale = 75.0358
# 迭代 199000/300000, 损失 = 0.0567, rank_scale = 75.2876
# 迭代 200000/300000, 损失 = 0.0566, rank_scale = 75.5340
# 迭代 201000/300000, 损失 = 0.0566, rank_scale = 75.7781
# 迭代 202000/300000, 损失 = 0.0566, rank_scale = 76.0223
# 迭代 203000/300000, 损失 = 0.0566, rank_scale = 76.2664
# 迭代 204000/300000, 损失 = 0.0566, rank_scale = 76.5106
# 迭代 205000/300000, 损失 = 0.0566, rank_scale = 76.7547
# 迭代 206000/300000, 损失 = 0.0566, rank_scale = 76.9935
# 迭代 207000/300000, 损失 = 0.0566, rank_scale = 77.2300
# 迭代 208000/300000, 损失 = 0.0566, rank_scale = 77.4665
# 迭代 209000/300000, 损失 = 0.0566, rank_scale = 77.7030
# 迭代 210000/300000, 损失 = 0.0565, rank_scale = 77.9395
# 迭代 211000/300000, 损失 = 0.0565, rank_scale = 78.1760
# 迭代 212000/300000, 损失 = 0.0565, rank_scale = 78.4099
# 迭代 213000/300000, 损失 = 0.0565, rank_scale = 78.6388
# 迭代 214000/300000, 损失 = 0.0565, rank_scale = 78.8676
# 迭代 215000/300000, 损失 = 0.0565, rank_scale = 79.0965
# 迭代 216000/300000, 损失 = 0.0565, rank_scale = 79.3254
# 迭代 217000/300000, 损失 = 0.0565, rank_scale = 79.5543
# 迭代 218000/300000, 损失 = 0.0565, rank_scale = 79.7832
# 迭代 219000/300000, 损失 = 0.0564, rank_scale = 80.0058
# 迭代 220000/300000, 损失 = 0.0564, rank_scale = 80.2271
# 迭代 221000/300000, 损失 = 0.0564, rank_scale = 80.4483
# 迭代 222000/300000, 损失 = 0.0564, rank_scale = 80.6696
# 迭代 223000/300000, 损失 = 0.0564, rank_scale = 80.8908
# 迭代 224000/300000, 损失 = 0.0564, rank_scale = 81.1121
# 迭代 225000/300000, 损失 = 0.0564, rank_scale = 81.3300
# 迭代 226000/300000, 损失 = 0.0564, rank_scale = 81.5436
# 迭代 227000/300000, 损失 = 0.0564, rank_scale = 81.7572
# 迭代 228000/300000, 损失 = 0.0564, rank_scale = 81.9709
# 迭代 229000/300000, 损失 = 0.0564, rank_scale = 82.1845
# 迭代 230000/300000, 损失 = 0.0563, rank_scale = 82.3981
# 迭代 231000/300000, 损失 = 0.0563, rank_scale = 82.6117
# 迭代 232000/300000, 损失 = 0.0563, rank_scale = 82.8209
# 迭代 233000/300000, 损失 = 0.0563, rank_scale = 83.0269
# 迭代 234000/300000, 损失 = 0.0563, rank_scale = 83.2329
# 迭代 235000/300000, 损失 = 0.0563, rank_scale = 83.4389
# 迭代 236000/300000, 损失 = 0.0563, rank_scale = 83.6449
# 迭代 237000/300000, 损失 = 0.0563, rank_scale = 83.8508
# 迭代 238000/300000, 损失 = 0.0563, rank_scale = 84.0568
# 迭代 239000/300000, 损失 = 0.0563, rank_scale = 84.2619
# 迭代 240000/300000, 损失 = 0.0562, rank_scale = 84.4603
# 迭代 241000/300000, 损失 = 0.0562, rank_scale = 84.6587
# 迭代 242000/300000, 损失 = 0.0562, rank_scale = 84.8570
# 迭代 243000/300000, 损失 = 0.0562, rank_scale = 85.0554
# 迭代 244000/300000, 损失 = 0.0562, rank_scale = 85.2538
# 迭代 245000/300000, 损失 = 0.0562, rank_scale = 85.4521
# 迭代 246000/300000, 损失 = 0.0562, rank_scale = 85.6505
# 迭代 247000/300000, 损失 = 0.0562, rank_scale = 85.8468
# 迭代 248000/300000, 损失 = 0.0562, rank_scale = 86.0375
# 迭代 249000/300000, 损失 = 0.0562, rank_scale = 86.2282
# 迭代 250000/300000, 损失 = 0.0562, rank_scale = 86.4190
# 迭代 251000/300000, 损失 = 0.0562, rank_scale = 86.6097
# 迭代 252000/300000, 损失 = 0.0562, rank_scale = 86.8004
# 迭代 253000/300000, 损失 = 0.0562, rank_scale = 86.9912
# 迭代 254000/300000, 损失 = 0.0561, rank_scale = 87.1819
# 迭代 255000/300000, 损失 = 0.0561, rank_scale = 87.3725
# 迭代 256000/300000, 损失 = 0.0561, rank_scale = 87.5556
# 迭代 257000/300000, 损失 = 0.0561, rank_scale = 87.7387
# 迭代 258000/300000, 损失 = 0.0561, rank_scale = 87.9218
# 迭代 259000/300000, 损失 = 0.0561, rank_scale = 88.1049
# 迭代 260000/300000, 损失 = 0.0561, rank_scale = 88.2880
# 迭代 261000/300000, 损失 = 0.0561, rank_scale = 88.4711
# 迭代 262000/300000, 损失 = 0.0561, rank_scale = 88.6542
# 迭代 263000/300000, 损失 = 0.0561, rank_scale = 88.8373
# 迭代 264000/300000, 损失 = 0.0561, rank_scale = 89.0188
# 迭代 265000/300000, 损失 = 0.0561, rank_scale = 89.1943
# 迭代 266000/300000, 损失 = 0.0561, rank_scale = 89.3697
# 迭代 267000/300000, 损失 = 0.0561, rank_scale = 89.5452
# 迭代 268000/300000, 损失 = 0.0561, rank_scale = 89.7207
# 迭代 269000/300000, 损失 = 0.0561, rank_scale = 89.8962
# 迭代 270000/300000, 损失 = 0.0560, rank_scale = 90.0716
# 迭代 271000/300000, 损失 = 0.0560, rank_scale = 90.2471
# 迭代 272000/300000, 损失 = 0.0560, rank_scale = 90.4226
# 迭代 273000/300000, 损失 = 0.0560, rank_scale = 90.5981
# 迭代 274000/300000, 损失 = 0.0560, rank_scale = 90.7672
# 迭代 275000/300000, 损失 = 0.0560, rank_scale = 90.9351
# 迭代 276000/300000, 损失 = 0.0560, rank_scale = 91.1029
# 迭代 277000/300000, 损失 = 0.0560, rank_scale = 91.2708
# 迭代 278000/300000, 损失 = 0.0560, rank_scale = 91.4386
# 迭代 279000/300000, 损失 = 0.0560, rank_scale = 91.6064
# 迭代 280000/300000, 损失 = 0.0560, rank_scale = 91.7743
# 迭代 281000/300000, 损失 = 0.0560, rank_scale = 91.9421
# 迭代 282000/300000, 损失 = 0.0560, rank_scale = 92.1100
# 迭代 283000/300000, 损失 = 0.0560, rank_scale = 92.2778
# 迭代 284000/300000, 损失 = 0.0560, rank_scale = 92.4391
# 迭代 285000/300000, 损失 = 0.0560, rank_scale = 92.5993
# 迭代 286000/300000, 损失 = 0.0560, rank_scale = 92.7595
# 迭代 287000/300000, 损失 = 0.0559, rank_scale = 92.9198
# 迭代 288000/300000, 损失 = 0.0559, rank_scale = 93.0800
# 迭代 289000/300000, 损失 = 0.0559, rank_scale = 93.2402
# 迭代 290000/300000, 损失 = 0.0559, rank_scale = 93.4004
# 迭代 291000/300000, 损失 = 0.0559, rank_scale = 93.5606
# 迭代 292000/300000, 损失 = 0.0559, rank_scale = 93.7208
# 迭代 293000/300000, 损失 = 0.0559, rank_scale = 93.8811
# 迭代 294000/300000, 损失 = 0.0559, rank_scale = 94.0403
# 迭代 295000/300000, 损失 = 0.0559, rank_scale = 94.1929
# 迭代 296000/300000, 损失 = 0.0559, rank_scale = 94.3454
# 迭代 297000/300000, 损失 = 0.0559, rank_scale = 94.4980
# 迭代 298000/300000, 损失 = 0.0559, rank_scale = 94.6506
# 迭代 299000/300000, 损失 = 0.0559, rank_scale = 94.8032
# 迭代 300000/300000, 损失 = 0.0559, rank_scale = 94.9558
#
# 随机搜索: {'lambda_defense': 0.12973169683940733, 'lambda_supervision': 0.0412037280884873, 'lambda_reg': 0.004119890406724053}
# 迭代 1000/300000, 损失 = 0.1081, rank_scale = 1.4105
# 迭代 2000/300000, 损失 = 0.0756, rank_scale = 1.7361
# 迭代 3000/300000, 损失 = 0.0575, rank_scale = 2.0366
# 迭代 4000/300000, 损失 = 0.0467, rank_scale = 2.3343
# 迭代 5000/300000, 损失 = 0.0400, rank_scale = 2.6391
# 迭代 6000/300000, 损失 = 0.0355, rank_scale = 2.9562
# 迭代 7000/300000, 损失 = 0.0325, rank_scale = 3.2882
# 迭代 8000/300000, 损失 = 0.0305, rank_scale = 3.6353
# 迭代 9000/300000, 损失 = 0.0290, rank_scale = 3.9957
# 迭代 10000/300000, 损失 = 0.0279, rank_scale = 4.3673
# 迭代 11000/300000, 损失 = 0.0271, rank_scale = 4.7482
# 迭代 12000/300000, 损失 = 0.0265, rank_scale = 5.1373
# 迭代 13000/300000, 损失 = 0.0260, rank_scale = 5.5337
# 迭代 14000/300000, 损失 = 0.0255, rank_scale = 5.9362
# 迭代 15000/300000, 损失 = 0.0251, rank_scale = 6.3439
# 迭代 16000/300000, 损失 = 0.0248, rank_scale = 6.7561
# 迭代 17000/300000, 损失 = 0.0244, rank_scale = 7.1723
# 迭代 18000/300000, 损失 = 0.0241, rank_scale = 7.5919
# 迭代 19000/300000, 损失 = 0.0237, rank_scale = 8.0146
# 迭代 20000/300000, 损失 = 0.0234, rank_scale = 8.4401
# 迭代 21000/300000, 损失 = 0.0231, rank_scale = 8.8683
# 迭代 22000/300000, 损失 = 0.0229, rank_scale = 9.2988
# 迭代 23000/300000, 损失 = 0.0226, rank_scale = 9.7315
# 迭代 24000/300000, 损失 = 0.0224, rank_scale = 10.1663
# 迭代 25000/300000, 损失 = 0.0222, rank_scale = 10.6028
# 迭代 26000/300000, 损失 = 0.0220, rank_scale = 11.0411
# 迭代 27000/300000, 损失 = 0.0218, rank_scale = 11.4808
# 迭代 28000/300000, 损失 = 0.0216, rank_scale = 11.9219
# 迭代 29000/300000, 损失 = 0.0214, rank_scale = 12.3642
# 迭代 30000/300000, 损失 = 0.0212, rank_scale = 12.8076
# 迭代 31000/300000, 损失 = 0.0210, rank_scale = 13.2521
# 迭代 32000/300000, 损失 = 0.0209, rank_scale = 13.6975
# 迭代 33000/300000, 损失 = 0.0207, rank_scale = 14.1437
# 迭代 34000/300000, 损失 = 0.0205, rank_scale = 14.5905
# 迭代 35000/300000, 损失 = 0.0204, rank_scale = 15.0379
# 迭代 36000/300000, 损失 = 0.0202, rank_scale = 15.4861
# 迭代 37000/300000, 损失 = 0.0201, rank_scale = 15.9344
# 迭代 38000/300000, 损失 = 0.0200, rank_scale = 16.3828
# 迭代 39000/300000, 损失 = 0.0198, rank_scale = 16.8328
# 迭代 40000/300000, 损失 = 0.0197, rank_scale = 17.2829
# 迭代 41000/300000, 损失 = 0.0196, rank_scale = 17.7330
# 迭代 42000/300000, 损失 = 0.0194, rank_scale = 18.1832
# 迭代 43000/300000, 损失 = 0.0193, rank_scale = 18.6333
# 迭代 44000/300000, 损失 = 0.0192, rank_scale = 19.0834
# 迭代 45000/300000, 损失 = 0.0191, rank_scale = 19.5336
# 迭代 46000/300000, 损失 = 0.0190, rank_scale = 19.9837
# 迭代 47000/300000, 损失 = 0.0189, rank_scale = 20.4338
# 迭代 48000/300000, 损失 = 0.0188, rank_scale = 20.8840
# 迭代 49000/300000, 损失 = 0.0187, rank_scale = 21.3341
# 迭代 50000/300000, 损失 = 0.0186, rank_scale = 21.7842
# 迭代 51000/300000, 损失 = 0.0185, rank_scale = 22.2343
# 迭代 52000/300000, 损失 = 0.0184, rank_scale = 22.6826
# 迭代 53000/300000, 损失 = 0.0183, rank_scale = 23.1308
# 迭代 54000/300000, 损失 = 0.0182, rank_scale = 23.5791
# 迭代 55000/300000, 损失 = 0.0181, rank_scale = 24.0273
# 迭代 56000/300000, 损失 = 0.0181, rank_scale = 24.4755
# 迭代 57000/300000, 损失 = 0.0180, rank_scale = 24.9220
# 迭代 58000/300000, 损失 = 0.0179, rank_scale = 25.3683
# 迭代 59000/300000, 损失 = 0.0178, rank_scale = 25.8146
# 迭代 60000/300000, 损失 = 0.0178, rank_scale = 26.2604
# 迭代 61000/300000, 损失 = 0.0177, rank_scale = 26.7048
# 迭代 62000/300000, 损失 = 0.0176, rank_scale = 27.1492
# 迭代 63000/300000, 损失 = 0.0175, rank_scale = 27.5931
# 迭代 64000/300000, 损失 = 0.0175, rank_scale = 28.0356
# 迭代 65000/300000, 损失 = 0.0174, rank_scale = 28.4781
# 迭代 66000/300000, 损失 = 0.0173, rank_scale = 28.9194
# 迭代 67000/300000, 损失 = 0.0173, rank_scale = 29.3600
# 迭代 68000/300000, 损失 = 0.0172, rank_scale = 29.8001
# 迭代 69000/300000, 损失 = 0.0171, rank_scale = 30.2388
# 迭代 70000/300000, 损失 = 0.0171, rank_scale = 30.6775
# 迭代 71000/300000, 损失 = 0.0170, rank_scale = 31.1143
# 迭代 72000/300000, 损失 = 0.0170, rank_scale = 31.5511
# 迭代 73000/300000, 损失 = 0.0169, rank_scale = 31.9862
# 迭代 74000/300000, 损失 = 0.0169, rank_scale = 32.4210
# 迭代 75000/300000, 损失 = 0.0168, rank_scale = 32.8559
# 迭代 76000/300000, 损失 = 0.0167, rank_scale = 33.2872
# 迭代 77000/300000, 损失 = 0.0167, rank_scale = 33.7183
# 迭代 78000/300000, 损失 = 0.0166, rank_scale = 34.1494
# 迭代 79000/300000, 损失 = 0.0166, rank_scale = 34.5792
# 迭代 80000/300000, 损失 = 0.0165, rank_scale = 35.0064
# 迭代 81000/300000, 损失 = 0.0165, rank_scale = 35.4337
# 迭代 82000/300000, 损失 = 0.0165, rank_scale = 35.8609
# 迭代 83000/300000, 损失 = 0.0164, rank_scale = 36.2845
# 迭代 84000/300000, 损失 = 0.0164, rank_scale = 36.7080
# 迭代 85000/300000, 损失 = 0.0163, rank_scale = 37.1314
# 迭代 86000/300000, 损失 = 0.0163, rank_scale = 37.5519
# 迭代 87000/300000, 损失 = 0.0162, rank_scale = 37.9715
# 迭代 88000/300000, 损失 = 0.0162, rank_scale = 38.3911
# 迭代 89000/300000, 损失 = 0.0161, rank_scale = 38.8079
# 迭代 90000/300000, 损失 = 0.0161, rank_scale = 39.2237
# 迭代 91000/300000, 损失 = 0.0161, rank_scale = 39.6395
# 迭代 92000/300000, 损失 = 0.0160, rank_scale = 40.0522
# 迭代 93000/300000, 损失 = 0.0160, rank_scale = 40.4642
# 迭代 94000/300000, 损失 = 0.0159, rank_scale = 40.8761
# 迭代 95000/300000, 损失 = 0.0159, rank_scale = 41.2842
# 迭代 96000/300000, 损失 = 0.0159, rank_scale = 41.6924
# 迭代 97000/300000, 损失 = 0.0158, rank_scale = 42.0995
# 迭代 98000/300000, 损失 = 0.0158, rank_scale = 42.5038
# 迭代 99000/300000, 损失 = 0.0158, rank_scale = 42.9082
# 迭代 100000/300000, 损失 = 0.0157, rank_scale = 43.3100
# 迭代 101000/300000, 损失 = 0.0157, rank_scale = 43.7106
# 迭代 102000/300000, 损失 = 0.0157, rank_scale = 44.1109
# 迭代 103000/300000, 损失 = 0.0156, rank_scale = 44.5076
# 迭代 104000/300000, 损失 = 0.0156, rank_scale = 44.9044
# 迭代 105000/300000, 损失 = 0.0156, rank_scale = 45.2990
# 迭代 106000/300000, 损失 = 0.0155, rank_scale = 45.6920
# 迭代 107000/300000, 损失 = 0.0155, rank_scale = 46.0847
# 迭代 108000/300000, 损失 = 0.0155, rank_scale = 46.4738
# 迭代 109000/300000, 损失 = 0.0154, rank_scale = 46.8629
# 迭代 110000/300000, 损失 = 0.0154, rank_scale = 47.2497
# 迭代 111000/300000, 损失 = 0.0154, rank_scale = 47.6350
# 迭代 112000/300000, 损失 = 0.0154, rank_scale = 48.0195
# 迭代 113000/300000, 损失 = 0.0153, rank_scale = 48.4009
# 迭代 114000/300000, 损失 = 0.0153, rank_scale = 48.7824
# 迭代 115000/300000, 损失 = 0.0153, rank_scale = 49.1608
# 迭代 116000/300000, 损失 = 0.0152, rank_scale = 49.5385
# 迭代 117000/300000, 损失 = 0.0152, rank_scale = 49.9145
# 迭代 118000/300000, 损失 = 0.0152, rank_scale = 50.2883
# 迭代 119000/300000, 损失 = 0.0152, rank_scale = 50.6619
# 迭代 120000/300000, 损失 = 0.0151, rank_scale = 51.0319
# 迭代 121000/300000, 损失 = 0.0151, rank_scale = 51.4019
# 迭代 122000/300000, 损失 = 0.0151, rank_scale = 51.7691
# 迭代 123000/300000, 损失 = 0.0151, rank_scale = 52.1353
# 迭代 124000/300000, 损失 = 0.0150, rank_scale = 52.4998
# 迭代 125000/300000, 损失 = 0.0150, rank_scale = 52.8622
# 迭代 126000/300000, 损失 = 0.0150, rank_scale = 53.2240
# 迭代 127000/300000, 损失 = 0.0150, rank_scale = 53.5826
# 迭代 128000/300000, 损失 = 0.0149, rank_scale = 53.9412
# 迭代 129000/300000, 损失 = 0.0149, rank_scale = 54.2965
# 迭代 130000/300000, 损失 = 0.0149, rank_scale = 54.6513
# 迭代 131000/300000, 损失 = 0.0149, rank_scale = 55.0039
# 迭代 132000/300000, 损失 = 0.0149, rank_scale = 55.3549
# 迭代 133000/300000, 损失 = 0.0148, rank_scale = 55.7049
# 迭代 134000/300000, 损失 = 0.0148, rank_scale = 56.0520
# 迭代 135000/300000, 损失 = 0.0148, rank_scale = 56.3992
# 迭代 136000/300000, 损失 = 0.0148, rank_scale = 56.7426
# 迭代 137000/300000, 损失 = 0.0148, rank_scale = 57.0860
# 迭代 138000/300000, 损失 = 0.0147, rank_scale = 57.4267
# 迭代 139000/300000, 损失 = 0.0147, rank_scale = 57.7662
# 迭代 140000/300000, 损失 = 0.0147, rank_scale = 58.1044
# 迭代 141000/300000, 损失 = 0.0147, rank_scale = 58.4401
# 迭代 142000/300000, 损失 = 0.0147, rank_scale = 58.7755
# 迭代 143000/300000, 损失 = 0.0146, rank_scale = 59.1073
# 迭代 144000/300000, 损失 = 0.0146, rank_scale = 59.4392
# 迭代 145000/300000, 损失 = 0.0146, rank_scale = 59.7680
# 迭代 146000/300000, 损失 = 0.0146, rank_scale = 60.0961
# 迭代 147000/300000, 损失 = 0.0146, rank_scale = 60.4223
# 迭代 148000/300000, 损失 = 0.0145, rank_scale = 60.7466
# 迭代 149000/300000, 损失 = 0.0145, rank_scale = 61.0704
# 迭代 150000/300000, 损失 = 0.0145, rank_scale = 61.3908
# 迭代 151000/300000, 损失 = 0.0145, rank_scale = 61.7113
# 迭代 152000/300000, 损失 = 0.0145, rank_scale = 62.0286
# 迭代 153000/300000, 损失 = 0.0144, rank_scale = 62.3452
# 迭代 154000/300000, 损失 = 0.0144, rank_scale = 62.6599
# 迭代 155000/300000, 损失 = 0.0144, rank_scale = 62.9727
# 迭代 156000/300000, 损失 = 0.0144, rank_scale = 63.2854
# 迭代 157000/300000, 损失 = 0.0144, rank_scale = 63.5943
# 迭代 158000/300000, 损失 = 0.0144, rank_scale = 63.9033
# 迭代 159000/300000, 损失 = 0.0143, rank_scale = 64.2096
# 迭代 160000/300000, 损失 = 0.0143, rank_scale = 64.5148
# 迭代 161000/300000, 损失 = 0.0143, rank_scale = 64.8200
# 迭代 162000/300000, 损失 = 0.0143, rank_scale = 65.1247
# 迭代 163000/300000, 损失 = 0.0143, rank_scale = 65.4223
# 迭代 164000/300000, 损失 = 0.0143, rank_scale = 65.7198
# 迭代 165000/300000, 损失 = 0.0143, rank_scale = 66.0174
# 迭代 166000/300000, 损失 = 0.0142, rank_scale = 66.3149
# 迭代 167000/300000, 损失 = 0.0142, rank_scale = 66.6118
# 迭代 168000/300000, 损失 = 0.0142, rank_scale = 66.9017
# 迭代 169000/300000, 损失 = 0.0142, rank_scale = 67.1916
# 迭代 170000/300000, 损失 = 0.0142, rank_scale = 67.4815
# 迭代 171000/300000, 损失 = 0.0142, rank_scale = 67.7714
# 迭代 172000/300000, 损失 = 0.0141, rank_scale = 68.0607
# 迭代 173000/300000, 损失 = 0.0141, rank_scale = 68.3430
# 迭代 174000/300000, 损失 = 0.0141, rank_scale = 68.6252
# 迭代 175000/300000, 损失 = 0.0141, rank_scale = 68.9075
# 迭代 176000/300000, 损失 = 0.0141, rank_scale = 69.1898
# 迭代 177000/300000, 损失 = 0.0141, rank_scale = 69.4718
# 迭代 178000/300000, 损失 = 0.0141, rank_scale = 69.7465
# 迭代 179000/300000, 损失 = 0.0140, rank_scale = 70.0211
# 迭代 180000/300000, 损失 = 0.0140, rank_scale = 70.2958
# 迭代 181000/300000, 损失 = 0.0140, rank_scale = 70.5704
# 迭代 182000/300000, 损失 = 0.0140, rank_scale = 70.8451
# 迭代 183000/300000, 损失 = 0.0140, rank_scale = 71.1140
# 迭代 184000/300000, 损失 = 0.0140, rank_scale = 71.3810
# 迭代 185000/300000, 损失 = 0.0140, rank_scale = 71.6480
# 迭代 186000/300000, 损失 = 0.0140, rank_scale = 71.9151
# 迭代 187000/300000, 损失 = 0.0140, rank_scale = 72.1821
# 迭代 188000/300000, 损失 = 0.0139, rank_scale = 72.4466
# 迭代 189000/300000, 损失 = 0.0139, rank_scale = 72.7060
# 迭代 190000/300000, 损失 = 0.0139, rank_scale = 72.9654
# 迭代 191000/300000, 损失 = 0.0139, rank_scale = 73.2248
# 迭代 192000/300000, 损失 = 0.0139, rank_scale = 73.4842
# 迭代 193000/300000, 损失 = 0.0139, rank_scale = 73.7436
# 迭代 194000/300000, 损失 = 0.0139, rank_scale = 73.9972
# 迭代 195000/300000, 损失 = 0.0139, rank_scale = 74.2490
# 迭代 196000/300000, 损失 = 0.0138, rank_scale = 74.5008
# 迭代 197000/300000, 损失 = 0.0138, rank_scale = 74.7525
# 迭代 198000/300000, 损失 = 0.0138, rank_scale = 75.0043
# 迭代 199000/300000, 损失 = 0.0138, rank_scale = 75.2561
# 迭代 200000/300000, 损失 = 0.0138, rank_scale = 75.5004
# 迭代 201000/300000, 损失 = 0.0138, rank_scale = 75.7446
# 迭代 202000/300000, 损失 = 0.0138, rank_scale = 75.9887
# 迭代 203000/300000, 损失 = 0.0138, rank_scale = 76.2329
# 迭代 204000/300000, 损失 = 0.0138, rank_scale = 76.4770
# 迭代 205000/300000, 损失 = 0.0138, rank_scale = 76.7211
# 迭代 206000/300000, 损失 = 0.0137, rank_scale = 76.9581
# 迭代 207000/300000, 损失 = 0.0137, rank_scale = 77.1946
# 迭代 208000/300000, 损失 = 0.0137, rank_scale = 77.4311
# 迭代 209000/300000, 损失 = 0.0137, rank_scale = 77.6676
# 迭代 210000/300000, 损失 = 0.0137, rank_scale = 77.9042
# 迭代 211000/300000, 损失 = 0.0137, rank_scale = 78.1407
# 迭代 212000/300000, 损失 = 0.0137, rank_scale = 78.3716
# 迭代 213000/300000, 损失 = 0.0137, rank_scale = 78.6004
# 迭代 214000/300000, 损失 = 0.0137, rank_scale = 78.8293
# 迭代 215000/300000, 损失 = 0.0137, rank_scale = 79.0582
# 迭代 216000/300000, 损失 = 0.0136, rank_scale = 79.2871
# 迭代 217000/300000, 损失 = 0.0136, rank_scale = 79.5160
# 迭代 218000/300000, 损失 = 0.0136, rank_scale = 79.7430
# 迭代 219000/300000, 损失 = 0.0136, rank_scale = 79.9643
# 迭代 220000/300000, 损失 = 0.0136, rank_scale = 80.1855
# 迭代 221000/300000, 损失 = 0.0136, rank_scale = 80.4068
# 迭代 222000/300000, 损失 = 0.0136, rank_scale = 80.6280
# 迭代 223000/300000, 损失 = 0.0136, rank_scale = 80.8493
# 迭代 224000/300000, 损失 = 0.0136, rank_scale = 81.0705
# 迭代 225000/300000, 损失 = 0.0136, rank_scale = 81.2888
# 迭代 226000/300000, 损失 = 0.0136, rank_scale = 81.5024
# 迭代 227000/300000, 损失 = 0.0136, rank_scale = 81.7160
# 迭代 228000/300000, 损失 = 0.0135, rank_scale = 81.9296
# 迭代 229000/300000, 损失 = 0.0135, rank_scale = 82.1433
# 迭代 230000/300000, 损失 = 0.0135, rank_scale = 82.3569
# 迭代 231000/300000, 损失 = 0.0135, rank_scale = 82.5705
# 迭代 232000/300000, 损失 = 0.0135, rank_scale = 82.7841
# 迭代 233000/300000, 损失 = 0.0135, rank_scale = 82.9914
# 迭代 234000/300000, 损失 = 0.0135, rank_scale = 83.1974
# 迭代 235000/300000, 损失 = 0.0135, rank_scale = 83.4034
# 迭代 236000/300000, 损失 = 0.0135, rank_scale = 83.6094
# 迭代 237000/300000, 损失 = 0.0135, rank_scale = 83.8154
# 迭代 238000/300000, 损失 = 0.0134, rank_scale = 84.0214
# 迭代 239000/300000, 损失 = 0.0134, rank_scale = 84.2274
# 迭代 240000/300000, 损失 = 0.0134, rank_scale = 84.4276
# 迭代 241000/300000, 损失 = 0.0134, rank_scale = 84.6260
# 迭代 242000/300000, 损失 = 0.0134, rank_scale = 84.8244
# 迭代 243000/300000, 损失 = 0.0134, rank_scale = 85.0227
# 迭代 244000/300000, 损失 = 0.0134, rank_scale = 85.2211
# 迭代 245000/300000, 损失 = 0.0134, rank_scale = 85.4194
# 迭代 246000/300000, 损失 = 0.0134, rank_scale = 85.6178
# 迭代 247000/300000, 损失 = 0.0134, rank_scale = 85.8154
# 迭代 248000/300000, 损失 = 0.0134, rank_scale = 86.0061
# 迭代 249000/300000, 损失 = 0.0134, rank_scale = 86.1969
# 迭代 250000/300000, 损失 = 0.0134, rank_scale = 86.3876
# 迭代 251000/300000, 损失 = 0.0133, rank_scale = 86.5784
# 迭代 252000/300000, 损失 = 0.0133, rank_scale = 86.7691
# 迭代 253000/300000, 损失 = 0.0133, rank_scale = 86.9598
# 迭代 254000/300000, 损失 = 0.0133, rank_scale = 87.1506
# 迭代 255000/300000, 损失 = 0.0133, rank_scale = 87.3413
# 迭代 256000/300000, 损失 = 0.0133, rank_scale = 87.5260
# 迭代 257000/300000, 损失 = 0.0133, rank_scale = 87.7091
# 迭代 258000/300000, 损失 = 0.0133, rank_scale = 87.8922
# 迭代 259000/300000, 损失 = 0.0133, rank_scale = 88.0753
# 迭代 260000/300000, 损失 = 0.0133, rank_scale = 88.2584
# 迭代 261000/300000, 损失 = 0.0133, rank_scale = 88.4415
# 迭代 262000/300000, 损失 = 0.0133, rank_scale = 88.6246
# 迭代 263000/300000, 损失 = 0.0133, rank_scale = 88.8077
# 迭代 264000/300000, 损失 = 0.0133, rank_scale = 88.9908
# 迭代 265000/300000, 损失 = 0.0133, rank_scale = 89.1665
# 迭代 266000/300000, 损失 = 0.0132, rank_scale = 89.3420
# 迭代 267000/300000, 损失 = 0.0132, rank_scale = 89.5175
# 迭代 268000/300000, 损失 = 0.0132, rank_scale = 89.6930
# 迭代 269000/300000, 损失 = 0.0132, rank_scale = 89.8684
# 迭代 270000/300000, 损失 = 0.0132, rank_scale = 90.0439
# 迭代 271000/300000, 损失 = 0.0132, rank_scale = 90.2194
# 迭代 272000/300000, 损失 = 0.0132, rank_scale = 90.3949
# 迭代 273000/300000, 损失 = 0.0132, rank_scale = 90.5703
# 迭代 274000/300000, 损失 = 0.0132, rank_scale = 90.7411
# 迭代 275000/300000, 损失 = 0.0132, rank_scale = 90.9090
# 迭代 276000/300000, 损失 = 0.0132, rank_scale = 91.0768
# 迭代 277000/300000, 损失 = 0.0132, rank_scale = 91.2447
# 迭代 278000/300000, 损失 = 0.0132, rank_scale = 91.4125
# 迭代 279000/300000, 损失 = 0.0132, rank_scale = 91.5804
# 迭代 280000/300000, 损失 = 0.0132, rank_scale = 91.7482
# 迭代 281000/300000, 损失 = 0.0132, rank_scale = 91.9161
# 迭代 282000/300000, 损失 = 0.0132, rank_scale = 92.0839
# 迭代 283000/300000, 损失 = 0.0131, rank_scale = 92.2518
# 迭代 284000/300000, 损失 = 0.0131, rank_scale = 92.4156
# 迭代 285000/300000, 损失 = 0.0131, rank_scale = 92.5758
# 迭代 286000/300000, 损失 = 0.0131, rank_scale = 92.7360
# 迭代 287000/300000, 损失 = 0.0131, rank_scale = 92.8962
# 迭代 288000/300000, 损失 = 0.0131, rank_scale = 93.0564
# 迭代 289000/300000, 损失 = 0.0131, rank_scale = 93.2166
# 迭代 290000/300000, 损失 = 0.0131, rank_scale = 93.3769
# 迭代 291000/300000, 损失 = 0.0131, rank_scale = 93.5371
# 迭代 292000/300000, 损失 = 0.0131, rank_scale = 93.6973
# 迭代 293000/300000, 损失 = 0.0131, rank_scale = 93.8575
# 迭代 294000/300000, 损失 = 0.0131, rank_scale = 94.0177
# 迭代 295000/300000, 损失 = 0.0131, rank_scale = 94.1722
# 迭代 296000/300000, 损失 = 0.0131, rank_scale = 94.3247
# 迭代 297000/300000, 损失 = 0.0131, rank_scale = 94.4773
# 迭代 298000/300000, 损失 = 0.0131, rank_scale = 94.6299
# 迭代 299000/300000, 损失 = 0.0131, rank_scale = 94.7825
# 迭代 300000/300000, 损失 = 0.0131, rank_scale = 94.9351
#
# 随机搜索: {'lambda_defense': 0.021616722433639893, 'lambda_supervision': 0.18323522915498705, 'lambda_reg': 0.013022300234864177}
# 迭代 1000/300000, 损失 = 0.0870, rank_scale = 1.4108
# 迭代 2000/300000, 损失 = 0.0785, rank_scale = 1.7358
# 迭代 3000/300000, 损失 = 0.0737, rank_scale = 2.0355
# 迭代 4000/300000, 损失 = 0.0709, rank_scale = 2.3316
# 迭代 5000/300000, 损失 = 0.0690, rank_scale = 2.6341
# 迭代 6000/300000, 损失 = 0.0676, rank_scale = 2.9475
# 迭代 7000/300000, 损失 = 0.0664, rank_scale = 3.2735
# 迭代 8000/300000, 损失 = 0.0655, rank_scale = 3.6123
# 迭代 9000/300000, 损失 = 0.0647, rank_scale = 3.9630
# 迭代 10000/300000, 损失 = 0.0641, rank_scale = 4.3248
# 迭代 11000/300000, 损失 = 0.0635, rank_scale = 4.6970
# 迭代 12000/300000, 损失 = 0.0630, rank_scale = 5.0782
# 迭代 13000/300000, 损失 = 0.0626, rank_scale = 5.4672
# 迭代 14000/300000, 损失 = 0.0622, rank_scale = 5.8629
# 迭代 15000/300000, 损失 = 0.0619, rank_scale = 6.2646
# 迭代 16000/300000, 损失 = 0.0616, rank_scale = 6.6716
# 迭代 17000/300000, 损失 = 0.0613, rank_scale = 7.0833
# 迭代 18000/300000, 损失 = 0.0610, rank_scale = 7.4991
# 迭代 19000/300000, 损失 = 0.0608, rank_scale = 7.9188
# 迭代 20000/300000, 损失 = 0.0606, rank_scale = 8.3419
# 迭代 21000/300000, 损失 = 0.0604, rank_scale = 8.7680
# 迭代 22000/300000, 损失 = 0.0603, rank_scale = 9.1971
# 迭代 23000/300000, 损失 = 0.0601, rank_scale = 9.6290
# 迭代 24000/300000, 损失 = 0.0600, rank_scale = 10.0638
# 迭代 25000/300000, 损失 = 0.0598, rank_scale = 10.5019
# 迭代 26000/300000, 损失 = 0.0597, rank_scale = 10.9436
# 迭代 27000/300000, 损失 = 0.0595, rank_scale = 11.3883
# 迭代 28000/300000, 损失 = 0.0594, rank_scale = 11.8349
# 迭代 29000/300000, 损失 = 0.0592, rank_scale = 12.2827
# 迭代 30000/300000, 损失 = 0.0591, rank_scale = 12.7314
# 迭代 31000/300000, 损失 = 0.0589, rank_scale = 13.1806
# 迭代 32000/300000, 损失 = 0.0588, rank_scale = 13.6308
# 迭代 33000/300000, 损失 = 0.0587, rank_scale = 14.0809
# 迭代 34000/300000, 损失 = 0.0585, rank_scale = 14.5320
# 迭代 35000/300000, 损失 = 0.0584, rank_scale = 14.9831
# 迭代 36000/300000, 损失 = 0.0582, rank_scale = 15.4342
# 迭代 37000/300000, 损失 = 0.0581, rank_scale = 15.8858
# 迭代 38000/300000, 损失 = 0.0580, rank_scale = 16.3379
# 迭代 39000/300000, 损失 = 0.0579, rank_scale = 16.7899
# 迭代 40000/300000, 损失 = 0.0577, rank_scale = 17.2420
# 迭代 41000/300000, 损失 = 0.0576, rank_scale = 17.6940
# 迭代 42000/300000, 损失 = 0.0575, rank_scale = 18.1461
# 迭代 43000/300000, 损失 = 0.0574, rank_scale = 18.5981
# 迭代 44000/300000, 损失 = 0.0572, rank_scale = 19.0501
# 迭代 45000/300000, 损失 = 0.0571, rank_scale = 19.5022
# 迭代 46000/300000, 损失 = 0.0570, rank_scale = 19.9542
# 迭代 47000/300000, 损失 = 0.0569, rank_scale = 20.4055
# 迭代 48000/300000, 损失 = 0.0568, rank_scale = 20.8556
# 迭代 49000/300000, 损失 = 0.0567, rank_scale = 21.3058
# 迭代 50000/300000, 损失 = 0.0566, rank_scale = 21.7559
# 迭代 51000/300000, 损失 = 0.0565, rank_scale = 22.2061
# 迭代 52000/300000, 损失 = 0.0564, rank_scale = 22.6562
# 迭代 53000/300000, 损失 = 0.0563, rank_scale = 23.1049
# 迭代 54000/300000, 损失 = 0.0563, rank_scale = 23.5531
# 迭代 55000/300000, 损失 = 0.0562, rank_scale = 24.0013
# 迭代 56000/300000, 损失 = 0.0561, rank_scale = 24.4496
# 迭代 57000/300000, 损失 = 0.0560, rank_scale = 24.8965
# 迭代 58000/300000, 损失 = 0.0559, rank_scale = 25.3429
# 迭代 59000/300000, 损失 = 0.0559, rank_scale = 25.7892
# 迭代 60000/300000, 损失 = 0.0558, rank_scale = 26.2353
# 迭代 61000/300000, 损失 = 0.0557, rank_scale = 26.6797
# 迭代 62000/300000, 损失 = 0.0556, rank_scale = 27.1242
# 迭代 63000/300000, 损失 = 0.0556, rank_scale = 27.5683
# 迭代 64000/300000, 损失 = 0.0555, rank_scale = 28.0108
# 迭代 65000/300000, 损失 = 0.0554, rank_scale = 28.4533
# 迭代 66000/300000, 损失 = 0.0554, rank_scale = 28.8948
# 迭代 67000/300000, 损失 = 0.0553, rank_scale = 29.3354
# 迭代 68000/300000, 损失 = 0.0553, rank_scale = 29.7758
# 迭代 69000/300000, 损失 = 0.0552, rank_scale = 30.2145
# 迭代 70000/300000, 损失 = 0.0551, rank_scale = 30.6532
# 迭代 71000/300000, 损失 = 0.0551, rank_scale = 31.0902
# 迭代 72000/300000, 损失 = 0.0550, rank_scale = 31.5270
# 迭代 73000/300000, 损失 = 0.0550, rank_scale = 31.9624
# 迭代 74000/300000, 损失 = 0.0549, rank_scale = 32.3972
# 迭代 75000/300000, 损失 = 0.0548, rank_scale = 32.8321
# 迭代 76000/300000, 损失 = 0.0548, rank_scale = 33.2638
# 迭代 77000/300000, 损失 = 0.0547, rank_scale = 33.6948
# 迭代 78000/300000, 损失 = 0.0547, rank_scale = 34.1259
# 迭代 79000/300000, 损失 = 0.0546, rank_scale = 34.5562
# 迭代 80000/300000, 损失 = 0.0546, rank_scale = 34.9834
# 迭代 81000/300000, 损失 = 0.0545, rank_scale = 35.4106
# 迭代 82000/300000, 损失 = 0.0545, rank_scale = 35.8379
# 迭代 83000/300000, 损失 = 0.0545, rank_scale = 36.2620
# 迭代 84000/300000, 损失 = 0.0544, rank_scale = 36.6854
# 迭代 85000/300000, 损失 = 0.0544, rank_scale = 37.1088
# 迭代 86000/300000, 损失 = 0.0543, rank_scale = 37.5298
# 迭代 87000/300000, 损失 = 0.0543, rank_scale = 37.9494
# 迭代 88000/300000, 损失 = 0.0542, rank_scale = 38.3690
# 迭代 89000/300000, 损失 = 0.0542, rank_scale = 38.7863
# 迭代 90000/300000, 损失 = 0.0542, rank_scale = 39.2021
# 迭代 91000/300000, 损失 = 0.0541, rank_scale = 39.6179
# 迭代 92000/300000, 损失 = 0.0541, rank_scale = 40.0311
# 迭代 93000/300000, 损失 = 0.0540, rank_scale = 40.4430
# 迭代 94000/300000, 损失 = 0.0540, rank_scale = 40.8550
# 迭代 95000/300000, 损失 = 0.0540, rank_scale = 41.2636
# 迭代 96000/300000, 损失 = 0.0539, rank_scale = 41.6717
# 迭代 97000/300000, 损失 = 0.0539, rank_scale = 42.0792
# 迭代 98000/300000, 损失 = 0.0539, rank_scale = 42.4836
# 迭代 99000/300000, 损失 = 0.0538, rank_scale = 42.8879
# 迭代 100000/300000, 损失 = 0.0538, rank_scale = 43.2903
# 迭代 101000/300000, 损失 = 0.0538, rank_scale = 43.6909
# 迭代 102000/300000, 损失 = 0.0537, rank_scale = 44.0914
# 迭代 103000/300000, 损失 = 0.0537, rank_scale = 44.4884
# 迭代 104000/300000, 损失 = 0.0537, rank_scale = 44.8851
# 迭代 105000/300000, 损失 = 0.0536, rank_scale = 45.2803
# 迭代 106000/300000, 损失 = 0.0536, rank_scale = 45.6732
# 迭代 107000/300000, 损失 = 0.0536, rank_scale = 46.0661
# 迭代 108000/300000, 损失 = 0.0535, rank_scale = 46.4556
# 迭代 109000/300000, 损失 = 0.0535, rank_scale = 46.8447
# 迭代 110000/300000, 损失 = 0.0535, rank_scale = 47.2321
# 迭代 111000/300000, 损失 = 0.0534, rank_scale = 47.6173
# 迭代 112000/300000, 损失 = 0.0534, rank_scale = 48.0025
# 迭代 113000/300000, 损失 = 0.0534, rank_scale = 48.3840
# 迭代 114000/300000, 损失 = 0.0534, rank_scale = 48.7654
# 迭代 115000/300000, 损失 = 0.0533, rank_scale = 49.1445
# 迭代 116000/300000, 损失 = 0.0533, rank_scale = 49.5222
# 迭代 117000/300000, 损失 = 0.0533, rank_scale = 49.8989
# 迭代 118000/300000, 损失 = 0.0532, rank_scale = 50.2727
# 迭代 119000/300000, 损失 = 0.0532, rank_scale = 50.6465
# 迭代 120000/300000, 损失 = 0.0532, rank_scale = 51.0169
# 迭代 121000/300000, 损失 = 0.0532, rank_scale = 51.3870
# 迭代 122000/300000, 损失 = 0.0531, rank_scale = 51.7548
# 迭代 123000/300000, 损失 = 0.0531, rank_scale = 52.1210
# 迭代 124000/300000, 损失 = 0.0531, rank_scale = 52.4861
# 迭代 125000/300000, 损失 = 0.0531, rank_scale = 52.8485
# 迭代 126000/300000, 损失 = 0.0531, rank_scale = 53.2109
# 迭代 127000/300000, 损失 = 0.0530, rank_scale = 53.5697
# 迭代 128000/300000, 损失 = 0.0530, rank_scale = 53.9283
# 迭代 129000/300000, 损失 = 0.0530, rank_scale = 54.2843
# 迭代 130000/300000, 损失 = 0.0530, rank_scale = 54.6391
# 迭代 131000/300000, 损失 = 0.0529, rank_scale = 54.9924
# 迭代 132000/300000, 损失 = 0.0529, rank_scale = 55.3433
# 迭代 133000/300000, 损失 = 0.0529, rank_scale = 55.6940
# 迭代 134000/300000, 损失 = 0.0529, rank_scale = 56.0411
# 迭代 135000/300000, 损失 = 0.0529, rank_scale = 56.3883
# 迭代 136000/300000, 损失 = 0.0528, rank_scale = 56.7324
# 迭代 137000/300000, 损失 = 0.0528, rank_scale = 57.0757
# 迭代 138000/300000, 损失 = 0.0528, rank_scale = 57.4172
# 迭代 139000/300000, 损失 = 0.0528, rank_scale = 57.7567
# 迭代 140000/300000, 损失 = 0.0528, rank_scale = 58.0955
# 迭代 141000/300000, 损失 = 0.0527, rank_scale = 58.4312
# 迭代 142000/300000, 损失 = 0.0527, rank_scale = 58.7668
# 迭代 143000/300000, 损失 = 0.0527, rank_scale = 59.0991
# 迭代 144000/300000, 损失 = 0.0527, rank_scale = 59.4310
# 迭代 145000/300000, 损失 = 0.0527, rank_scale = 59.7607
# 迭代 146000/300000, 损失 = 0.0526, rank_scale = 60.0887
# 迭代 147000/300000, 损失 = 0.0526, rank_scale = 60.4158
# 迭代 148000/300000, 损失 = 0.0526, rank_scale = 60.7400
# 迭代 149000/300000, 损失 = 0.0526, rank_scale = 61.0643
# 迭代 150000/300000, 损失 = 0.0526, rank_scale = 61.3849
# 迭代 151000/300000, 损失 = 0.0526, rank_scale = 61.7053
# 迭代 152000/300000, 损失 = 0.0525, rank_scale = 62.0234
# 迭代 153000/300000, 损失 = 0.0525, rank_scale = 62.3401
# 迭代 154000/300000, 损失 = 0.0525, rank_scale = 62.6557
# 迭代 155000/300000, 损失 = 0.0525, rank_scale = 62.9685
# 迭代 156000/300000, 损失 = 0.0525, rank_scale = 63.2813
# ...
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 liga-nos 图 -> /Users/peixuanma/Downloads/Output_Graphs/liga-nos_evolution.png
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 serie-b 图 -> /Users/peixuanma/Downloads/Output_Graphs/serie-b_evolution.png
# 保存 2-bundesliga 图 -> /Users/peixuanma/Downloads/Output_Graphs/2-bundesliga_evolution.png
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 premiership 图 -> /Users/peixuanma/Downloads/Output_Graphs/premiership_evolution.png
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:394: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 23432 (\N{CJK UNIFIED IDEOGRAPH-5B88}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 38431 (\N{CJK UNIFIED IDEOGRAPH-961F}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 28436 (\N{CJK UNIFIED IDEOGRAPH-6F14}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_21326/3242261356.py:396: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=150)
# 保存 pro-league 图 -> /Users/peixuanma/Downloads/Output_Graphs/pro-league_evolution.png
#
# 完成！

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, train_test_split, GridSearchCV
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix
from scipy.stats import uniform
import sklearn

print(f"scikit-learn 版本: {sklearn.__version__}")

# ====================== 攻防ELO评分模块 (无修改) ======================
class OffensiveDefensiveELO:
    def __init__(self, teams, initial_elo=1500, k_factor=30):
        self.ratings = {team: {'off': initial_elo, 'def': initial_elo} for team in teams}
        self.k = k_factor
        self.initial_elo = initial_elo
    def get_rating(self, team):
        return self.ratings.get(team, {'off': self.initial_elo, 'def': self.initial_elo})
    def update_ratings(self, home_team, away_team, home_xg, away_xg):
        home_ratings, away_ratings = self.get_rating(home_team), self.get_rating(away_team)
        home_off_elo, home_def_elo = home_ratings['off'], home_ratings['def']
        away_off_elo, away_def_elo = away_ratings['off'], away_ratings['def']
        exp_home_off_vs_away_def = 1 / (1 + 10**((away_def_elo - home_off_elo) / 400))
        exp_away_off_vs_home_def = 1 / (1 + 10**((home_def_elo - away_off_elo) / 400))
        total_xg = home_xg + away_xg
        if total_xg == 0: return
        expected_xg_home = total_xg * (exp_home_off_vs_away_def / (exp_home_off_vs_away_def + exp_away_off_vs_home_def))
        expected_xg_away = total_xg * (exp_away_off_vs_home_def / (exp_home_off_vs_away_def + exp_away_off_vs_home_def))
        home_offense_performance = self.k * (home_xg - expected_xg_home)
        away_offense_performance = self.k * (away_xg - expected_xg_away)
        self.ratings[home_team]['off'] += home_offense_performance
        self.ratings[away_team]['def'] -= home_offense_performance
        self.ratings[away_team]['off'] += away_offense_performance
        self.ratings[home_team]['def'] -= away_offense_performance

def calculate_elo_history(match_df, all_teams):
    if 'timestamp' not in match_df.columns: raise ValueError("DataFrame必须包含 'timestamp' 列用于排序")
    if 'home_xg' not in match_df.columns or 'away_xg' not in match_df.columns:
        print("警告: xG数据列缺失，将使用0.5作为默认值"); match_df['home_xg'], match_df['away_xg'] = 0.5, 0.5
    match_df['home_xg'] = pd.to_numeric(match_df['home_xg'], errors='coerce').fillna(0.5)
    match_df['away_xg'] = pd.to_numeric(match_df['away_xg'], errors='coerce').fillna(0.5)
    df_sorted = match_df.sort_values(by='timestamp').reset_index(drop=True)
    elo_system = OffensiveDefensiveELO(teams=all_teams)
    elo_history = []
    for index, row in df_sorted.iterrows():
        home_team, away_team = row['home_team_name'], row['away_team_name']
        home_ratings, away_ratings = elo_system.get_rating(home_team), elo_system.get_rating(away_team)
        elo_history.append({'match_id': index, 'home_team_name': home_team, 'away_team_name': away_team, 'home_off_elo_before': home_ratings['off'], 'home_def_elo_before': home_ratings['def'], 'away_off_elo_before': away_ratings['off'], 'away_def_elo_before': away_ratings['def']})
        elo_system.update_ratings(home_team, away_team, row['home_xg'], row['away_xg'])
    return pd.DataFrame(elo_history), elo_system.ratings

# ====================== 其他函数 (无修改) ======================
def compute_defensive_stats(match_df, team_positions_df):
    epsilon = 1e-8; team_stats = {}
    for team in team_positions_df['team_name'].unique(): team_stats[team] = {'total_goals_conceded': 0, 'ratio1_list': [], 'ratio2_list': [], 'ratio3_list': [], 'ratio4_list': [], 'ratio5_list': [], 'ratio6_list': [], 'num_matches': 0}
    for idx, row in match_df.iterrows():
        home_team, away_team = row['home_team_name'], row['away_team_name']
        if home_team not in team_stats or away_team not in team_stats: continue
        if row.get('Pre-Match PPG (Away)', 0) > 0: team_stats[home_team]['ratio1_list'].append(row['away_team_goal_count'] / (row['Pre-Match PPG (Away)'] + epsilon))
        if row.get('away_team_corner_count', 0) > 0: team_stats[home_team]['ratio2_list'].append(row['away_team_goal_count'] / (row['away_team_corner_count'] + epsilon))
        denominator = row.get('home_team_yellow_cards', 0) + row.get('home_team_red_cards', 0) + row.get('home_team_fouls', 0) + epsilon
        team_stats[home_team]['ratio3_list'].append(row.get('away_team_goal_count', 0) / denominator)
        away_xg = row.get('away_xg', 0)
        if away_xg > 0: team_stats[home_team]['ratio4_list'].append(row['away_team_goal_count'] / (away_xg + epsilon))
        shots_total = row.get('away_team_shots_on_target', 0) + row.get('away_team_shots_off_target', 0) + epsilon
        team_stats[home_team]['ratio5_list'].append(row.get('away_team_goal_count', 0) / shots_total)
        if row.get('away_team_possession', 0) > 0: team_stats[home_team]['ratio6_list'].append(row.get('away_team_goal_count', 0) / (row['away_team_possession'] + epsilon))
        team_stats[home_team]['total_goals_conceded'] += row.get('away_team_goal_count', 0)
        team_stats[home_team]['num_matches'] += 1
    for idx, row in match_df.iterrows():
        away_team = row['away_team_name']
        if away_team not in team_stats: continue
        team_stats[away_team]['total_goals_conceded'] += row.get('home_team_goal_count', 0)
        team_stats[away_team]['num_matches'] += 1
    data = []
    for team, stats in team_stats.items():
        num_matches = stats['num_matches']
        average_goals_conceded = stats['total_goals_conceded'] / num_matches if num_matches > 0 else 0
        data.append({'team_name': team, 'ratio1': np.mean(stats['ratio1_list']) if stats['ratio1_list'] else 0, 'ratio2': np.mean(stats['ratio2_list']) if stats['ratio2_list'] else 0,'ratio3': np.mean(stats['ratio3_list']) if stats['ratio3_list'] else 0,'ratio4': np.mean(stats['ratio4_list']) if stats['ratio4_list'] else 0,'ratio5': np.mean(stats['ratio5_list']) if stats['ratio5_list'] else 0,'ratio6': np.mean(stats['ratio6_list']) if stats['ratio6_list'] else 0,'total_goals_conceded': stats['total_goals_conceded'],'average_goals_conceded': average_goals_conceded})
    return pd.DataFrame(data)

def compute_home_away_diff(match_df, team_positions_df, final_elos):
    epsilon = 1e-8; home_away_diff = {}; avg_elos = {team: (ratings['off'] + ratings['def']) / 2 for team, ratings in final_elos.items()}
    for team in team_positions_df['team_name'].unique():
        for season in match_df['season'].unique():
            team_matches = match_df[((match_df['home_team_name'] == team) | (match_df['away_team_name'] == team)) & (match_df['season'] == season)]
            if team_matches.empty: continue
            opponents = set(team_matches['home_team_name'].unique()) | set(team_matches['away_team_name'].unique());
            if team in opponents: opponents.remove(team)
            diff_ratios, weights = [], []
            for opponent in opponents:
                home_match, away_match = team_matches[(team_matches['home_team_name'] == team) & (team_matches['away_team_name'] == opponent)], team_matches[(team_matches['away_team_name'] == team) & (team_matches['home_team_name'] == opponent)]
                if not home_match.empty and not away_match.empty:
                    home_xg, away_xg = home_match.get('home_xg', pd.Series([0])).values[0], away_match.get('away_xg', pd.Series([0])).values[0]
                    home_conceded_xg, away_conceded_xg = home_match.get('away_xg', pd.Series([0])).values[0], away_match.get('home_xg', pd.Series([0])).values[0]
                    diff_ratios.append(((home_xg / (away_xg + epsilon)) + (home_conceded_xg / (away_conceded_xg + epsilon))) / 2)
                    weights.append(avg_elos.get(opponent, 1500))
            if diff_ratios: home_away_diff[f"{team}_{season}"] = np.average(diff_ratios, weights=weights)
            else: home_away_diff[f"{team}_{season}"] = 1.0
    return home_away_diff

def load_all_league_data(base_path, leagues, seasons):
    all_team_positions, all_match_positions = [], []
    for country_name, league_name in leagues:
        for season in seasons:
            team_file, match_file = os.path.join(base_path, f"{country_name}-{league_name}-teams-{season}-stats.csv"), os.path.join(base_path, f"{country_name}-{league_name}-matches-{season}-stats.csv")
            if not os.path.exists(team_file) or not os.path.exists(match_file): continue
            team_df, match_df = pd.read_csv(team_file), pd.read_csv(match_file)
            team_df['team_name'] = team_df.get('common_name', team_df.get('team_name', None)).str.strip().str.lower()
            match_df['home_team_name'], match_df['away_team_name'] = match_df['home_team_name'].str.strip().str.lower(), match_df['away_team_name'].str.strip().str.lower()
            team_names = team_df['team_name'].unique()
            match_df = match_df[match_df['home_team_name'].isin(team_names) & match_df['away_team_name'].isin(team_names)]
            if match_df.empty: continue
            match_df['league'], match_df['season'], team_df['league'], team_df['season'] = league_name, season, league_name, season
            team_df = team_df.merge(compute_defensive_stats(match_df, team_df), on='team_name', how='left')
            all_team_positions.append(team_df); all_match_positions.append(match_df)
    combined_teams = pd.concat(all_team_positions, ignore_index=True).drop_duplicates(subset=['team_name', 'season'])
    combined_matches = pd.concat(all_match_positions, ignore_index=True)
    return combined_teams, combined_matches

# ====================== 核心修改：Adaboost优化权重 ======================
def compute_adaboost_weights(team_positions_df):
    """使用Adaboost计算防守比率的最佳权重"""
    # 确保有足够的数据用于拆分和交叉验证
    if len(team_positions_df) < 10:
        print("警告: 数据量过小，无法进行Adaboost权重计算。返回默认权重。")
        return np.ones(6, dtype=np.float32) / 6

    ratios = team_positions_df[['ratio1', 'ratio2', 'ratio3', 'ratio4', 'ratio5', 'ratio6']].replace([np.inf, -np.inf], np.nan).fillna(0)
    scaler = StandardScaler()
    ratios_scaled = scaler.fit_transform(ratios)
    
    # 确保标签列有足够的变化
    if team_positions_df['average_goals_conceded'].nunique() < 2:
        print("警告: 目标变量 'average_goals_conceded' 缺乏变化，无法进行分类。返回默认权重。")
        return np.ones(6, dtype=np.float32) / 6
        
    labels = pd.qcut(team_positions_df['average_goals_conceded'], q=2, labels=[0, 1], duplicates='drop').fillna(0).astype(int)
    
    X_train, X_test, y_train, y_test = train_test_split(ratios_scaled, labels, test_size=0.2, random_state=42, stratify=labels)

    # <--- MODIFICATION START --->
    # 动态计算交叉验证折数(cv)，以避免ValueError
    min_class_count = y_train.value_counts().min()
    # cv值不能大于任何类别的样本数，且最小为2
    cv_value = min(5, min_class_count)
    if cv_value < 2:
        print(f"警告: 训练集中最小类别样本数({min_class_count})过少，无法进行交叉验证。返回默认权重。")
        return np.ones(6, dtype=np.float32) / 6
    # <--- MODIFICATION END --->

    ada = AdaBoostClassifier(algorithm='SAMME', random_state=42)
    param_grid = {'estimator': [DecisionTreeClassifier(max_depth=5), DecisionTreeClassifier(max_depth=10)],'n_estimators': [50, 100, 200, 500],'learning_rate': [0.01, 0.1, 0.5]}
    
    # <--- MODIFICATION START --->
    # 使用动态cv_value，并将n_jobs=1以避免潜在的protobuf错误
    grid_search = GridSearchCV(ada, param_grid, cv=cv_value, scoring='accuracy', n_jobs=1)
    # <--- MODIFICATION END --->
    
    grid_search.fit(X_train, y_train)
    best_params = grid_search.best_params_
    adaboost = AdaBoostClassifier(estimator=best_params['estimator'],n_estimators=best_params['n_estimators'],learning_rate=best_params['learning_rate'],algorithm='SAMME',random_state=42)
    adaboost.fit(X_train, y_train)
    
    feature_importances = np.zeros(6)
    if hasattr(adaboost, 'estimator_weights_'):
        for i, est in enumerate(adaboost.estimators_):
            feature_importances += adaboost.estimator_weights_[i] * est.feature_importances_
        if np.sum(adaboost.estimator_weights_) > 0:
            feature_importances /= np.sum(adaboost.estimator_weights_)

    weights = feature_importances / np.sum(feature_importances) if np.sum(feature_importances) > 0 else np.ones(6) / 6
    return weights.astype(np.float32)

# ====================== 损失函数和优化器 (无修改) ======================
def compute_total_loss(positions, match_data, points_per_game, rank_scale, ratios, w, normalized_defense_score, lambda_defense, lambda_supervision, lambda_reg):
    epsilon = 1e-8
    match_home_idx, match_away_idx = tf.cast(match_data[:, 0], dtype=tf.int32), tf.cast(match_data[:, 1], dtype=tf.int32)
    match_PC1, match_PC2 = match_data[:, 2], match_data[:, 3]
    home_off_elo, home_def_elo, away_off_elo, away_def_elo = match_data[:, 4], match_data[:, 5], match_data[:, 6], match_data[:, 7]
    home_pos, away_pos = tf.gather(positions, match_home_idx), tf.gather(positions, match_away_idx)
    match_points = tf.stack([match_PC1, match_PC2], axis=1)
    dist_home, dist_away = tf.norm(home_pos - match_points + epsilon, axis=1), tf.norm(away_pos - match_points + epsilon, axis=1)
    all_distances = tf.concat([dist_home, dist_away], axis=0)
    dist_range = tf.reduce_max(all_distances) - tf.reduce_min(all_distances) + epsilon
    dist_home_norm, dist_away_norm = (dist_home - tf.reduce_min(all_distances)) / dist_range, (dist_away - tf.reduce_min(all_distances)) / dist_range
    elo_diff = tf.abs((home_off_elo - away_def_elo) - (away_off_elo - home_def_elo))
    weight = 1.0 / (1.0 + elo_diff * rank_scale + epsilon)
    match_loss = tf.reduce_mean(weight * (dist_home_norm + dist_away_norm))
    w = tf.abs(w)
    defense_target = -tf.reduce_sum(w * ratios, axis=1)
    defense_loss = tf.reduce_mean(tf.square(positions[:, 1] - defense_target))
    supervision_loss = tf.reduce_mean(tf.square(defense_target - normalized_defense_score))
    regularization_loss = lambda_reg * tf.reduce_sum(tf.square(w))
    total_loss = match_loss + lambda_defense * defense_loss + lambda_supervision * supervision_loss + regularization_loss
    return tf.where(tf.math.is_nan(total_loss) | tf.math.is_inf(total_loss), 0.0, total_loss)

def adam_optimize_positions(team_positions_df, match_positions_with_elo_df, initial_lr=0.0005, iterations=50000, patience=100, w=None, lambda_defense=0.1, lambda_supervision=0.1, lambda_reg=0.01):
    team_seasons = team_positions_df['team_season'].unique(); team_season_to_idx = {t: i for i, t in enumerate(team_seasons)}
    team_positions_df = team_positions_df.set_index('team_season')
    init_positions = np.random.rand(len(team_seasons), 2)
    ratios = team_positions_df.loc[team_seasons].reindex(columns=['ratio1', 'ratio2', 'ratio3', 'ratio4', 'ratio5', 'ratio6']).fillna(0).values
    scaler_pos, scaler_rat = StandardScaler(), StandardScaler()
    positions_scaled, ratios_scaled = scaler_pos.fit_transform(init_positions), scaler_rat.fit_transform(ratios)
    positions, ratios_tf = tf.Variable(positions_scaled, dtype=tf.float32), tf.constant(ratios_scaled, dtype=tf.float32)
    normalized_defense_score = tf.constant(team_positions_df.loc[team_seasons, 'normalized_defense_score'].fillna(0).values, dtype=tf.float32)
    points_per_game = tf.constant(team_positions_df.loc[team_seasons, 'points_per_game'].fillna(0).values, dtype=tf.float32)
    match_array = []
    for _, row in match_positions_with_elo_df.iterrows():
        home_ts, away_ts = f"{row['league']}_{row['home_team_name']}_{row['season']}", f"{row['league']}_{row['away_team_name']}_{row['season']}"
        if home_ts in team_season_to_idx and away_ts in team_season_to_idx:
            match_array.append([team_season_to_idx[home_ts], team_season_to_idx[away_ts], row.get('PC1', 0), row.get('PC2', 0), row['home_off_elo_before'], row['home_def_elo_before'], row['away_off_elo_before'], row['away_def_elo_before']])
    if not match_array: print("警告: 无有效比赛数据用于优化"); return [], team_positions_df.reset_index(), None, None
    match_data_tf = tf.constant(np.array(match_array, dtype=np.float32))
    rank_scale, w_tf = tf.Variable(1.0, dtype=tf.float32), tf.Variable(np.abs(w) if w is not None else np.ones(6, dtype=np.float32) / 6, dtype=tf.float32)
    optimizer = tf.keras.optimizers.Adam(learning_rate=initial_lr)
    losses, best_loss, patience_counter, best_positions = [], float('inf'), 0, positions.numpy().copy()
    for i in range(iterations):
        with tf.GradientTape() as tape:
            loss = compute_total_loss(positions, match_data_tf, points_per_game, rank_scale, ratios_tf, w_tf, normalized_defense_score, lambda_defense, lambda_supervision, lambda_reg)
        grads = tape.gradient(loss, [positions, rank_scale, w_tf])
        if grads[0] is None: continue
        optimizer.apply_gradients(zip(grads, [positions, rank_scale, w_tf]))
        loss_val = float(loss.numpy())
        losses.append(loss_val)
        if loss_val < best_loss: best_loss, best_positions, patience_counter = loss_val, positions.numpy().copy(), 0
        else: patience_counter += 1
        if patience_counter >= patience: print(f"早停触发，训练在第 {i + 1} 轮停止"); break
        if (i + 1) % 1000 == 0: print(f"迭代 {i + 1}/{iterations}, 损失 = {loss_val:.4f}")
    positions.assign(best_positions)
    final_pos = scaler_pos.inverse_transform(positions.numpy())
    team_positions_df['PC1'], team_positions_df['PC2'] = final_pos[:, 0], final_pos[:, 1]
    return losses, team_positions_df.reset_index(), float(rank_scale.numpy()), w_tf.numpy()

def random_search_hyperparameters(*args, **kwargs): pass
def visualize_team_evolution_by_league_static(*args, **kwargs): pass

# ====================== 主函数 (流程重构) ======================
if __name__ == "__main__":
    base_path = '/Users/peixuanma/Downloads/data1'
    leagues, seasons = [("england", "premier-league"), ("germany", "bundesliga"), ("spain", "la-liga")], ["2022-to-2023", "2023-to-2024"]

    print("===== 1. 加载所有联赛和赛季数据 =====")
    all_teams_df, all_matches_df = load_all_league_data(base_path, leagues, seasons)
    
    # 确保模拟数据和真实数据都有必要的列
    for col in ['points_per_game', 'average_goals_conceded', 'normalized_defense_score', 'ratio1', 'ratio2', 'ratio3', 'ratio4', 'ratio5', 'ratio6']:
        if col not in all_teams_df.columns: all_teams_df[col] = np.random.rand(len(all_teams_df))
    all_teams_df['team_season'] = all_teams_df['league'].astype(str) + '_' + all_teams_df['team_name'].astype(str) + '_' + all_teams_df['season'].astype(str)

    print("===== 2. 计算全局攻防ELO历史 =====")
    all_teams_list = all_teams_df['team_name'].unique()
    elo_history_df, final_elos = calculate_elo_history(all_matches_df, all_teams_list)
    all_matches_df_sorted = all_matches_df.sort_values(by='timestamp').reset_index(drop=True).reset_index().rename(columns={'index': 'match_id'})
    matches_with_elo_df = pd.merge(all_matches_df_sorted, elo_history_df, on=['match_id', 'home_team_name', 'away_team_name'], how='left')
    print("ELO历史已合并到比赛数据中。")
    
    print("===== 3. 计算其他特征 (Adaboost, 主客场差异等) =====")
    adaboost_weights = compute_adaboost_weights(all_teams_df)
    
    print("\n===== 4. 最终训练 =====")
    best_params = {'lambda_defense': 0.1, 'lambda_supervision': 0.1, 'lambda_reg': 0.01}
    final_losses, final_team_positions, final_rank_scale, final_w = adam_optimize_positions(all_teams_df.copy(), matches_with_elo_df.copy(), w=adaboost_weights, **best_params)

    if final_losses:
        final_team_positions.to_csv("trained_team_positions_with_od_elo.csv", index=False)
        print(f"\n训练完成！最终损失: {final_losses[-1]:.4f}")
        print("最终位置数据已保存到 'trained_team_positions_with_od_elo.csv'")
    else:
        print("\n训练失败或没有有效数据。")

    print("\n完成！")
# Out:
# scikit-learn 版本: 1.4.2
# ===== 1. 加载所有联赛和赛季数据 =====
# ===== 2. 计算全局攻防ELO历史 =====
# 警告: xG数据列缺失，将使用0.5作为默认值
# ELO历史已合并到比赛数据中。
# ===== 3. 计算其他特征 (Adaboost, 主客场差异等) =====
#
# ===== 4. 最终训练 =====
# 迭代 1000/50000, 损失 = 0.4824
# 迭代 2000/50000, 损失 = 0.1244
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_61198/573886000.py in ?()
#     265     adaboost_weights = compute_adaboost_weights(all_teams_df)
#     266
#     267     print("\n===== 4. 最终训练 =====")
#     268     best_params = {'lambda_defense': 0.1, 'lambda_supervision': 0.1, 'lambda_reg': 0.01}
# --> 269     final_losses, final_team_positions, final_rank_scale, final_w = adam_optimize_positions(all_teams_df.copy(), matches_with_elo_df.copy(), w=adaboost_weights, **best_params)
#     270
#     271     if final_losses:
#     272         final_team_positions.to_csv("trained_team_positions_with_od_elo.csv", index=False)
#
# /var/folders/m9/4339fc7572b6ls3dzsvjfg000000gn/T/ipykernel_61198/573886000.py in ?(team_positions_df, match_positions_with_elo_df, initial_lr, iterations, patience, w, lambda_defense, lambda_supervision, lambda_reg)
#     223     losses, best_loss, patience_counter, best_positions = [], float('inf'), 0, positions.numpy().copy()
#     224     for i in range(iterations):
#     225         with tf.GradientTape() as tape:
#     226             loss = compute_total_loss(positions, match_data_tf, points_per_game, rank_scale, ratios_tf, w_tf, normalized_defense_score, lambda_defense, lambda_supervision, lambda_reg)
# --> 227         grads = tape.gradient(loss, [positions, rank_scale, w_tf])
#     228         if grads[0] is None: continue
#     229         optimizer.apply_gradients(zip(grads, [positions, rank_scale, w_tf]))
#     230         loss_val = float(loss.numpy())
#
# /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/eager/backprop.py in ?(self, target, sources, output_gradients, unconnected_gradients)
#    1062               output_gradients))
#    1063       output_gradients = [None if x is None else ops.convert_to_tensor(x)
#    1064                           for x in output_gradients]
#    1065
# -> 1066     flat_grad = imperative_grad.imperative_grad(
#    1067         self._tape,
#    1068         flat_targets,
#    1069         flat_sources,
#
# /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/eager/imperative_grad.py in ?(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      63   except ValueError:
#      64     raise ValueError(
#      65         "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
#      66
# ---> 67   return pywrap_tfe.TFE_Py_TapeGradient(
#      68       tape._tape,  # pylint: disable=protected-access
#      69       target,
#      70       sources,
#
# /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/eager/backprop.py in ?(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     144     gradient_name_scope = "gradient_tape/"
#     145     if forward_pass_name_scope:
#     146       gradient_name_scope += forward_pass_name_scope + "/"
#     147     with ops.name_scope(gradient_name_scope):
# --> 148       return grad_fn(mock_op, *out_grads)
#     149   else:
#     150     return grad_fn(mock_op, *out_grads)
#
# /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/ops/array_grad.py in ?(op, grad)
#     856 @ops.RegisterGradient("Squeeze")
#     857 def _SqueezeGrad(op: ops.Operation, grad):
# --> 858   return _ReshapeToInput(op, grad)
#
# /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/ops/array_grad.py in ?(op, grad)
#     845 def _ReshapeToInput(op: ops.Operation, grad):
#     846   """Reshapes the gradient to the shape of the original input."""
# --> 847   return array_ops.reshape(
#     848       _IndexedSlicesToTensorNoWarning(grad), array_ops.shape(op.inputs[0]))
#
# /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/ops/weak_tensor_ops.py in ?(*args, **kwargs)
#      86   def wrapper(*args, **kwargs):
#      87     if not ops.is_auto_dtype_conversion_enabled():
# ---> 88       return op(*args, **kwargs)
#      89     bound_arguments = signature.bind(*args, **kwargs)
#      90     bound_arguments.apply_defaults()
#      91     bound_kwargs = bound_arguments.arguments
#
# /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/ops/array_ops.py in ?(tensor, shape, name)
#     195
#     196   Returns:
#     197     A `Tensor`. Has the same type as `tensor`.
#     198   """
# --> 199   result = gen_array_ops.reshape(tensor, shape, name)
#     200   shape_util.maybe_set_static_shape(result, shape)
#     201   return result
#
# /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/ops/gen_array_ops.py in ?(tensor, shape, name)
#    8788         _ctx, "Reshape", name, tensor, shape)
#    8789       return _result
#    8790     except _core._NotOkStatusException as e:
#    8791       _ops.raise_from_not_ok_status(e, name)
# -> 8792     except _core._FallbackException:
#    8793       pass
#    8794     try:
#    8795       return reshape_eager_fallback(
#
# KeyboardInterrupt:
