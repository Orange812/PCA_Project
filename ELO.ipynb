# %%
import os
import pandas as pd
import numpy as np

# ====================== ELO评分算法实现 ======================
def initialize_elo_scores(team_positions_df):
    """初始化球队ELO分数"""
    teams = team_positions_df['team_name'].unique().tolist()
    team_elo = {team: 1500 for team in teams}
    for team in teams:
        team_data = team_positions_df[team_positions_df['team_name'] == team]
        rank = team_data['points_per_game'].rank().iloc[0]
        team_elo[team] += (20 * (len(teams) - rank))
    return team_elo

def update_elo_scores(elo_scores, home_team, away_team, home_score, away_score, K=30):
    """更新ELO分数"""
    home_elo, away_elo = elo_scores[home_team], elo_scores[away_team]
    expected_home = 1 / (1 + 10 ** ((away_elo - home_elo) / 400))
    expected_away = 1 / (1 + 10 ** ((home_elo - away_elo) / 400))

    if home_score > away_score:
        elo_scores[home_team] += K * (1 - expected_home)
        elo_scores[away_team] += K * (0 - expected_away)
    elif home_score < away_score:
        elo_scores[home_team] += K * (0 - expected_home)
        elo_scores[away_team] += K * (1 - expected_away)
    else:
        elo_scores[home_team] += K * (0.5 - expected_home)
        elo_scores[away_team] += K * (0.5 - expected_away)
    return elo_scores

# ====================== 数据加载并计算ELO ======================
def load_all_league_data(base_path, leagues, seasons):
    """加载所有联赛数据，计算ELO并输出最高和最低值"""
    for country_name, league_name in leagues:
        for season in seasons:
            print(f"加载数据: {country_name} - {league_name} - {season}")
            team_file = os.path.join(base_path, f"{country_name}-{league_name}-teams-{season}-stats.csv")
            match_file = os.path.join(base_path, f"{country_name}-{league_name}-matches-{season}-stats.csv")
            if not os.path.exists(team_file) or not os.path.exists(match_file):
                print(f"警告: {country_name} - {league_name} - {season} 文件缺失")
                continue

            team_df = pd.read_csv(team_file)
            match_df = pd.read_csv(match_file)

            # 统一球队名称格式
            team_df['team_name'] = team_df.get('common_name', team_df.get('team_name', None)).str.strip().str.lower()
            match_df['home_team_name'] = match_df['home_team_name'].str.strip().str.lower()
            match_df['away_team_name'] = match_df['away_team_name'].str.strip().str.lower()

            team_names = team_df['team_name'].unique()
            original_match_count = len(match_df)
            match_df = match_df[
                match_df['home_team_name'].isin(team_names) & match_df['away_team_name'].isin(team_names)]
            if len(match_df) < original_match_count:
                print(f"警告: 过滤了 {original_match_count - len(match_df)} 场比赛")

            if match_df.empty:
                print("警告: 无有效比赛数据")
                continue

            # 初始化ELO分数
            elo_scores = initialize_elo_scores(team_df)

            # 更新ELO分数
            for _, row in match_df.iterrows():
                home_team = row['home_team_name']
                away_team = row['away_team_name']
                home_score = row['home_team_goal_count']
                away_score = row['away_team_goal_count']
                elo_scores = update_elo_scores(elo_scores, home_team, away_team, home_score, away_score)

            # 找到ELO最高和最低的球队
            max_elo_team = max(elo_scores, key=elo_scores.get)
            min_elo_team = min(elo_scores, key=elo_scores.get)
            print(f"{league_name} - {season}: 最高ELO: {max_elo_team} ({elo_scores[max_elo_team]:.2f}), "
                  f"最低ELO: {min_elo_team} ({elo_scores[min_elo_team]:.2f})")

# ====================== 主函数 ======================
if __name__ == "__main__":
    base_path = '/Users/peixuanma/Downloads/data1'
    leagues = [
        ("england", "premier-league"), ("germany", "bundesliga"), ("spain", "la-liga"),
        ("france", "ligue-1"), ("italy", "serie-a"), ("netherlands", "eredivisie"),
        ("portugal", "ligapro"), ("denmark", "superliga"), ("england", "championship"),
        ("portugal", "liga-nos"), ("italy", "serie-b"), ("germany", "2-bundesliga")
    ]
    seasons = [
        "2013-to-2014", "2014-to-2015", "2015-to-2016", "2016-to-2017", "2017-to-2018",
        "2018-to-2019", "2020-to-2021", "2021-to-2022", "2022-to-2023", "2023-to-2024"
    ]

    # 加载数据并计算ELO
    load_all_league_data(base_path, leagues, seasons)
# Out:
# 加载数据: england - premier-league - 2013-to-2014
# premier-league - 2013-to-2014: 最高ELO: manchester city (2060.30), 最低ELO: cardiff city (1746.34)
# 加载数据: england - premier-league - 2014-to-2015
# premier-league - 2014-to-2015: 最高ELO: chelsea (2049.61), 最低ELO: queens park rangers (1754.03)
# 加载数据: england - premier-league - 2015-to-2016
# premier-league - 2015-to-2016: 最高ELO: leicester city (2037.13), 最低ELO: aston villa (1686.95)
# 加载数据: england - premier-league - 2016-to-2017
# premier-league - 2016-to-2017: 最高ELO: chelsea (2076.84), 最低ELO: sunderland (1718.84)
# 加载数据: england - premier-league - 2017-to-2018
# premier-league - 2017-to-2018: 最高ELO: manchester city (2103.06), 最低ELO: swansea city (1774.37)
# 加载数据: england - premier-league - 2018-to-2019
# premier-league - 2018-to-2019: 最高ELO: manchester city (2108.67), 最低ELO: huddersfield town (1677.22)
# 加载数据: england - premier-league - 2020-to-2021
# premier-league - 2020-to-2021: 最高ELO: manchester city (2039.39), 最低ELO: sheffield united (1738.13)
# 加载数据: england - premier-league - 2021-to-2022
# premier-league - 2021-to-2022: 最高ELO: liverpool (2096.97), 最低ELO: watford (1702.62)
# 加载数据: england - premier-league - 2022-to-2023
# premier-league - 2022-to-2023: 最高ELO: manchester city (2055.79), 最低ELO: southampton (1726.51)
# 加载数据: england - premier-league - 2023-to-2024
# premier-league - 2023-to-2024: 最高ELO: manchester city (2091.68), 最低ELO: sheffield united (1679.80)
# 加载数据: germany - bundesliga - 2013-to-2014
# bundesliga - 2013-to-2014: 最高ELO: bayern münchen (2049.46), 最低ELO: hamburger sv (1709.73)
# 加载数据: germany - bundesliga - 2014-to-2015
# bundesliga - 2014-to-2015: 最高ELO: bayern münchen (1974.61), 最低ELO: paderborn (1739.58)
# 加载数据: germany - bundesliga - 2015-to-2016
# bundesliga - 2015-to-2016: 最高ELO: bayern münchen (2045.78), 最低ELO: hannover 96 (1719.54)
# 加载数据: germany - bundesliga - 2016-to-2017
# bundesliga - 2016-to-2017: 最高ELO: bayern münchen (2026.38), 最低ELO: darmstadt 98 (1726.40)
# 加载数据: germany - bundesliga - 2017-to-2018
# bundesliga - 2017-to-2018: 最高ELO: bayern münchen (2022.45), 最低ELO: köln (1714.06)
# 加载数据: germany - bundesliga - 2018-to-2019
# bundesliga - 2018-to-2019: 最高ELO: bayern münchen (2018.63), 最低ELO: nürnberg (1682.73)
# 加载数据: germany - bundesliga - 2020-to-2021
# bundesliga - 2020-to-2021: 最高ELO: bayern münchen (2005.82), 最低ELO: schalke 04 (1667.31)
# ligue-1 - 2021-to-2022: 最高ELO: psg (2027.50), 最低ELO: bordeaux (1775.29)
# 加载数据: france - ligue-1 - 2022-to-2023
# ligue-1 - 2022-to-2023: 最高ELO: lens (2052.26), 最低ELO: angers sco (1699.27)
# 加载数据: france - ligue-1 - 2023-to-2024
# ligue-1 - 2023-to-2024: 最高ELO: psg (1996.87), 最低ELO: metz (1724.72)
# 加载数据: italy - serie-a - 2013-to-2014
# serie-a - 2013-to-2014: 最高ELO: juventus (2128.50), 最低ELO: livorno (1712.25)
# 加载数据: italy - serie-a - 2014-to-2015
# serie-a - 2014-to-2015: 最高ELO: juventus (2045.95), 最低ELO: cesena (1726.23)
# 加载数据: italy - serie-a - 2015-to-2016
# serie-a - 2015-to-2016: 最高ELO: juventus (2089.40), 最低ELO: frosinone (1759.71)
# 加载数据: italy - serie-a - 2016-to-2017
# serie-a - 2016-to-2017: 最高ELO: napoli (2077.77), 最低ELO: pescara (1690.80)
# 加载数据: italy - serie-a - 2017-to-2018
# serie-a - 2017-to-2018: 最高ELO: juventus (2090.43), 最低ELO: hellas verona (1705.27)
# 加载数据: italy - serie-a - 2018-to-2019
# serie-a - 2018-to-2019: 最高ELO: juventus (2023.30), 最低ELO: chievo (1731.96)
# 加载数据: italy - serie-a - 2020-to-2021
# serie-a - 2020-to-2021: 最高ELO: inter milan (2078.55), 最低ELO: parma (1692.58)
# 加载数据: italy - serie-a - 2021-to-2022
# serie-a - 2021-to-2022: 最高ELO: ac milan (2054.51), 最低ELO: venezia (1742.30)
# 加载数据: italy - serie-a - 2022-to-2023
# serie-a - 2022-to-2023: 最高ELO: napoli (2042.31), 最低ELO: sampdoria (1710.99)
# 加载数据: italy - serie-a - 2023-to-2024
# serie-a - 2023-to-2024: 最高ELO: inter milan (2077.87), 最低ELO: salernitana (1692.50)
# 加载数据: netherlands - eredivisie - 2013-to-2014
# eredivisie - 2013-to-2014: 最高ELO: ajax (1979.01), 最低ELO: roda jc (1722.22)
# 加载数据: netherlands - eredivisie - 2014-to-2015
# eredivisie - 2014-to-2015: 最高ELO: psv (2048.00), 最低ELO: dordrecht (1707.68)
# 加载数据: netherlands - eredivisie - 2015-to-2016
# eredivisie - 2015-to-2016: 最高ELO: psv (2046.08), 最低ELO: cambuur (1667.20)
# 加载数据: netherlands - eredivisie - 2016-to-2017
# eredivisie - 2016-to-2017: 最高ELO: ajax (2022.22), 最低ELO: go ahead eagles (1691.28)
# 加载数据: netherlands - eredivisie - 2017-to-2018
# eredivisie - 2017-to-2018: 最高ELO: psv (2018.40), 最低ELO: twente (1720.85)
# 加载数据: netherlands - eredivisie - 2018-to-2019
# eredivisie - 2018-to-2019: 最高ELO: ajax (2039.66), 最低ELO: nac breda (1705.51)
# 加载数据: netherlands - eredivisie - 2020-to-2021
# eredivisie - 2020-to-2021: 最高ELO: ajax (2068.57), 最低ELO: vvv (1679.18)
# 加载数据: netherlands - eredivisie - 2021-to-2022
# eredivisie - 2021-to-2022: 最高ELO: ajax (2029.50), 最低ELO: pec zwolle (1755.10)
# 加载数据: netherlands - eredivisie - 2022-to-2023
# eredivisie - 2022-to-2023: 最高ELO: feyenoord (2033.74), 最低ELO: groningen (1655.83)
# 加载数据: netherlands - eredivisie - 2023-to-2024
# eredivisie - 2023-to-2024: 最高ELO: psv (2059.28), 最低ELO: volendam (1679.23)
# 加载数据: portugal - ligapro - 2013-to-2014
# 警告: portugal - ligapro - 2013-to-2014 文件缺失
# 加载数据: portugal - ligapro - 2014-to-2015
# ligapro - 2014-to-2015: 最高ELO: cf união (2070.07), 最低ELO: cd trofense (1835.13)
# 加载数据: portugal - ligapro - 2015-to-2016
# ligapro - 2015-to-2016: 最高ELO: portimonense (2051.81), 最低ELO: ud oliveirense (1782.14)
# 加载数据: portugal - ligapro - 2016-to-2017
# ligapro - 2016-to-2017: 最高ELO: cd aves (2030.87), 最低ELO: sc olhanense (1786.32)
# 加载数据: portugal - ligapro - 2017-to-2018
# ligapro - 2017-to-2018: 最高ELO: cd nacional (2008.03), 最低ELO: real sc (1779.89)
# 加载数据: portugal - ligapro - 2018-to-2019
# ligapro - 2018-to-2019: 最高ELO: paços de ferreira (1968.80), 最低ELO: vitória guimarães ii (1760.97)
# 加载数据: portugal - ligapro - 2020-to-2021
# ligapro - 2020-to-2021: 最高ELO: fc vizela (1975.43), 最低ELO: ud oliveirense (1747.27)
# 加载数据: portugal - ligapro - 2021-to-2022
# ligapro - 2021-to-2022: 最高ELO: rio ave fc (1981.81), 最低ELO: associação académica de coimbra oaf (1676.81)
# 加载数据: portugal - ligapro - 2022-to-2023
# ligapro - 2022-to-2023: 最高ELO: moreirense fc (2009.17), 最低ELO: sporting covilhã (1746.21)
# 加载数据: portugal - ligapro - 2023-to-2024
# ligapro - 2023-to-2024: 最高ELO: cd nacional (1989.22), 最低ELO: cf os belenenses (1727.25)
# 加载数据: denmark - superliga - 2013-to-2014
# superliga - 2013-to-2014: 最高ELO: aab (1813.93), 最低ELO: agf (1577.30)
# 加载数据: denmark - superliga - 2014-to-2015
# superliga - 2014-to-2015: 最高ELO: københavn (1851.69), 最低ELO: silkeborg (1549.14)
# 加载数据: denmark - superliga - 2015-to-2016
# superliga - 2015-to-2016: 最高ELO: københavn (1862.62), 最低ELO: hobro (1585.99)
# 加载数据: denmark - superliga - 2016-to-2017
# superliga - 2016-to-2017: 最高ELO: københavn (1938.53), 最低ELO: aab (1668.26)
# 加载数据: denmark - superliga - 2017-to-2018
# superliga - 2017-to-2018: 最高ELO: midtjylland (1972.82), 最低ELO: lyngby (1619.97)
# 加载数据: denmark - superliga - 2018-to-2019
# superliga - 2018-to-2019: 最高ELO: københavn (1915.11), 最低ELO: horsens (1654.05)
# 加载数据: denmark - superliga - 2020-to-2021
# superliga - 2020-to-2021: 最高ELO: brøndby (1811.90), 最低ELO: lyngby (1609.02)
# 加载数据: denmark - superliga - 2021-to-2022
# superliga - 2021-to-2022: 最高ELO: københavn (1864.57), 最低ELO: sønderjyske (1611.21)
# 加载数据: denmark - superliga - 2022-to-2023
# superliga - 2022-to-2023: 最高ELO: københavn (1818.51), 最低ELO: horsens (1592.88)
# 加载数据: denmark - superliga - 2023-to-2024
# serie-b - 2013-to-2014: 最高ELO: palermo (2073.30), 最低ELO: juve stabia (1735.38)
# 加载数据: italy - serie-b - 2014-to-2015
# serie-b - 2014-to-2015: 最高ELO: carpi (2021.52), 最低ELO: varese (1812.17)
# 加载数据: italy - serie-b - 2015-to-2016
# serie-b - 2015-to-2016: 最高ELO: trapani (2053.54), 最低ELO: como (1829.62)
# 加载数据: italy - serie-b - 2016-to-2017
# serie-b - 2016-to-2017: 最高ELO: spal (2027.64), 最低ELO: vicenza (1832.44)
# 加载数据: italy - serie-b - 2017-to-2018
# serie-b - 2017-to-2018: 最高ELO: empoli (2080.18), 最低ELO: ternana (1815.52)
# 加载数据: italy - serie-b - 2018-to-2019
# serie-b - 2018-to-2019: 最高ELO: brescia (1959.62), 最低ELO: carpi (1743.93)
# 加载数据: italy - serie-b - 2020-to-2021
# serie-b - 2020-to-2021: 最高ELO: empoli (1993.27), 最低ELO: virtus entella (1718.22)
# 加载数据: italy - serie-b - 2021-to-2022
# serie-b - 2021-to-2022: 最高ELO: monza (2008.38), 最低ELO: pordenone (1703.88)
# 加载数据: italy - serie-b - 2022-to-2023
# serie-b - 2022-to-2023: 最高ELO: frosinone (2022.80), 最低ELO: benevento (1788.04)
# 加载数据: italy - serie-b - 2023-to-2024
# serie-b - 2023-to-2024: 最高ELO: como (1994.53), 最低ELO: lecco (1728.33)
# 加载数据: germany - 2-bundesliga - 2013-to-2014
# 2-bundesliga - 2013-to-2014: 最高ELO: köln (1957.48), 最低ELO: energie cottbus (1704.00)
# 加载数据: germany - 2-bundesliga - 2014-to-2015
# 2-bundesliga - 2014-to-2015: 最高ELO: ingolstadt (1927.50), 最低ELO: aalen (1780.68)
# 加载数据: germany - 2-bundesliga - 2015-to-2016
# 2-bundesliga - 2015-to-2016: 最高ELO: freiburg (1975.23), 最低ELO: fsv frankfurt (1734.15)
# 加载数据: germany - 2-bundesliga - 2016-to-2017
# 2-bundesliga - 2016-to-2017: 最高ELO: hannover 96 (1965.99), 最低ELO: karlsruher sc (1707.44)
# 加载数据: germany - 2-bundesliga - 2017-to-2018
# 2-bundesliga - 2017-to-2018: 最高ELO: fortuna düsseldorf (1911.18), 最低ELO: eintracht braunschweig (1796.76)
# 加载数据: germany - 2-bundesliga - 2018-to-2019
# 2-bundesliga - 2018-to-2019: 最高ELO: paderborn (1899.79), 最低ELO: msv duisburg (1756.47)
# 加载数据: germany - 2-bundesliga - 2020-to-2021
# 2-bundesliga - 2020-to-2021: 最高ELO: greuther fürth (1950.69), 最低ELO: osnabrück (1736.79)
# 加载数据: germany - 2-bundesliga - 2021-to-2022
# 2-bundesliga - 2021-to-2022: 最高ELO: schalke 04 (1953.69), 最低ELO: ingolstadt (1709.79)
# 加载数据: germany - 2-bundesliga - 2022-to-2023
# 2-bundesliga - 2022-to-2023: 最高ELO: heidenheim (1953.88), 最低ELO: sandhausen (1724.09)
# 加载数据: germany - 2-bundesliga - 2023-to-2024
# 2-bundesliga - 2023-to-2024: 最高ELO: holstein kiel (1959.64), 最低ELO: wehen wiesbaden (1723.46)
